# %%
from lib.BBRadar import BBRadar

# %%
emotions = ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']
predictions = [0.04045128605018059,
               0.3372649804999431,
               0.029534351934368413,
               0.33119267721970874,
               0.24915542546659708,
               0.012401290975200633]
labels = [0.04045128605018059,
          0.2372649804999431,
          0.029534351934368413,
          0.23119267721970874,
          0.24915542546659708,
          0.11240129097520063]

# %%
radar = BBRadar(emotions, predictions, labels, 'Barney')
radar.plotEmotionsRadar()
