# %%
# Import character dictionaries, useful to map a character to its data, and a fixed random seed
from Data.data_dicts import character_dict, source_dict, random_state

# Characters list
characters = ['Barney', 'Sheldon' , 'Harry' , 'Fry' , 'Vader' , 'Joey' , 'Phoebe' , 'Bender']

# %%
# Mount google drive, if in Colaboratory environment
import os
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    base_folder = '/content/drive/My Drive/unibo/NLP_project/BarneyBot'
    os.system("pip install datasets")
    os.system("pip install transformers")
    os.system("pip install rouge_score")
    os.system("pip install -U sentence-transformers")
else:
    base_folder = os.getcwd()
    
# Set cache folder for huggingface locally
os.environ["HF_DATASETS_CACHE"] = os.path.join(base_folder, "cache")

# %%
# Imports to handle loading the various tv/series datasets and the creation of the common dataset
import pandas as pd
from tqdm import tqdm
from datasets import load_dataset, DatasetDict

# %%
# Function to load the dataset for a given character
def load_df(character):
    # Define input and output folders for chosen character
    in_folder = os.path.join(base_folder, 'Data', 'Characters', character)
    if not os.path.exists(in_folder):
        os.makedirs(in_folder)
    out_folder = os.path.join(base_folder, 'Data', 'Characters', character)
    if not os.path.exists(out_folder):
        os.makedirs(out_folder)

    # Get dataset path
    dataset_path = os.path.join(base_folder, "Data", "Characters", character, character+'.csv')
    # Load HuggingFace dataset
    character_hg = load_dataset('csv', 
                                data_files=dataset_path, 
                                cache_dir=os.path.join(base_folder, "cache"))
    
    # Perform 85% train / 10% test / 5% validation with a fixed seed (same one used for the bot, of course)
    train_test_hg = character_hg['train'].train_test_split(test_size=0.15, seed=random_state)
    test_val = train_test_hg['test'].train_test_split(test_size=0.33, seed=random_state)
    
    # Store splits into a HuggingFace dataset
    character_hg = DatasetDict({
        'train': train_test_hg['train'],
        'test': test_val['train'],
        'val': test_val['test']
    })
    
    # Return dataset
    return character_hg

# %%
# Initialize list of selected lines
lines_selected_list = []

# %% [markdown]
# # Characters

# %% [markdown]
# ## Barney

# %%
# Load Barney dataset
temp = load_df(characters[0])
# Out:
# Using custom data configuration default-a6ad4235c1f657bf
# Reusing dataset csv (C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-a6ad4235c1f657bf\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-a6ad4235c1f657bf\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-42d4a60678e52392.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-a6ad4235c1f657bf\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-9f2121ab0c631844.arrow
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-a6ad4235c1f657bf\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-0c8b5f20a1ab2b69.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-a6ad4235c1f657bf\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-9a6642094a4b5bc0.arrow

# %%
# Print Barney lines for sanity check
[s for s in temp['test']]
# Out:
# [{'response': "Daddy's home.",
#   'context/0': "I know, it's two years of my life I'm never getting back. A little part of me just wants to jump the bones of the next guy I see.",
#   'context/1': "I'm just surprised you didn't dump him sooner.",
#   'context/2': 'And then Trudy filled us in.',
#   'context/3': 'Trudy. My name is Trudy.',
#   'context/4': 'Wait, this is klling me. We have to find out who that girl is.'},
#  {'response': "I don't have much time!",
#   'context/0': "Wh-Where'd you get a meatball...",
#   'context/1': 'Eat this meatball sub.',
#   'context/2': 'Yes, of course, of course... anything.',
#   'context/3': 'Thank you, Marshall.  Marshall... can I ask one final favor, my friend?',
#   'context/4': "We're not going anywhere, buddy. We're gonna stay here right till the end."},
#  {'response': "I could tell you knew something was up with me, and you're right. But I can't tell you what it is. I should tell you, but I can't! I have to. I never will! I'm going to. Let's just drop it. What's up with you?",
#   'context/0': 'Okay, what is so urgent that you called me and begged me to come over at 7:22 in the morning?',
#   'context/1': "Are you kidding? That was a great joke. It's smart, funny, beautiful, the whole package. It's everything you're afraid to let yourself want. In a joke. Bogeyman with a teleprompter. Classic.",
#   'context/2': "Barney, no offense to Robin, but that wasn't that funny.",
#   'context/3': "Bogeyman with a teleprompter. That's hilarious! Great joke, Robin, great joke.",
#   'context/4': "Okay, I officially hate my job. I'm not a reporter, I'm just someone who shows up at night and scares people. I'm the bogeyman with a teleprompter."},
#  {'response': 'A little.',
#   'context/0': 'How much?',
#   'context/1': "I need a lawyer. I'll pay you.",
#   'context/2': 'For the last time, Barney, I will not be your butler.',
#   'context/3': 'I know. I want to hire you.',
#   'context/4': "Yeah, I'm kind of real focused on the job hunt right now."},
#  {'response': "I'm being Barney, and I think tonight's going to be de... wait for it... lightful. Delightful.",
#   'context/0': "You're being super nice. It's... freaking me out. Be... gross, be inappropriate. Be Barney.",
#   'context/1': 'Like what?',
#   'context/2': 'Why are you acting like this?',
#   'context/3': "I'm not looking to problem-solve, I'm just looking to listen.",
#   'context/4': 'What?'},
#  {'response': "Thank you, Lily. Is there anything you'd like to say about my show?",
#   'context/0': "Okay! Stop! You win. Fine. Barney, I'm sorry I made you come to my show.",
#   'context/1': "And when that didn't work...",
#   'context/2': 'Feelings. Inside. Oh, no!',
#   'context/3': 'And then it just got weird.',
#   'context/4': 'I never get picked for audience participation.'},
#  {'response': 'Well, I found! There are bars country, the giddy ups, there are tons of guys in overalls. Copilot me!',
#   'context/0': 'There was never a next time. The window of Maggie never reopened.',
#   'context/1': "Well... I'll see you next time!",
#   'context/2': "So the kids, I'm left with... the neighbor because the neighbor.",
#   'context/3': 'Yeah, sure!',
#   'context/4': 'I think you have much to catch up.'},
#  {'response': 'A Guide. I guided a young, once. I made him my co-pilot. Then one day, he hired an assistant to work 3 meters from her room, which... Check it out... is not a hottie, proving he has never listened. You know how to call this type?',
#   'context/0': 'No, I guide him.',
#   'context/1': 'PJ is a guy? PJ, this is not a hottie you fck?',
#   'context/2': 'You see? It is useful.',
#   'context/3': 'If Ted says that PJ is necessary to society, then PJ will go nowhere.',
#   'context/4': 'Okay, but PJ does not help.'},
#  {'response': "Do you know why you're not over Lily yet? It's 'cause you can still picture her naked. You can't get over a woman until you can no longer picture her boobs. It's a scientific fact. The average male brain can only store a finite number of boob images, or BPEGs and your hard drive's filled to capacity with Lily's.",
#   'context/0': "Barney, I really don't think this is gonna help.",
#   'context/1': 'Gentlemen, please welcome to the stage Sunshine!',
#   'context/2': 'Mmm. Sunshine.',
#   'context/3': 'It is time for some tough love. We need to get him out of that apartment. He needs fresh air. He needs sunshine.',
#   'context/4': 'He watched a scary movie.'},
#  {'response': 'Not at all. I could run a marathon anytime I wanted to.',
#   'context/0': "You're kidding, right?",
#   'context/1': "You don't need to train for a marathon. You just run it.",
#   'context/2': 'What?',
#   'context/3': 'Training for a marathon.',
#   'context/4': 'Yeah. It sucks, all that work I put in training for the marathon was a total waste.'},
#  {'response': 'Ted, Ted.',
#   'context/0': "All right. I'll be right there. Stay where you are.",
#   'context/1': "Listen to me, Ted. I'm going to lose you any second. I'm on the fourth car of the six train heading south from Pelham Bay Park in the Bronx. Meet me at the 86th Street station in, like, half an hour?",
#   'context/2': 'Best 50 bucks I ever spent.',
#   'context/3': "Barney's legs won't work. He's riding the subway from end to end because he physically can't get off the train.",
#   'context/4': "My legs don't work. I've already ridden the subway twice end to end. I've seen where it turns around. Ted, you don't ever want to see where the subway turns around."},
#  {'response': 'Anyway, I need you guys to come out to Staten Island on Saturday and help box everything up.',
#   'context/0': "With her new hippie husband, Clint. The comfort of home is a little ruined when someone turns your old room into what I'm pretty sure is a Tantric sx temple. With all the bamboo, pot smoke and '60s music, it's like my old G.I. Joes are frozen in some weird Vietnam flashback.",
#   'context/1': 'What are you talking about? Your mother still lives in the house you grew up in.',
#   'context/2': "That sucks. I've been there, buddy.",
#   'context/3': "All right, I'll tell you! My mother is selling the house I grew up in. All of my childhood memories gone, just like that!",
#   'context/4': 'Did I ever! Deadliest Catch ever!'},
#  {'response': 'Why, am I under arrest?',
#   'context/0': 'Exit the vehicle.',
#   'context/1': 'You must have a permit to be as pretty. And this body? I imagine that something as explsive must be registered with the authorities.',
#   'context/2': 'Pardon?',
#   'context/3': 'Licensing and registration papers.',
#   'context/4': 'Driver and...'},
#  {'response': "Come on, baby. please, no. You don't understand. What have I done? This is the worst. How could you...?  You're not going anywhere. Live claritin clear. Wow, that was close. That hippie chick wouldn't leave. She was ready to squat here.",
#   'context/0': "You son of a bitch! I can't believe I let you enter my sacred temple.",
#   'context/1': 'Yes.',
#   'context/2': 'Yes?',
#   'context/3': 'What? No. Yes!',
#   'context/4': 'Oh my god! Are you married? Is this your wife?'},
#  {'response': "Your loss, her gain.  Excuse me, can I show you the roof? It's magical up there!",
#   'context/0': "I don't think so.",
#   'context/1': 'On a silver platter! Bon appetite!',
#   'context/2': 'No.',
#   'context/3': 'No.',
#   'context/4': 'Excuse me,  Anyone know a Carlos?'},
#  {'response': "Okay, let's take a look. Oh, yeah, it's a cougar all right. A prime specimen. See, you can identify a cougar by a few key characteristics. Start with the hair. The cougar keeps up with current hairstyles as a form of camouflage. The prey may not realize that he's engaged a cougar until he's already being dragged, helpless, back to her lair. Now, the blouse. The cougar displays maximum cleavage possible to captivate her prey. If you're watching them bounce, she's about to pounce. See the claws? Long and sharp, to ward off rival females... Or open alimony checks. Yeah, this one's a beaut. Okay, let the hunt begin.",
#   'context/0': "Okay, wait, wait, wait. That's professor Lewis's office there.",
#   'context/1': 'Man, that guy is a total, well...',
#   'context/2': "That's the spirit. Now, gather 'round. This isn't just about trees, Ted. This is about life. And sometimes in life, you have to get the trees just right or you're fired, hmm?",
#   'context/3': 'Styrofoam trees!',
#   'context/4': 'Styrofoam trees!'},
#  {'response': 'I know.',
#   'context/0': 'I love salmon risotto.',
#   'context/1': "San Marino! Oh, you're serious? Yikes. No. We have to try Casa A Pezzi. Best salmon risotto I have ever had.",
#   'context/2': "That's funny, I didn't even look in the mirror today. That's not anything, is it? So, I made a reservation at San Marino tonight for 8:00.",
#   'context/3': 'A real looker.',
#   'context/4': "Oh, it's wonderful to meet you, Robin. Oh, you are so pretty. Isn't she pretty, Al?"},
#  {'response': "Hi, there. We've had a lot of fun tonight, but on a more serious note, this is the time of year when we remember the importance of giving. And there's no greater gift than the gift of booty. So, this holiday season, why not bang someone in need? I'm Barney Stinson, and that's... One to grow on.",
#   'context/0': "Scherbatsky... I'm gonna crush it.",
#   'context/1': 'Ted, will you be my best man?',
#   'context/2': "Are you asking what I think you're asking?",
#   'context/3': '...I could really use someone like you. You know, in case I freak out. When I freak out. You interested?',
#   'context/4': 'Big mistake, but go on.'},
#  {'response': "Ranjit, take me to Gregor's.",
#   'context/0': 'Hello.',
#   'context/1': 'Keep it.',
#   'context/2': 'This is my cab! Aah!',
#   'context/3': 'And just like that, Becky started to eclipse Robin. I mean, literally eclipse her.',
#   'context/4': "You're still the star. I made chocolate chip cookies for everybody! Yay!"},
#  {'response': 'Folks, sorry to stop you before Marshall falls into tears, but Robin, check it out. What you need is a super video resume. Like mine. I present to you: Barneysvideocv.com. Hello. Barney Stinson, you have achieved great successes in business, sport and personal relationships, and have been an inspiration to many people.',
#   'context/0': 'Obviously, the stirrups were too far apart during his last visit to the gynecologist.',
#   'context/1': 'Thank you, Lily.',
#   'context/2': 'Come on, guys. It did not hurt while dancing.',
#   'context/3': 'Well, go ahead, feel free to me.',
#   'context/4': 'I have a technical question. Is it easier to dance when you do not have external genitalia?'},
#  {'response': 'I like beer. We should go to Germany. MDR. JP.MDR.',
#   'context/0': "Deuzio: it's far too early suggestions crazy travel.",
#   'context/1': 'You like architecture? We should get married. Ha-ha.MDR. Just kidding. So what?',
#   'context/2': 'First: he jokes with the marriage.',
#   'context/3': "And it's coming. It shows all the telltale signs.",
#   'context/4': "It's been that Ted did not like someone. He stored much... We thought him to say I love you when he contacted her."},
#  {'response': 'Stack we make love, we order a pizza face and it stays there to moan.',
#   'context/0': "And you know what happens right after a fight? Gender reconciliation. What is different... when you're in a loving and lasting relationship.",
#   'context/1': "So you're happy?",
#   'context/2': 'Can you ask me this question. We argue constantly, but you know what they say about relationships, Every moment is a battle.',
#   'context/3': "So you're happy?",
#   'context/4': "Are you kidding?! How could I not be? It's Robin!"},
#  {'response': "Well, you didn't ruin it; you made it so much worse! I can't eat. I can't sleep. I've lost ten pounds; my suits are wearing me. You know what? I'm outta here.",
#   'context/0': 'I thought I ruined it by putting a clock on it, Barney?',
#   'context/1': "Oh, God! don't slap me again! I don't want to get slapped again, and the first two times hurt so bad, I don't like it! I don't like it one bit!",
#   'context/2': "I'm sorry, what?",
#   'context/3': "Please don't slap me.",
#   'context/4': "Then why is your right cheek twitching? It's not... maybe it's because future me slaps future you so hard, it reverberates back to the present, shattering the time-slap continuum."},
#  {'response': "She'd give it up for a bad pun. I'm telling you, she's a laugh slut.",
#   'context/0': "Yeah. No, you're right. Lily would laugh at anything.",
#   'context/1': 'And in almost no time, that spark turned into a roaring fire.',
#   'context/2': 'There you go.',
#   'context/3': 'Fiercely independent? Brave? I guess it was a little selfish.',
#   'context/4': 'Okay. She called off your wedding and dumped you to be a painter in San Francisco. What do you call that?'},
#  {'response': "That's what i thought.",
#   'context/0': "Come on people, get excited for us! We've got a great thing going here.",
#   'context/1': 'Say we want to play a game of charades...',
#   'context/2': 'We just go across the hall.',
#   'context/3': "And say we want to have a dinner party exploring the wine and cuisine of France's Loire Valley.",
#   'context/4': 'We just go across the hall.'},
#  {'response': 'Bang, bang, bangity bang...',
#   'context/0': "Okay, I promise I won't lie to her. I may, however, lie on her. I said, bang-bang, bangity-bang. Bang-bang-bang, bangity-bang",
#   'context/1': "Okay, fine. On one condition. You have to promise me you won't lie to Nora. She seems like something special.",
#   'context/2': 'Yes!',
#   'context/3': "Do you want me to go with you because you're a lot scared?",
#   'context/4': 'No.'},
#  {'response': 'Come on. This is so about the girl.',
#   'context/0': 'Barney, this is about the building.',
#   'context/1': 'Um... thank you for, um, not using a first name in that story.',
#   'context/2': 'What...?! No... What?!...No... What?!',
#   'context/3': 'It was last call. In this very bar.',
#   'context/4': 'I once knew such a girl.'},
#  {'response': "No, you guys go ahead. I'm going to find the veil.",
#   'context/0': 'Yeah, okay.',
#   'context/1': "Or we looked everywhere, and we couldn't find one.",
#   'context/2': 'No, we got to go get the veil.',
#   'context/3': 'You guys want to go gamble?',
#   'context/4': "I'm going to get the bouquet. You guys get the veil. We'll meet in the chapel in 20 minutes. Ready? Break."},
#  {'response': 'Yeah, she told me already. Go on.',
#   'context/0': 'What?',
#   'context/1': "Oh, you mean how Robin's in love with Ted?",
#   'context/2': "Let me call you back. Honey, there's a situation developing. Do you remember the huge secret that you told me that you weren't supposed to but you did? The thing... about Robin?",
#   'context/3': "No. I need a ruling. Um, I'm... Yeah, this is stupid. It's not even a big deal, but I'm on my way over to Robin's right now. She got a new juicer. Whatever. We're going to test it out.",
#   'context/4': 'Hey, did she call?'},
#  {'response': "You can't just... Wow!",
#   'context/0': "Why don't you just check out the girl's reflection in the bar mirror?",
#   'context/1': "It's one of the many risks of the blind approach. It's usually a two-man operation where Ted signals that the target is hot. But Ted's too busy being in a lesbian relationship.",
#   'context/2': "Barney, this is the third time you've hit on me by accident.",
#   'context/3': 'Hundred dollars says when you turn around, I say wow.',
#   'context/4': "Good, cause this thing's empty."},
#  {'response': 'I like it.',
#   'context/0': 'Rotate the camera. Connectitude.',
#   'context/1': "All right. Do not do it. There are many exciting stories to cover in Canada. I just read it, the nephew of the mayor of Winnipeg went fishing on the ice and took a pole of 7 Kg Live from the worst place in the world, I'm Robin Scherbatsky.",
#   'context/2': 'How does make me feel stupid commit somewhere?',
#   'context/3': "Cut! You're mired in details. We need you to be vague, at ease with buzzwords like synergy and dynamism. You can invent a word, as... Relationality.",
#   'context/4': 'Since I was little...'},
#  {'response': 'Look, it did.',
#   'context/0': 'Oh, thank you! Wait. Good evening, New York.',
#   'context/1': '59 p.m., Robin arrives at the studio of Metro New One.',
#   'context/2': 'Really. New Jersey wins.',
#   'context/3': 'Really?',
#   'context/4': 'I moved here.'},
#  {'response': 'And this, my friends, is the effect cheerleaders. Also known as the paradox of a bridesmaid syndrome sorority, and for a brief moment in the 90s, the conspiracy of the Spice Girls.Scary Spice, indeed.  Barney Stinson. OK.Understood. Great, we remember.',
#   'context/0': 'Yeah, really cute.',
#   'context/1': 'I know. The last one is kinda cute.',
#   'context/2': 'Look at it carefully. Individually.',
#   'context/3': 'Anything.',
#   'context/4': 'There is so much to learn. You are only victims of...the effect cheerleaders. Good question. The effect cheerleading is when a group of women air cannon, but only in groups. As with the cheerleaders. They look like cannon, but take them individually? Cod.'},
#  {'response': 'You regret it.',
#   'context/0': "I can not believe I do that. But I'll leave you one last chance. But be aware, if you exceed the limits of a toe, you play the duck shting in your mother's so fast it will make you dizzy. Get out!",
#   'context/1': 'My pleasure. Do not do that. This game is all I have.And I nearly enough tickets for the remote controlled helicopter. Pity.',
#   'context/2': "You forget what it's there. Your fat ass is stuck here for too long.",
#   'context/3': "Listen, you're a good player laser tag. Perhaps the best I've seen. But someday, you will hurt someone.Maybe even you.",
#   'context/4': "I know, I'm not your precious rules, McCracken, but, damn, the results are there!"},
#  {'response': "I know, it's a terrible idea. You can't do it. Just look at me.",
#   'context/0': 'We have an annoucement.',
#   'context/1': 'Hey, hey guys.',
#   'context/2': "They're back.",
#   'context/3': "The world needs Marshall and Lily... together... I'm not crying, there's something in my eye.",
#   'context/4': "Yeah, it is. It's weird."},
#  {'response': 'So I threw the pressure air oxygen into its mouth. I sht the tnk, boo, nomore shark. Mr. Hall and I swam back to shore. Hey,let me serve you a drink.',
#   'context/0': "Kids, in the spring of 2008 something kind of strange have been happening to your uncle Barney. He's been doing great with a woman.",
#   'context/1': 'Why would be looking for one?',
#   'context/2': 'Wait, did I gave you a reason or were you looking for one?',
#   'context/3': "Obviously, I can't. You know there's always a reason not to sleep with a guy, and you just gave me yours.",
#   'context/4': 'You can trust me.'},
#  {'response': 'Did you hear that, Ted? Dana works security at the Liberty Bell.',
#   'context/0': "I can't breathe!",
#   'context/1': "Really? Well I thought it was kinda weird, but if you're cool with it. Yeah. It's off and she's talking to some guy. Do you want me to go over and...",
#   'context/2': "Is she talking to some hot guy? Oh, you can tell me. It's totally cool. It was my idea! Hell, I told her she could take the ring off.",
#   'context/3': "She's uh...",
#   'context/4': "Robin! Uh... Where's Lily"},
#  {'response': 'Is it? Describe your first 8.3 seconds with Stella.',
#   'context/0': "That's ridiculous.",
#   'context/1': "Ted, do you know how long it takes a woman to decide whether or not she's going to sleep with a guy? 8.3 seconds. After that, her decision is made. She will not change her mind.",
#   'context/2': 'Sloppy Joe, shrimp cocktail and a milk shake.',
#   'context/3': "This is far from over. We're talking ten weeks from now. Who knows what she'll want then? Do you know what you're going to want for lunch ten weeks from now?",
#   'context/4': "No... Hmm. What could she mean when she says 'no'? I don't know, it is totally cryptic."},
#  {'response': "You are the best. My girlfriend is at a strip club with me and she couldn't care less.",
#   'context/0': 'Wow.',
#   'context/1': 'Wow.',
#   'context/2': 'She wants to pay the restaurant. He offers her his jacket. They takes pictures with Moustache Marshall. He calls her after their date. They marry.',
#   'context/3': "No, it wasn't. I had a great time tonight. And seven years ago, if you think about it, we didn't miss by that much. If a couple things had gone a little bit differently... who knows what",
#   'context/4': "The only thing that we've learned is that, seven years ago, it was mistake for us to go out. And I guess it was a mistake for us to go out tonight."},
#  {'response': "Is insurance going to cover that? Sometimes they don't.",
#   'context/0': 'Right. So I went to the chiropractor yesterday. That guy bent me over the table and pounded me for a good hour.',
#   'context/1': "I'm being Barney, and I think tonight's going to be de... wait for it... lightful. Delightful.",
#   'context/2': "You're being super nice. It's... freaking me out. Be... gross, be inappropriate. Be Barney.",
#   'context/3': 'Like what?',
#   'context/4': 'Why are you acting like this?'},
#  {'response': "There's been no light.",
#   'context/0': 'No. I want to.',
#   'context/1': 'It is said? It should.',
#   'context/2': "I just had a conversation strange. A woman at the GNB told me that the new tower was abandoned last month. It's crazy, right? What is this look?",
#   'context/3': "Yeah. It's nonprofit. They just want to disseminate information.",
#   'context/4': 'Point org?'},
#  {'response': "Dude... don't poop where you eat.",
#   'context/0': 'What? What do you mean?',
#   'context/1': "what's matter with you?",
#   'context/2': 'Ted, why would you do that?',
#   'context/3': 'I asked her out.',
#   'context/4': 'what?'},
#  {'response': "You don't have to say it, though.",
#   'context/0': "We're showing Ted how lame he is.",
#   'context/1': 'Abby and I are in love. Not hot passionate love. Couple love. You know, movie night with my girlfriend, then waiting for her to go to bed so I can steal one pitiful moment of hollow ecstasy by the cold, blue light of my computer monitor.',
#   'context/2': "That's right. And girlfriends are lame. Unless they're me. I miss you, Ted.",
#   'context/3': "That's right. I am done with this whole being awesome thing. Now I'm all about farmers' markets and day hikes in matching khaki cargo shorts. Isn't that right, sweetie?",
#   'context/4': 'Hello, Abby. So, uh, s-so you guys are dating now?'},
#  {'response': 'Hey.',
#   'context/0': 'You always do.',
#   'context/1': 'Yes, but I always cover it with a cough.',
#   'context/2': 'Well, you have farted in front of me.',
#   'context/3': "No, but we haven't, because I want to keep some of the mystery alive.",
#   'context/4': "Baby, why don't you just go? Tons of other couples have peed in front of each other."},
#  {'response': "Dude, that's awesome! You're finally forgetting about that short redhead.",
#   'context/0': 'What? No. I... Barney, I was...',
#   'context/1': "You just checked out Robin's ass.",
#   'context/2': 'See ya.',
#   'context/3': "I'll walk you out.",
#   'context/4': 'Alright, see you guys later.'},
#  {'response': 'Of course.',
#   'context/0': 'Hello, Barney.',
#   'context/1': 'No, no.',
#   'context/2': 'Sorry, baby, I gotta work. I need all my blood  Anybody seen a big-ass book?',
#   'context/3': 'Hey little old books. Ready for a little fifteen minute recess?',
#   'context/4': 'Or Casual?'},
#  {'response': 'Shannon, there is no...',
#   'context/0': "It's just, he's still supporting me, and... Look, he's coming by soon to talk about it, but I think you should go on without me.",
#   'context/1': 'But the Nicaraguans need us!',
#   'context/2': "Oh, I'm sorry. My dad won't let me go.",
#   'context/3': 'Sugar Bear, where were you?',
#   'context/4': 'Barney.'},
#  {'response': 'I would say even more. You, sir, did think Stella. Ted looked so cool now. Do I chose the wrong? Wait a week. The bush on the back. And belly. Have you felt that? There was an earthquake Tope-there.',
#   'context/0': "I think you've been great.",
#   'context/1': 'Enchanted.',
#   'context/2': 'Magic.',
#   'context/3': "It's my new bride. This is Stella, except that it is French and, as you see, she has enormous breasts.",
#   'context/4': '... up...'},
#  {'response': "Man, I always thought I had it rough not really knowing my dad, but... now I realize at least I'll never have to suffer like this. Our next video is called German Shepherd Activates Tennis Ball Cannon While Fat Kid Sips Energy Drink.",
#   'context/0': 'Yes.',
#   'context/1': 'Lawyered. Now can we all just admit that last words are, in fact, a big deal?',
#   'context/2': 'You remembered my birthday!',
#   'context/3': "No, here's the awful part.",
#   'context/4': "That's awful."},
#  {'response': 'Really?',
#   'context/0': "My great... you cause me problems since you joined this club. But damn... if this is not the best battle of PQ I've ever seen. You are returned... And right away.",
#   'context/1': 'Thank you. Yours is.',
#   'context/2': 'Your way is perhaps not completely stupid.',
#   'context/3': 'I know, baby.',
#   'context/4': "I love it. I worked hard. It's nice to be appreciated at its true value."},
#  {'response': 'Okay, go. You are not obliged to return, but you can not stay. I always wanted to say that. I mean, in a bar. I say all the time with me.',
#   'context/0': 'Do it.  Now, go find your wife.',
#   'context/1': 'I know not how you thought I draguais you, but...',
#   'context/2': 'Close your eyes.',
#   'context/3': "Robin, I'm sorry. You're not a robot. If you are, you are a very advanced model, and the human race has no chance. You did not choose to show your love through rituals tacky, and that's good. But maybe we did that because we have always done and we know no other way. What I know is that if there sitting alone at the airport, I have to go get her.These are the rules.",
#   'context/4': 'A car.'},
#  {'response': 'She was the wife of Archie in All in the family, or the same voice?',
#   'context/0': 'You know Neil Young is my favorite musician.',
#   'context/1': 'thank you God, the song is over. Who was the old devil who sang?',
#   'context/2': 'And, of course, the biggest, the Canadian-American wr.',
#   'context/3': 'The jokes about magic, the stormtrooper...',
#   'context/4': 'I said nothing.'},
#  {'response': 'Dude, you show up to an interview in that, even the hippie lawyers from Granola Mountain Earth Pals will hackey sack you straight out the door.',
#   'context/0': "I don't have another one. I'm flat broke. My only other suit options are track or birthday.",
#   'context/1': 'So wear another one.',
#   'context/2': "I have a big interview coming up, and my suit has holes in it. I can't sew, I don't own Navy boxers, so, yeah, I'm coloring in my butt.",
#   'context/3': 'Um, are you coloring in your butt?',
#   'context/4': 'Yeah, well, things with Victoria were fun, and easy, and uncomplicated. It was pretty great.'},
#  {'response': "Of course. I'm sorry, I forgot to call you. That's not the place. The real place is on 106th and Manhattan Avenue. We're headed there right now.",
#   'context/0': "Regis. I'm at the place.",
#   'context/1': "I'm sorry, this is...?",
#   'context/2': 'Barney, where the hell are you?',
#   'context/3': 'Barney Stinson.',
#   'context/4': '106. A numbered street. Of course.'},
#  {'response': "And that's not happy?",
#   'context/0': "You're not happy. You just think you're happy because you feel happy.",
#   'context/1': "Lily, can't you just let us be happy?",
#   'context/2': 'Yes! No! Lily, private convo time.',
#   'context/3': 'Define the relationship.',
#   'context/4': 'Run tell that.'},
#  {'response': "Listen, Arthur, Marshall's wife has an idea for how we can save, not saving The Arcadian.",
#   'context/0': 'No! Tugboat, my other dog, that was a cute dog. This little disappointment is nothing but a cheap facsimile. I said it! Yeah, my love is reserved for dogs that go to the bathroom on command instead of wasting my time!',
#   'context/1': 'Oh, cute dog!',
#   'context/2': 'Hey, Arthur!',
#   'context/3': 'What is so difficult about this?! Tugboat figured this out in, like, five minutes. This is bush league!',
#   'context/4': 'We have to find Arthur right now.'},
#  {'response': "First of all, Robin, my dad could beat up your dad. Second, you don't have to worry. He's cool. Now if you'll excuse me... I have to go renew my passport, and get a travel-sized rotating Vietnamese Shame Wheel. Don't ask; you're not ready.",
#   'context/0': "Barney, we just don't want to see you get hurt.",
#   'context/1': 'Well, this guy has flaked out on your whole life. It sounds like he just might be telling you what you want to hear.',
#   'context/2': 'What do you mean?',
#   'context/3': "Barney, we... we know you're psyched, but just... be careful.",
#   'context/4': "This is going to be the second-most fun I've ever had on an Asian leg."},
#  {'response': "Then why don't you say it now?",
#   'context/0': "Why is this such a big deal? It's just a word. We use lots of words, every day. It shouldn't be any different than any other word.",
#   'context/1': 'Oh, Ted. Oh, Teddy boy.',
#   'context/2': 'Yeah.',
#   'context/3': "The best friend's job is to call me that word?",
#   'context/4': "I was trying to help him. I'm his best friend. That's the best friend's job."},
#  {'response': 'Really?',
#   'context/0': "Actually, oddly, we both think you're meant for each other.",
#   'context/1': 'She told you? Great. I guess you marrez my back all this time.',
#   'context/2': 'Lily told me.',
#   'context/3': 'What?',
#   'context/4': "I know you're in love with Robin."},
#  {'response': "Um... Um... I'm have... I'm having trouble breathing!",
#   'context/0': 'I think the smaller turkey just tried to crawl further inside the bigger turkey.',
#   'context/1': "It's not awesome!",
#   'context/2': 'This is awesome!',
#   'context/3': "Hey, just so you guys know, there was a tiny explsin at the sewage treatment plant across the street from our apartment, but I'm sure it's fine by now.",
#   'context/4': 'Huh. I should probably disconnect the gas.'},
#  {'response': 'Ted, you klutzy, great guy, you!',
#   'context/0': 'Alright, um, I think we need to refine our back-story first. How did we...',
#   'context/1': "Okay, carousel four is tapped out. Ready? Because I'm about to drop some knowledge. Cute girls are not from Buffalo. Time-out. Ten o'clock. You ready to rock this, Tedder?",
#   'context/2': 'Oh. Oh, hello!',
#   'context/3': 'Hey.',
#   'context/4': "I guess that's one drawback to being engaged. I'm sure that's why he didn't..."},
#  {'response': 'I wear this jumpsuit since 1:30!',
#   'context/0': "I'm in love with her for 12 years!",
#   'context/1': "I'm in love with her for 5 years!",
#   'context/2': 'Sir! You just missed... the night of your life! The night... of your life.',
#   'context/3': "Yeah, I'll sleep with her. After, he'll tell her he loves her.And you can do... what you want. Is there agreement on the order?",
#   'context/4': 'Put yourself on the line Bob!'},
#  {'response': 'Ted has a little sister who is so playful every day. And if I meet with her breasts, I will play! Little sister, Little Sister!What? I can also celebrate Hanukkah.',
#   'context/0': 'If I could see her naked. If I could see her naked. If I could see her naked. And fours.',
#   'context/1': "Drop your trousers. Mine hard. Under the bunch of mistletoe, I'll make your sister moan. Oh! Dear Heather, Heather dear, we'll do it in all directions...",
#   'context/2': 'I never will. Every year, when the greeting card of Mosby happens...',
#   'context/3': 'Since that time Heather happening in New York, Ted has never left the Barney show.',
#   'context/4': 'And?'},
#  {'response': 'Milk Duds.',
#   'context/0': 'Mounds.',
#   'context/1': "Yeah! It's like being in a candy store. You just walk right in and grab yourself some Whoppers. Yeah. Is Whoppers the best ones?",
#   'context/2': 'Candy.',
#   'context/3': 'Marshall, being a single guy in New York city is like... Pfff... What does everybody like?',
#   'context/4': 'Oh, God!'},
#  {'response': 'I know. I want to hire you.',
#   'context/0': "Yeah, I'm kind of real focused on the job hunt right now.",
#   'context/1': 'Hey, Marshall, I need your help.',
#   'context/2': 'Hello.',
#   'context/3': "Stella! You have a serious girlfriend now! You're over this one. Robin who, right? Stella makes this one look like a filthy bag of gbabage, am I right? Happy birthday, bro.",
#   'context/4': "Guys, cut the act. I know. I know about the surprise party you guys are throwing me. Marshall let it slip earlier today. Hey, I'll totally act surprised and everything. Just be sure to invite Stella."},
#  {'response': 'I understand. Zoey has magic lady bits.',
#   'context/0': "It's not because I'm mad at you. Barney, The Arcadian was designed by a guy named John Clifford Larrabee. And even though he's been dead for half a century, it's my duty, architect to architect, to keep his work alive. Please tell me a little part of you understands.",
#   'context/1': "Secondly, Ted, I'm sorry I said mean things about Zoey. Are you really going to walk away from this project just because you're mad at me?",
#   'context/2': 'Nailed it.',
#   'context/3': "Okay, okay. A couple of things. Lily, how'd I do?",
#   'context/4': "And she hasn't since."},
#  {'response': 'There should be a bar.',
#   'context/0': 'Except where everyone ended up spending the best night of his life, then we put the chairs on the tables and pulled out the margarita fountain.',
#   'context/1': 'No nightcap!',
#   'context/2': "That's... a great name for a bar! And also, Puzzles: no nightcap.",
#   'context/3': "And dude, dude, dude, dude... The name of our bar will be... Puzzles. People will, Why Puzzles? That's the puzzle.",
#   'context/4': 'Our bar would be great.'},
#  {'response': 'Why? Why? Why?! Why?!',
#   'context/0': 'What? Why?',
#   'context/1': 'Love it? Hold on a second. Love it? I hate it!',
#   'context/2': 'Wow, Barney, why do you love that car so much?',
#   'context/3': 'Come on, Marshall. This is your Fiero. You know the rightthing to do here.',
#   'context/4': "I don't know. I don't know. I don't know."},
#  {'response': 'No.',
#   'context/0': "You're dating a girl from New Jersey?",
#   'context/1': "Wow. You know I really should check out this subway. Heard so much about it. Wow. Look at me. Slumming it. Maybe I'll make a weekend out of it and I'll call my bridge and tunnel girl tonight.",
#   'context/2': 'Oh, hey, just so you know, uh, all marathon runners get to use the subway for free today.',
#   'context/3': "Huh? Can't believe they haven't made a coin for this yet. Anyway, I'm heading home. Might go hit the gym.",
#   'context/4': 'All right. I got to admit, you earned this.'},
#  {'response': "Yes. The chain of screaming starts at the top. Arthur's boss's boss screams at Arthur's boss. Arthur's boss screams at Arthur. Arthur screams at you. You go home and scream at Lily. Lily screams at one of the kids in her kindergarten class. Then that kid screams at her dad, Arthur's boss's boss. And the whole thing starts all over again, Thus completing the circle of screaming.",
#   'context/0': 'Chain of screaming?',
#   'context/1': "Lily, control your woman. The lesson of Blauman is that when your boss screams at you, you never scream back. That's why there's a little thing in corporate America I like to call the chain of screaming.",
#   'context/2': "How does that help me? How does any of this help me? Can somebody, for god's sakes, please give me one piece of useful advice?",
#   'context/3': 'No, no, of course not... he died.',
#   'context/4': "That's it? that's the end of the story?"},
#  {'response': "Ted, what's the first syllable in rutting",
#   'context/0': "It's not a rut, okay. It's a routine and I like it!",
#   'context/1': 'Consistently.',
#   'context/2': "Uhh... because he's getting laid.",
#   'context/3': 'Why can Marshall say no?',
#   'context/4': 'I understand.  Get in the cab.'},
#  {'response': "You've heard of the golden rule, right? love their neighbor?",
#   'context/0': "and in this case, you're paying them... then yes, it counts.",
#   'context/1': "If it's someone you see on a regular basis, and you can't avoid them...",
#   'context/2': "oh, no, this doesn't count.",
#   'context/3': "Dude... don't poop where you eat.",
#   'context/4': 'What? What do you mean?'},
#  {'response': 'The committee realized he had erred. In addition, you are precious to them and they want you to be happy.',
#   'context/0': 'Really?',
#   'context/1': "Those guys were morons. Of course, they had cool ideas... really cool ideas. In fact, I wonder if it's not too late...The fact is: you have the job.",
#   'context/2': 'What?',
#   'context/3': 'It turned Sven.',
#   'context/4': 'What hat?'},
#  {'response': "Oh no, the night's ruined!",
#   'context/0': "So, Barney, why don't we take this party to a more horizontal location?",
#   'context/1': "What are you talking about? Barney: If you must know, it wasn't a freak beverage malfunction that stopped me from riding the tricycle that night.",
#   'context/2': 'Leave him alone! Sometimes even the greatest warriors sht themselves in the foot.',
#   'context/3': "Ted, you're ruining this for everyone.",
#   'context/4': "I'll get your coats? Ted: I don't know why I said that. Why did I say that? It's the opposite of what I meant. I wanna take clothes off them, not put more on."},
#  {'response': "I'm not saying he loves pizza, but the last time he went, the doctor said, stop eating pizza. Marshall: Why? Doc: To you examine.  But seriously, we laugh because we love you.",
#   'context/0': 'Our coupons are your effigy.',
#   'context/1': 'I even caught a pizza in the shower.',
#   'context/2': 'It was literally across the country a hundred times for a pizza.',
#   'context/3': 'What!?',
#   'context/4': 'You know, in fact, it was not me who should pay.Because I do not really like pizza.'},
#  {'response': 'Vegas.',
#   'context/0': "Whoa, we're leaving the city. Where the hell is this party?",
#   'context/1': "Okay, everyone, Ted's in the limo, five-minute warning! Everyone get ready! Oh, Missy, are you excit?? Yes, you are!",
#   'context/2': 'Whoa, you guys went all out.',
#   'context/3': 'Okay. Bye.',
#   'context/4': 'Uh, gotta go. Here he comes.'},
#  {'response': "Ted! Fine, fine. You cannot play it. Shannon! I love you! I love you so much. What about us changing the world together? Don't tell me you've forgotten. I know I haven't. Will I ever see another rainbow? Will an eagle ever soar through this tempest of woe? Baby, please Don't go There's a thief in the palace, she's stolen all my love There's a thief in the palace and she's...",
#   'context/0': 'Play the tape, play it, play it!',
#   'context/1': 'Give it to me, give it, give me...',
#   'context/2': "Yeah, you were acting so weird about it, I gave you Ted's graduation tape instead. So, should we pop it in?",
#   'context/3': 'Drink!',
#   'context/4': 'What?!'},
#  {'response': "And right by Saint Valentine's side was his best bro, Saint Desperatius, there to pick off insecure bridesmaids.",
#   'context/0': "This won't be.",
#   'context/1': "Wait, there's more.",
#   'context/2': "That's actually true.",
#   'context/3': "It's a thing. Much like Valentine's Day itself, Desperation Day dates back thousands of years. Weddings were forbidden under ancient Roman law, so Saint Valentine performed them in secret, under threat of death.",
#   'context/4': "That's not a thing."},
#  {'response': "Nah. I'm so over karaoke.",
#   'context/0': 'So, Barney, you gonna sing anything?',
#   'context/1': "You're right. They're delightful.",
#   'context/2': 'Dude, Scarlett Johannsen with no arms, any day of the week. Yeah.',
#   'context/3': "But wait, knock-knock, back door, who's there? Angelina Jolie... wait, in a wheelchair. What do you do? Go.",
#   'context/4': 'Okay.'},
#  {'response': 'Really? Laid, you say?',
#   'context/0': "Yeah, well, it was supposed to be, but my professor's like the toughest grader I've ever seen. She had like a bad divorce this summer and now she's taking it out on us. To tell you the truth, I think she just needs to get laid.",
#   'context/1': 'I thought you said your semester was gonna be a piece of cake. I remember because you were eating a piece of cake at the time and you said, dude, my semester is gonna be this.',
#   'context/2': "I've never need the beer more than I do right now.",
#   'context/3': "Although, you might want to bring out the big hawaiian drum because I'm pretty sure today's my birthday.",
#   'context/4': 'Thank you.'},
#  {'response': "Someone who likes you, really. And suspicious, and probably accurately you do it over more later, and therefore he feels the need... I'm sorry, you spoke of this fantastic pair of tits, right? Because I seek, and I do not see them.",
#   'context/0': 'What is wrong with you? What kind of people need to lie like that?',
#   'context/1': "Wait, Nora, waiting... No, please. I'm sorry.",
#   'context/2': 'Breasts...',
#   'context/3': 'What? Where? Oh, and shit.',
#   'context/4': 'Wow, this one has a beautiful chest.'},
#  {'response': 'Ah. Thank you.',
#   'context/0': "That night, Barney didn't take care of business. Instead, Nora took care of Barney.",
#   'context/1': "Come on, let's get you sorted out.",
#   'context/2': "The bed... that's where all the...happens.",
#   'context/3': "Huh, let's say well-endowed... with phlegm. All right, let's go. It's bedtime.",
#   'context/4': 'Handsome? Rich? Well-endowed?'},
#  {'response': 'The Robin.',
#   'context/0': 'Night, night, little Marvin',
#   'context/1': 'Do you, Robin?',
#   'context/2': "And so, kids, on that cold December night I decided to take your Uncle Marshall's advice and be a little selfish.",
#   'context/3': 'Enough with the damn music!',
#   'context/4': '06 p.m.-- put on edible underwear.'},
#  {'response': 'Go and eat your ice.',
#   'context/0': 'You can stop with that?',
#   'context/1': 'Come on, Barney. You have no idea of the difficulty of getting a job beneath you. I really liked your tip on the bones of dinosaurs.',
#   'context/2': 'No weak link in this scene. Bravo!',
#   'context/3': 'I will take a little ice in the freezer downstairs and make the ice creams in the kitchen.',
#   'context/4': "We're a happy family."},
#  {'response': "You're kidding me!",
#   'context/0': 'Karen is here?',
#   'context/1': 'My ex, Karen, is in New York. The usual routine.',
#   'context/2': 'I have used questionable methods to skip a very silly girl.',
#   'context/3': "What do you want? Sometimes it's like that. The same thing over and over again. One of my students ate glue.",
#   'context/4': 'Come on, guys. You are four young people active in the most exciting city in the world. And you have nothing to tell me?'},
#  {'response': "Well, obviously, I've been proven right, so in the interest of Robin's dignity, I won't show anymore. Plus, it's getting late. It's already slap o'clock.",
#   'context/0': 'Oh my God.',
#   'context/1': "Please, Mr. Johnson, I'm sorry I was a bad girl. Please don't give me detention. Isn't there something I can do to make it up to you?",
#   'context/2': 'It always does.',
#   'context/3': 'And it started out as an innocent modeling job.',
#   'context/4': 'They never do.'},
#  {'response': "Yes, I'm in the office. This is the sound of my stapler.This is the sound of my trouilloteuse. And that, the sound of me, ranking the company's directive on sexual harassment. What's new? I gotta run, great leader.",
#   'context/0': "Marshall. So, you're in the office? You're not, I do not know, driving a taxi, with a wig?",
#   'context/1': 'Barney here.',
#   'context/2': "I've moved up.",
#   'context/3': 'Wait 2 seconds! It could easily be Barney who tries to fck chicks.',
#   'context/4': 'Decided!'},
#  {'response': 'Oh, once I am the soul man. There was this pretty girl who only go out with black.',
#   'context/0': "Ok, let's move. What was the worst? The best of the worst? The cream of the crop?",
#   'context/1': 'I do not have time to explain how I got there. I just need someone to suck the poison. The surgeon gave me a new face, darling. You realize that I am alive? My name is David Beckham. If I castais only the white swan, is the role for you. No, I am a lesbian. What I wear is just very realistic.',
#   'context/2': 'Meanwhile, Barney continued to list every lie he used to sleep.',
#   'context/3': 'Just myself.',
#   'context/4': 'Who are you playing anyway?'},
#  {'response': "It's a long story. As you know, my father had to leave my mother when I was a baby because he became presenter of the Just Price.",
#   'context/0': "What's that, Barney?",
#   'context/1': "Will in, little rascal! I'll see you at the bar?",
#   'context/2': 'Me-seven!',
#   'context/3': 'Me too.',
#   'context/4': 'Guilty. I love you.'},
#  {'response': 'No thank you.',
#   'context/0': 'It was pretty awesome. You should try it. I still have a few.',
#   'context/1': 'No, sir. I like to play by the rules. While I can not say I did not propose to.',
#   'context/2': 'Barney, I will interrupt you one second, I must ask you something. Have you ever taken Viagra?',
#   'context/3': 'Guys, guys, look!',
#   'context/4': 'Why do you...'},
#  {'response': 'Big fan. Barney Stinson. So, uh... what about this party?',
#   'context/0': "Wow. You're friendly.",
#   'context/1': 'Welcome.',
#   'context/2': 'Sure.',
#   'context/3': 'You want a ride?',
#   'context/4': "Yeah, I'm just going to this party downtown."},
#  {'response': 'This morning I made the heart of the Ambassador of the Netherlands. I hope he gets better.',
#   'context/0': 'He will watch it.',
#   'context/1': 'I look, sir.',
#   'context/2': "Mini pizzas? French fries? Something that makes me think I'm a giant?",
#   'context/3': 'I do not think, sir.',
#   'context/4': 'You have nothing that resembles a mini cheeseburger?'},
#  {'response': 'Absolutely not.',
#   'context/0': 'And those girls over there? They are cannon.',
#   'context/1': "I'm not impressed by the talent here tonight. And more I drink, the less it is attractive. I'm a whiskey and Coke in the Cantina scene in Star Wars.",
#   'context/2': 'Here we go at once. And it was over. At this point, I was not angry. I saw that she was made to be with him.Children, you might think that the only choices are to swallow his anger, or swing at someone. There is another option: you can let it flow, and when you do that, we can forget and move forward. And that was the perfect ending to a perfect love story.It was just not mine. Mine was always there, waiting for me.',
#   'context/3': 'Mom!',
#   'context/4': 'So I got out of the cab, ready to tell her everything, ready to explode but then...'},
#  {'response': "Ted, I'm going to teach you how to live.  Barney, we met at the urinal.",
#   'context/0': 'I see what this is about. Have you forgotten what I said to you the night we met?',
#   'context/1': "You know, ever since college it's been Marshall and Lily and me. Now it's going to be Marshall and Lily... and me. They'll get married, start a family-before long I'm the weird, middle-aged bachelor their kids call Uncle Ted.",
#   'context/2': 'It was a blazer!',
#   'context/3': 'I did that one time.',
#   'context/4': "Where's your suit!? Just once when I say suit up, I wish you'd put on a suit."},
#  {'response': 'Hey, Ranjit, pull over.',
#   'context/0': "Well, you're in luck. See that gothic church over there? Those corinthian columns were designed by Giuseppe Pegatto in 1896.",
#   'context/1': 'Last seat. Thank God. I just had the worst cab ride of my life.',
#   'context/2': 'He thought of all the times that he had beaten the machine. He triumphed over Pitfall He vanquished the alarm. He brought the jukebox back to life with his Fonzarelli arm Marshall versus the machines.',
#   'context/3': 'Hey, Christine.',
#   'context/4': 'As Marshall ran with all his might and passed his friend Christine'},
#  {'response': 'Help me!',
#   'context/0': 'You called, said..., and hung up. What do you want?',
#   'context/1': "Ah, ah, it's her, it's Robin. What do I do? No-no-no-no, aah! Robin... Great to hear from you. To what do I owe the pleasure?",
#   'context/2': 'Great. Now we need a new code word.',
#   'context/3': 'We have to go.',
#   'context/4': 'Rhinoceros.'},
#  {'response': "Suits are full of joy. They're the sartorial equivalent of a baby's smile.",
# ...
#   'context/1': 'Nothing.',
#   'context/2': 'What never happened? What are you guys talking about?',
#   'context/3': "You're really gonna pretend this never happened?",
#   'context/4': 'What thing?'},
#  {'response': "Ted, have you not been listening? Attraction, bargaining, submission, perks, tipping point, purgatory, confrontation, fallout! These things will all happen to you as surely as they happened to all of us! It's a rule of nature.",
#   'context/0': "You're such a jerk!",
#   'context/1': 'I have a date.',
#   'context/2': 'What?',
#   'context/3': "All right, i'm taking off.",
#   'context/4': "You're an idiot."},
#  {'response': 'What do I do? Tell me what to do, Ted.',
#   'context/0': 'Zitch dogs, this. Or nothing.',
#   'context/1': 'Dude, a dog.',
#   'context/2': "Relax. You're doing great. Ignore the old lady on the rascal; this isn't a race.",
#   'context/3': "This isn't right. God never meant for us to travel at such breakneck speeds.",
#   'context/4': "Well, guess what? You're getting your chance. Because I'm going to teach you. Barney Stinson, buckle up."},
#  {'response': "You're really gonna pretend this never happened?",
#   'context/0': 'What thing?',
#   'context/1': 'Because of our thing.',
#   'context/2': 'Why?',
#   'context/3': 'Being around Ted.',
#   'context/4': 'What is?'},
#  {'response': 'Ted, you still with us?',
#   'context/0': 'Good luck, dude. Grab me a cupcake.',
#   'context/1': 'Buttercup Bakery. This is it.',
#   'context/2': "The real Ted sounds real sexy. It's too bad I'll never get to see it.",
#   'context/3': "You know, I don't look like this every day. On a real weekend, the real Ted wears a pair of jeans and a sweatshirt with bleach stains on it.",
#   'context/4': 'You got me, you are good.'},
#  {'response': "I only have one rule. Never, ever, ever meet a girl's parents.",
#   'context/0': 'This was a big deal for Barney.',
#   'context/1': "It's funny you should say that, because, as it happens, my parents are in town. They're only here like once a year. We're getting brunch tomorrow. Do you want to meet them?",
#   'context/2': "Okay, I think that we're done here, I think that we have adequately established that Barney is... the kind of guy that you would bring home to meet your parents. Okay? So... let's just drop it, all right?",
#   'context/3': "I don't recall.",
#   'context/4': 'Really? So Barney really is a genuinely a nice guy.'},
#  {'response': "And there's more. Do you still do that thing where you give people in need clothes for job interviews?",
#   'context/0': 'Positive.',
#   'context/1': 'You sure?',
#   'context/2': "And that's the tour. Uh, staff meeting's at noon, you'll meet everyone there, but first you need to head down to security. You need to get your picture taken. For your I.D. badge.",
#   'context/3': 'Nope.',
#   'context/4': "Wow. That's a lot of zeroes. Y-you sure you're not missing a decimal point?"},
#  {'response': "I should go, too. I hooked up with this Chinese girl last night and I don't know, it's weird. I already feel like seconds.",
#   'context/0': 'What!',
#   'context/1': 'Even better, seeing him naked.',
#   'context/2': "You're still seeing that guy?",
#   'context/3': 'OK, I should get going. I got a date.',
#   'context/4': 'God... you just get me.'},
#  {'response': 'What, she is upset?',
#   'context/0': 'Barney, sit down, there are two three things to tell you.',
#   'context/1': 'Typical of a guy.',
#   'context/2': 'You see nothing.',
#   'context/3': 'The period of mourning? She has not had a period of mourning.',
#   'context/4': 'You were a real asshle to Robin when she was in her period of mourning.'},
#  {'response': 'And I said my name was...?',
#   'context/0': 'It rhymes with your name.',
#   'context/1': "... don't see eye-to-eye on anything! Totally.",
#   'context/2': "Yes, they do. It's like they...",
#   'context/3': "No, they don't.",
#   'context/4': 'Yes, they do.'},
#  {'response': 'Really? Laid, you say?',
#   'context/0': "Yeah, well, it was supposed to be, but my professor's like the toughest grader I've ever seen. She had like a bad divorce this summer and now she's taking it out on us. To tell you the truth, I think she just needs to get laid.",
#   'context/1': 'I thought you said your semester was gonna be a piece of cake. I remember because you were eating a piece of cake at the time and you said, dude, my semester is gonna be this.',
#   'context/2': "I've never need the beer more than I do right now.",
#   'context/3': "Although, you might want to bring out the big hawaiian drum because I'm pretty sure today's my birthday.",
#   'context/4': 'Thank you.'},
#  {'response': "I don't always want to be that guy. Sometimes I want to be someone you can have an actual conversation with. Now, tell me something about you that I don't know yet. Seriously.",
#   'context/0': 'Nothing? Not even a glance? Even I was thinking about rocking a motorboat on those bad boys. What the hell is wrong with you?',
#   'context/1': 'Thanks.',
#   'context/2': 'What part, what part?',
#   'context/3': 'Should I leave, too?',
#   'context/4': "Wait, it's really important to you that I like this movie, isn't it? I'm not gonna like it with you staring at me the whole time. Go to your room and I will come get you when it's over. Go."},
#  {'response': 'Can you believe...',
#   'context/0': "I'd love to.  There's just one little thing, and it probably doesn't matter, but... I don't want to get married. I've been saying that all night just to get in your pants.",
#   'context/1': 'Do you want to come upstairs?',
#   'context/2': 'Yeah, me, too.',
#   'context/3': 'Here we are. I had a really great time tonight.',
#   'context/4': 'Scooby got out!'},
#  {'response': 'Okay, this place is actually pretty nice.',
#   'context/0': 'I have a hot tub.',
#   'context/1': 'Your place? Thanks, but no thanks, 1994 Courtney Love.',
#   'context/2': "Good idea. Let's all go back to my place.",
#   'context/3': "You... your vg1n... Ted, this chick is crazy. We're leaving.",
#   'context/4': 'Tell me something. Do you ask your tailor to leave extra room in the crotch for your huge vg1n?'},
#  {'response': 'Mind you, it is rather barrel.  I choose you you, baby. Tomorrow morning, I get rid of these costumes.',
#   'context/0': 'Nothing suits her better... than... Costume.In costume! In costume! Costume...!',
#   'context/1': "I'll stop. These are the costumes. Stops just bullshit.Two, three, four! Girls come and depart, but the clothes remain constant! Each buddy dpote and rambling, it is no substitute!Sorry, my costumes, I give you my life. My Sunday clothes are my best friends! The casual clothes go in the basket because nothing goes better with the undisputed often praised, claiming to fame... a true... Expect more... Costume...",
#   'context/2': 'And a world at peace would be within your reach?',
#   'context/3': 'Do we see.',
#   'context/4': 'What would you choose: a million girls and one three parts?'},
#  {'response': "Really? 'Cause I could swear you fell straight out of heaven. Angel... Give him your number. What? Give him your number. What?",
#   'context/0': "No, I haven't.",
#   'context/1': "You've had a terrible fall.",
#   'context/2': 'What are you talking about?',
#   'context/3': 'I think there might be some internal bleeding. Probably some fractures. We got to get her to the hospital.',
#   'context/4': 'What is going on?!'},
#  {'response': "Awesome. Say that is a tailor and you have found a nice suit. A nice suit Canada. Superb chest. You try it, but it does not suit you perfectly. So you return it. Then I try it. I'm not too keen... a suit that you have caught the eye, but at the same time, I love this costume.",
#   'context/0': 'I have to really work, so...',
#   'context/1': 'What do you think of Robin?',
#   'context/2': 'No.',
#   'context/3': "It's time to talk?",
#   'context/4': 'A hat-shaped building.'},
#  {'response': "How would you like to extend your stay here? All you'd have to do is pretend to be my wife, and scare off the occasional one-night stand. I know,I know. You've got your ethics. You've got your principles...",
#   'context/0': 'Thank you.',
#   'context/1': "She was freakishly immune to everything in my apartment... Except you. You're better than prn.",
#   'context/2': "Well, she'd have to with your spring-loaded toilet seat, wouldn't she?",
#   'context/3': "Come on, baby. please, no. You don't understand. What have I done? This is the worst. How could you...?  You're not going anywhere. Live claritin clear. Wow, that was close. That hippie chick wouldn't leave. She was ready to squat here.",
#   'context/4': "You son of a bitch! I can't believe I let you enter my sacred temple."},
#  {'response': 'Oh, my God.',
#   'context/0': 'I showed up with wet hair once! Once!',
#   'context/1': 'What, wear a wrinkled suit and not give a damn about what your hair looked like?',
#   'context/2': 'Do you know what I had to do to will myself to show up every day?',
#   'context/3': 'Do you know what I had to do to get you that job?',
#   'context/4': 'I-I guess. That... seems like a whole other thing. We need a drink that will start a fight.'},
#  {'response': 'Your nails?',
#   'context/0': "You know what, Doug? I will gladly pay. And why?As adults do. They pay their glasses, and they fight it. You know what I did when you were kids? That's what I did.",
#   'context/1': 'Because thou hast not supported. They supported me.',
#   'context/2': 'Why should I pay?',
#   'context/3': 'The pot of victory! Blackjack! Blackjack! Blackjack!Blackjack!  7 50.',
#   'context/4': "My God, it's hot!"},
#  {'response': 'I just want to see your phone. Let me see your phone.',
#   'context/0': 'Why?',
#   'context/1': "Don't change the subject. Let me see your phone.",
#   'context/2': 'Hey, bro.',
#   'context/3': 'No, he... No! That... is impossible. Excuse... Excuse... Ex...',
#   'context/4': "And, Barney... I hate to be the one to tell you this, but... he's texting."},
#  {'response': "Yeah, I couldn't get her face in it. But she looks just like you.",
#   'context/0': 'Oh!',
#   'context/1': 'Ladies, meet Stripper Lily.',
#   'context/2': "And Moustache Marshall. By the following summer, we would find the remaining two doppelgangers. But I'll get to that.",
#   'context/3': 'Lesbian Robin.',
#   'context/4': 'Hey, hey, hey, hey!'},
#  {'response': "Lily, this girl hates me. I hooked up with her in an apartment I was pretending was my own, told her I loved her, and then ditched her there. She got arrested for trespassing, bit a cop, and spent eight days in jail. Oh, crap, there she is! If she sees me, she's gonna kll me!",
#   'context/0': "Barney, you're doing this.",
#   'context/1': "Are you nuts? That would involve me speaking to a woman I've already had sx with, which, frankly, is a little t like changing the oil in a rental car.",
#   'context/2': "That woman, like every woman in your Final Four, deserves an apology, and I'm not telling you if she's the one until hear you say, I'm sorry.",
#   'context/3': 'What do you mean no?',
#   'context/4': 'No.'},
#  {'response': 'What?',
#   'context/0': 'Ah, here we go.',
#   'context/1': 'This wedding does sound pretty amazing though. Fancy hotel ballroom, everybody all dressed up.',
#   'context/2': "What I don't get is, why is Claudia marrying Stuart? She's way hotter than him. How way? Way way.",
#   'context/3': 'I need a date to this wedding. Wish me luck',
#   'context/4': "On New Year's Eve, we kissed again. Fact."},
#  {'response': "More than once... Wow, this is... I guess if we... so, technically, there were a number of times I've lied to a woman to sleep with her.",
#   'context/0': 'More than once?',
#   'context/1': "Have I ever... If I'm totally honest... Yes.",
#   'context/2': 'OK Have you ever managed to get in bed with a woman that you lied?',
#   'context/3': "Okay, I did not know. Mea culpa. So, from now, more lies. I never lie to you. I'm serious. Ask me anything.",
#   'context/4': 'Let me clarify something for you. I do not date guys who lie to me.'},
#  {'response': 'Mini golf?',
#   'context/0': "beautiful, smart, funny, huge fan of prewar architecture, favorite poet Neruda, favorite movie Ghostbusters, and she didn't hate Cleveland.",
#   'context/1': 'That night I tried online dating.',
#   'context/2': 'the jealousy, the insecurity, those high-fives would be high-fives of condolence.',
#   'context/3': 'In May of 2012, Marshall and Lily hosted a baby shower in the apartment.',
#   'context/4': 'Later that night...'},
#  {'response': 'They have a big problem.',
#   'context/0': 'There is nothing serious. And certainly nothing serious enough that you hold my hand.',
#   'context/1': 'She makes her dishes right away, Ted. I give them two or three weeks maximum.',
#   'context/2': 'I gotta go.',
#   'context/3': 'No problem.',
#   'context/4': 'Baby, you can wash it?'},
#  {'response': "- Yeah. He's the awesome-est, most best looking-est, greatest guy ever.",
#   'context/0': '- You have a brother?',
#   'context/1': '- Hey!',
#   'context/2': "Yes. And do you know why? Hang on to your bedsores, grandparents from Willy Wonka, because guess who's on his way up to this apartment right now? My... wait for it... brother, James. React.",
#   'context/3': '- No.',
#   'context/4': 'Finally, he decided to bring in reinforcements.'},
#  {'response': "All right, Ted. Imagine the heads of two Irish babies. Let's call them...",
#   'context/0': 'Paint me a word picture.',
#   'context/1': 'Mmmm...',
#   'context/2': 'So these boobs...',
#   'context/3': "C! And that wasn't spanish, that was cup size! What up!",
#   'context/4': "You're talking about her boobs, right?"},
#  {'response': "Well, well, well. How rich. You make me promise to be on my best behavior around your girlfriend, yet, you have been lying to her since day one. Excuse me.Hi. Leg Warehouse? Yeah, my friend Ted needs something to stand on. So, nothing for him to stand on? Okay, and thanks so much. Ted, doesn't Victoria deserve to know that you once had the hots for Robin? I have half a mind to tell the story of the re-return.",
#   'context/0': "Okay, I want to lay down some ground rules for tonight. Barney, I actually like Victoria... a lot, so don't say anything embarrass... Don't say anything. And guys, I haven't exactly told Victoria that I used to have a kind of thing for Robin, so we you could just avoid the...",
#   'context/1': "I'm going to go get another round.",
#   'context/2': "I'm so excited Victoria's coming.",
#   'context/3': 'No. Backgammon sucks. I took the only good part of backgammon, the gammon, and I left the rest of it in the trash where it belongs.',
#   'context/4': 'Backgammon, obviously.'},
#  {'response': 'Owl. How do we go? We will do what? Jump?',
#   'context/0': 'It looks to be a... sacred... spa.',
#   'context/1': 'The terrace of the building next door. A paradise waiting for us behind a pit of 2 or 3 meters. And the best...',
#   'context/2': 'You know who knows how to live? These people.',
#   'context/3': 'Forget it. It really is not class. At best, it sucks.',
#   'context/4': 'I should explain. A few years earlier...'},
#  {'response': "A bit strongly. She's not my girlfriend.",
#   'context/0': "That's putting it a bit strongly.",
#   'context/1': 'Wow, wow, wow, Girlfriend? Hey, come on.',
#   'context/2': "It's okay, dude. I shouldn't go kissing some other guy's girlfriend.",
#   'context/3': "Brad, we can't fight like this all night! We both got some good shots in. Let's call a truce!",
#   'context/4': 'Hey Brad!'},
#  {'response': "I'm gonna head out to a reggae concert. I'm a huge fan of reggae.",
#   'context/0': 'I do.',
#   'context/1': "Yeah, wait, don't tell me you go to yoga here too?",
#   'context/2': "Yeah. Oh, you're Ted's friend from the bar?",
#   'context/3': 'Stacy, right?',
#   'context/4': "I'm sorry."},
#  {'response': 'Basically, it is of Mad Men.',
#   'context/0': "It's great. Drinking at work.",
#   'context/1': 'And then you go up on the roof... and drink beer.',
#   'context/2': 'Sorry, I gotta go.',
#   'context/3': 'Marshall, the teleconference begins soon.',
#   'context/4': 'It works like this: one of us goes into the office the other and said...'}]

# %%
# Select a few specific lines from the dataset, and append them to the selected ones
lines_selected_list.append(['Barney, this is about the building.', 'Come on. This is so about the girl.', 'HIMYM'])
lines_selected_list.append(["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'])
lines_selected_list.append(["I think there's a pretty girl smiling at me there.", 'Hey, this is a chair, but go ahead and drag it.', 'HIMYM'])
lines_selected_list.append(['I love you, man.', 'Me too, buddy.', 'HIMYM'])
lines_selected_list.append(["Not even if she's hot?", "Not even if her mom's hot.", "HIMYM"])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM']]

# %% [markdown]
# ## Sheldon

# %%
temp = load_df(characters[1])
# Out:
# Using custom data configuration default-c73314df1b13186a
# Reusing dataset csv (C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-c73314df1b13186a\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-c73314df1b13186a\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-1cb608e470b09cb3.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-c73314df1b13186a\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-67190f9a5dd10a36.arrow
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-c73314df1b13186a\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-50ba7b187fd844a8.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-c73314df1b13186a\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-8ba2b6ec05e5e394.arrow

# %%
[s for s in temp['test']]
# Out:
# [{'response': 'She called me dumbass.',
#   'context/0': 'Oh, sweetie, Im sorry.',
#   'context/1': 'Leslie Winkle, Penny. She belittles my research.',
#   'context/2': 'Sheldon, come back, youre losing me.',
#   'context/3': 'Do you know, its amazing how many supervillains have advanced degrees. Graduate school should probably do a better job of screening those people out.',
#   'context/4': 'Okay, I get it, I get it, I get it.'},
#  {'response': 'Well never know.',
#   'context/0': 'Oh. Wow. Good job. Okay, um, can you do this?',
#   'context/1': 'I am doing it.',
#   'context/2': 'All right, lets start with a toe touch. Okay, you do it.',
#   'context/3': 'All right.',
#   'context/4': 'Its good to stretch your muscles before you run.'},
#  {'response': 'Oh, you shouldnt have.',
#   'context/0': 'Thanks. And, Sheldon, I know tonights the night you eat Thai food, so I went to the Asian market, got all the ingredients and made it from scratch.',
#   'context/1': 'Ooh, it smells good.',
#   'context/2': 'Hi.',
#   'context/3': 'Hey, guys, come on in.',
#   'context/4': 'No, we wouldnt ask him. Wed just show him the closet and let the goblins in his head take it from there.'},
#  {'response': 'Youre going up Euclid Avenue?',
#   'context/0': 'Too bad.',
#   'context/1': 'Of course not.',
#   'context/2': 'Do you have any alcohol?',
#   'context/3': 'Studies have shown that performing tasks such as eating, talking on a cell phone or drinking coffee while driving reduces ones reaction time by the same factor as an ounce of alcohol.',
#   'context/4': 'What?'},
#  {'response': 'Get rid of the trade route part? Then how would Palpatine get Chancellor Valorum kicked out of office? How would he get himself elected? How? Can we get through one holiday without you saying something ridiculous?',
#   'context/0': 'Okay, so youd lose most of Jar Jar, all the trade route talk and the boring senate hearings, which are like watching C-SPAN with monsters.',
#   'context/1': 'You know, I heard of this way of watching the movies called the Machete Order, where you watch Episodes IV and V, then skip Episode I, watch II and III as a flashback, and then finish with VI.',
#   'context/2': 'Howard, I think you of all people should avoid espousing the principle that if something is not our favourite we should just get rid of it.',
#   'context/3': 'Since we all agree Episode I isnt our favourite, maybe we just skip it this time.',
#   'context/4': 'Ugh, lets get this over with.'},
#  {'response': 'Are you comfortable?',
#   'context/0': 'It was a classic western set in the post-Jurassic period, and it changed my life.',
#   'context/1': 'You shouldve seen us after The Good Dinosaur.',
#   'context/2': 'Wow. Youve been talking about Frozen for an hour?',
#   'context/3': 'Oh, thats what I said an hour ago.',
#   'context/4': 'I just think it gets more credit than it deserves.'},
#  {'response': 'Offer them a hot beverage.',
#   'context/0': 'Sheldon, your friend is hurtin. What do we do when someones hurtin?',
#   'context/1': 'Oh, yes, born alone, die alone. Its a tragic human condition. Now, Raj, if youll excuse my mother, shes about to make a pecan pie thatll be so good Ill almost forget how she blew it with the fried chicken.',
#   'context/2': 'Im so lonely.',
#   'context/3': 'Thats better. Now tell me whats bothering you.',
#   'context/4': 'No.'},
#  {'response': 'If I am permitted to speak again, Dr. Sheldon Cooper for the win.',
#   'context/0': 'Really? Oh, look at that, I have a girlfriend.',
#   'context/1': 'Stephanie Barnett is in a relationship with Leonard Hofstadter.',
#   'context/2': 'Dont even! I dont want to hear another word out of you.',
#   'context/3': 'In which I am not an expert.',
#   'context/4': 'Are you insane? Now shes going to think Im desperate. Youve destroyed this relationship! And you want to know what the worst part is? You dont even understand what you did wrong because you cant conceive of something that you are not an expert in!'},
#  {'response': 'Hmm. What are you doing now?',
#   'context/0': 'Uh, making sure the telescopes camera is white-field balanced.',
#   'context/1': 'What are you doing?',
#   'context/2': 'Hmm, I just have never been in this room while youre awake.',
#   'context/3': 'What?',
#   'context/4': 'Hmm.'},
#  {'response': 'Clarify something for me. Isnt the point of a communal meal the exchange of ideas and opinions? An opportunity to consider important issues of the day?',
#   'context/0': 'Fine.',
#   'context/1': 'I did shut up. Now you shut up.',
#   'context/2': 'Way to go shutting up.',
#   'context/3': 'He never touched my telescope.',
#   'context/4': 'Whoa. Where did that come from?'},
#  {'response': 'Stop yelling! Im not happy about this.',
#   'context/0': 'Irasshaimase!',
#   'context/1': 'Although, I do regret not following up with that specialist in Houston.',
#   'context/2': 'Told you.',
#   'context/3': 'Actually, I had him tested as a child. Doctor says hes fine.',
#   'context/4': 'Sheldon, youre talking like a crazy person.'},
#  {'response': 'Well, they cant cancel it. It ended on a cliffhanger.',
#   'context/0': 'There is no season three. They cancelled that show.',
#   'context/1': 'No, thats the season two finale. That was quite the cliffhanger. Im going to re-watch it before season three starts.',
#   'context/2': 'You know, if youre trying to make space on the DVR, why dont you just get rid of some of the stuff youve already watched? Like, um, Alphas.',
#   'context/3': 'Well, hang on. Maybe the Chinese havent finished watching it yet.',
#   'context/4': 'Im deleting it.'},
#  {'response': 'Just to be clear here, youre asking for my assistance.',
#   'context/0': 'Sheldon, wait! Will you?',
#   'context/1': 'Of course I could.',
#   'context/2': 'Sheldon, hold on. Could you maybe show me how to make more money with this?',
#   'context/3': 'I have a working knowledge of the important things in the universe. Good luck.',
#   'context/4': 'Whos Radiohead?'},
#  {'response': 'April 13, a dark night, indeed.',
#   'context/0': 'Well, the last time you made an unscheduled video-chat, there was a curly fry in your regular fries and you thought someone might be trying to slip you a mickey.',
#   'context/1': 'Yes. Why?',
#   'context/2': 'Hello, Sheldon. Is everything okay?',
#   'context/3': 'I am, Im really proud.',
#   'context/4': 'You sound kind of proud of it.'},
#  {'response': 'All right, now Im starting to sense a little tension.',
#   'context/0': 'Hello to you, you wrinkled old bastard.',
#   'context/1': 'Hello, my hateful shrew.',
#   'context/2': 'And, of course, Mom.',
#   'context/3': 'Hi.',
#   'context/4': 'A pleasure.'},
#  {'response': 'Fine. Bad.',
#   'context/0': 'No.',
#   'context/1': 'Bad. However',
#   'context/2': 'Giving Mrs. Davis the box set of Roots was?',
#   'context/3': 'Glad.',
#   'context/4': 'The fact that there are so many people here tonight doesnt make us cranky and claustrophobic. It makes us?'},
#  {'response': 'Thank you. I wouldnt even know how to begin.',
#   'context/0': 'Thats me, your emotional outhouse. You know, if you ever decide you want to do something about this, Im, Im here for you.',
#   'context/1': 'What good is having a girlfriend if you cant unload your psychological sewage on her?',
#   'context/2': 'Thank you for trusting me.',
#   'context/3': 'Only you.',
#   'context/4': 'So, no one else knows about this?'},
#  {'response': 'Well, I know it was your idea, but the reporter said hes been following my work for a while, and the only reason they even mentioned it in the magazine is cause my name is on it.',
#   'context/0': 'You know, for an extra four bucks, I can have this thing here tomorrow.',
#   'context/1': 'Why did he think youre the lead scientist? It was my idea.',
#   'context/2': 'He said they made the editorial decision to only cite the lead scientist.',
#   'context/3': 'Thank you. What did he say?',
#   'context/4': 'I did.'},
#  {'response': 'How is it sexist? My character wields a battle axe as well as any man.',
#   'context/0': 'Guys, our topic is encouraging women in science, can you at least play a less sexist game',
#   'context/1': 'No, youre a tool I was using to make my point.',
#   'context/2': 'So, you think Im one of the smarter kids?',
#   'context/3': 'Were not. This time youre the smart kid doing all the work while the even smarter kids sit back and watch.',
#   'context/4': 'Guys, please dont make this a school project where Im the smart kid doing all the work while the slackers sit back and watch.'},
#  {'response': 'I wouldnt say amazing. At best, its a modest leap forward from the basic technology that gave us Country Bear Jamboree.',
#   'context/0': 'Oh ha-ha, oh. Thats amazing.',
#   'context/1': 'Okay, here we go. Passing the soy sauce. Put out your hand.',
#   'context/2': 'I thought you broke up with her. Why is she here?',
#   'context/3': 'Really? Theyre going to make a robot that spits on your hamburger?',
#   'context/4': 'You realize, Penny, that the technology that went into this arm will one day make unskilled food servers such as yourself obsolete.'},
#  {'response': 'I know what your point is. Youre intimidated by Amys intellect. To that I say, buck up.',
#   'context/0': 'Yeah, not my point.',
#   'context/1': 'Oh, I never identified with the rebel alliance. Despite their tendency to build Death Stars, Ive always been more of an empire man.',
#   'context/2': 'Uh-huh. Anyway, Im not sure shes the best fit for our little, how should we call it, rebel alliance.',
#   'context/3': 'Although, for the record, on one occasion, she licked her thumb to remove raspberry jelly from the corner of my mouth. Its an action we both regret to this day.',
#   'context/4': 'Got it.'},
#  {'response': 'Okay. Do you think your fathers doing unspeakable things to my mother?',
#   'context/0': 'Go to sleep.',
#   'context/1': 'I hope youre right. Cause a grown man living with his brother and his brothers wife is weird.',
#   'context/2': 'Were not gonna be brothers. Were not gonna be stepbrothers. Go to sleep.',
#   'context/3': 'You realize you and I could become brothers.',
#   'context/4': 'What?'},
#  {'response': 'I have no idea. Because the story of me sewing the first American flag is unsupported poppycock.',
#   'context/0': 'Say, Betsy Ross, what you working on?',
#   'context/1': 'Fwag, fwag, not a fwag, fwag, I am cwushing this.',
#   'context/2': 'And now its time for the speed round of Flag or Not a Flag.',
#   'context/3': 'Australia, mate.',
#   'context/4': 'Crikey, what flag do we have today?'},
#  {'response': 'Fair enough. What stake do you propose?',
#   'context/0': 'Okay, I believe a chicken made you his bitch. But the cricket thing, I dont buy. Bet me.',
#   'context/1': 'Thank God.',
#   'context/2': 'Chickens cant climb trees',
#   'context/3': 'Ive always found that an inappropriate slur. Chickens are not, by nature, at all timid. In fact, when I was young, my neighbours chicken got loose and chased me up the big elm tree in front of our house.',
#   'context/4': 'Whats the matter, you chicken?'},
#  {'response': 'No, of course not.',
#   'context/0': 'And you want me to kill her? Done.',
#   'context/1': 'Priya has essentially nullified my roommate agreement with Leonard, making life in the apartment very uncomfortable for me.',
#   'context/2': 'Of course. Whats rattling around that big bulbous brain of yours?',
#   'context/3': 'Thank you. May I share something with you thats troubling me?',
#   'context/4': 'Yeah. Hes kind of an ass.'},
#  {'response': 'Well, right now, Pennys imagination is running wild, but if they meet, that will eliminate the mystery and alleviate her fears. Like when that Sparkletts guy let me look under his eye patch.',
#   'context/0': 'What? Why?',
#   'context/1': 'Bring Penny to meet Mandy.',
#   'context/2': 'Wake up, wake up, wake up.',
#   'context/3': 'Now, forgive me for eavesdropping, but as I see it, theres a simple solution.',
#   'context/4': 'Okay, look, I might be overreacting, but how am I supposed to get past this when I know tomorrow youre gonna go to work and see this woman?'},
#  {'response': 'You know, a number of significant innovations have been inspired by science fiction. The, the geosynchronous satellite from Arthur C. Clarke. The Motorola flip phone, that came from Star Trek. And Ive long suspected that the idea of an African-American president was stolen from the movie Deep Impact.',
#   'context/0': 'You know, lets just come up with something new.',
#   'context/1': 'No, it vibrates. Keep going.',
#   'context/2': 'Okay, lets just skip all the inventions you can have sex with. All right, no, here we go, ergonomic heated seat cushion.',
#   'context/3': 'Boy, when you met Bernadette, the field of robotics really took a hit.',
#   'context/4': 'Theres just some things you dont do with your robot girlfriend.'},
#  {'response': 'Because Im trying to decide between getting an Xbox One or a PS4. Oh, pee, whyd I say that?',
#   'context/0': 'Why not?',
#   'context/1': 'I cant.',
#   'context/2': 'So go to the bathroom.',
#   'context/3': 'Seriously. I feel like Ive got a fish tank in my pelvis.',
#   'context/4': 'If only there were a solution to that.'},
#  {'response': 'Thats exactly what my father said. Come to the games, watch the games, week in and week out from the time I was five until I went off to college. Longest seven years of my life.',
#   'context/0': 'Come on, Sheldon, please teach me about football. Itll be fun.',
#   'context/1': 'If you want to blend in with Pennys friends, Id think looking like an idiot would be the perfect camouflage.',
#   'context/2': 'Football. Im going to Pennys on Saturday to watch a game with her friends and I dont want to look like an idiot. I want to blend in.',
#   'context/3': 'Football or chicken-fried meats?',
#   'context/4': 'So you could teach me?'},
#  {'response': 'Leonard, are you in the shower?',
#   'context/0': 'Youre pregnant?',
#   'context/1': 'Yes, not important. Just stopped by to let you know Im getting orthotics. Also, Im carrying Sheldons baby. Mums the word.',
#   'context/2': 'Oh, hey, Amy. Bernadette just texted me. Howard proposed?',
#   'context/3': 'Thats great.',
#   'context/4': 'As good an explanation as any.'},
#  {'response': 'Or the first door closing causes a change of air pressure that acts upon the second door.',
#   'context/0': 'No, no, I meant',
#   'context/1': 'No it doesnt. Not unless the two doors are connected by relays, or there are motion sensors involved.',
#   'context/2': 'Well, maybe its all for the best, you know I always say, when one door closes, another one opens.',
#   'context/3': 'Theoretical physicists do not get canned. But yeah.',
#   'context/4': 'So you got canned, huh?'},
#  {'response': 'Oh! I dont usually pick up on those things. Good for me.',
#   'context/0': 'Yes Im upset.',
#   'context/1': 'Well, it was a number of things. First the late hour, then your demeanour seems very low energy, plus your irritability',
#   'context/2': 'What was your first clue?',
#   'context/3': 'Are you upset about something?',
#   'context/4': 'But it would make the present so much nicer.'},
#  {'response': 'Not Sunday, I love Sunday.',
#   'context/0': 'Sundays gone.',
#   'context/1': 'Oh, Sundays the worst. Everybodys leaving, most of the good panels are over, and the only T-shirts they have left are small and XXXXL.',
#   'context/2': 'Oh, Thursdays gone. Just Sunday left.',
#   'context/3': 'Really?',
#   'context/4': 'Oh, they only have Thursday and Sunday passes left.'},
#  {'response': 'Oh, God, now even youre smarter than me.',
#   'context/0': 'Antonio Salieri?',
#   'context/1': 'Fifteen years old. Dennis Kim is fifteen years old, and hes already correcting my work. Today I went from being Wolfgang Amadeus Mozart to you know, that other guy.',
#   'context/2': 'Something youd like to share? A tale of woe perhaps.',
#   'context/3': 'Uh-uh-uh.',
#   'context/4': 'Sure. Raj, hug Howard.'},
#  {'response': 'Hardly. Fear of heights is illogical. Fear of falling, on the other hand, is prudent and evolutionary. What would you say is the minimum altitude I need to achieve to cement our new-found friendship?',
#   'context/0': 'You afwaid of heights, Cooper?',
#   'context/1': 'This appears significantly more monolithic than it did on my laptop. No, one expects to see Hominids learning to use bones as weapeons.',
#   'context/2': 'Nope, I wanna climb some wocks.',
#   'context/3': 'You know, I am a fan of ventriloquism. Maybe you, me and your dummy could go get a hot beverage. He could talk while you drink.',
#   'context/4': 'Alright Kripke, that last interest strikes me as the least objectionable and I would like to propose that we do that together. Tomorrow. Yes, Ill pay. Alright, goodbye. Alright! Time to learn rock climbing.'},
#  {'response': 'Whos in the mood to laugh?',
#   'context/0': 'No, forget it. I take it back. Offers off the table.',
#   'context/1': 'That is not what I said.',
#   'context/2': 'Okay, so, so you dont want to marry me?',
#   'context/3': 'Look, you know I love you but, but youre, youre drunk and sad and feeling lost.',
#   'context/4': 'Did you seriously just say um?'},
#  {'response': 'Frankly, Mom, Im encouraged to see how advanced your group has become, willing to sail out into the ocean without fear of falling off the edge.',
#   'context/0': 'Oh, it is a hoot and a half. You write your sins on a clay pigeon, they fire em up in the air, and you pulverize them with a 12-gauge shotgun full of our Lords forgiveness.',
#   'context/1': 'Whats Gunning with God? Im afraid to ask.',
#   'context/2': 'Youre missing out. Its gonna be wall-to-wall fun. Its all themed. Theres Jonah and the Whale Watching, all-you-can-eat Last Supper Buffet, and my personal favourite, Gunning with God.',
#   'context/3': 'Well, Mom, if I did, it would be conclusive proof that your God can work miracles.',
#   'context/4': 'Its called the Born Again Boat Ride. Christian Quarterly gave it their highest rating, five thorny crowns. I do wish youd come with me, Sheldon.'},
#  {'response': 'You know, I dont want to tell you how to do your job, but when a mouse completes a maze, it gets a food pellet.',
#   'context/0': '33 seconds. Okay, thatll be our baseline.',
#   'context/1': 'Done.',
#   'context/2': 'Okay, well do it.',
#   'context/3': 'Well, I suppose',
#   'context/4': 'Hold on. Whats in it for us?'},
#  {'response': 'Okay. Ill give it a shot.',
#   'context/0': 'I said, get out.',
#   'context/1': 'Well, I have to tell you that while I do have a theoretical understanding of the workings of an internal combustion engine, Im not sure Im capable of performing diagnostics.',
#   'context/2': 'Get out.',
#   'context/3': 'All right. Hmm, huh, Im sorry, Im finding your reckless nonchalance regarding the check-engine light to be very troubling.',
#   'context/4': 'How about we just have a little quiet time now?'},
#  {'response': 'Oh, no, I got bored with that. Im just browsing cuticle scissors on Amazon.',
#   'context/0': 'Its actually steamier than it looks. Sheldons looking up the phallic symbolism of root vegetables in Renaissance paintings.',
#   'context/1': 'Awkward silence, Sheldon on his phone, no touching. Somebodys having date night.',
#   'context/2': 'Although, technically, Indy was supposed to take the ark to a museum to be studied. He couldnt even get that done.',
#   'context/3': 'Yeah!',
#   'context/4': 'Like a hero.'},
#  {'response': 'Whos he?',
#   'context/0': 'Okay. How bout a little Miley Cyrus next?',
#   'context/1': 'Then Ill look from the door of my heavenly home, and pity the miner that mines my poor bones.',
#   'context/2': 'Getting kind of grim.',
#   'context/3': 'Well, I pray when Im dead and the ages shall roll, that my body will blacken and turn into coal.',
#   'context/4': 'Its a little more bleak than I thought.'},
#  {'response': 'He also has a remarkable amount of credit card debt.',
#   'context/0': 'Wait, wait, not shopping for clothes, right? Because look.',
#   'context/1': 'Well, his rent and car lease are exceedingly high. You couple that with his penchant for dining out and shopping.',
#   'context/2': 'Well, he has a job. How bad can it be?',
#   'context/3': 'Were helping Raj figure out his finances.',
#   'context/4': 'Oh, let me guess. You guys are drafting your fantasy accounting firms.'},
#  {'response': 'I wasnt referring to this evening. Ten years ago, upon first seeing me, your husband claimed that I looked like C-3PO and Pee-wee Herman. And he called me C-3P-wee Herman.',
#   'context/0': 'I didnt do anything. I was just sitting here.',
#   'context/1': 'Well, with that sorted out, Im happy to answer your question, Bernadette. Howard started it.',
#   'context/2': 'No, no, no. This is not a fight. I was just excited that someone offered you a part and a little surprised that youd rather sit at home and do nothing than take it. Now its a fight.',
#   'context/3': 'I think were gonna go.',
#   'context/4': 'Oh, Im sure he does it out of love. The same way my boyfriend makes me feel terrible about my life choices.'},
#  {'response': 'Well, wait. What if, just this once, we suspend the date night parameters and you stay later?',
#   'context/0': 'Come on, Ill help you take this down.',
#   'context/1': 'Well, of course we do. Fort Knox doesnt have a secret physics lending library.',
#   'context/2': 'We both know this ones gonna win.',
#   'context/3': 'Wait, no. We havent picked a winner.',
#   'context/4': 'And McBlanket over Sumter cause it has a higher thread count. Oh. Ten oclock. Date nights over.'},
#  {'response': 'Danger, danger.',
#   'context/0': 'That girl needs to get a life.',
#   'context/1': 'Right, gimme, gimme, gimme, I want to kill the guard captain. .',
#   'context/2': 'There you go, one enchanted sword.',
#   'context/3': 'No, thats Marcie. Peppermint Pattys just athletic.',
#   'context/4': 'I always thought Peppermint Patty was a lesbian?'},
#  {'response': 'The fun starts with brunch at Carneys in Studio City, a hot dog stand in a converted railroad dining car. Next stop, Travel Town, an outdoor museum featuring 43 railroad engines, cars and other rolling stock from the 1880s to the 1930s. Finally, were off to the glitz and glamour of Hollywood for dinner at, thats right, the Hollywood Carneys, a hot dog stand in a different converted railroad dining car.',
#   'context/0': 'Train day?',
#   'context/1': 'I always tell people, if you have only one day in Los Angeles, make it a train day.',
#   'context/2': 'Oh, not really, just hang out.',
#   'context/3': 'So, you got any special plans with your sister?',
#   'context/4': 'Whoa-whoa-whoa-whoa-whoa.  Okay.'},
#  {'response': 'Youre just misappropriating my understanding.',
#   'context/0': 'Well, I understand, too.',
#   'context/1': 'No, he doesnt understand. I understand.',
#   'context/2': 'Im so glad you understand.',
#   'context/3': 'Well, who wants to stay in a hotel? With windows that dont open, those crazy card-shaped keys.',
#   'context/4': 'Thank you so much for opening up your home to me.'},
#  {'response': 'Leonard will be here in a moment. Hes looking for a different parking space.',
#   'context/0': 'Needy Baby, Greedy Baby indeed.',
#   'context/1': 'Fine.',
#   'context/2': 'Its not about you. Its about a poor immigrant from Pakistan trying to make his way in America by working the graveyard shift at the Colorado Boulevard Chevron.',
#   'context/3': 'I dont want beef jerky.',
#   'context/4': 'Heres two dollars. Go buy some beef jerky.'},
#  {'response': 'Oh, no, the new ones, theyre here.',
#   'context/0': 'I guess I wont be needing this.',
#   'context/1': 'Hey, Penny, its Leonard. Good news, you can take your head out of the oven.',
#   'context/2': 'Fine, Ill stay! You happy, crazy lady? I sure as hell hope so, because youre ruining my life!',
#   'context/3': 'Little bird? Youre almost 30, fly, for gods sake!',
#   'context/4': 'Okay, I get it, youre angry. You dont want to see your little bird leave the nest.'},
#  {'response': 'You know, exactly. Weve never thrown a brunch before, and I wanted to work out all the kinks.',
#   'context/0': 'Uh, no. He, he just means that you were the first people we thought of.',
#   'context/1': 'Practice round? For-for what?',
#   'context/2': 'This is it. You are the practice round.',
#   'context/3': 'Really, no one else is coming?',
#   'context/4': 'My sisters husband took all her things, too. Story at eleven.'},
#  {'response': 'Cathedra mea, regulae meae. Thats Latin for my chair, my rules. Now, you said on the phone that your area of study is physics.',
#   'context/0': 'Can you do that?',
#   'context/1': 'This seat is ideally located both in relation to the heat source in the winter and a cross breeze in the summer. It also faces the television at a direct angle allowing me to immerse myself in entertainment or game play without being subjected to conversation. As a result, Ive placed it in a state of eternal dibs.',
#   'context/2': 'Whats the difference?',
#   'context/3': 'No! Thats where I sit!',
#   'context/4': 'Okay.'},
#  {'response': 'Oh, no, he broke my collarbone. I can still hear it click.',
#   'context/0': 'Did it work?',
#   'context/1': 'Oh, certainly. Uh, when I was eight years old, Billy Sparks cornered me in the playground. I asked myself what would Spock do? Then I grabbed Billy on his shoulder and performed my first Vulcan nerve pinch.',
#   'context/2': 'What about from when you were a kid?',
#   'context/3': 'I knew I could smell em.',
#   'context/4': 'Yes. Oh, for example, three years ago when I discovered Penny was eating all my Pop-Tarts, instead of getting angry or vindictive, you know, I got a floor safe.'},
#  {'response': 'He cant kill me, even if I turn.',
#   'context/0': 'Yeah. We also put in what happens if one of us wins a MacArthur Grant, or if one of us gets superpowers, or if one of us is bitten by a zombie.',
#   'context/1': 'You actually put that in an agreement?',
#   'context/2': 'Oh, for Gods sakes.',
#   'context/3': 'Indeed, the roommate agreement. I call your attention to the Friendship Rider in Appendix C, Future Commitments. Number 37, in the event one friend is ever invited to visit the Large Hadron Collider, now under construction in Switzerland, he shall invite the other friend to accompany him.',
#   'context/4': 'Not the roommate agreement.'},
#  {'response': 'Thats just wrong.',
#   'context/0': 'Penny.',
#   'context/1': 'Please try to wear something appropriate. It wont help my case if the judge is busy trying to read the word Juicy scrawled across your buttocks.',
#   'context/2': 'Oh, balls.',
#   'context/3': 'Raj? Youll be there, wont you?  All right, then, my so-called friends have forsaken me. So, I guess itll just be me and my eyewitness.',
#   'context/4': 'Wow. Uh, Stan Lee, or you in court? Uh, if this was Sophies Choice it wouldve been a much shorter movie. No.'},
#  {'response': 'Howards allergic to peanuts. How can I use that against him?',
#   'context/0': 'Yeah.',
#   'context/1': 'Leonard?',
#   'context/2': 'Might be something to think about.',
#   'context/3': 'Interesting point. Youre suggesting that I have emotional issues below my consciousness which drive my behaviour, thus causing me to lash out at anything or anyone that threatens my intellectual superiority.',
#   'context/4': 'You want to know what I think? I think the idea that someone could be as smart as you, or even smarter, scares the pants off you, and you cant deal with it.'},
#  {'response': 'Why would she keep something from me, you know? I shared my body with that woman. And my Netflix password. They recommended Stella Got Her Groove Back because of her.',
#   'context/0': 'You heard him, guys, dont ask.',
#   'context/1': 'Well, whatever it is, its troubling me. And I cant eat, I cant sleep. And dont even ask about the consistency of my bowel movements.',
#   'context/2': 'I wouldnt worry about it. Shes probably just distracted by work.',
#   'context/3': 'Her behaviour. No, I have the feeling that shes hiding something.',
#   'context/4': 'Oh. Well, just out of curiosity, what registers as odd to you?'},
#  {'response': 'So trick her.',
#   'context/0': 'Instead of dwelling on the negative, think about this. Your girlfriend was given an amazing opportunity, which gives you an opportunity to show her that youre a loving and supportive boyfriend.',
#   'context/1': 'No, but that list was sounding a little thin.',
#   'context/2': 'Do you really care about that last one?',
#   'context/3': 'Am I? Yesterday I had an Air Force project, a girlfriend who lived with me, and my good friend Raj right across the hall.',
#   'context/4': 'Sheldon, youre being silly.'},
#  {'response': 'Even the girls.',
#   'context/0': 'All of them?',
#   'context/1': 'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'context/2': 'Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'context/3': 'Perhaps I should explain. While working with Koothrappali, we discovered an asteroid, and I named it after you.',
#   'context/4': 'Uh, please tell me what to say next.'},
#  {'response': 'That would be acceptable. On Mondays, I eat Thai food. Mee krob and chicken sate with extra peanut sauce from Siam Palace.',
#   'context/0': 'What if I brought food to your place?',
#   'context/1': 'Three tines is not a fork, three tines is a trident. Forks are for eating, tridents are for ruling the seven seas.',
#   'context/2': 'Sheldon lives in fear of the three-tined fork.',
#   'context/3': 'Excuse me?',
#   'context/4': 'I never eat in strange restaurants. One runs the risk of non-standard cutlery.'},
#  {'response': 'Hello, Amy. Its nice to see you.',
#   'context/0': 'Okay. I dont get it, you said make an effort, here I am making an effort.',
#   'context/1': 'Okay. Leonard, I really appreciate that, but I need a little time to myself.',
#   'context/2': 'I came here to apologize.',
#   'context/3': 'What are you doing here?',
#   'context/4': 'Hey.'},
#  {'response': 'I think the same thing that appeals to people everywhere, the dream of a cold, rational world entirely without human emotion. Spock came from a planet governed only by logic. You know, on Vulcan, when your brother asks, why are you hitting yourself? the answer is, Im not. Youre moving my arm. To which he says, Fascinating. And then you both watch educational television.',
#   'context/0': 'What was it about Spock that appealed to you?',
#   'context/1': 'The first episode of Star Trek: The Original Series I ever saw was The Galileo Seven. Uh, Spock had just landed on the planet Taurus II. Then my brother came in, sat on my head, and said eat farts. After that day, I was hooked. On Star Trek, not my brothers sphincter-based cuisine.',
#   'context/2': 'And what is your earliest memory of the character Spock?',
#   'context/3': 'Dr. Sheldon Cooper, theoretical physicist, Caltech.',
#   'context/4': 'Lets start with your name and occupation.'},
#  {'response': 'Like what?',
#   'context/0': 'Cancel my next appointment. This is gonna take a while. Dr. Cooper, you said things to your employee that you just cannot say in the workplace.',
#   'context/1': 'So Ive been told. But I cant understand what she has to complain about. I mean, she has a front-row seat as I make scientific history. Theres string cheese in my mini-fridge, and thats for anyone. Yeah, and just yesterday I led her away from a life of sexual promiscuity by making her look at pictures of disease-ridden genitalia.',
#   'context/2': 'I called you in today because your assistant Alex Jensen has lodged a complaint against you.',
#   'context/3': 'Thank you.',
#   'context/4': 'Ah, Dr. Cooper, have a seat.'},
#  {'response': 'Oh yes, like the male peacock with brilliant plumage or the rutting baboon with engorged hindquarters.',
#   'context/0': 'Noticed the eye patch, did you? Its all part of a technique Ive been studying for picking up women. You employ a visual display designed to make yourself distinctive and memorable.',
#   'context/1': 'Ahoy, matey.',
#   'context/2': 'Hello, boys.',
#   'context/3': 'Rock-paper-scissors- lizard-Spock!  Oh!',
#   'context/4': 'Okay, I think I got it.'},
#  {'response': 'Youre overestimating the tensile strength of the substructure youre building.',
#   'context/0': 'Hang on, I think Ive got this. Help me see if we can wedge this little piece of PVC behind the support rod.',
#   'context/1': 'If you really want to clean up your karma, go get my freakin latte.',
#   'context/2': 'Look, Leonard, what goes on between me and Stuart is none of your business. So just leave it alone, okay?',
#   'context/3': 'Okay I just I kind of',
#   'context/4': 'I said I dont want to talk about it.'},
#  {'response': 'And then Leonard took me to the barber and the dentist, and then to cap off the perfect day, the Los Angeles Bureau of Weights and Measures.',
#   'context/0': 'Uh, it wasnt anything weird. It was just to see how big they were.',
#   'context/1': 'Thank you.',
#   'context/2': 'I suppose so.',
#   'context/3': 'Okay.',
#   'context/4': 'So, can we please put aside these petty differences and just be glad were here together?'},
#  {'response': 'Fine. Leonard made me soup, and I was mean to him. Hey, I felt a little something. Let me try again. Leonard made me soup, and I was mean to him. I was mean to him. He must have felt terrible. Oh, now I feel terrible. Neat.',
#   'context/0': 'Great. Now try it as if this isnt your first day as a person.',
#   'context/1': 'I have empathy. Watch. Leonard made me soup, and I was mean to him.',
#   'context/2': 'Maybe you could try apologizing because you actually feel bad. Its called empathy. Its something you could work on.',
#   'context/3': 'Fine, if thats what it takes to go on their dumb trip.',
#   'context/4': 'Sheldon, I understand that youre upset because you feel left out, but I dont know why were even talking about this. Just apologize to them.'},
#  {'response': 'Try and stop me.',
#   'context/0': 'Sheldon, you cant go back there.',
#   'context/1': 'A little tremor that turns routine sinus surgery into a frontal lobotomy. Oh, I dont care for this at all. Oh, I need to see hes okay.',
#   'context/2': 'Sheldon, it was just a little tremor.',
#   'context/3': 'And Im not? Its an earthquake. I knew it.',
#   'context/4': 'Obviously, I care about Leonard. Im gonna spend the rest of my life with him.'},
#  {'response': 'Hes a snowy tree cricket, and his name is Jiminy.',
#   'context/0': 'All right. Tell you what, lets go down to the Entomology Department and let Professor',
#   'context/1': 'We havent established that Im wrong once.',
#   'context/2': 'Yeah, fine, whatever. The point is, youre wrong again.',
#   'context/3': 'Forgive me. Yiddish was not spoken in east Texas. And if it was, it wasnt spoken for long.',
#   'context/4': 'Shiksa. Shik-sa.'},
#  {'response': 'Its Oatmeal Day.',
#   'context/0': 'All right, want some French toast?',
#   'context/1': 'The math would suggest that in a few Im a clown made of candy. But I dont dance.',
#   'context/2': 'Are you fun in any of them?',
#   'context/3': 'Penny, while I subscribe to the many worlds theory which posits the existence of an infinite number of Sheldons in an infinite number of universes, I assure you that in none of them am I dancing.',
#   'context/4': 'Why not?'},
#  {'response': 'All I know is you can only fit one of her in a car. And theres the clown that came out of her. I really didnt want to come here, but this is shaping up to be one of the best Thanksgivings Ive had in a long time.',
#   'context/0': 'I dont know whats scarier, the bathroom clowns or the woman that put them there.',
#   'context/1': 'Did somebody say pie?',
#   'context/2': 'That is not what I expected when you said you were gonna burp pie.',
#   'context/3': 'Know what they say, happy wife, happy life. Lets eat.',
#   'context/4': 'Im about to. Sign the paper.'},
#  {'response': 'All right, Ill bow to social pressure. Hey!',
#   'context/0': 'Hey.',
#   'context/1': 'Hey.',
#   'context/2': 'Hey, guys.',
#   'context/3': 'Its not a home. Its a senior centre. Wed never put Meemaw in a home!',
#   'context/4': 'Fine. If I dont meet someone soon, you can put me in a home.'},
#  {'response': 'Hello.',
#   'context/0': 'Hey.',
#   'context/1': 'Amy.',
#   'context/2': 'Gentlemen.',
#   'context/3': 'Uh, it also wouldnt have happened if, in the early universe, hydrogen was a little more common or a little less common. This is fun. Your turn.',
#   'context/4': 'I mean, you know, Sheldon, none of this wouldve happened if I hadnt tried to help you.'},
#  {'response': 'Just the hits.  Where its dark as a dungeon, and its damp as the dew.',
#   'context/0': 'Do you know any mining songs?',
#   'context/1': 'Miners often sang mining songs to keep their spirits up.',
#   'context/2': 'Lets set up the equipment. Itll help take your mind off of it.',
#   'context/3': 'Good. Little claustrophobic.',
#   'context/4': 'How you feeling?'},
#  {'response': 'You are ignoring the square-cube law. The giant ant would be crushed under the weight of its own exoskeleton. And for the record, the appropriate ranking of cool modes of transportation is jet pack, hoverboard, transporter, Batmobile, and then giant ant.',
#   'context/0': 'Sheldon says impossible. Howard and I say not only possible, but as a mode of transportation, way cooler than a Batmobile.',
#   'context/1': 'Hey, Leonard, where do you come down on giant ants?',
#   'context/2': 'Good night.',
#   'context/3': 'Okay, good night, sweetie.',
#   'context/4': 'Yeah, probably.'},
#  {'response': 'Oh. Remember when we got this at Comic-Con?',
#   'context/0': 'Yeah, let him do it.',
#   'context/1': 'Howard just did that.',
#   'context/2': 'Then Ill check the batteries in the smoke detectors.',
#   'context/3': 'I did that, too.',
#   'context/4': 'Okay, then Ill dust.'},
#  {'response': 'Did you get the part?',
#   'context/0': 'Oh, yeah, yeah. Its real great. Today I drove to Van Nuys for an audition I thought was going to be for a cat food commercial. Turned out to be porn.',
#   'context/1': 'So, Penny, Leonard tells me youre an actress. That must be pretty exciting.',
#   'context/2': 'Oh, who are you kidding? Shes breathtaking.',
#   'context/3': 'Im fine.',
#   'context/4': 'So, how you holding up?'},
#  {'response': 'Need you ask? But I still dont understand why no-one else bid.',
#   'context/0': 'A time share time machine? Im in. Sheldon?',
#   'context/1': 'Why dont we share it? Well each put in two hundred bucks and well take turns having it in our homes.',
#   'context/2': 'Yeah, I know, I still cant afford it.',
#   'context/3': 'I wonder why no-one else bid, this is a classic piece of sci-fi movie memorabilia.',
#   'context/4': 'You lucky duck.'},
#  {'response': 'These are my own bowling shoes.',
#   'context/0': 'I thought you were bringing your own bowling shoes.',
#   'context/1': 'Please reserve that butch spirit for the lanes.',
#   'context/2': 'Bite me!',
#   'context/3': 'Pacific Daylight time!',
#   'context/4': 'Got it.'},
#  {'response': 'Dont stop. Yes, keep going. Just like that.',
#   'context/0': 'And the home of the brave.',
#   'context/1': 'There he is.',
#   'context/2': 'Oh, yeah.',
#   'context/3': 'And a complete sucker.',
#   'context/4': 'Im proud of you, Sheldon.'},
#  {'response': 'Leonard takes Los Robles Avenue.',
#   'context/0': 'Mm-hmm.',
#   'context/1': 'Youre going up Euclid Avenue?',
#   'context/2': 'Too bad.',
#   'context/3': 'Of course not.',
#   'context/4': 'Do you have any alcohol?'},
#  {'response': 'Amy, its Pennys turn. Penny?',
#   'context/0': 'Are you in the lanthanoid series?',
#   'context/1': 'No.',
#   'context/2': 'Are you usually radioactive when found in nature?',
#   'context/3': 'No. Amy?',
#   'context/4': 'Are you an element in the actinoid series?'},
#  {'response': 'A tad asymmetrical, but nothing to be concerned about.',
#   'context/0': 'So, what do you think?',
#   'context/1': 'More.',
#   'context/2': 'Keep going.',
#   'context/3': 'Disagree.',
#   'context/4': 'Okay, thats enough.'},
#  {'response': 'Leonard, social protocol states when a friend is upset, you offer them a hot beverage, such as tea.',
#   'context/0': 'No.',
#   'context/1': 'Did you offer him a hot beverage?',
#   'context/2': 'Howards gonna sleep here tonight. He had a fight with his mother.',
#   'context/3': 'Whats going on?',
#   'context/4': 'No, we agreed they all have their merits. This was about Bernadette.'},
#  {'response': 'Doesnt like games. Thats one.',
#   'context/0': 'Can we not play this game?',
#   'context/1': 'Thats not a problem, we can figure this out. What are the reasons women reject Raj?',
#   'context/2': 'I dont know, she didnt even give me a reason.',
#   'context/3': 'I thought things were going well. What happened?',
#   'context/4': 'She said she didnt want to see me any more and I found that insulting.'},
#  {'response': 'What are you doing? Two fifty is already the discounted price.',
#   'context/0': 'Slow down. Two hundred.',
#   'context/1': 'Oh, did you hear that? Were getting the friends and family discount. We are honoured and we will take it.',
#   'context/2': 'Are you kidding? Im already giving you the friends and family discount.',
#   'context/3': 'Hang on. Can you do any better?',
#   'context/4': 'Only 8,000? Were wasting precious time. Buy it.'},
#  {'response': 'All right. Look, now, this may be the rum talking, but as long as the unpinning rate of the vortices is kept within 1.1 and 1.3, the Magnus force issue should be negligible.',
#   'context/0': 'Can you focus on what were talking about?',
#   'context/1': 'This video. The baby panda sneezes, and the mama panda gets so scared.',
#   'context/2': 'Damn. What is it?',
#   'context/3': 'Oh, wait, I found something.',
#   'context/4': 'Its a good sign.'},
#  {'response': 'And now you know as much about him as I do.',
#   'context/0': 'Oh, oh, I have a receipt from a blood bank. Im O-negative.',
#   'context/1': 'Thats true, but had I done something under the line, there wouldnt be a man in your kitchen who cant produce a single form of ID.',
#   'context/2': 'All right, Sheldon, this is over the line.',
#   'context/3': 'Anyway, Ill leave you be. I have to, oh, oh, hes expecting a newspaper in the morning. Apparently, they still make them.',
#   'context/4': 'Its like the 40s again.'},
#  {'response': 'Really? Cause every time I come in here, I think less of me.',
#   'context/0': 'I dont.',
#   'context/1': 'It ends with dinosaurs. Im sorry if you think less of me.',
#   'context/2': 'Okay. I get it. I get it.',
#   'context/3': 'Id like to say its nostalgia, but every time I think of throwing anything away, my ears start to ring, and I get butterflies in my stomach. And then it feels like the butterflies get eaten by rats, and then the, the rats get eaten by',
#   'context/4': 'So, why do you feel you need to save these things?'},
#  {'response': 'All right, theres no need to bark at me. According to the inexplicably irritable nurse behind the desk, youll be seen after the man who claims to be having a heart attack, but appears to be well enough to play Doodle Jump on his iPhone. We have to fill these out. Describe illness or injury.',
#   'context/0': 'Okay.',
#   'context/1': 'Me too. Check and see if we have any more pudding.',
#   'context/2': 'Oh, god, I am so hungry.',
#   'context/3': 'I know theyre poison, but they look like big, yummy otter pops.',
#   'context/4': 'The only thing in here are blue ice packs.'},
#  {'response': 'Hi.',
#   'context/0': 'Hi.',
#   'context/1': 'Hi.',
#   'context/2': 'Leonard, Sheldon.',
#   'context/3': 'Oh, okay, well, guess Im your new neighbour, Penny.',
#   'context/4': 'Oh uh no we dont live together um we live together but in separate, heterosexual bedrooms.'},
#  {'response': 'How did we get in the car?',
#   'context/0': 'Well, we were on our way to my mothers house',
#   'context/1': 'And before our next drive to Comic-Con, I need the name of that juice.',
#   'context/2': 'So, what happened in Texas that was so bad?',
#   'context/3': 'It was fine. Other than the weird-tasting juice Amy gave me, I slept the whole way.',
#   'context/4': 'Did you at least have a good flight down there?'},
#  {'response': 'Would you like some aloe vera? You just got burned. All right, my turn. Howard, Bernadette. Daq tu taH Daq yIn tlhej ghajtaH.',
#   'context/0': 'Thank you, Amy. Very touching. Howard and Bernadette, you are lucky enough to be best friends who love each other. And thats the strongest kind of love because at its core, it has kindness, patience, and respect. Qualities that are hard to find in people these days.',
#   'context/1': 'Well, Im ending it. Bernadette, I want to thank you for allowing me to be your maid of honour. I also want you to know, that I will be happy to do it again if this marriage craps out.',
#   'context/2': 'Well, he started it.',
#   'context/3': 'All right, thats enough from the both of you.',
#   'context/4': 'Hey, I didnt say it.'},
#  {'response': 'Howard Hughes saved his urine in milk bottles.',
#   'context/0': 'Ill love you no matter what.',
#   'context/1': 'Its hard to say. Ive never really lived by myself. What if I become strange and eccentric?',
#   'context/2': 'Do you think its possible you might enjoy being on your own for a little while?',
#   'context/3': 'Hmm, yes. Yeah, perhaps Ive been harder on them than they deserve.',
#   'context/4': 'Is it?'},
#  {'response': 'To comfort you, of course. No, thats not going to work at all, Ill comfort you from over here. Leonard, what youre experiencing is a classic Jungian crisis in which the aging individual mourns the loss of the never-to-be realized ideal family unit.',
#   'context/0': 'I want that too. Why are you here?',
#   'context/1': 'What I want is to be departing the Starship Enterprise in a one-man shuttle craft headed to the planetoid I rule known as Sheldon Alpha Five.',
#   'context/2': 'What do you want, Sheldon?',
#   'context/3': 'Oh, is it? Were conversing. Checkmate.',
#   'context/4': 'Thats a lousy conversation starter.'},
#  {'response': 'Simple extrapolation. In the three years that Ive known you, you were single for two. During that time, I saw 17 different suitors. If we work backwards, correcting for observation bias and postulate an initial dating age of 15',
#   'context/0': 'What? Where did you get 171 men?',
#   'context/1': 'Your characterization of approximately 171 different men as a few.',
#   'context/2': 'Uh, yeah, I wouldnt say many. A few.',
#   'context/3': 'Once a year. Its a deal I made with my mother in exchange for her silence on the matter, as well as the occasional use of her George Foreman Grill that seals in the flavour without the fat. How about you, Penny? Do you go on many dates?',
#   'context/4': 'So, um, Amy, what about you? Do you date much?'},
#  {'response': 'They lose their sensitivity to serotonin and norepinephrine.',
#   'context/0': 'Okay, Sheldon. What happens to our neuroreceptors when we dont get enough REM sleep?',
#   'context/1': 'No, thats a crazy thing.',
#   'context/2': 'Toad of truth? Is that a physics thing?',
#   'context/3': 'I dont know, two, three days. Not important. I dont need sleep, I need answers. I need to determine where in this swamp of unbalanced formulas squatteth the toad of truth.',
#   'context/4': 'Sheldon, when was the last time you got any sleep?'},
#  {'response': 'I like it. Yeah, well take the A-M from Amy and, uh, the Y from Emily.',
#   'context/0': 'So, uh, what were you thinking? Combine their names?',
#   'context/1': 'Its perfect. It appears romantic, but its really just a rock in space that gets me out of Valentines Day forever.',
#   'context/2': 'That is a great idea.',
#   'context/3': 'You know whatd be nice? Name it after your girlfriends. Show them how much you care.',
#   'context/4': 'All right, way to go, Cat Poster. You hang in there.'},
#  {'response': 'Well, what if I spill tomato soup on my shirt and have to come home to change, only to find theres no water for an enzyme soak.',
#   'context/0': 'No, no, it doesnt matter, well be at work.',
#   'context/1': 'Thats unacceptable. Were supposed to be given written notice.',
#   'context/2': 'Oh, uh, building manager. They have to fix a pipe so the water will be off tomorrow from noon to two.',
#   'context/3': 'No. But its a shame our society mocks the differently uvulated. Who was at the door?',
#   'context/4': 'You dont want that, do you?'},
# ...
#   'context/3': 'Leonard.',
#   'context/4': 'Me, neither. Except for one night when the heat went out. Long story, its dont ask.'},
#  {'response': 'Its dark matter. When I entered the field of string theory, I was a prodigy. I rose to a position of respect, and I assumed my career would continue on that upward trajectory. Now here I am in my 30s, Im back at square one. And, frankly, its frightening.',
#   'context/0': 'Oh. Is it Amy?',
#   'context/1': 'My struggle is emotional.',
#   'context/2': 'If you would just use the bucket, youd be so much more comfortable.',
#   'context/3': 'I apologize. I just, Im plagued by an internal struggle.',
#   'context/4': 'You dont have to bite my head off.'},
#  {'response': 'I cant see it! It just wont coalesce.',
#   'context/0': 'Aye, aye, Captain.',
#   'context/1': 'Captain Hooks hand was eaten by a crocodile, not an alligator. If youre going to mock me, at least get your facts straight.',
#   'context/2': 'Mmm, hes either isolating the terms of his formula and examining them individually, or looking for the alligator that swallowed his hand after Peter Pan cut it off.',
#   'context/3': 'What is he doing now?',
#   'context/4': 'Penny, I told you if you dont put him in his crate at night he just runs around the apartment.'},
#  {'response': 'Leonard.',
#   'context/0': 'You want me to put it back?',
#   'context/1': 'No. It upsets Sheldon when she willy-nilly takes it from the containers without regard for its equitable distribution. This is essentially why you have famine in India.',
#   'context/2': 'I think it upsets Sheldon when you play with the food.',
#   'context/3': 'Leonard, shes doing it again.',
#   'context/4': 'Hey, Leonard, check this out.'},
#  {'response': 'Im fine.',
#   'context/0': 'Sheldon, knight takes bishop. You all right?',
#   'context/1': 'Bishop to queen four, level two. Check.',
#   'context/2': 'We can only hope that he doesnt.',
#   'context/3': 'But, Howie, my dad can be a bully. Hes gonna make you cancel your space flight.',
#   'context/4': 'No. I, uh, I should talk to him, man to man.'},
#  {'response': 'I was asking for directions. Apparently, there was a communication problem.',
#   'context/0': 'Whyd you get that? You hate lamb.',
#   'context/1': 'Well, I do now. Theyre a lovely people. Although terrifying when you wake up face-to-face with them. If youre hungry, I brought home some mutton and coconut milk.',
#   'context/2': 'I did not.',
#   'context/3': 'Did you know that Los Angeles has a Little Sri Lanka?',
#   'context/4': 'Oh, no.'},
#  {'response': 'See, I did all this great work, and now hes just going to come along and ruin it. I am angrier than ever and filled with despair.',
#   'context/0': 'Oh, teacher! Me! Me!',
#   'context/1': 'Yes, cocoa. Do you have any idea what its like to be paired with someone whos so incredibly annoying?',
#   'context/2': 'So, cocoa?',
#   'context/3': 'Tea is for when Im upset. Im not upset. The universitys forcing me to work with Kripke. Im outraged.',
#   'context/4': 'Want me to make you some tea?'},
#  {'response': 'Penny..',
#   'context/0': 'Im back here.',
#   'context/1': 'Penny?',
#   'context/2': 'Come in! Hurry!',
#   'context/3': 'I need to go, but you keep in mind that my sharply worded comments on yelp.com recently took down a local muffin store.  Penny..',
#   'context/4': 'Sheldon help!'},
#  {'response': 'Or a mutant army. It depends on how my Kickstarter goes.',
#   'context/0': 'Stop it.',
#   'context/1': 'A crazy person with a long memory, and if all goes according to plan, a robot army.',
#   'context/2': 'You know what? Youre a crazy person.',
#   'context/3': 'Howard, Raj. Judas.',
#   'context/4': 'Thats so great. If you guys prove the existence of Unruh radiation Hey, hey, hey, hey. My eyes are up here.'},
#  {'response': 'Its a rhetorical question. There is nothing more important than Wii bowling night.',
#   'context/0': 'Actually, I was',
#   'context/1': 'Where were you thats more important than Wii bowling night?',
#   'context/2': 'There are always do-overs when my people play sports.',
#   'context/3': 'There are no do-overs in Wii bowling.',
#   'context/4': 'That doesnt count. Do over! Do over!'},
#  {'response': 'Actually, yes. I do.',
#   'context/0': 'You did it. Do you feel okay?',
#   'context/1': 'I will always have the dent to remember it by.',
#   'context/2': 'Oh. Okay.',
#   'context/3': 'I suppose I could try getting rid of the golf ball.',
#   'context/4': 'Baby steps, I guess.'},
#  {'response': 'What are you smiling at?',
#   'context/0': 'Hello, boys.',
#   'context/1': 'That reminds me, I was thinking about wearing my NASA jumpsuit as a costume. But then I realized everyone would be, like, wheres your costume? Why are you wearing your work clothes, you nut?',
#   'context/2': 'Ooh, Hallow-weenies! Thats a good one. Theyll pair nicely with my Draculoni and Cheese. How do I do it?',
#   'context/3': 'Im sorry, but these are just ordinary foods with the names bent into tortured puns. The dishes themselves are in no way Halloweenie.',
#   'context/4': 'Its funny because bread sounds like dead.'},
#  {'response': 'Yes, youre fine as long as you have a buffer living with you to distract from your marital problems. It used to be me. Now its Raj and his attack Tribble. Anyway, Im sorry for everything. Oh, and FYI, if you cry while theyre fighting, theyll take you to McDonalds.',
#   'context/0': 'What are you talking about? Were fine.',
#   'context/1': 'Beverly pointed out that Im experiencing insecurities in my relationship with Amy, in the same way that Leonard and Penny are in their relationship.',
#   'context/2': 'I dont know who you talked to, but that wasnt my mother.',
#   'context/3': 'No, I cant take all the credit. I spoke with Leonards mother, and she made me feel better.',
#   'context/4': 'Thank you. I appreciate that.'},
#  {'response': 'Tuesday night we played Klingon boggle until one in the morning.',
#   'context/0': 'Yes I now, but',
#   'context/1': 'Thats not true. Koothrapali and Wolowitz come over all the time.',
#   'context/2': 'Well this is nice. We dont have a lot of company over.',
#   'context/3': 'Aaah!',
#   'context/4': 'Sheldon, sit!'},
#  {'response': 'Bernadette.',
#   'context/0': 'We should play limbo next. No one beats me at limbo.',
#   'context/1': 'Bernadette, left foot yellow.',
#   'context/2': 'Yeah, I heard you. I got red.',
#   'context/3': 'Penny, I said right hand red.',
#   'context/4': 'Feel free to retain a lawyer.'},
#  {'response': 'Oh, Ive been meaning to tell you, I figured out your magic trick.',
#   'context/0': 'It is pretty spicy.',
#   'context/1': 'Oh, thats, hot, hot, hot, hot! Whoo! It really sneaks up on ya, huh? All right, I gotta go.',
#   'context/2': 'Good night.',
#   'context/3': 'Bye.',
#   'context/4': 'So, hows the food here? Oh, wow, that is really, really good. Oh, Im sorry. You guys are on a date. We can hang out anytime. Have fun.'},
#  {'response': 'That doesnt sound terrifying.',
#   'context/0': 'He gave me his business card and asked me to please pass it along to Howard.',
#   'context/1': 'Oh, what did he say?',
#   'context/2': 'Yeah. This military guy showed up at Howards door. He was terrifying.',
#   'context/3': 'Really?',
#   'context/4': 'The Air Force contacted me about our quantum gyroscope. They want to have a meeting.'},
#  {'response': 'But it wasnt my fault. I didnt exclude him. And I didnt write the article.',
#   'context/0': 'Leonard is as much a part of this paper as you are, and he was overlooked. Hes going to feel bad.',
#   'context/1': 'Well, I dont know, were all Groot? Just tell me.',
#   'context/2': 'Try again.',
#   'context/3': 'Grass is always greener?',
#   'context/4': 'No.'},
#  {'response': 'Seriously? Airborne worms?',
#   'context/0': 'Fine. I want to release butterflies.',
#   'context/1': 'Fine. I want black-tie.',
#   'context/2': 'All right, well, I want it in a church.',
#   'context/3': 'Okay, two friends each.',
#   'context/4': 'I doubt it.'},
#  {'response': 'Listen, Leonards mom is a renowned psychiatrist and woman of science. Can you please keep the Bible babble to yourself while shes here?',
#   'context/0': 'The floating bodies of drowned sinners, of course.',
#   'context/1': 'What did they feed the lions, Mother?',
#   'context/2': 'Interesting. You can believe that, but God filling an ark with animals two-by-two is nonsense.',
#   'context/3': 'Oh, its quite straightforward, actually. It describes a new model of the universe that conceptualizes it as the surface of an n-dimensional superfluid.',
#   'context/4': 'I tried to read your paper, but it was very hard for me to understand.'},
#  {'response': 'Well, then at least hold her still so I can pretend shes stuffed. Raj, I let my emotions get the best of me, and I unfairly took it out on you.',
#   'context/0': 'Sheldon, shes fine.',
#   'context/1': 'Hey, Raj, I owe you an apology. Look, could you please put your dog on a leash?',
#   'context/2': 'Thatll do it.',
#   'context/3': 'Do you actually pay for that haircut?',
#   'context/4': 'Thank you, but how do I know youre not saying that just to be nice?'},
#  {'response': 'When its done charging. Or you land on the time machine. Obviously.',
#   'context/0': 'Hang on. When is my pawn allowed to use the golf cart?',
#   'context/1': 'Nice. Okay, rook to transporter pad. And he comes out at Leonards Queens Bishop',
#   'context/2': 'My catapult flings my bishop to Howards Queens Gorilla two.',
#   'context/3': 'I think the word youre looking for is befuddled.',
#   'context/4': 'Okay, well, its getting late. This was terrific. You win. Bernie?'},
#  {'response': 'No. Now that you know my weakness, I hate you more than ever.',
#   'context/0': 'Is it working?',
#   'context/1': 'I was hoping by admitting my weakness to you, Id somehow be unburdened.',
#   'context/2': 'Wow, I won the MacArthur Grant, everyones jealous of me. Once I get Lasik, Ill be out of things to wish for.',
#   'context/3': 'Rock, rock, water fountain. I am not proud of this, but I have been envious of your recent success.',
#   'context/4': 'What happened to you?'},
#  {'response': 'Thank you for carving a smiley face in my grilled cheese sandwich.',
#   'context/0': 'Whatever. Jesus still loves you.',
#   'context/1': 'My objection was based on considerations other than difficulty.',
#   'context/2': 'Amen. Now, that wasnt so hard, was it?',
#   'context/3': 'Plateful.',
#   'context/4': 'For every cup and every'},
#  {'response': 'It doesnt matter.',
#   'context/0': 'And go where?',
#   'context/1': 'No. Ive reached my breaking point. I need to leave. Now.',
#   'context/2': 'Okay, I know youre upset and theres a lot of stuff going on, but its nothing we cant work out. Come on, lets get you home.',
#   'context/3': 'My plan is to stop at malls and buy what I need. Its called living off the land.',
#   'context/4': 'Seriously? You dont even have a change of clothes or a toothbrush.'},
#  {'response': 'Wow. Im starting to think you didnt mean it when you said you wanted to spruce up the place.',
#   'context/0': 'For the last time, no Hulk, no Batman, no life-size statues.',
#   'context/1': 'Lets hope he thinks so, too.',
#   'context/2': 'That sounds awful.',
#   'context/3': 'Well, we can make some space in the garage. Maybe put a cot out there, get him a space heater, maybe a hot plate.',
#   'context/4': 'Where would he stay? We already have Stuart.'},
#  {'response': 'Oh, nice job, man-hands.',
#   'context/0': 'What?',
#   'context/1': 'Its broken.',
#   'context/2': 'Mmmmm!',
#   'context/3': 'Yes.',
#   'context/4': 'You know, youre right. I mean, its from you, Im never going to sell it. Im opening it.'},
#  {'response': 'Ive never slept on an air mattress before. No lumbar support whatsoever.',
#   'context/0': 'Shouldnt you have put him in a brown paper bag and set him on fire?',
#   'context/1': 'Tag. Youre it.',
#   'context/2': 'Strippergram.',
#   'context/3': 'Who is it?',
#   'context/4': 'Sorry, I didnt mean to offend you. Obviously youre not that familiar with Indian cinema.'},
#  {'response': 'All right. So the topic at hand is sexual fidelity. Probably wont be relying on Seuss here. Although One Fish, Two Fish, Red Fish, Blue Fish might be surprisingly applicable. Go on.',
#   'context/0': 'Oh, what the hell. Im supposed to go see that girl from the comic book store, Alice, but I dont know if I should, because Im going out with Priya, but shes in India.',
#   'context/1': 'Well, if its of any help, Ive read all the great moral philosophers, including Dr. Seuss.',
#   'context/2': 'No. Im having a moral crisis.',
#   'context/3': 'Are you concerned because the world is filled with big dogs and bullies?',
#   'context/4': 'Yeah, me, too. I cant make up my mind.'},
#  {'response': 'They lie so they dont look petty.',
#   'context/0': 'I, looked her in the eye, smiled and said, Im happy for you. Because thats what friends do.',
#   'context/1': 'You ripped out your own fake blonde hair.',
#   'context/2': 'It wasnt me. But she was also an actress, and we were both up for the same part in a toothpaste commercial. She got it. Look, I was so jealous. But instead of ripping out her fake blonde hair',
#   'context/3': 'It was you.',
#   'context/4': 'Look, sweetie, this is a natural thing to feel, okay? But just because good things are happening to Leonard doesnt take anything away from you. You know what? Let me tell you a little story. Once there was a girl who worked at the Cheesecake Factory, and she wasnt very good at her job.'},
#  {'response': 'Well, you doled out affection as a reward for achievement, a proven way to raise a child. Or train a rat.',
#   'context/0': 'I cant help but notice how her unconditional love for you is diametrically opposed to my own parenting strategies.',
#   'context/1': 'Oh, its all right. Shell forgive you. She has to or she goes to hell.',
#   'context/2': 'Im terribly sorry that I upset your mother.',
#   'context/3': 'Youre right. Its time for me to act like an adult in this marriage. Starting with my husbandly duty of taking out the trash. Bernie, I made a mess.',
#   'context/4': 'Face it, dude, Bernadette treats you the same way your mother used to, and that was not a healthy relationship.'},
#  {'response': 'Yes, Id like a seven-day course of penicillin, some, uh, syrup of ipecac, to induce vomiting, and a mint.',
#   'context/0': 'You guys ready to order?',
#   'context/1': 'Hey! Thats my sister and my country youre talking about. Leonard may have defiled one, but I wont have you talking smack about the other.',
#   'context/2': 'Im sorry, do I really need to connect the dots for you? The backwash into this glass is every pathogen that calls your mouth home, sweet home. Not to mention the visitors who arrive on the dancing tongue of your subtropical girlfriend.',
#   'context/3': 'Here we go.',
#   'context/4': 'Well, thats it then. Im dead.'},
#  {'response': 'Yes. Now, when the robots rise up, theyll know that Ive been rooting for them the whole time.',
#   'context/0': 'Its amazing a machine can do that.',
#   'context/1': 'This things pretty cool. It interprets emotions using a wireless signal to analyse subtle changes in breathing and heart rate.',
#   'context/2': 'Remember that when the new TV falls off the wall and crushes us both.',
#   'context/3': 'Okay. Thank you, youre the best. Mm.',
#   'context/4': 'Of course not. I mean, hes your brother.'},
#  {'response': 'What is that awful smell?',
#   'context/0': 'Scientific Principle: Accelerated Corrosion.',
#   'context/1': 'Its a bachelor party. Lighten up.',
#   'context/2': 'Thats not very nice.',
#   'context/3': 'Yep. A six-foot wiener in a Flash T-shirt.',
#   'context/4': 'We do?'},
#  {'response': 'An interesting question. Well, good night.',
#   'context/0': 'I dont understand it. Im a nice guy, I have a great job, Im well-educated, come from a good family. Why dont women want to be with me?',
#   'context/1': 'Hmm. You think youre five-foot-six, thats funny.',
#   'context/2': 'Come on. How can you be sad when youre going home with all five-foot-six of this?',
#   'context/3': 'Leonard, you are really not cheering me up.',
#   'context/4': 'And I got itchy and swollen just watching you.'},
#  ...]

# %%
lines_selected_list.append(['Soft kitty, warm kitty Little ball of fur', 'Happy kitty, slippy kitty Pur pur pur', 'TBBT'])
lines_selected_list.append(['Penny.', 'Thats just wrong.', 'TBBT'])
lines_selected_list.append(['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?', 'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.', 'TBBT'])
lines_selected_list.append(['I didnt break it. I, I guess Stuart sold it to me like this.', 'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.', 'TBBT'])
lines_selected_list.append(['Be careful.', 'If I were not being careful, your telling me to be careful would not make me careful.', 'TBBT'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT']]

# %% [markdown]
# ## Harry

# %%
temp = load_df(characters[2])
# Out:
# Using custom data configuration default-82f37a1aaf6145b7
# Reusing dataset csv (C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-82f37a1aaf6145b7\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-82f37a1aaf6145b7\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-363e838cf8c57927.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-82f37a1aaf6145b7\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-395c96d1ffa05f88.arrow
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-82f37a1aaf6145b7\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-5404ccb9ff06d17b.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-82f37a1aaf6145b7\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-a3852ad9abbfd5bf.arrow

# %%
[s for s in temp['test']]
# Out:
# [{'response': 'Stop, Dobby!',
#   'context/0': 'Bad Dobby!',
#   'context/1': 'That was an awful thing to say.',
#   'context/2': 'No, I havent.',
#   'context/3': 'You cant have met many decent wizards then.',
#   'context/4': 'Dobby has heard of your greatness, sir, but never has he been asked to sit down by a wizard, like an equal.'},
#  {'response': "My dad wasn't a drunk.",
#   'context/0': 'What did you say?',
#   'context/1': "That's a lie.",
#   'context/2': 'And a drunk too, no doubt?',
#   'context/3': 'He was unemployed.',
#   'context/4': "Nothing. He didn't work."},
#  {'response': "Alive, you're free.",
#   'context/0': 'Besides, dead, the truth dies with him.',
#   'context/1': "I didn't think my dad would have wanted his best friends to become killers.",
#   'context/2': "He doesn't deserve it.",
#   'context/3': 'That was a noble thing you did back there.',
#   'context/4': "It'll be nice to do it again as a free man."},
#  {'response': "Don't even think about it.",
#   'context/0': "In fact, I'm going to have to do the same to you.",
#   'context/1': "I'd never have sold another book.",
#   'context/2': 'Otherwise, all those wizards would have gone blabbing.',
#   'context/3': "I'm rather gifted with Memory Charms.",
#   'context/4': 'Yes, now you mention it.'},
#  {'response': 'Fortuna Major.',
#   'context/0': "She just won't let me in.",
#   'context/1': 'Here, listen.',
#   'context/2': 'Fortuna Major.',
#   'context/3': 'But you know, happiness can be found even in the darkest of times if one only remembers to turn on the light.',
#   'context/4': 'It is not in the nature of a dementor to be forgiving.'},
#  {'response': "It's a snake.",
#   'context/0': "That's why I can hear it speak.",
#   'context/1': 'The monster in the Chamber of Secrets is a basilisk.',
#   'context/2': 'Ron, this is it.',
#   'context/3': 'Spiders flee before it.',
#   'context/4': "Capable of living for hundreds of years instant death awaits any who meet this giant serpent's eye."},
#  {'response': 'This is it.',
#   'context/0': 'I just remember seeing a pair of great, big, yellow eyes over there by that sink.',
#   'context/1': 'Just like that? How?',
#   'context/2': 'And I realized it was a boy, so I unlocked the door to tell him to go away and I died.',
#   'context/3': 'But they said something funny, a kind of made-up language.',
#   'context/4': "I don't know. I was distraught!"},
#  {'response': 'You need to sound more like Crabbe.',
#   'context/0': 'We still sound like ourselves.',
#   'context/1': 'Bloody hell!',
#   'context/2': 'Ron.',
#   'context/3': 'Harry?',
#   'context/4': 'Me too.'},
#  {'response': 'Are you mad?',
#   'context/0': "Why aren't we leaving?",
#   'context/1': "And we aren't leaving?",
#   'context/2': 'Fudge is coming.',
#   'context/3': "We can't be seen.",
#   'context/4': 'Awful things happen to wizards who meddle with time Harry.'},
#  {'response': 'Malfoy.',
#   'context/0': "Who's that?",
#   'context/1': "He'll have to be trained up a bit, of course.",
#   'context/2': 'Ohh! Oooh, ooh, ooh, well...',
#   'context/3': "Don't you, Norbert? Dededede.",
#   'context/4': "Yeah, well, he's got to have a name, doesn't he?"},
#  {'response': "But you're innocent.",
#   'context/0': "And besides you're meant to be here.",
#   'context/1': 'For some time, my life will be too unpredictable.',
#   'context/2': 'One day, perhaps.',
#   'context/3': 'I want to go with you.',
#   'context/4': "I'll be forever grateful for this to both of you."},
#  {'response': 'Thank you. Bye.',
#   'context/0': 'Okay, bye.',
#   'context/1': "Right. I'll leave you to it.",
#   'context/2': "You'll be all right now then, Harry?",
#   'context/3': 'I definitely need to remember that one.',
#   'context/4': 'Oculus Reparo.'},
#  {'response': "I'll see you back in the common room.",
#   'context/0': 'For all we know, you could be.',
#   'context/1': 'He lived a thousand years ago.',
#   'context/2': "I can't be.",
#   'context/3': "But I'm not.",
#   'context/4': "Now the whole school's gonna think you're his great-great-great grandson."},
#  {'response': 'I fell over.',
#   'context/0': 'What you doing down there?',
#   'context/1': 'My name is Stan Shunpike, and I will be your conductor for this evening.',
#   'context/2': 'Welcome to the Knight Bus...emergency transport for the stranded witch or wizard.',
#   'context/3': 'Anywhere is better than here.',
#   'context/4': "I don't care."},
#  {'response': 'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'context/0': 'But why would anyone go near that dog?',
#   'context/1': "But, he got himself bitten, that's why he's limping.",
#   'context/2': "Listen, last night, I'm guessing Snape let the troll in as a diversion so he could try and get past that 3 headed dog.",
#   'context/3': 'Blood?',
#   'context/4': 'That explains the blood.'},
#  {'response': 'This way, now.',
#   'context/0': 'This way.',
#   'context/1': 'Come on.',
#   'context/2': "You'll find no small glasses in this house, professor.",
#   'context/3': 'Thank you.',
#   'context/4': 'Oh, executioner, your services are no longer required.'},
#  {'response': 'Oh!',
#   'context/0': 'Yeah!',
#   'context/1': "I've got presents?",
#   'context/2': "Looks like you've got one too!",
#   'context/3': 'Oh, Mum made it.',
#   'context/4': 'What are you wearing?'},
#  {'response': "Snape doesn't want the stone for himself, he wants the stone for Voldemort.",
#   'context/0': "Don't you see? We had it wrong.",
#   'context/1': "He's living off the unicorns.",
#   'context/2': "But he's weak.",
#   'context/3': "You mean, You-Know-Who's out there, right now, in the forest?",
#   'context/4': "You're safe now. Good luck."},
#  {'response': 'Follow the spiders.',
#   'context/0': 'You heard what Hagrid said.',
#   'context/1': 'What?',
#   'context/2': 'Come on.',
#   'context/3': 'Come on, Fang.',
#   'context/4': 'Come on.'},
#  {'response': "I think it's a warning.",
#   'context/0': 'Perhaps you should see the nurse.',
#   'context/1': 'Not like this.',
#   'context/2': "It's happened before.",
#   'context/3': 'My scar. It keeps burning.',
#   'context/4': 'All right there, Harry?'},
#  {'response': 'we almost get killed by a tree...',
#   'context/0': "So a house-elf shows up in my bedroom we can't get through the barrier to platform 93 4...",
#   'context/1': 'See you, Hedwig.',
#   'context/2': "Dad's gonna kill me.",
#   'context/3': 'The caaaar!',
#   'context/4': "Scabbers, you're okay."},
#  {'response': 'Oh, no.',
#   'context/0': "Buckbeak didn't mean no harm.",
#   'context/1': "Let's go!",
#   'context/2': 'I thought I just saw...Never mind.',
#   'context/3': 'What?',
#   'context/4': 'The execution shall dispatch...'},
#  {'response': "You see, sir, I couldn't help but notice certain things, certain...",
#   'context/0': "It's just...",
#   'context/1': 'Am I right, Harry?',
#   'context/2': 'And second I sense that something is troubling you.',
#   'context/3': 'Nothing but that could have called Fawkes to you.',
#   'context/4': 'You must have shown me real loyalty down in the Chamber.'},
#  {'response': "I didn't.",
#   'context/0': 'What did you say your name was?',
#   'context/1': "It's going to be a bumpy ride.",
#   'context/2': 'Yeah, take it away, Ernie.',
#   'context/3': 'Take her away, Ern.',
#   'context/4': 'Come on. Come on. Move on, move on.'},
#  {'response': "Hey, he's gone!",
#   'context/0': 'I got about six of him.',
#   'context/1': "I've got Dumbledore!",
#   'context/2': "They've only got one good jump in them to begin with.",
#   'context/3': "Oh, that's rotten luck.",
#   'context/4': 'Watch it!'},
#  {'response': 'Where are we? A graveyard.',
#   'context/0': "I don't like this at all.",
#   'context/1': "I don't like this.",
#   'context/2': 'Hurry up!',
#   'context/3': 'Catch the key!',
#   'context/4': 'This complicates things a bit!'},
#  {'response': "Look. Buckbeak's still alive.",
#   'context/0': "Come on. We should be at Hagrid's.",
#   'context/1': 'Not good, brilliant.',
#   'context/2': 'That felt good.',
#   'context/3': "I'm gonna get that jumped-up mudblood! Mark my words.",
#   'context/4': 'Not a word to anyone, understood?'},
#  {'response': 'Hey, Hagrid.',
#   'context/0': 'Hello, Harry.',
#   'context/1': 'Come on now, hurry up.',
#   'context/2': "Come on, now, first years, don't be shy.",
#   'context/3': 'First years, this way, please!',
#   'context/4': 'Right, then.'},
#  {'response': "Let's go.",
#   'context/0': "Come on, Ginny, we'll get you a seat. Hurry.",
#   'context/1': 'After you, dear.',
#   'context/2': 'Okay.',
#   'context/3': 'Fred, George, Percy, you first.',
#   'context/4': "Oh dear! The train'll be leaving any moment!"},
#  {'response': 'Come on, move faster!',
#   'context/0': 'Come on!',
#   'context/1': 'Now!',
#   'context/2': 'Get us out of here.',
#   'context/3': "Don't mention it.",
#   'context/4': 'Thanks for that.'},
#  {'response': 'Hello, can you hear me?',
#   'context/0': 'Are you Tom Riddle?',
#   'context/1': "Could you tell me what's going on here?",
#   'context/2': 'Excuse me.',
#   'context/3': '13th June..',
#   'context/4': 'Let me take you back fifty years ago.'},
#  {'response': 'I should be in Slytherin.',
#   'context/0': 'So the Sorting Hat was right.',
#   'context/1': 'Not intentionally but yes.',
#   'context/2': 'Voldemort transferred some of his powers to me?',
#   'context/3': "If I'm not mistaken, Harry he transferred some of his powers to you the night he gave you that scar.",
#   'context/4': 'Because Lord Voldemort can speak Parseltongue.'},
#  {'response': 'RON!',
#   'context/0': 'Ahhhh!',
#   'context/1': 'Check.',
#   'context/2': 'Knight...to H-3.',
#   'context/3': 'Not me, not Hermione, you.',
#   'context/4': "Harry, it's you that has to go on. I know it."},
#  {'response': 'Mr. Weasley why would I go looking for someone who wants to kill me?',
#   'context/0': "Harry, swear to me that whatever you might hear you won't go looking for Black.",
#   'context/1': 'And kill me.',
#   'context/2': 'To find you.',
#   'context/3': 'And that is why he has escaped from Azkaban.',
#   'context/4': 'And in his mind you are the only thing that stands in the way of You-Know-Who returning to power.'},
#  {'response': 'Who is it?',
#   'context/0': 'No, Dobby. Tell me.',
#   'context/1': 'Dobby only wants Harry Potter to be safe.',
#   'context/2': 'Dobby cannot say, sir.',
#   'context/3': "Who's doing it now?",
#   'context/4': 'Tell me Dobby when did this happen before?'},
#  {'response': "It's fine. I'll stay.",
#   'context/0': "No. Don't worry, okay?",
#   'context/1': 'You better go.',
#   'context/2': 'Okay.',
#   'context/3': "But the fleas, they're murder.",
#   'context/4': 'The tail I could live with.'},
#  {'response': "We've got to talk to Hagrid, Ron.",
#   'context/0': 'Unless the culprit behind these attacks is caught it is likely the school will be closed.',
#   'context/1': 'I should tell you this:',
#   'context/2': 'No exceptions.',
#   'context/3': 'All students will be escorted to each lesson by a teacher.',
#   'context/4': 'All students will return to their house common rooms by 6:00 every evening.'},
#  {'response': 'Tell those spiders.',
#   'context/0': "I don't wanna tap-dance!",
#   'context/1': 'Spiders. They want me to tap-dance.',
#   'context/2': "Spiders! There's... There's spiders.",
#   'context/3': "Buckbeak's been sentenced to death!",
#   'context/4': "No, I'm not sacked."},
#  {'response': 'Professor, why do the dementors affect me so?',
#   'context/0': 'No.',
#   'context/1': 'Is there no chance of fixing it?',
#   'context/2': "I'm sorry to hear about your broomstick.",
#   'context/3': 'When you fell, your broom sort of blew into the Whomping Willow, and...Well...',
#   'context/4': "There's something else you should know too."},
#  {'response': 'I spoke a different language?',
#   'context/0': 'Snake language.',
#   'context/1': 'I heard you speaking Parseltongue.',
#   'context/2': 'You were there. You heard me.',
#   'context/3': "That's what you said to it.",
#   'context/4': "What's bad? If I hadn't told that snake not to attack Justin..."},
#  {'response': 'Sorry about him.',
#   'context/0': "He's boring.",
#   'context/1': "He's asleep!",
#   'context/2': 'Move!',
#   'context/3': 'Move!',
#   'context/4': 'Make it move.'},
#  {'response': 'But this is important!',
#   'context/0': "He's gone?! Now?",
#   'context/1': 'He received an urgent owl from the Ministry of Magic and left immediately for London.',
#   'context/2': "I'm afraid Professor Dumbledore is not here.",
#   'context/3': 'We have to see Professor Dumbledore, immediately!',
#   'context/4': 'Where you going?! Wait!'},
#  {'response': 'Sounds like wings.',
#   'context/0': "I don't know.",
#   'context/1': 'What is that?',
#   'context/2': 'Lucky Hermione pays attention in Herbology.',
#   'context/3': "Whew. Lucky we didn't panic!",
#   'context/4': 'Okay.'},
#  {'response': 'Come on!',
#   'context/0': 'Now!',
#   'context/1': 'Get us out of here.',
#   'context/2': "Don't mention it.",
#   'context/3': 'Thanks for that.',
#   'context/4': 'Arania Exumai!'},
#  {'response': 'Rictusempra!',
#   'context/0': 'Everte Statum!',
#   'context/1': 'One. Two...',
#   'context/2': "We don't want any accidents here.",
#   'context/3': 'On the count of three cast your charms to disarm your opponent. Only to disarm.',
#   'context/4': 'You wish.'},
#  {'response': "Don't follow until I give you a sign.",
#   'context/0': "I'll go first.",
#   'context/1': 'Come on! Okay. Push!',
#   'context/2': 'What?!',
#   'context/3': 'We have to move its paw.',
#   'context/4': "Uh. It's got horrible breath!"},
#  {'response': 'What are you talking about?',
#   'context/0': 'After you, of course.',
#   'context/1': 'Can I have a go, Harry?',
#   'context/2': 'Wherever did you get it?',
#   'context/3': 'Harry.',
#   'context/4': "Stand back, I said! Or I'll take it upstairs if you don't settle."},
#  {'response': "But Flamel, he'll die, won't he?",
#   'context/0': 'My friend Nicholas and I had a little chat and agreed it was best all around.',
#   'context/1': 'Relax, dear boy. The stone has been destroyed.',
#   'context/2': 'But, what happened to the Stone?',
#   'context/3': "Fine. They're both just fine.",
#   'context/4': 'What about Hermione?'},
#  {'response': "But the Muggles. Can't they see us?",
#   'context/0': 'If you have pea soup make sure you eat it before it eats you.',
#   'context/1': 'The Leaky Cauldron.',
#   'context/2': "You hear that? The Leaky Cauldron. That's in London.",
#   'context/3': "he Leaky Cauldron. That's in London.",
#   'context/4': 'Where abouts are you headed?'},
#  {'response': "Be thankful it's not your neck.",
#   'context/0': 'My wand. Look at my wand.',
#   'context/1': 'Stop! Stop! Stop!',
#   'context/2': 'Aaahhh! Aaah!',
#   'context/3': 'Up! Ron, mind that tree!',
#   'context/4': "It's not working!"},
#  {'response': "Only that he's escaped from Azkaban.",
#   'context/0': 'What do you know about Sirius Black, Harry?',
#   'context/1': 'Has this anything to do with Sirius Black, sir?',
#   'context/2': 'Grave danger.',
#   'context/3': 'You are in danger.',
#   'context/4': 'But I think that you need to know the facts.'},
#  {'response': "I don't understand.",
#   'context/0': 'Yes?',
#   'context/1': 'No, thank you. Minister?',
#   'context/2': 'Pea soup?',
#   'context/3': "So that's that and no harm done.",
#   'context/4': 'She will have no recollection of the incident whatsoever.'},
#  {'response': "She only saw the basilisk's reflection.",
#   'context/0': 'There was water on the floor that night.',
#   'context/1': 'The water.',
#   'context/2': "I'm pretty sure she didn't havea camera or a mirror, Harry.",
#   'context/3': 'And Mrs. Norris?',
#   'context/4': 'I bet you she was using it to look around corners in case it came along.'},
#  {'response': "It's Mrs. Norris.",
#   'context/0': "It's Filch's cat.",
#   'context/1': 'Oh, no.',
#   'context/2': "It's written in blood.",
#   'context/3': 'Enemies of the Heir, beware.',
#   'context/4': 'The Chamber of Secrets has been opened. Enemies of the Heir, beware.'},
#  {'response': 'Dumbledore?',
#   'context/0': 'Professor Dumbledore.',
#   'context/1': 'Riddle! Come.',
#   'context/2': 'Hello, can you hear me?',
#   'context/3': 'Are you Tom Riddle?',
#   'context/4': "Could you tell me what's going on here?"},
#  {'response': 'Dobby, please, no!',
#   'context/0': 'Dobby, get back here!',
#   'context/1': 'No! Ahh! Ooh...',
#   'context/2': 'Give me those, now!',
#   'context/3': 'Heh- Dobby hoped, if Harry Potter thought his friends had forgotten him, Harry Potter might not want to go back to school, sir.',
#   'context/4': 'Harry Potter mustnt be angry with Dobby.'},
#  {'response': 'Come on.',
#   'context/0': 'Run! Run!',
#   'context/1': 'Remus! Remus!',
#   'context/2': 'Harry!',
#   'context/3': 'Expelliarmus!',
#   'context/4': 'This flesh is only flesh!'},
#  {'response': 'Platform 9 3 4?',
#   'context/0': 'Stick to your ticket.',
#   'context/1': "Stick to it, Harry that's very important.",
#   'context/2': "Here's your ticket.",
#   'context/3': 'Now, uh, your train leaves in 10 minutes.',
#   'context/4': "Well, he'll be wanting to see me."},
#  {'response': 'Open it.',
#   'context/0': 'Come, Dobby.',
#   'context/1': "Why don't you prove it?",
#   'context/2': 'You do, do you?',
#   'context/3': "I think you slipped the diary into Ginny Weasley's cauldron that day at Diagon Alley.",
#   'context/4': 'I think you do, sir.'},
#  {'response': 'Expecto Patronum!',
#   'context/0': 'Expecto Patronum!',
#   'context/1': 'Just do it.',
#   'context/2': "Then let's give it a try. You feel ready?",
#   'context/3': 'Is it strong?',
#   'context/4': "It's the happiest I've ever felt but it's complicated."},
#  {'response': 'I think we found the train.',
#   'context/0': "I'm trying. Your hand's all sweaty.",
#   'context/1': 'Hold on!',
#   'context/2': 'Take my hand!',
#   'context/3': 'Hold oonnn!!!',
#   'context/4': 'Haaaarryyy!'},
#  {'response': 'We are pleased to inform you that you have been accepted at Hogwarts School of Witchcraft and Wizardry.',
#   'context/0': 'Dear Mr. Potter,',
#   'context/1': "Anything you couldn't explain, when you were angry or scared?",
#   'context/2': 'Well, Just Harry, did you ever make anything happen?',
#   'context/3': 'Just Harry.',
#   'context/4': "I mean, I'm just Harry."},
#  {'response': 'that was drinking its blood...that was Voldemort?',
#   'context/0': 'Do you mean to say...that that thing that killed the unicorn...',
#   'context/1': 'Can you think of no one?',
#   'context/2': 'But who would choose such a life?',
#   'context/3': 'A cursed life.',
#   'context/4': 'You have slain something so pure that the moment the blood touches your lips, you will have a half-life.'},
#  {'response': 'Dumbledore and the others, I mean?',
#   'context/0': 'Do you think I should have told them?',
#   'context/1': "and then Mrs. Norris turns up Petrified. It's just strange.",
#   'context/2': 'You hear this voice, a voice only you can hear...',
#   'context/3': 'Strange?',
#   'context/4': "It's a bit strange, isn't it?"},
#  {'response': "Hermione that's the he betrayed my parents.",
#   'context/0': "Harry, you can't.",
#   'context/1': "That's Pettigrew.",
#   'context/2': 'Keep a closer eye on your pet.',
#   'context/3': "Scabbers, you're alive!",
#   'context/4': "Otherwise, he'll think Hagrid set him free."},
#  {'response': "I'm Harry. Harry Potter.",
#   'context/0': 'Ron Weasley.',
#   'context/1': "I'm Ron, by the way.",
#   'context/2': 'No. Not at all.',
#   'context/3': 'Everywhere else is full.',
#   'context/4': 'Excuse me. Do you mind?'},
#  {'response': "Right there. You'll see.",
#   'context/0': 'Any minute now.',
#   'context/1': "He'll conjure the Patronus.",
#   'context/2': 'My dad will come.',
#   'context/3': "Don't worry.",
#   'context/4': 'This is horrible.'},
#  {'response': "I don't know, Sir.",
#   'context/0': 'And what is the difference between monkshood and wolfsbane?',
#   'context/1': "I don't know, Sir.",
#   'context/2': 'Where, Mr Potter, would you look if I asked you to find me a bezoar?',
#   'context/3': "You don't know? Well, let's try again.",
#   'context/4': 'Tell me, what would I get if I added powdered root of asphodel to an infusion of wormwood?'},
#  {'response': 'Hedwig.',
#   'context/0': 'Room 11.',
#   'context/1': 'Yeah, take it away, Ernie!',
#   'context/2': 'Take it away, Ern.',
#   'context/3': 'Mr. Potter, at last.',
#   'context/4': 'Next stop, Knockturn Alley.'},
#  {'response': 'Not as long as those who remain are loyal to him.',
#   'context/0': "He'll never be gone.",
#   'context/1': "Dumbledore's been driven out of this castle by the mere memory of me.",
#   'context/2': 'Albus Dumbledore is the greatest sorcerer in the world.',
#   'context/3': 'No. I fashioned myself a new name, a name I knew wizards everywhere would fear to speak when I became the greatest sorcerer in the world.',
#   'context/4': "Surely you didn't think .I was going to keep my filthy Muggle father's name?"},
#  {'response': 'Hang on.',
#   'context/0': 'I was lost, I...',
#   'context/1': "People will think you're up to no good.",
#   'context/2': "Don't want no one to see you there.",
#   'context/3': 'Dodgy place.',
#   'context/4': 'Skulking around Knockturn Alley?'},
#  {'response': 'Why was he trying to get past that 3 headed dog on Halloween?',
#   'context/0': 'Who knows.',
#   'context/1': "Why would Snape put a curse on Harry's broom?",
#   'context/2': 'Nonsense.',
#   'context/3': 'Go go Gryffindor! Go go Gryffindor!',
#   'context/4': 'Whoo-hoo!'},
#  {'response': 'Earlier, it showed someone in the castle.',
#   'context/0': "Professor, just so you know, I don't think that map always works.",
#   'context/1': 'If you do, I shall know.',
#   'context/2': "And don't take any detours.",
#   'context/3': 'I want you to return to your dormitory and stay there.',
#   'context/4': 'Yes, sir.'},
#  {'response': 'This says platform 9 3 4.',
#   'context/0': 'But, Hagrid, there must be a mistake.',
#   'context/1': 'Platform 9 3 4?',
#   'context/2': 'Stick to your ticket.',
#   'context/3': "Stick to it, Harry that's very important.",
#   'context/4': "Here's your ticket."},
#  {'response': 'Sir? I wonder if I could have that?',
#   'context/0': "Come, Dobby. We're leaving.",
#   'context/1': 'Dumbledore.',
#   'context/2': "Don't worry. I will be.",
#   'context/3': 'Well, let us hope that Mr. Potter will always be around to save the day.',
#   'context/4': 'The consequences for the one responsible would be severe.'},
#  {'response': "Hagrid, what's that?",
#   'context/0': "Right. Let's go.",
#   'context/1': 'Nighty-night.',
#   'context/2': 'You can be sure of that.',
#   'context/3': "There's more than werewolves in those trees, lad.",
#   'context/4': 'And there are...werewolves!'},
#  {'response': 'Dobby?',
#   'context/0': 'Hello.',
#   'context/1': 'Time to kill..',
#   'context/2': 'Kill. Kill.!!',
#   'context/3': 'Pumpkin juice?',
#   'context/4': 'What do you expect?'},
#  {'response': 'Wait a minute.',
#   'context/0': 'Pawn to C-3!',
#   'context/1': 'Castle to E-4!',
#   'context/2': "Yes, Hermione, I think this is going to be exactly like wizard's chess!",
#   'context/3': 'You there! D-5!',
#   'context/4': "Ron, you don't suppose this is going to be like...real wizard's chess, do you?"},
#  {'response': "No. Don't worry, okay?",
#   'context/0': 'You better go.',
#   'context/1': 'Okay.',
#   'context/2': "But the fleas, they're murder.",
#   'context/3': 'The tail I could live with.',
#   'context/4': 'More than once, James suggested that I make the change permanent.'},
#  {'response': 'Catch the key!',
#   'context/0': 'This complicates things a bit!',
#   'context/1': "You're the youngest seeker in a century!",
#   'context/2': 'If Snape can catch it on that old broomstick, you can!',
#   'context/3': 'Oh, go on, Harry!',
#   'context/4': "It's too simple."},
#  {'response': 'You were brilliant, Fawkes.',
#   'context/0': "Follow the Chamber and you'll find Ron.",
#   'context/1': 'Ginny, you need to get yourself out.',
#   'context/2': "Don't worry.",
#   'context/3': "Harry, you're hurt.",
#   'context/4': 'Riddle made me, and...'},
#  {'response': 'With the Elixir of Life, Voldemort will be strong again.',
#   'context/0': "Snape doesn't want the stone for himself, he wants the stone for Voldemort.",
#   'context/1': "Don't you see? We had it wrong.",
#   'context/2': "He's living off the unicorns.",
#   'context/3': "But he's weak.",
#   'context/4': "You mean, You-Know-Who's out there, right now, in the forest?"},
#  {'response': "She's cold as ice.",
#   'context/0': 'A memory preserved in a diary for 50 years.',
#   'context/1': 'Are you a ghost?',
#   'context/2': "She's still alive, but only just.",
#   'context/3': "She's not...?",
#   'context/4': "What do you mean, she won't wake?"},
#  {'response': 'Expecto Patronum!',
#   'context/0': 'No. Sirius!',
#   'context/1': 'Sirius!',
#   'context/2': 'Come back here, Potter!',
#   'context/3': 'Sirius!',
#   'context/4': 'There you are, Potter!'},
#  {'response': 'Hagrid!',
#   'context/0': 'Harry?',
#   'context/1': 'No. Please...',
#   'context/2': "We'll help you find your way back.",
#   'context/3': 'Come with us.',
#   'context/4': "I'm fine, thank you. I was just going..."},
#  {'response': 'You were right, Hermione.',
#   'context/0': 'Expecto Patronum!',
#   'context/1': 'Harry!',
#   'context/2': "You're dying both of you.",
#   'context/3': 'Sirius.',
#   'context/4': 'He will come.'},
#  {'response': 'I think you do, sir.',
#   'context/0': "Mine? I don't know what you're talking about.",
#   'context/1': 'I have something of yours.',
#   'context/2': 'Mr. Malfoy!',
#   'context/3': 'Mr. Malfoy.',
#   'context/4': 'Sir? I wonder if I could have that?'},
#  {'response': 'Hagrid, who gave you the dragon egg?',
#   'context/0': "Why didn't I see it before?",
#   'context/1': 'I mean, how many people wander around with dragon eggs in their pockets?',
#   'context/2': "Don't you think it's a bit odd that what Hagrid wants more than anything is a dragon, and a stranger shows up and just happens to have one?",
#   'context/3': 'What is it?',
#   'context/4': 'Oh. Of course!'},
#  {'response': 'Lucky Hermione pays attention in Herbology.',
#   'context/0': "Whew. Lucky we didn't panic!",
#   'context/1': 'Okay.',
#   'context/2': 'Yeah.',
#   'context/3': 'Ron, are you okay?',
#   'context/4': 'Ahhh!'},
#  {'response': "No. Mr. Filch! You don't understand...",
#   'context/0': 'Mark my words.',
#   'context/1': "I'll have you out this time, Potter.",
#   'context/2': 'Caught in the act.',
#   'context/3': 'Time to kill.',
#   'context/4': 'Kill. Kill. Kill.'},
#  {'response': 'Everyone?',
#   'context/0': 'Everyone.',
#   'context/1': 'So you mean this map shows...',
#   'context/2': 'Does that a lot.',
#   'context/3': 'Pacing.',
#   'context/4': 'In his study.'},
#  {'response': 'Yes, sir... See why Ive got to go back?',
#   'context/0': 'And fix that door!',
#   'context/1': 'One more sound, and youll wish youd never been born, boy!',
#   'context/2': 'Sorry.',
#   'context/3': 'You just ruined the punch line of my Japanese golfer joke!',
#   'context/4': 'I- I was just'},
#  {'response': "So a house-elf shows up in my bedroom we can't get through the barrier to platform 93 4...",
#   'context/0': 'See you, Hedwig.',
#   'context/1': "Dad's gonna kill me.",
#   'context/2': 'The caaaar!',
#   'context/3': "Scabbers, you're okay.",
#   'context/4': 'Come on, go! Fast!'},
#  {'response': 'Tom. Tom Riddle.',
#   'context/0': "She won't wake.",
#   'context/1': 'Please wake up.',
#   'context/2': 'Wake up, wake up.',
#   'context/3': "Ginny! Ginny, please don't be dead.",
#   'context/4': 'Okay.'},
#  {'response': 'Are you a ghost?',
#   'context/0': "She's still alive, but only just.",
#   'context/1': "She's not...?",
#   'context/2': "What do you mean, she won't wake?",
#   'context/3': 'Tom. Tom Riddle.',
#   'context/4': "She won't wake."},
#  {'response': "I don't suppose you could tell me why you're trying to kill me?",
#   'context/0': 'Dobby gets them five times a day at home.',
#   'context/1': 'Dobby is used to death threats, sir.',
#   'context/2': 'You better clear off before my bones come back Dobby, or I might strangle you.',
#   'context/3': 'Dobby had to iron his hands.',
#   'context/4': 'Dobby feels most aggrieved, sir.'},
#  {'response': 'Look in properly. Go on.',
#   'context/0': 'I only see us.',
#   'context/1': "Come on. Come. Come look, it's my parents!",
#   'context/2': 'Now, come on!',
#   'context/3': "There's something you've got to see.",
#   'context/4': 'Why?'},
#  {'response': "I can't be.",
#   'context/0': "But I'm not.",
#   'context/1': "Now the whole school's gonna think you're his great-great-great grandson.",
#   'context/2': 'Exactly.',
#   'context/3': 'He could talk to snakes too.',
#   'context/4': 'Salazar Slytherin was a Parselmouth.'},
#  {'response': "he Leaky Cauldron. That's in London.",
#   'context/0': 'Where abouts are you headed?',
#   'context/1': "I didn't.",
#   'context/2': 'What did you say your name was?',
#   'context/3': "It's going to be a bumpy ride.",
#   'context/4': 'Yeah, take it away, Ernie.'},
#  {'response': 'Professor.',
#   'context/0': 'Harry?',
#   'context/1': "You're wrong.",
#   'context/2': 'You would have done well in Slytherin.',
#   'context/3': 'But I stand by what I said last year.',
#   'context/4': 'Yes. You were particularly difficult to place.'},
#  {'response': 'What?',
#   'context/0': "He's not about to steal it!",
#   'context/1': 'Snape is one of the teachers protecting the Stone!',
#   'context/2': "We just don't know why.",
#   'context/3': "Hagrid, we know he's after the Stone.",
#   'context/4': "Snape? Blimey, Harry, you're not still on about him, are you?"},
#  {'response': "They're my letters!",
#   'context/0': 'Get off!',
#   'context/1': 'Give me that letter!',
#   'context/2': 'Give me that!',
#   'context/3': "Mummy, what's happening?",
#   'context/4': 'Stop it!'},
#  {'response': "But I didn't realize...",
#   'context/0': 'I spoke a different language?',
#   'context/1': 'Snake language.',
#   'context/2': 'I heard you speaking Parseltongue.',
#   'context/3': 'You were there. You heard me.',
#   'context/4': "That's what you said to it."},
#  {'response': 'Certain similarities between Tom Riddle and me.',
#   'context/0': "You see, sir, I couldn't help but notice certain things, certain...",
#   'context/1': "It's just...",
#   'context/2': 'Am I right, Harry?',
#   'context/3': 'And second I sense that something is troubling you.',
#   'context/4': 'Nothing but that could have called Fawkes to you.'}]

# %%
lines_selected_list.append(['But why would anyone go near that dog?', 'The day I was at Gringotts, Hagrid took something out of one of the vaults.', 'HP'])
lines_selected_list.append(['Expecto Patronum!', 'Expecto Patronum!', 'HP'])
lines_selected_list.append(['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'])
lines_selected_list.append(['I spoke a different language?', "But I didn't realize...", 'HP'])
lines_selected_list.append(['Harry?', 'Professor.', 'HP'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP']]

# %% [markdown]
# ## Fry

# %%
temp = load_df(characters[3])
# Out:
# Using custom data configuration default-095be2aab8976f7d
# Reusing dataset csv (C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-095be2aab8976f7d\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-095be2aab8976f7d\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-05c20a0414aaab49.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-095be2aab8976f7d\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-3c93b3526e468e71.arrow
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-095be2aab8976f7d\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-dba8888b5ae9634f.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-095be2aab8976f7d\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-2d14009b5605d617.arrow

# %%
[s for s in temp['test']]
# Out:
# [{'response': "If I were in charge I wouldn't treat you like this. You're nothing but a big blowhard.",
#   'context/0': "Eh, I've heard better.",
#   'context/1': "Fine, I've got a toast. To Captain Bender! He's the best......at being a big jerk and his big ugly face is as dumb as a butt.",
#   'context/2': "Thank you steward. Wiggles? Weren't you about to propose a toast to your gallant captain?",
#   'context/3': "Would you cram a sock in it Bender? Those aren't even medals! They're bottlecaps and pepperoni slices.",
#   'context/4': 'Brilliant!'},
#  {'response': 'Evil Knievel could!',
#   'context/0': 'Hah! No human could do all that.',
#   'context/1': 'And I can deliver them. Billions and billions in one night.',
#   'context/2': 'Toys! Toys! Toys!',
#   'context/3': 'Now we can make toys again!',
#   'context/4': "He's trapped!"},
#  {'response': 'I was just working my way towards the medulla oblongata - control centre of the heart and lungs. And if I kill myself, you die with me.',
#   'context/0': "You've damaged your brain Universe, but no more than a week of binge drinking or five minutes on a cell phone.",
#   'context/1': 'Stop it man!',
#   'context/2': "Obviously you've never been in love! Ow! Ow! Ow! Now, the hand-eye co-ordination lobe.",
#   'context/3': "He's bluffing. No creature would willingly make an idiot out of itself.",
#   'context/4': 'Everyone out of my body or the brain gets it!'},
#  {'response': 'Who said that? Hey! What the--? Ooh! Ow! Ow!',
#   'context/0': 'There he is. Seize him.',
#   'context/1': 'Toss it in the garbage!',
#   'context/2': "Hey, Hawking! Your pizza's ready.",
#   'context/3': 'There is nothing to be concerned about. I must go. There is much to do.',
#   'context/4': "Let me ask you something: Has anyone ever discovered a hole in nothing with monsters in it? 'Cause if I'm the first, I want them to call it a Fry Hole."},
#  {'response': 'Hey! You opened a franchise!',
#   'context/0': "Welcome to Fenway Park, home of the Boston Poindexters where the Mets close out a season that'll rank among mankind's most awful crimes.",
#   'context/1': "Oh you got that too? I think there's a rash goin' around.",
#   'context/2': "I didn't hit the batter! For once I was pitching and not just belly-itching!",
#   'context/3': 'You did it Leela!',
#   'context/4': 'Hooray!'},
#  {'response': 'Professor, when did you become so obsessed with voting?',
#   'context/0': "Yes, that's a capital idea. Let's all go register.",
#   'context/1': "The point is, one vote can make a difference and even though it won't, I'm still taking you to get registered.",
#   'context/2': 'But, like most politicians, he promised more than he could deliver.',
#   'context/3': 'Ah, yes. John Quincy Adding Machine. He struck a cord with the voters when he pledged not to go on a killing spree.',
#   'context/4': "That's not true. The first robot president won by exactly one vote."},
#  {'response': 'I can sorta dance like a robot. Will that help?',
#   'context/0': "We'll have to walk like robots, talk like robots and, if necessary, solve complex differential equations like robots.",
#   'context/1': 'I am fully operational, captain.',
#   'context/2': "OK. If we're going to save Bender, we've got to look and act exactly like robots.",
#   'context/3': "I don't know! I don't know! It's not an easy decision. If only I had two or three minutes to think about it.",
#   'context/4': 'W-what are we gonna do?'},
#  {'response': "Wait, let's go by rank.",
#   'context/0': 'OK. First Bender, then Flexo, then Fry.',
#   'context/1': "Wait, I don't like the sound of that. Let's just go alphabetically.",
#   'context/2': "Space banditos have been operating in this quadrant so you'll each take 8-hour shifts guarding the safe. First Bender, then Flexo, then Fry.",
#   'context/3': "Flexo's great you say? Well that's good enough for me. Welcome aboard lad.",
#   'context/4': "Uh, maybe we should stick with people we know and trust. I mean, Flexo's great but -"},
#  {'response': "Now it's personal.",
#   'context/0': 'Once their task is complete, they will ensure no new information arises in the only way possible: by destroying the universe.',
#   'context/1': "I'm as mad as I've ever been.",
#   'context/2': 'Being brains, they feel compelled to know everything. And soon they will.',
#   'context/3': 'Those bastards!',
#   'context/4': 'Right.'},
#  {'response': 'But instead of falling in and getting frozen, I missed and wanged my head.',
#   'context/0': 'I call it a Hawking Chamber.',
#   'context/1': 'So then my chair tilted back and I almost fell into this freezer thingy.',
#   'context/2': "If we don't go back there and make the event happen, the entire universe will be destroyed! And as an environmentalist, I'm against that.",
#   'context/3': "That's why we had to beat you with tennis rackets.",
#   'context/4': "Mr. Fry, the time disruption indicates that some of that was supposed to happen but didn't, due to a quantum fluctuation."},
#  {'response': "Bigfoot? Is that you? I'm not like the others Bigfoot. I see through your monster coatings to the gentle loner inside. I bet you have a wounded racoon friend that you tenderly nurse back to health and go......and in the end they shoot you. But you teach us about things. Oh, it's a flying saucer. Excuse me? You can't park here. The parking area's over there. Wow nice tube! Hey. Hey what's the big idea? Stop abducting me. Why does your vanity plate say Probe 1?",
#   'context/0': 'Bigfoot? Bigfoot?',
#   'context/1': "Who's that? A wolf? Or some kind of boogen? Oh God I wish I was safe inside a tent. Fry, Fry wake up! It's me! Bigface!",
#   'context/2': "Better than these gnats! That guy won't be goin' home to his kids!",
#   'context/3': "You doin' alright out there buddy?",
#   'context/4': 'Goodnight Hubert.'},
#  {'response': "Stand back. I'm a tool-bot.",
#   'context/0': "I'll show ye!",
#   'context/1': "That's a plus sign, you pointy-haired loony! Quit thinking you're a robot!",
#   'context/2': 'Relax, mammal. My robotic software shall meet your calculatory needs. What is the meaning of this symbol?',
#   'context/3': "Robots don't say ye!",
#   'context/4': 'Fear not! For I shall assist ye!'},
#  {'response': 'Whoa! Letters like U and R can mean words like You and Are. Here Leela, U-R-2 Cute!',
#   'context/0': "My family has been making these hearts since the 1900's. Tastes may have changed but our secret recipe sure hasn't.",
#   'context/1': 'Impressive!',
#   'context/2': 'And now friends and lovers we come to the heart of our operation. Pun definately intended!',
#   'context/3': 'Does that dummy have a brother?',
#   'context/4': 'My two favourite things are commitment and changing myself.'},
#  {'response': 'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'context/0': "I'm too scared.",
#   'context/1': 'Bender, do something.',
#   'context/2': "I'll take care of this.",
#   'context/3': "That's El Chupanibre.",
#   'context/4': 'Say what?'},
#  {'response': "He's dead.",
#   'context/0': 'Dr. Zoidberg? Are you OK?',
#   'context/1': 'All opposed? All abstaining?',
#   'context/2': 'Alright, yup.',
#   'context/3': 'Yeah!',
#   'context/4': "Now well all love Nibbler, so it's only fair that we all pitch in and clean it up together. Still, I propose we make Zoidberg do it. All in favour?"},
#  {'response': "Look out! We're heading straight for those trees!",
#   'context/0': 'Sweet lion of Zion! Look at the Professor go.',
#   'context/1': "At least you're not cold blooded!",
#   'context/2': "Jah damnit! We're stuck.",
#   'context/3': "Enough of your mindless chitchat, let's get going.",
#   'context/4': 'Hi!'},
#  {'response': 'Hm.',
#   'context/0': 'Behold: The Great Stone Face of Mars.',
#   'context/1': 'Did I say girlfriend? She sounds more like a wife!',
#   'context/2': "She won't leave me alone.",
#   'context/3': "I didn't realise you were bringing your girlfriend, lieutenant!",
#   'context/4': 'Aw, look. Betsy followed you, Kif!'},
#  {'response': 'Damn.',
#   'context/0': 'As a friend.',
#   'context/1': 'Even me?',
#   'context/2': "I can't. I love every living creature.",
#   'context/3': 'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'context/4': "I'm too scared."},
#  {'response': 'Huh?',
#   'context/0': "Well, whatever. Hey, listen, as long as we're not seeing each other, you mind if I ask someone else out for Valentine's Day?",
#   'context/1': "I'm sorry, but it is.",
#   'context/2': "But, I was really having fun. If that's how you feel.",
#   'context/3': 'I just think we should start seeing other people.',
#   'context/4': "You're breaking up with me?"},
#  {'response': 'Yes!',
#   'context/0': "Won't you come in?",
#   'context/1': 'You favourite what? Why does my foot hurt?',
#   'context/2': 'Oh, daffodils. 70 years and you remembered my favourite flower.',
#   'context/3': 'Here, I brought you these.',
#   'context/4': 'Move your freaking hoof, you goat!'},
#  {'response': 'Why?',
#   'context/0': 'Enough! There will be no further questions.',
#   'context/1': "I'm just asking cause they look kind of secret.",
#   'context/2': 'Yes.',
#   'context/3': 'You positive?',
#   'context/4': 'No.'},
#  {'response': "I don't mean to nitpick, super-doc, but do you think maybe you could take one more whack at this?",
#   'context/0': 'I may not know from emotions but when it comes to medicine, forget about it.',
#   'context/1': 'Yeah!',
#   'context/2': 'Yeah!',
#   'context/3': 'Hooray!',
#   'context/4': "Yes biggie. I learned to feel things I'd never felt before: Love, jealousy, passion for disembowling. I owe it all to you. There! I pronounce the operation a success."},
#  {'response': "I'll take care of this! Back! Back!",
#   'context/0': "Mutants! They're real!",
#   'context/1': 'Mutants!',
#   'context/2': "OK, OK, nevermind. I'll just ask those people for directions.",
#   'context/3': 'Idiot.',
#   'context/4': 'Idiot.'},
#  {'response': "Wait a second! That's my name! Good Lord. He ditched his goofy name and stole mine!",
#   'context/0': "Hold the phone. If that's Yancy then why does the inscription read Philip J. Fry?",
#   'context/1': "It's my brother Yancy! And there in his lapel - my seven leaf clover! I knew he stole it.",
#   'context/2': 'Who is that God-like figure?',
#   'context/3': "You think? 'Cause I always kinda wished that -",
#   'context/4': "Aw, brothers always fight. I'm sure deep down he loved you. He just never got a chance to say it before you got frozen."},
#  {'response': "I'm walking on sunshine! La la la la sunshine!",
#   'context/0': 'What up?',
#   'context/1': "Aw, I'll never recombobulate this ship! When the Professor finds out, he'll tear me a new cloaca! Wait! What would the robot do? Frame someone.",
#   'context/2': 'I knocked it up a notch. Bam!',
#   'context/3': 'I thought that was number two.',
#   'context/4': 'I hate you.'},
#  {'response': 'There must be people somewhere.',
#   'context/0': "Oh, yeah? Well, listen to this: I'm leaving you.",
#   'context/1': 'Quit standing up for yourself, Fry. When we get back to the hole, we are going to have a long, boring talk about our relationship!',
#   'context/2': "Yeah, but in the year 3000, I had it all. Several friends, a low-paying job, a bed in a robot's closet. I envied no man. But you wrecked everything.",
#   'context/3': "That's because you're a loser. You were a loser in the year 2000 and you're a loser in the year 4000.",
#   'context/4': "I find this post-apocalyptic wasteland very confusing. Seriously, I'm weirded out."},
#  {'response': 'Hey, I plan on having a few brewskis myself.',
#   'context/0': "You're in tremendous danger, you idiot! Half of these Emperors were drunk at their own coronation.",
#   'context/1': "Well at least my assassin will get what's coming to him.",
#   'context/2': "Every Emperor ascended to power by assassinating the previous one. And guess who's next?",
#   'context/3': "Damn! I knew you wouldn't have asked unless it was really high or really low.",
#   'context/4': 'No. One week.'},
#  {'response': 'Ha! That barely hurt Leela at all!',
#   'context/0': 'Fire detected in the vicinity of Leela.',
#   'context/1': "Now look missy! If you don't trun around now I'm going to have to shut down your brain!",
#   'context/2': "Leela. Bender and I really need to be alone. So, I'm turning off the oxygen.",
#   'context/3': "Look, I don't know if you want my opinion",
#   'context/4': 'Whoa whoa whoa! Slow down! All of my friends that have done that said that afterwards all the passion went out of their relationship.'},
#  {'response': 'Words. Nothing sweet, sweet words that turn into bitter orange wax in my ears.',
#   'context/0': "Fry, it doesn't mean anything. I have love enough for two.",
#   'context/1': 'It was very sweet of you, Bender.',
#   'context/2': 'I tried to run you over?',
#   'context/3': "Not physically. But why don't you ask your new best friend, Leela?",
#   'context/4': "Oh God. Fry, I'm so glad to see you. I didn't hurt you did I?"},
#  {'response': "Bender? No! He's an old fashioned one spaceship robot. Look I'll tell him you stopped by OK?",
#   'context/0': "Oh I see. He didn't fly there in another spaceship did he?",
#   'context/1': "Uh, um no. I think he's at his parent's.",
#   'context/2': 'Oh. Hi Fry. Is Bender home?',
#   'context/3': 'Planet Express Ship? Is that you?',
#   'context/4': 'You know Elzar?'},
#  {'response': "He's made of candy.",
#   'context/0': 'And hard working.',
#   'context/1': "He's so polite.",
#   'context/2': "Oh, Bender's a model employee.",
#   'context/3': "I don't know. I usually hire people who are a little less unbearable.",
#   'context/4': "So, how 'bout I work part time at the restaurant to pay off our debt?"},
#  {'response': "So that's where my clover is? Hey, is that orbitting cemetary near here?",
#   'context/0': "Phil came in right, sturmmed out this tune yeah. And I said That's a number one record!",
#   'context/1': "That's what I'm known for!",
#   'context/2': "That's my clover! Yancy stole it!",
#   'context/3': 'That should have been me!',
#   'context/4': 'Shut up friends. My internet browser heard us saying the word Fry and it found a movie about Philip J. Fry for us. It alwso opened my calendar to Friday and ordered me some French fries.'},
#  {'response': "I've had better.",
#   'context/0': 'What about that bathroom egg salad from the truck stop?',
#   'context/1': 'No.',
#   'context/2': 'Fry, did you eat anything unusual recently?',
#   'context/3': "He's a witch!",
#   'context/4': "That's normal. Next patient."},
#  {'response': "But I don't like being a delivery boy.",
#   'context/0': '...out of a cannon into the Sun!',
#   'context/1': 'Fine!',
#   'context/2': "Then you'll be fired...",
#   'context/3': 'What if I refuse?',
#   'context/4': "Take your hands off me! You've been assigned the job you're best at just like everyone else."},
#  {'response': "I'm bored. You're boring, Zoidberg. I'm gonna go watch TV.",
#   'context/0': "So, it's just as I suspected all along. The crime is unsolvable! A letter from Bender, my good friend. Dear Dr. Jerkberg, if you're reading this, I'm already dead. The person who killed me was ... was-- My God! It can't be! The murderer, it was--",
#   'context/1': "Scruffy knows who killed them people. In Scruffy's opinion, it were--",
#   'context/2': "My next clue came at 4.15, when the clock stopped. And another came two hours later at 4.15, when I discovered the murdered body of Amy's dead, deceased corpse.",
#   'context/3': 'This is preposterous. Obviously the murderer is--',
#   'context/4': 'Ew! What smells like boot feet?'},
#  {'response': 'Giant Space Robot, this is Captain Fry of the USS Planet Express Ship; We come in peace.',
#   'context/0': 'By J. Stewart Burns Transcribed by Dave, The Neutral Planet',
#   'context/1': 'FUTURAMA',
#   'context/2': "Compassion? Shrimptoast? Antiquing? I'm alright!",
#   'context/3': 'Enough already!',
#   'context/4': 'Stop it, mon!'},
#  {'response': 'Leela? What are you guys doing here in the year 4000?',
#   'context/0': 'Fry, thank God we found you.',
#   'context/1': "Yes! Footprints! And hand prints? But? What's happening?",
#   'context/2': 'There must be people somewhere.',
#   'context/3': "Oh, yeah? Well, listen to this: I'm leaving you.",
#   'context/4': 'Quit standing up for yourself, Fry. When we get back to the hole, we are going to have a long, boring talk about our relationship!'},
#  {'response': 'Tell me what?',
#   'context/0': 'Someone should tell him.',
#   'context/1': 'Uh...no.',
#   'context/2': "That's what I'm trying to tell you. See - Why are you all staring at me like that? Is there something on my face?",
#   'context/3': 'Fry! What in Sega Genesis happened to you?',
#   'context/4': "Amy, you won't believe what happened......it was so scary that you wouldn't - I know but listen it gets even scarier."},
#  {'response': 'Wait a minute! This says Z-Ray.',
#   'context/0': 'Ah! Is X-Ray eyes. See through anything!',
#   'context/1': "Ooh! What's this?",
#   'context/2': 'Psst! You want to buy organ? Fresh and cheap. Ready for transplant!',
#   'context/3': "Come on, man, don't hold out on me like this!",
#   'context/4': 'Among other things.'},
#  {'response': 'Nah, I had it coming.',
#   'context/0': 'Cram a ham in it you twerps! Sorry!',
#   'context/1': "Well mine's louder!",
#   'context/2': 'Me too. I mean, I have it now, but I forgot.',
#   'context/3': "This show is awesome! When I grow up I'm gonna have so much amnesia!",
#   'context/4': "I 'unno."},
#  {'response': 'Is that an invitation?',
#   'context/0': "Look at yourself. You're a wreck! You've got to find a new place to live.",
#   'context/1': "Oh, it's Bender's apartment. He put in carpeting yesterday so now my head hits the ceiling. Hey, do you realise you're standing at a weird angle? Now you're OK.",
#   'context/2': 'What happened to you?',
#   'context/3': "Yeah, this past week with Fry's been a blast! Y'know, beneath this warm, sunny exterior, beats the cold, mechanical heart of a robot.",
#   'context/4': 'We sure are cheerful this morning.'},
#  {'response': 'Uh, sorry.',
#   'context/0': 'But soon after Charles graduated, our marriage ran into difficulties.',
#   'context/1': 'Sorry.',
#   'context/2': 'His name was Charles. He attended a law school so prestigious, the basketball team was coached by Ruth Bader Ginsberg. I put him through law school by working as a dog walker for antisocial dogs.',
#   'context/3': "I'm sorry.",
#   'context/4': 'Oh, Fry. After you left, things took a turn for the worse. I got married.'},
#  {'response': "You're right Professor. We might not be a traditional family like the Murphy's next door or the lesbian coven across the street but we are a family, and That Guy understands that.",
#   'context/0': "This isn't a business, I've always thought of it as more of a source of cheap labour. Like a family.",
#   'context/1': "I don't care what Ms Johnson says, Thst Guy's turning this place into some kind of...business.",
#   'context/2': 'Thanks doll.',
#   'context/3': 'No sir Mr Fry.',
#   'context/4': "What? I haven't changed. Suz? Have I changed?"},
#  {'response': 'Who are you?',
#   'context/0': "I'm so lonely since I came to the future. Will you be my friend? Ow!",
#   'context/1': 'My work here is done!',
#   'context/2': "Let's watch, shall we?",
#   'context/3': "Ooh! Ooh! I wanna aks it a question! As a robot living among humans, I've never really felt accepted at parties or nude beaches. So I've always secretly wondered: What if I was 500-feet tall?",
#   'context/4': "Of course it works! It's just not very long."},
#  {'response': "I didn't order any --",
#   'context/0': "We're here to tighten your drains.",
#   'context/1': "Mr. Fry. It's those three plumbers you called for.",
#   'context/2': "Get his PIN number, you idiots! Now I'm off to some chairty BS for knocked-up teenage sluts.",
#   'context/3': 'What?',
#   'context/4': 'You know what needs to be done.'},
#  {'response': 'Be brave my friend.',
#   'context/0': 'Poor Bender.',
#   'context/1': 'Destroy all robots! Destroy all robots!',
#   'context/2': "I must go now, to help collect cans on Jupiter. Peace out ya'll!",
#   'context/3': 'The conference is over.',
#   'context/4': "Wait, surely there's a better -"},
#  {'response': 'Where are we?',
#   'context/0': 'Icky!',
#   'context/1': 'You have not won yet. Each book in this room is a gateway to a mental realm and I shall take you there and imprison you forever.',
#   'context/2': "Take that! And that! This sentence I don't understand but take this one!",
#   'context/3': 'Oh, niggle-snoosh!',
#   'context/4': 'Sometimes I fear we are cute.'},
#  {'response': "I don't get it.",
#   'context/0': "No way! Mine's 2716057!",
#   'context/1': '3370318.',
#   'context/2': "Hey brobot, what's you serial number?",
#   'context/3': "No duh dreadlock, we're both bending units.",
#   'context/4': 'Sweet llamas of the Bahamas! Except for that stylish beard, he looks just like Bender!'},
#  {'response': "I'm nobody. There are guys in the background with Mary Worth comics who are more important than me.",
#   'context/0': "So? I'm just as important as him. It's just that, the kind of importance I have, it doesn't matter if I...don't do it.",
#   'context/1': "I do go! He's a very important man.",
#   'context/2': 'Ooo, you go mutant girl!',
#   'context/3': "I met him at that charity cock fight last week. He's the mayor's aide.",
#   'context/4': 'Chaz?'},
#  {'response': "Of all the parasites I've had over the years, these worms are among the - hell! They are the best! Leela, how can I ever repay you for saving them?",
#   'context/0': "If anyone wants to tell me what's going on here, I'll be in the lounge.",
#   'context/1': "Oh that's stupid!",
#   'context/2': 'So? Did you ever stop to think that Fry is better off with worms?',
#   'context/3': 'Leela you ignorant dope! Now the worms will be in Fry forever.',
#   'context/4': "I'm OK."},
#  {'response': "C'mon!",
#   'context/0': 'Mine! Mine!',
#   'context/1': "Son your name is Yancy, just like me and my grandfather and so on. All the way back to minuteman Yancy Fry, who blasted commies in the American Revolution. Philip, until I find a suitable model of an ICBM you'll have to make do learnin' to fear this toy spacecraft.",
#   'context/2': 'I wanna be named Philip! Me Philip! Me Philip!',
#   'context/3': 'Look Yancy, its your baby brother Philip.',
#   'context/4': "That's a fantastic idea. More morphine please."},
#  {'response': "I'm over here.",
#   'context/0': 'Aww, that was uncalled for!',
#   'context/1': 'Try to stay with the crowd so no one notices how crummy you look.',
#   'context/2': "What do you mean What's that?? It's 5 o'clock: Time for the daily human hunt.",
#   'context/3': "What's that?",
#   'context/4': 'Yeah, it was a real chick flick.'},
#  {'response': "Please, it's important to me.",
#   'context/0': "You don't have to do that. I'm still seduced from before.",
#   'context/1': "I'm about to. Leela, let me play for you one for time.",
#   'context/2': 'Fry? I missed you. Did you find out what you needed to find out?',
#   'context/3': "Stop! We'll leave. But one day you'll be eating a fast-food burger and boom! You'll be crawling with us again! Ever wonder what makes special sauce so special? Yo!",
#   'context/4': "I hope Satan has a nice colon, 'cause that's where you're gonna be living!"},
#  {'response': 'Wow!',
#   'context/0': 'And Superking! The best one of the three!',
#   'context/1': 'Clobberella!',
#   'context/2': 'Captain Yesterday!',
#   'context/3': 'A new era of justice has begun.',
#   'context/4': "Listen up New New York! There's a new group of superheros in town! And we're"},
#  {'response': 'I do other human stuff! I age! See?',
#   'context/0': 'Yes, you do. You need to relax more. Terrific. Now, consider the following: You were admitted to this robot asylum. Therefore, you must be a robot. Diagnosis complete.',
#   'context/1': "Look! There's been a terrible mistake. I'm a human being. See? I'm all squishy and flabby. Also, I complain a lot.",
#   'context/2': 'Greetings. I am Dr. Perceptron. Let me give you something to help you relax.',
#   'context/3': 'I find that offensive!',
#   'context/4': 'What the--?'},
#  {'response': 'Blast-off!',
#   'context/0': 'One!',
#   'context/1': 'Two.',
#   'context/2': 'Three.',
#   'context/3': 'Four.',
#   'context/4': 'Five!'},
#  {'response': 'I should be the one in that grave!',
#   'context/0': "They buried your brother in the world heroes section? I'm impressed.",
#   'context/1': "Hmm Breakfast Club, this'll clear out the room at the end of the reception.",
#   'context/2': "Have a look downstairs. Your brother may be missing but his crap sure isn't.",
#   'context/3': "Oh that reminds me. I was thinking of rummaging through Phil's records for something to play at the wedding.",
#   'context/4': "I'll never forget the day Philip disappeared. Wisconsin won the rose bowl 17-9. Oh I miss him."},
#  {'response': 'No! No!',
#   'context/0': 'Hey everyone jam a sock in your spit faucets. Not long ago I spent my lonely nights renting slash flicks with Rat Man and his girlfriend. But then a beautiful woman arrived and - stop eating pig! And she brought new hope for me and our once great civilisation. Now a million centuries of Cyclops destiny depend on the answer to one question......Leela, will you marry me?',
#   'context/1': "I'm trying.",
#   'context/2': "C'mon Leela you deserve better than this guy! Dump him already!",
#   'context/3': 'Yeah, like crap.',
#   'context/4': 'Yo Leela, what gives? Pig says your slop tastes like crap.'},
#  {'response': 'Start with a compliment: Tell her she looks thin.',
#   'context/0': "Dr. Zoidberg, that doesn't make sense. But OK.",
#   'context/1': "I just wanna talk, it has nothing to do with mating. Fry, that doesn't make sense.",
#   'context/2': 'You just wanna talk, it has nothing to do with mating.',
#   'context/3': 'I have no idea.',
#   'context/4': 'What the--? Dr. Zoidberg, your mating display failed. Why are you trying to talk to me?'},
#  {'response': "Why would robots vote for Nixon now that he's just a head in a jar?",
#   'context/0': 'Get out of town!',
#   'context/1': 'What?',
#   'context/2': 'No!',
#   'context/3': 'The time is 7:59 and the robot polls are now opening...and the robot vote is in. Nixon has won!',
#   'context/4': 'Yes! The system works!'},
#  {'response': "It'll be a rich, full day.",
#   'context/0': "Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   'context/1': "Wouldn't it make sense to weld everyone except me to the wall?",
#   'context/2': 'There. No rampaging for you tonight.',
#   'context/3': "Now go! Go! Uh, could one of you just...? Ah, forget it. I'll just sleep here.",
#   'context/4': "I wouldn't wanna be me right now."},
#  {'response': 'Sure.',
#   'context/0': 'Anyone wanna play Dungeons amp; Dragons for the next quadrillion years?',
#   'context/1': "Eternity with nerds. It's the Pasadena Star Trek convention all over again.",
#   'context/2': "I don't know. But I can darn well tell you where we're not: The universe.",
#   'context/3': 'Destroyed? Then where are we now?',
#   'context/4': 'Great. The entire universe was destroyed.'},
#  {'response': "Uh....I-I've got talking hump syndrome.",
#   'context/0': 'Did you hump just say something?',
#   'context/1': 'Stupid robot.',
#   'context/2': 'Eh, keep the change buddy.',
#   'context/3': 'We only need one cell!',
#   'context/4': 'Got a hot steaming batch right here!'},
#  {'response': "Don't you worry about blank let me worry about blank.",
#   'context/0': "OK, lets work on your execu-speak. I'm worried about blank.",
#   'context/1': 'Make it two. And a glass of all your water.',
#   'context/2': 'Bring me that.',
#   'context/3': 'Everything.',
#   'context/4': "What have you got that's really overpriced?"},
#  {'response': "Oh wow. It's like that drug trip I saw in that movie when I was on that drug trip.",
#   'context/0': 'Come out of your universe with your hands up!',
#   'context/1': "I tell you they're not evil. But don't be confused. They are jerks.",
#   'context/2': 'Leela? The good Leela. I want you to snoop around the other universe and find out how evil they are. Here.',
#   'context/3': "Oh this is awful. Somewhere there's a Bender more evil than me. I do my best dammit!",
#   'context/4': "Oh you'd like us to believe that wouldn't you Leela? Or should I say Eveela?"},
#  {'response': 'Bathroom.',
#   'context/0': 'Bath what?',
#   'context/1': "Uh, listen, Bender, uh, where's your bathroom?",
#   'context/2': 'I was having the most wonderful dream. I think you were in it.',
#   'context/3': 'Bender, wake up!',
#   'context/4': 'Kill all humans...kill all humans...must kill all the humans.'},
#  {'response': 'Oh, no! Any sign of Leela or Amy?',
#   'context/0': "Well, hello! I usually don't say this but you are the most beautiful trio of gigantic ladies I've ever laid eyes on. I find the most erotic part of a woman is the boo--",
#   'context/1': 'No big deal. Everybody make mistake.',
#   'context/2': 'Me hear people. But me not see people.',
#   'context/3': 'What is it?',
#   'context/4': 'Well, nothing to do now but repopulate the human race. Just me and you! And maybe you.'},
#  {'response': "Great he's whacked out on electricity again.",
#   'context/0': "Oh, what a beautiful morning, oh what a beautiful day! Greetings, friends. Don't we all look nice today?",
#   'context/1': 'This is a witch hunt!',
#   'context/2': 'And as a further cost-cutting measure, I have eliminted the salt-water cooler.',
#   'context/3': 'Me.',
#   'context/4': 'So I ask ya: Who will stand up and be saved? Who? Who?'},
#  {'response': "What's the word...uh...sir?",
#   'context/0': 'Of course, my significant soldier. The bomb is voice activated. It will detonate the instant the robot unwittingly speaks a certain word.',
#   'context/1': 'Uh, commander? Could you tell me when the bomb is exploding?',
#   'context/2': 'Come along, Lemon before this whole dump blows up.',
#   'context/3': "Attention: All personnel evacuate the planet immediately. And not just because it's meat loaf night.",
#   'context/4': 'Whoa! Scuse me.'},
#  {'response': 'What a pleasant surprise!',
#   'context/0': "Very good. I also would have accepted Blank? Blank?! you're not looking at the big picture!",
#   'context/1': "Don't you worry about blank let me worry about blank.",
#   'context/2': "OK, lets work on your execu-speak. I'm worried about blank.",
#   'context/3': 'Make it two. And a glass of all your water.',
#   'context/4': 'Bring me that.'},
#  {'response': 'Strike him out Leela! Do it for the hundreds of women everywhere!',
#   'context/0': 'Put it right down the pike!',
#   'context/1': 'Come on Leela!',
#   'context/2': 'Go Leela!',
#   'context/3': 'Bean! Bean! Bean! Bean! Bean!',
#   'context/4': "Alright then. Get in there and pitch like you've never pitched like you before!"},
#  {'response': "I don't get it, Michelle. The last time I saw you, you were doing great. You had just dumped me and you were well on your way to getting you life back on track. Why'd you freeze yourself?",
#   'context/0': 'Oh, Fry, it is you!',
#   'context/1': 'Who wants to know?',
#   'context/2': "What do you mean you don't know? Are you you or not?",
#   'context/3': "I don't know. Is it really you?",
#   'context/4': 'Fry? Is it really you?'},
#  {'response': 'What?',
#   'context/0': "Uh-oh, jealousy. You think you're so hot!",
#   'context/1': "Hell, no! It's Leela's stupid feelings. Why can't she just drink herself happy like a normal person?",
#   'context/2': 'You do?',
#   'context/3': 'I miss Nibbler.',
#   'context/4': "What's your problem?"},
#  {'response': "If those aren't tears of happiness, please stop crying.",
#   'context/0': 'Wooo!',
#   'context/1': 'Yes! I mean no! Just make sure you get my nonchalant side!',
#   'context/2': "Mind if I get a picture of you with your picture for the news, ma'am?",
#   'context/3': "That's it, Albert, no more espresso for you.",
#   'context/4': "Nuh uh, 'cause I'm double Leela!"},
#  {'response': "Junk? Maybe you can't understand this but I've finally found what I need to be happy, and it's not friends: It's things.",
#   'context/0': 'Yeah. Now are you gonna come to the squid fights with us or sit here wallowing in your prehistoric junk?',
#   'context/1': "But we're your friends and we live here in the year 3000.",
#   'context/2': "I'm rich! I can live whenever I want.",
#   'context/3': "Fry, this isn't healthy. You're living in the past.",
#   'context/4': "I could if you hadn't turned on the lights and shut off the stereo."},
#  {'response': "They're OK.",
#   'context/0': "Oh, here's a cryogenic counsellor! Do you like Mondays?",
#   'context/1': "Delivery boy? I must have mixed up the chips. It's a simple mis -",
#   'context/2': 'Just put your hand under the scanner so I can verify your career chip. Calcutta, we have a problem.',
#   'context/3': 'Monday Monkey lives for the weekend, sir.',
#   'context/4': 'Oh, I was hoping you would come back! I even saved your poster of a chimp expressing your distaste for Mondays.'},
#  {'response': 'There. Finished!',
#   'context/0': 'Show us this, the wheel.',
#   'context/1': 'Never heard of it.',
#   'context/2': 'It was called...let me think. It was really famous - Ruth Gordon had one. The wheel!',
#   'context/3': 'Impossible!',
#   'context/4': 'Wait. In my time, we had a way of moving things long distances without hovering.'},
#  {'response': 'Never mind Professor, she came to.',
#   'context/0': 'I was having the most wonderful dream. Except you were there and you were there and you were there.',
#   'context/1': 'Leela, are you alright? You got wanged on the head.',
#   'context/2': 'Wake up!',
#   'context/3': "Uh sorry, I think there's a problem with your upstairs toilet.",
#   'context/4': "Uh, alright. Here I go. There's no place like - I wanna be a witch! Oh no, help, what's happening?"},
#  {'response': 'Are you still mad at me for wrecking your once in a lifetime chance to learn the meaning of your existence?',
#   'context/0': 'Come on. We have worked to do.',
#   'context/1': "Oh Leela. I feel terrible. If there's anything I can ever do - Gotcha! I won! I'm the greatest!",
#   'context/2': "Fry, you idiot. Ever since I was abandoned on Earth I've been searching for who my people are and where they come from. Then I finally meet another Cyclops and you blast him. You wrecked my one chance to learn who I am.",
#   'context/3': 'Do you think perhaps you and I - ?',
#   'context/4': "I can't believe it. I've dreamed of this moment all my life."},
#  {'response': 'To the left! No to the up! U-turn, U-turn!',
#   'context/0': 'To the flying machine!',
#   'context/1': "I'm zeroing in on him. Bengay...mothballs......letters to the editor. It's the Professor!",
#   'context/2': "I think not. As you probably already don't know, odours are made up of particles that can't travel through the vacuum of space.",
#   'context/3': "If the smelloscope can pick up the Professor's odour, we may have a chance to save him.",
#   'context/4': 'Lay it on us big boots.'},
#  {'response': 'One year later I gave Leela a diamond scrunchy, and we were married.',
#   'context/0': 'You really missed out on something Leela. That date was magical.',
#   'context/1': "You mean you flipped the coin too? And it was tails? So that's why you said you had to meet that ghost.",
#   'context/2': 'I flipped a coin. It came up heads and we went out.',
#   'context/3': 'Oh Lord!',
#   'context/4': "Then one night when Fry asked me out the only excuse I could think of involved ghosts. I knew he wouldn't buy it so I did what I always do in those situations."},
#  {'response': "What's happening?",
#   'context/0': 'Time-out! Time-out!',
#   'context/1': 'Ladies and gentlemen, something very strange has just happened in this basketball game between space clowns and atomic monsters.',
#   'context/2': 'What the? Did everything just jump around? Or did my brain just stroke off there for a second?',
#   'context/3': 'Curly Joe, easily amused by his own antics......continues to wreak havoc on -',
#   'context/4': "It was always our plan to trail at the half. Thus deepening Earth's eventual humiliation. Also: What game were the refs watching?"},
#  {'response': "What's with the specs Bender?",
#   'context/0': "C'mon, let's deal. You'll have plenty of time to talk when you're poor.",
#   'context/1': "And my wife doesn't know I have a job. I keep my personal and professional lives serparate.",
#   'context/2': "But you never wore your ring. I didn't know you had a wife.",
#   'context/3': 'So I told Leela, Your request for a date is most flattering but I must decline. These office romances never work out. Afterall, that is how I met my horrible wife.',
#   'context/4': 'Let the games begin!'},
#  {'response': 'No knife can penetrate my skin-tanium armour.',
#   'context/0': "Let's see how much of a robot you really are!",
#   'context/1': "Fry! Don't be a hero! It's not covered by the health plan!",
#   'context/2': "I'm not crazy! Don't call me crazy! I'm just not user-friendly!",
#   'context/3': 'Negative, bossy meat creature. I know now what my primary function is: I am a battle-droid. Sworn to protect the weak from crazy robots.',
#   'context/4': "Fry! Stay back. He's too powerful."},
#  {'response': 'Oh yeah? Then what about this?',
#   'context/0': "It, uh, oo! Uh, hey sweetie, just go back to the castle and wait for me. She, she's nuts, I can morph into a 5-eyed alien and I kinda said I'd marry her. But I'm really a Cyclops and I'm really going to marry you.",
#   'context/1': 'Alkazar, why you are so late for our wedding? And why you have only one eye?',
#   'context/2': 'Hey Alkazar, you left somebody off the guest list.',
#   'context/3': 'What the?',
#   'context/4': 'Oh my God!'},
#  {'response': 'Christmas. You know? X-M-A-S.',
#   'context/0': 'What-mas?',
#   'context/1': 'Yeah, it really puts you in the Christmas spirit.',
#   'context/2': 'Ah! Nothing like a warm fire and a Super Soaker of fine cognac.',
#   'context/3': 'Wha?',
#   'context/4': 'Oh, excuse me. Hello there.'},
#  {'response': "Xmas, huh? Y'know this'll be my first Xmas away from home.",
#   'context/0': 'Oh, you mean Xmas. You must be using an archaic pronunciation. Like when you say ask instead of aks.',
#   'context/1': 'Christmas. You know? X-M-A-S.',
#   'context/2': 'What-mas?',
#   'context/3': 'Yeah, it really puts you in the Christmas spirit.',
#   'context/4': 'Ah! Nothing like a warm fire and a Super Soaker of fine cognac.'},
#  {'response': 'How can you people be so blase? Here you are in the year 3000 or so, yet you just sit around like its the boring time I came from.',
#   'context/0': "We all feel like that all the time. You don't hear us gassin' on about it.",
#   'context/1': 'Big deal.',
#   'context/2': "Well I don't care if it was some dork in a costume. For one brief moment I felt the heartbeat of creation. And it was one with my own.",
#   'context/3': 'They have a college kid wear that to attract customers.',
#   'context/4': 'Yeah.'},
#  {'response': 'Aha! Cornered!',
#   'context/0': 'Alright, bird, you thought you could beat me in a game of wits. But you just met your equal.',
#   'context/1': "I'm telling you why. Santa Claus is coming to town!",
#   'context/2': 'Why?',
#   'context/3': "Wait! You mean he's still out? His life's in danger!",
#   'context/4': 'I hear that! I aks him to set the table. Instead he goes out to buy you a present. Selfish dog.'},
#  {'response': "Ah, no one likes them at first but they'll grow on you.",
#   'context/0': "I don't know, I've had cow. Ew! Gross!",
#   'context/1': "OK, my friends. Get ready for the most delicious extinct animal you've ever tasted.",
#   'context/2': 'What a nice lady!',
#   'context/3': "Holy hell! You're going to eat them? Oh, well. Just make sure you eat them all. You're a growing boy. Toodle-oo! Dumb ass!",
#   'context/4': "You might as well put that chequebook away, because I've discovered something even more important. My friends. And they aren't worth even a penny to me. That's why these anchovies are going on a pizza, so I can share the food I love with the people I like."},
#  {'response': "OK, my best friend's life is at stake. I can finally prove that I'm not a coward. Will you push me?",
#   'context/0': "We're here. I followed the bouncing balls. I'll keep the chopper at a safe altitude while you parachute down.",
#   'context/1': "This isn't a productive area of discussion.",
#   'context/2': "These balls are making me testy. If they don't stop bouncing and jiggling, I swear I'm gonna shove this treaty up their -- Wait a second. Where do you shove things up a ball?",
#   'context/3': 'Mr. Ambassador, our people tell the same story. Oy.',
#   'context/4': 'The elders tell of a young ball much like you. He bounced three metres in the air. Then he bounced 1.8 metres in the air. Then he bounced four metres in the air. Do I make myself clear?'},
#  {'response': 'Ugh!',
#   'context/0': 'Nah, those lousy Moochers cleaned out our pantry. All they left was baking soda and capers. And here it is!',
#   'context/1': 'Dinner ready?',
#   'context/2': "I hate the Planet of the Moochers. They take you out for a drink, but when the check comes, their wallet's always in their other pants - which they borrowed from me!",
#   'context/3': "Nobody doesn't like Molten Boron!",
#   'context/4': 'Futurama is brought to you by......Molten Boron!'},
#  {'response': "Sir, I'm outfitting an expedition to a monestary high in the Himalayas. I'll need a long sleeved coat.",
#   'context/0': "What part of nay doesn't thou understand?",
#   'context/1': 'But, but Metal Lord.',
#   'context/2': "Malachi, every time I interfere I only make things worse. You're best off solving your own problems.",
#   'context/3': 'They talk of war against the faithful. I beseech thee. Rise up against them, smite someone who deserves it for once.',
#   'context/4': "Of course they're unheeded how am I supposed to hear prayers coming out of my ass?"},
#  {'response': "I don't know. Is it really you?",
#   'context/0': 'Fry? Is it really you?',
#   'context/1': 'Oh, my God!',
#   'context/2': 'Michelle!',
#   'context/3': 'Boo?',
#   'context/4': "Showtime! I'll pretend to be dying of space plague."},
#  {'response': "I'm not a robot! I'm not a robot!",
#   'context/0': 'Jeez, Red. Quit cowering. You call yourself a robot?',
#   'context/1': "Hey! Keep it down in there! I'm tuning my banjo!",
#   'context/2': 'No! Please! Help! Stop it! Please!',
#   'context/3': "Noticeably? I'll say! Now stand back, I gotta practice my stabbing.",
#   'context/4': 'N--, n--, n--'},
#  {'response': 'Where?',
#   'context/0': "Sandstorm! We're in the eye of the storm!",
#   'context/1': "Hey, it's that barbecue's over sound again.",
#   'context/2': 'I once took a seminar in ejecting chickens from a sand dune. The principle is essentially the same.',
#   'context/3': 'Kif! You did it! But how did you know the dynamite would work?',
#   'context/4': 'Too late! This is more fun!'},
#  {'response': "Uh, I'll have a coffee.",
#   'context/0': "I don't know you well enough to get into that. 300 please. Noon tomorrow. If you're late you only get to tread water in the scallop tank.",
#   'context/1': "Then why'd you become a whale biologist?",
#   'context/2': "Well you asked the right guy! I'm the whale biologist! Though personally I hate whales. Espeically Mushu.",
#   'context/3': "I'd like a pass to swim with Mushu please.",
#   'context/4': 'Ow!'},
#  {'response': 'Oh, right. Plus, the magnet screws up your inhibition unit and makes you sing folk songs.',
#   'context/0': "Oh, no, I'm not going near it. Last time, that magnetic psycho nearly cut my head off.",
#   'context/1': 'Whale oil. Bender, lift it up to the can opener.',
#   'context/2': 'Like what?',
#   'context/3': 'Gas was an environmental disaster, anyway. Now we use alternative fuels.',
#   'context/4': 'Wrong again, idiot. There is no gas. Petroleum reserves ran dry in 2038.'},
#  {'response': 'Tremble? I laugh. Nobody knows more about Star Trek than me!',
#   'context/0': 'Centuries ago, the videotaped adventures of the Enterprise crew rained down upon my planet. Over and over, I watched them. Especially the five with the energy beings. I am Melllvar! Seer of the tapes, knower of the episodes! Tremble before my encyclopaedic knowledge of Star Trek!',
#   'context/1': "Alright, you gas, what's the deal?",
#   'context/2': 'Hey! A body! Buff, tan. Yeah, this is mine alright!',
#   'context/3': 'Behold another power, different from the one you saw earlier.',
#   'context/4': 'Go yourself.'},
#  {'response': "Well Rudy, how'd you like this action?",
#   'context/0': 'No.',
#   'context/1': 'And remember when Mayor Giuliani cracked down on jaywalking?',
#   'context/2': 'New York is so burned.',
#   'context/3': "Wow! We've got Manhattan all to ourselves! I can finally do all the crazy stuff I always dreamed of doing! Howard Stern s overrated! Uh, oops!",
#   'context/4': 'Old New York. The city that inspired a casino in Las Vegas.'},
#  {'response': 'Come on!',
#   'context/0': 'Please, no!',
#   'context/1': 'Tom Sawyer, you tricked me. This is less fun than previously indicated. Let this corny slice of Americana be your tomb for all eternity.',
#   'context/2': "Yep. I let him help me whitewash Aunt Polly's fence.",
#   'context/3': 'Excuse me, have you seen a giant brain?',
#   'context/4': "Follow him! It's our only way out!"},
#  {'response': 'Hey, Bender?',
#   'context/0': "Come, Kif, it's time to begin our life as civilians. That's an order, soldier.",
#   'context/1': "No, it doesn't.",
#   'context/2': 'One day a man has everything, the next day he blows up a 400 billion space station and the next day he has nothing. It makes you think.',
#   'context/3': 'Kif Kroker, you are also stripped of your rank and dishonourably discharged.',
#   'context/4': 'What?'},
#  {'response': "You don't have to get so mad, Leela.",
#   'context/0': "Alright, this is the third hose fight I've broken up today and the second one using actual hoses. Now move your lazy asses and start scrubbing the ship like I ordered you to.",
#   'context/1': 'Yeah?',
#   'context/2': 'Hey, Bender?',
#   'context/3': "Come, Kif, it's time to begin our life as civilians. That's an order, soldier.",
#   'context/4': "No, it doesn't."},
#  {'response': "He's gonna blow.",
#   'context/0': "Rudolph's nose!",
#   'context/1': 'Watch out! His belly is shaking like a bowl full of nitro-glycerine!',
#   'context/2': 'Ho ho ho! Time to get jolly on your naughty asses!',
#   'context/3': "Yeah? Well I don't believe in Santa Claus. Come on, everybody, if you don't believe in him he can't hurt you. Ow! God! The pain!",
#   'context/4': "As for the rest of you, I'm going to tear off your skin like wrapping paper and deck the halls with your guts."},
#  {'response': 'Why would a robot need to drink?',
#   'context/0': "Well that's your job, whether you like it or not and it's my job to make you do your job whether I like it or not - which I do - very much! Now get to work! Life is good!",
#   'context/1': "Look, he's just a nobody who doesn't want to be a delivery boy. I'd really rather not force it on him.",
#   'context/2': 'This is unacceptable, Leela. You must find this Mr. Fry and install his chip.',
#   'context/3': 'Shut up, Terry.',
#   'context/4': 'Welcome to the world of tomorrow!'},
#  {'response': "I'll never remember that.",
#   'context/0': "Name's Old Man Waterfall. But most folks just call me Old Man.",
#   'context/1': 'Who are you, old man?',
#   'context/2': "Howdy there! I'm a lawyer and I'd like to help your friend out of his pickle.",
#   'context/3': 'Kill Zoidberg! Goodnight!',
#   'context/4': "I'll ask the head of the ACLU. Once he's done singing."},
#  {'response': "How's that?",
#   'context/0': "Aw yeah, that's it. A little lower.",
#   'context/1': 'Uh...sure.',
#   'context/2': "Actually your little stunt did a number on my back. You mind rubbin' it for me?",
#   'context/3': "Well just let me know if there's anything I can do to make it up to you.",
#   'context/4': "Well I don't feel as bad as you look! Nah I'm just messing with you kid. You're alright. That's some face you got though, I think they got a cream for that. Nah, you're great."},
#  {'response': "I'm telling you, Leela was cool, she was in command, and when she kicked people it hurt. It really hurt.",
# ...
#   'context/1': 'We gotta go rescue them!',
#   'context/2': 'The number you have dialled has crashed into a planet. Please make a note of it.',
#   'context/3': "I can't believe Leela and Amy aren't back yet from their half-date. I'm gonna call the restaurant.",
#   'context/4': 'Look, you fat fish. The Planet Express health plan only covers one kind of replacement shell.'},
#  {'response': 'Whoa! Check out that guy. He makes Speedy Gonzales look like Regular Gonzales.',
#   'context/0': "What's the matter, private? Tent got your tongue? Tent got your... Kif, write that down and send it to Humour In Uniform.",
#   'context/1': 'They look like dorks!',
#   'context/2': "A valid question. We know nothing about their language, their history or what they look like. But we can assume this: They stand for everything we don't stand for. Also, they told me you guys look like dorks.",
#   'context/3': "Uh, just so we'll know, who's the enemy?",
#   'context/4': "Don't ask me, you're the one who's going to be dying."},
#  {'response': 'Ah, futuristic!',
#   'context/0': "Uh, Fry, you're in the womens' steam room.",
#   'context/1': 'Co-ed steam rooms! I love the future!',
#   'context/2': 'Yo, yo, yo! Whassup whassup! Give up the rock!',
#   'context/3': 'What up, Dr. Z?',
#   'context/4': "We crustaceans don't like steam. I'm going to go work out with the Nautilus!"},
#  {'response': "Obviously you've never been in love! Ow! Ow! Ow! Now, the hand-eye co-ordination lobe.",
#   'context/0': "He's bluffing. No creature would willingly make an idiot out of itself.",
#   'context/1': 'Everyone out of my body or the brain gets it!',
#   'context/2': 'Listen you, I was born here. I raised a cloud of children here. My ancestors came over here on the sandwich. No one can make me leave!',
#   'context/3': "Well, a wonderful girl loves me. But I need to know if it's really me she loves, or just what you worms have made of me. That's why with all due respect, I'm asking you to leave.",
#   'context/4': 'No. I thought I was once but then I remember our species reproduces with a cloud of spores.'},
#  {'response': 'You OK there in the embassy, Zoidberg?',
#   'context/0': "Wait, you're a lawyer? You're hired!",
#   'context/1': "I don't condone what Dr. Zoidberg did but I'll fight tooth and nail for his freedom to do it. Or I would if I hadn't lost my teeth and nails on Mars and Saturn respectively.",
#   'context/2': 'The sparks keep me warm.',
#   'context/3': "Son, to me a robot's just a garbage can with sparks comin' out it.",
#   'context/4': 'And you wanna defend Zoidberg? Are you familiar with the old robot saying Does Not Compute?'},
#  {'response': 'Wow The jungles on Mars look just like the jungles on Earth.',
#   'context/0': 'Hey!',
#   'context/1': 'Fraternities, on your marks.',
#   'context/2': 'Well, I never!',
#   'context/3': 'Oh, yeah? Watch this!',
#   'context/4': 'Good one, Chet!'},
#  {'response': 'Thanks. Where is she?',
#   'context/0': 'Thanks.',
#   'context/1': 'That dress looks great on you.',
#   'context/2': "Oh, God, it's true!",
#   'context/3': "Yeah, but it's good to make them wait a little.",
#   'context/4': "20 minutes? You're practically ready now!"},
#  {'response': "No you can't. Shut your adorable trap!",
#   'context/0': 'We can explain!',
#   'context/1': 'You little runts froze me! You took away my life!',
#   'context/2': 'Detonation in T-15 seconds.',
#   'context/3': "I, I don't understand. You made me go in the freezer tube?",
#   'context/4': 'What the?'},
#  {'response': 'And action!',
#   'context/0': "Trust me on this. While other people were out living their lives, I wasted mine watching TV, because deep down I knew it might one day help me save the world. Plus, I would have lost my Workman's Comp if I hadd gone outside. Now just read these cue cards.",
#   'context/1': "Whatchoo talkin' 'bout, Fry?",
#   'context/2': "You see? TV audiences don't want anything original. They wanna see the same thing they've seen a thousand times before.",
#   'context/3': 'Attention, McNeal. Your unexpected marriage plan scares us. You stole our hearts as a single female lawyer, and so shall you remain -- or else!',
#   'context/4': "But that's not why people watch TV. Clever things make people feel stupid, and unexpected things make them feel scared."},
#  {'response': 'Think about it. Seymour lived a full life after I was gone. He probably added new songs to his repertoire.',
#   'context/0': "Fry, what's wrong?",
#   'context/1': "Oh sure! Smash the smart guy's machine!",
#   'context/2': 'Stop the cloning.',
#   'context/3': 'Indeed.',
#   'context/4': '15? You mean he lived for 12 more years after I got frozen?'},
#  {'response': 'Even bigger than those? Holy nuts! Where is it?',
#   'context/0': 'You go fight biggest brain of all.',
#   'context/1': 'No, Leela. Brain make people smart.',
#   'context/2': 'Brain. Brain make people dumb.',
#   'context/3': 'Oh! Chester A. Arthur fall down.',
#   'context/4': 'The professy will help! Fire indeed hot!'},
#  {'response': "Nope, I'm better than ever. Before the accident I couldn't do this!",
#   'context/0': 'Fry? I thought you were dead.',
#   'context/1': 'Leela?',
#   'context/2': "They say a spoonful of space honey helps ease the pain. It's good. I feel funny. Haha funny!",
#   'context/3': 'Farewell from the world of tomorrow!',
#   'context/4': "All those times I said Kill all humans I'd always whisper except one. And Fry was that one. And I never told him so."},
#  {'response': 'Same thing.',
#   'context/0': "Bender's not a guy, he's a robot.",
#   'context/1': "Don't girl me with that girl stuff. Bender and me are guys. Guys don't have feelings.",
#   'context/2': "Only when he's in them and you know it. You really hurt his feelings.",
#   'context/3': 'Ah, come on. Bender loves mobs.',
#   'context/4': "Fry, you're Bender's best friend. How could you let that mob kick him out?"},
#  {'response': 'Leela back yet?',
#   'context/0': "Too bad Nibbler's not around. I guess I'll have to eat this raw, dripping ham by myself. Nibbler? Nibbler, you're scaring me. Nibbler?! Am I going crazy? Have my years of wild hedonism finally caught up with me? Nibbler, help! Don't leave me here. Uh, Nibbler? Could you scooch the seat up just a little bit?",
#   'context/1': 'No! Nibbler, come back!',
#   'context/2': 'What now?',
#   'context/3': "What's got into him? He's twitching like Zoidberg when someone mentions the word food.",
#   'context/4': "I'd hate to be those guys."},
#  {'response': 'Yeah!',
#   'context/0': 'A portion of the proceeds might go to help broken robots.',
#   'context/1': 'Tuesday, Golden Gate Park, the monsters of vaguely folkish alterna-rock will strum your brains out at Bend-Aid! Featuring Beck, Wailing Fungus and special guest, Bender!',
#   'context/2': "Wow, I forgot about TV. Living free on the road, you realise how much better life is without it. Well, let's see what's on.",
#   'context/3': 'Alright, but hands off the minibar.',
#   'context/4': 'Mind if we crash here tonight? The colours in the van are keeping us awake.'},
#  {'response': 'I just wanted to do something to make you happy. I mean, I miss my family but you never even had a family.',
#   'context/0': "You didn't need to buy me a present, Fry.",
#   'context/1': 'Leela! Oh, my God! You saved my life. I am gonna get you so many lizards.',
#   'context/2': 'Hi there!',
#   'context/3': 'Aha! Cornered!',
#   'context/4': 'Alright, bird, you thought you could beat me in a game of wits. But you just met your equal.'},
#  {'response': 'Hey, business is great.',
#   'context/0': "Bender's a genius.",
#   'context/1': 'Good idea.',
#   'context/2': 'Hey, yeah.',
#   'context/3': "Whoa, whoa, slow down there, Sigmund. I can't stand idly by while poor people get free food. We gotta sell these things!",
#   'context/4': 'Call them what you want. I call them a free meal.'},
#  {'response': 'Hooray!',
#   'context/0': "Bad news everyone. You're not good enough to go on your next mission.",
#   'context/1': 'A hush comes over the crowd. The only sound is Bender calling everyone else a jerk and he swings! And he slices it into the water, oh man!',
#   'context/2': 'By Patric M. Verrone Transcribed by Dave, The Neutral Planet',
#   'context/3': 'Yes!',
#   'context/4': 'FRY'},
#  {'response': 'I wanna hear a space story!',
#   'context/0': 'There. Todays story is from New Teen magazine. What would you rather hear about? Four legged Chachi or tentacled Chachi?',
#   'context/1': "I can't see from down here I can't.",
#   'context/2': "OK, quiet time. I know, everyone pretend to THING TO CHECK your tongue and I'll read you a story.",
#   'context/3': "Would you all chill! I can't think with you kids cramping my style! Oh I need a babysitter!",
#   'context/4': 'Oh sure like you need all your blood.'},
#  {'response': 'You alright, Bender?',
#   'context/0': "Ow, my head! My precious head! Stupid can opener. You killed my father and now you've come back for me!",
#   'context/1': 'Is it me?',
#   'context/2': 'Aww! Somebody likes snouts.',
#   'context/3': "Futurama is brought to you by ... ... Glagnar's Human Rinds. It's a buncha muncha cruncha human!",
#   'context/4': 'By Patric M. Verrone Transcribed by Dave, The Neutral Planet'},
#  {'response': 'Ow!',
#   'context/0': "Fry, that's offensive to our people. Isn't it?",
#   'context/1': "Is that anything like a cemetary 'cause I gotta take a leak. Ow!",
#   'context/2': 'The Forbidden Valley. A holy sancturary where no one may tread.',
#   'context/3': "What's over that hill?",
#   'context/4': "And there's the pirate Purple Beard, scourge of the six seas."},
#  {'response': 'Yeah, Leela.',
#   'context/0': "You left the keys in the ignition. I mean, look at those two. Wasn't it obvious what would happen?",
#   'context/1': 'What did I do?',
#   'context/2': "You've gone too far this time - all three of you!",
#   'context/3': "And no one suspects a thing! Whoa! And that's how we learned our lesson!",
#   'context/4': 'That was great!'},
#  {'response': "Then she wants me as a trophy husband. Leela, you gotta come to Europa with us, I can't be alone with her.",
#   'context/0': "Fry, she's pulling down billionaire trust-fund money.",
#   'context/1': "Am I? Face it, I'm a prize catch. I mean, I'm pulling down delivery boy money.",
#   'context/2': "I think you're over reacting.",
#   'context/3': "I'm doing my job -- there's Amy. I spend a few hours selecting a candy from the machine -- there's Amy. I wake up the morning after sleeping with Amy -- there's Amy!",
#   'context/4': 'Fry--!'},
#  {'response': "My nose is an aphrodisiac? I'm gonna drop a barf!",
#   'context/0': 'The valuable nose or human horn fetches a high price on alien worlds as an aphrodisiac.',
#   'context/1': 'The culprits: Shameless poachers, hunting humans without a permit.',
#   'context/2': 'Like me!',
#   'context/3': "Alien abductions: Until now, a harmless nuisance. But recently they've taken on a sinister dimension as unsuspecting victims are returned...without noses!",
#   'context/4': "Guys, guys! There's something on television."},
#  {'response': "Apology accepted. After all, you're only human.",
#   'context/0': "You're my best friend, Fry, I'm sorry I treated you so badly.",
#   'context/1': "She's right.",
#   'context/2': 'You guys could learn a lesson from those two.',
#   'context/3': "Apology accepted. After all, you're only human.",
#   'context/4': "You're my best friend. I'm sorry I treated you so badly."},
#  {'response': 'Uh, cheese and a -- That was quick!',
#   'context/0': 'Oh, right! Cheese pizza and a large soda!',
#   'context/1': 'Soda!',
#   'context/2': "Oh, I'll have a cheese pizza and a large...uh...line?",
#   'context/3': "Wait. You're Pamela Anderson! Cool! What can I get you?",
#   'context/4': 'Crap!'},
#  {'response': "Look, so we're not millionaires. At least we all still get to work together!",
#   'context/0': "Aha! Once again the conservative sangwich-heavy portfolio pays off for the hungry investor! Oh! I'm ruined. Why? Why?",
#   'context/1': "It is? Yahoo! We're poor no matter what I do! The deal is off!",
#   'context/2': "My Jah! It's worth less now than when it was worthless!",
#   'context/3': 'Oh come on!',
#   'context/4': "Millionaires nothing! The stock's only worth three kajiggers!"},
#  {'response': "Phil wins! Yancy's fans are stunned! There'll be no celebration at the Yancy dome!",
#   'context/0': "I'm dying of old age!",
#   'context/1': 'Holy camolie! A seven leaf clover!',
#   'context/2': "You're not the president of it!",
#   'context/3': "Hey. That's my patented spacehook! You stole it!",
#   'context/4': 'Yancy drives, he goes up with his patented spacehook!'},
#  {'response': 'Yeah. Give a little credit to our public schools.',
#   'context/0': "As unclean as it makes me feel, I agree with Bender. Kids don't turn rotten just from watching TV.",
#   'context/1': "Whoa, whoa, whoa. You can't censor me just 'cause I'm an obscenely bad role model.",
#   'context/2': 'No sir, not us FARTers.',
#   'context/3': "And for what? Some kind of cheap laugh? That's not what F-A-R-T is all about.",
#   'context/4': "Fathers Against Rude Television don't want our kids watching Bender's high definition filth."},
#  {'response': "Wow Bender. Are you and the ship an item? I mean I know you're both items but...how can you date a ship anyway? It'd be like me dating a really fat lady. And living inside her. And she'd be all like...",
#   'context/0': "It's not what it looks like. Bender was just helping me...zip up my turbine.",
#   'context/1': "Bender! What's going on in here? Planet Express Ship! Cover your shame!",
#   'context/2': 'No!',
#   'context/3': 'You know you love it sugar-engine!',
#   'context/4': "Stop it! You're mussing up my trajectory!"},
#  {'response': "So, Leela, how about a romantic ride in one of those swan boats? They're kinda dangerous but I finally mastered them.",
#   'context/0': 'Go get it, boy!',
#   'context/1': 'By Ken Keeler Transcribed by Dave, The Neutral Planet',
#   'context/2': 'FUTURAMA',
#   'context/3': 'Alright, alright. Let me just do one thing to cheer myself up.',
#   'context/4': "C'mon, Bender. If you're done scamming Beck, we're heading home."},
#  {'response': "Aw hey c'mon don't worry. We'll watch you clean up.",
#   'context/0': "Oh! I'll never pass inspection now! They'll bust me lower than a limbo stick - at carnival time. And that's as low as limbo sticks get.",
#   'context/1': 'Uh, it was ghosts! Big ones! And a tornado!',
#   'context/2': 'Great cow of Moscow!',
#   'context/3': "No don't hurt him! He's my best friend!",
#   'context/4': 'Break his neck!'},
#  {'response': "Yeah, that'd be a timesaver.",
#   'context/0': "That'll take forever. What she oughta do is find a nice guy with two eyes, then poke one out.",
#   'context/1': "I bet you Leela's holding out for a nice guy with one eye.",
#   'context/2': 'Why two? Oh!',
#   'context/3': "So we have to bring back two of each kind. Just like Noah's Ark.",
#   'context/4': "I didn't say anything about animals. Now it seems that the planet will collapse within three days. Incidentally, this will kill all the animals."},
#  {'response': "Shall we say 8 o'clock?",
#   'context/0': "You just assume I can't get a Valentine's date?",
#   'context/1': "Valentine's Day's coming? Oh, crap! I forgot to get a girlfriend again. Well since neither of us has a date, why don't we...",
#   'context/2': "Myself. I asked myself a Valentine's Day off. But I was in no mood for any of my shenanigans.",
#   'context/3': 'Hermes. Who were you yelling at?',
#   'context/4': "And now you're asking for a day off? Get out of my and my sight! You're bogarting my patience."},
#  {'response': "Let's just forget about the box. The Professor said to stay away.",
#   'context/0': 'Whatever.',
#   'context/1': 'Right! If they try to look in the box.',
#   'context/2': 'Scram you lousy green snakes! Here Leela, take this and use it to shoot those guys.',
#   'context/3': 'In my experience boxes are usually empty. Or maybe with a little cheese stuck to the top. And one time pepperoni! What a day that was! Give me the box!',
#   'context/4': "Whatever's in there it's the only thing I've ever wanted."}]

# %%
lines_selected_list.append(['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'])
lines_selected_list.append(["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.", "It'll be a rich, full day.", 'FTM'])
lines_selected_list.append(["I'm too scared.", 'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!', 'FTM'])
lines_selected_list.append(['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'])
lines_selected_list.append(['Fry, thank God we found you.', 'Leela? What are you guys doing here in the year 4000?', 'FTM'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP'],
#  ['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'],
#  ["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   "It'll be a rich, full day.",
#   'FTM'],
#  ["I'm too scared.",
#   'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'FTM'],
#  ['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'],
#  ['Fry, thank God we found you.',
#   'Leela? What are you guys doing here in the year 4000?',
#   'FTM']]

# %% [markdown]
# ## Vader

# %%
temp = load_df(characters[4])
# Out:
# Using custom data configuration default-8fc66de038de764b
# Reusing dataset csv (C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-8fc66de038de764b\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-8fc66de038de764b\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-fdf6a751d9e305ad.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-8fc66de038de764b\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-fd4f962239c0d8a3.arrow
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-8fc66de038de764b\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-724da1b5b03e5c90.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-8fc66de038de764b\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-6b695a18a6bce864.arrow

# %%
[s for s in temp['test']]
# Out:
# [{'response': 'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'context/0': 'I will not fight you.',
#   'context/1': 'You cannot hide forever, Luke.',
#   'context/2': 'Throw me another charge.',
#   'context/3': 'Yes, sir.',
#   'context/4': 'Send three squads to help. Open the back door.'},
#  {'response': 'Did you find any droids?',
#   'context/0': 'Unlock one-five-seven and nine.Release charges.',
#   'context/1': 'They must be trying to return thestolen plans to the princess. Shemay yet be of some use to us.',
#   'context/2': 'Yes.',
#   'context/3': 'Close all outboard shields! Closeall outboard shields!',
#   'context/4': 'Stormtroopers run to their posts.'},
#  {'response': 'They must never again leave thiscity.',
#   'context/0': 'Lord Vader, what about Leia and theWookiee?',
#   'context/1': 'He will not be permanently damaged.',
#   'context/2': "He's no good to me dead.",
#   'context/3': 'Lord Vader.',
#   'context/4': "Stormtroopers?Here?We're indanger.I must tell the others.Oh, no!I've been shot!"},
#  {'response': 'All to easy. Perhaps you are not as strong as the Emperor thought.',
#   'context/0': 'No!',
#   'context/1': 'Your destiny lies with me, Skywalker. Obi-Wan knew this to be true.',
#   'context/2': "You'll find I'm full of surprises.",
#   'context/3': 'You have learned much, young one.',
#   'context/4': "Oh, no!Chewie, they're behindyou!"},
#  {'response': 'Sister! So...you have a twinsister. Your feelings have now',
#   'context/0': 'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'context/1': 'I will not fight you.',
#   'context/2': 'You cannot hide forever, Luke.',
#   'context/3': 'Throw me another charge.',
#   'context/4': 'Yes, sir.'},
#  {'response': "I've been waiting for you, Obi-Wan. We meet again, at last. The circle is now complete.",
#   'context/0': 'Open the blast doors! Open theblast doors!',
#   'context/1': 'Close the blast doors!',
#   'context/2': 'Where could they be?',
#   'context/3': 'For luck!',
#   'context/4': 'Here they come!'},
#  {'response': 'They are clear, my Master.',
#   'context/0': 'Strange, that I have not. I wonder if your feelings on this matter are clear, Lord',
#   'context/1': 'I have felt him, my Master.',
#   'context/2': 'Are you sure?',
#   'context/3': 'My son is with them.',
#   'context/4': 'Yes, I know.'},
#  {'response': 'I have you now.',
#   'context/0': "Vader's targeting computer swings around into position.",
#   'context/1': "Luke's ship barrels down the trench.",
#   'context/2': 'Vader adjusts his control sticks, checking his projected',
#   'context/3': 'Luke looks anxiously at the exhaust port.',
#   'context/4': 'The three TIE fighters zoom down the Death Star trench in'},
#  {'response': 'That is correct, Commander. And heis most displeased with your',
#   'context/0': "The Emperor's coming here?",
#   'context/1': 'Then perhaps you can tell him when',
#   'context/2': 'But he asks the impossible. I need',
#   'context/3': 'The Emperor does not share youroptimistic appraisal of the',
#   'context/4': 'I tell you, this station will be'},
#  {'response': 'Obi-Wan is here. The Force is withhim.',
#   'context/0': 'The princess! Put all sections onalert!',
#   'context/1': 'Governor Tarkin, we have anemergency alert in detention blockA A-twenty- three.',
#   'context/2': 'Yes.',
#   'context/3': "The Jedi are extinct, their fire has gone out of the universe. You, my friend, are all that's left of their religion.",
#   'context/4': "Don't underestimate the power ofthe Force."},
#  {'response': 'Obi-Wan has taught you well.',
#   'context/0': 'Good.Use your aggressivefeelings, boy!Let the hate flowthrough you.',
#   'context/1': "Chewie!Get down here!She'swounded!No, wait....I got anidea.",
#   'context/2': 'Stay back.',
#   'context/3': 'Hands up! Stand up!',
#   'context/4': 'I know.'},
#  {'response': "Don't underestimate the power ofthe Force.",
#   'context/0': 'Surely he must be dead by now.',
#   'context/1': 'A tremor in the Force. The last time I felt it was in the presence of my old master.',
#   'context/2': 'Obi-Wan Kenobi! What makes youthink so?',
#   'context/3': 'He is here...',
#   'context/4': 'Come on!'},
#  {'response': 'No. Leave them to me. I will deal',
#   'context/0': 'Shall I hold them?',
#   'context/1': "It's an older code, sir, but itchecks out. I was about to clear",
#   'context/2': 'Do they have a code clearance?',
#   'context/3': 'Parts and technical crew for the',
#   'context/4': 'Shuttle Tydirium, what is your'},
#  {'response': 'The Empire will compensate you if he dies. Put him in!',
#   'context/0': "What if he doesn't survive? He's worth a lot to me.",
#   'context/1': "You're being put into carbonfreeze.",
#   'context/2': "What's going on... buddy?",
#   'context/3': "If only you had attached my legs, I wouldn't be in this ridiculous position. Now, remember, Chewbacca, you have a responsibility to me, so don't do anything foolish.",
#   'context/4': "I do not want the Emperor's prizedamaged.We will test it... onCaptain Solo."},
#  {'response': 'He will come to me?',
#   'context/0': 'Then you must go to the Sanctuary',
#   'context/1': 'They are clear, my Master.',
#   'context/2': 'Strange, that I have not. I wonder if your feelings on this matter are clear, Lord',
#   'context/3': 'I have felt him, my Master.',
#   'context/4': 'Are you sure?'},
#  {'response': 'I have felt him, my Master.',
#   'context/0': 'Are you sure?',
#   'context/1': 'My son is with them.',
#   'context/2': 'Yes, I know.',
#   'context/3': 'A small Rebel force has penetrated',
#   'context/4': 'I told you to remain on the command ship.'}]

# %%
lines_selected_list.append(['I will not fight you.', 'Give yourself to the dark side. It is the only way you can save your friends. Yes, your', 'SW'])
lines_selected_list.append(['Lord Vader, what about Leia and theWookiee?', 'They must never again leave thiscity.', 'SW'])
lines_selected_list.append(["The Emperor's coming here?", 'That is correct, Commander. And heis most displeased with your', 'SW'])
lines_selected_list.append(['Shall I hold them?', 'No. Leave them to me. I will deal', 'SW'])
lines_selected_list.append(['Lord Vader, what about Leia and theWookiee?', 'They must never again leave thiscity.', 'SW'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP'],
#  ['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'],
#  ["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   "It'll be a rich, full day.",
#   'FTM'],
#  ["I'm too scared.",
#   'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'FTM'],
#  ['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'],
#  ['Fry, thank God we found you.',
#   'Leela? What are you guys doing here in the year 4000?',
#   'FTM'],
#  ['I will not fight you.',
#   'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ["The Emperor's coming here?",
#   'That is correct, Commander. And heis most displeased with your',
#   'SW'],
#  ['Shall I hold them?', 'No. Leave them to me. I will deal', 'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW']]

# %% [markdown]
# ## Joy

# %%
temp = load_df(characters[5])
# Out:
# Using custom data configuration default-7f374cd700d2bdae
# Reusing dataset csv (C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-7f374cd700d2bdae\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-7f374cd700d2bdae\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-65c86748c5690d66.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-7f374cd700d2bdae\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-a81fcf1f90f0c48c.arrow
# Loading cached split indices for dataset at C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-7f374cd700d2bdae\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-bf1e6672a4b7f4b2.arrow and C:\Users\david\Documents\unibo\natural_language_processing\project\BarneyBot\cache\csv\default-7f374cd700d2bdae\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-3ba118b31d22c7a1.arrow

# %%
[s for s in temp['test']]
# Out:
# [{'response': 'Oh, yknow what? Since Im here, I think Im gonna have me a little beer on the port side.',
#   'context/0': 'No! No-no, no-no-no, very quiet, said with love, no yelling.',
#   'context/1': 'Okay! Okay, youre yelling again! See that?',
#   'context/2': 'Huh?',
#   'context/3': 'Okay, go to the left.  The left!',
#   'context/4': 'I dont know why you just dont say left.'},
#  {'response': 'Hey come on now, this is a real date. Uh, sonice place you got here. Foosball, huh? Pizza box. Oh, a subscription to Playboy, my kind of woman.',
#   'context/0': 'Oh man! This is so great! I actually feel like Im going on a real date! Although, I have a hint of morning sickness, and Im wearing underwear that goes up to aboutthere.',
#   'context/1': 'And, a brownie!  Well, half a brownie. Actually, its just bag. Its been a long walk from the flower shop and I was startin to feel faint so',
#   'context/2': 'Ohh, Lilies. Joey, theyre my favorite. Thank you.',
#   'context/3': 'No, Im picking you up for our date. These are for you.',
#   'context/4': 'Joey? Could you get that?  What are you doing here? I thought you were in your room?'},
#  {'response': 'No.  I was told the name of the movie would not appear on the bill!',
#   'context/0': 'Oh! Joey uh, were you in our room last night?',
#   'context/1': 'Hey!',
#   'context/2': 'Listen yknow what sir? For the last time, I dont care what the computer says, we did not take a bag of Mashuga nuts from the mini-bar and we did not watch Dr. Do-Me-A-Little!',
#   'context/3': 'David Schwimmer',
#   'context/4': 'Wait a minute! No! Im the nice one! Im the one who danced with the kids all night! HowHow small are your feet?!'},
#  {'response': 'We cant watch that! I mean thats Phoebe!',
#   'context/0': 'Wh-what, why?',
#   'context/1': 'All right well, Id better take that back.',
#   'context/2': 'Yes, but you are dead inside.',
#   'context/3': 'Hey, I had a terrible childhood and I dont do porn.',
#   'context/4': 'This is so bizarre. I guess it kinda makes sense though, yknow she had such a terrible childhood.'},
#  {'response': "Guess I don't know. My experience: if a girl says yes to being taped... She doesn't say no to much else, I tell ya...",
#   'context/0': "Allright, I'm gonna watch it... I mean look, it's probably not even what I think it is... And even if it is... It can't possibly be as bad as what I'm picturing in my head...  Can it?",
#   'context/1': 'How did she get me to settle down?',
#   'context/2': 'Yeah...!?',
#   'context/3': 'She hot?',
#   'context/4': 'Some girl...!?'},
#  {'response': "Yeah! How you doin'? Yeah alright!",
#   'context/0': "David, I'm pretending to read here!!",
#   'context/1': 'How do you think I should propose?',
#   'context/2': "Well, you're welcome! Glad I could help.",
#   'context/3': "Why not? It's brilliant!  Thank you, Chandler. Sincerely.",
#   'context/4': "I didn't mean now..."},
#  {'response': "Okay, buddy-boy. Here it is. You hide my clothes, I'm wearing everything you own.",
#   'context/0': 'Is it wrong that I was totally aroused by that?',
#   'context/1': "She's just getting dressed.",
#   'context/2': 'I love you.',
#   'context/3': 'Yes, Ross.',
#   'context/4': 'Okay. Honey?'},
#  {'response': "You got it. Thanks man. Thanks for doing this, I owe you one.  Oh, hey! There wasn't any change from that twenty, was there?",
#   'context/0': "No, it's a book that's just a book, okay? It's an early edition of the Velveteen Rabbit. It was her favorite book as a kid. So, uh, just... let me know if she likes it, okay?",
#   'context/1': "Is it like a book that's also a safe?",
#   'context/2': "I got something for her.  It's a book!",
#   'context/3': 'Our place, the hall! I...',
#   'context/4': 'Where?'},
#  {'response': 'What?',
#   'context/0': 'Joey, there was a little girl who lived here, but she died like 30 years ago.',
#   'context/1': 'Oh well, the little girl who lives here made me feel a lot better about the whole thing.',
#   'context/2': 'Really? What changed your mind?',
#   'context/3': 'Oh, just er... you know, looking around. But you know what? This house... is great.',
#   'context/4': 'Hey, where have you been?'},
#  {'response': 'Over the line?! You-youre-youre so far past the line, that you-you cant even see the line! The line is a dot to you!',
#   'context/0': 'Youre right, I have no excuses! I was totally over the line.',
#   'context/1': 'Who cares?! You went behind my back! I would never do that to you!',
#   'context/2': 'Look, Im sorry! But theres nothing I can do, I think Im in love with her!',
#   'context/3': 'I dont know! But its the same!',
#   'context/4': 'How is that worse?!'},
#  {'response': 'Yeah?!',
#   'context/0': 'Yes!!',
#   'context/1': 'Two brothers, one died!',
#   'context/2': 'Did you like learn about her family?',
#   'context/3': 'You-you think?',
#   'context/4': 'When two people finally realise their feelings for each other, and-and they talk for hours, and they-they learn all about the other person!'},
#  {'response': "Yeah, we haven't dropped it in",
#   'context/0': 'Monica, whatever you do, do not drop that ball!',
#   'context/1': 'What?!',
#   'context/2': "Oh, I don't know. Yeah, can't do it.",
#   'context/3': 'Guys, could you please just stop throwing the ball for one minute and just help me find it!',
#   'context/4': "How do you know? You don't have a watch."},
#  {'response': 'MIKE!!!',
#   'context/0': 'That I was going to eat him.',
#   'context/1': 'Why? What was it?',
#   'context/2': 'Yeah, he used to have this recurring nightmare, just really freaked him out.',
#   'context/3': 'He saw a therapist?',
#   'context/4': 'Oh, maybe he was getting him confused with his childhood therapist.'},
#  {'response': 'Hey, can I ask you something? In this, in this picture of you and your wife, is your wife Rachel?',
#   'context/0': 'No! No I cant. I mean Rachels out with some guy. My baby went with her. If anything that picture keeps moving further away.',
#   'context/1': 'Thats a nice picture. Maybe you can still have that!',
#   'context/2': 'Its just I always thought when I had another kid it would be different. Now I-I love Ben, but every time I have to drop him off at Carol and Susans, its likeIt breaks my heart a little. I mean Ive always had this picture of me and my next wife in bed on Sunday and, my kid comes running in and leaps up onto the bed. And we all read the paper together. Yknow? Maybe fight over the science section.',
#   'context/3': 'What do you mean?',
#   'context/4': 'I dont know! I guess I just cant believe any of this is happening.'},
#  {'response': 'All right, Ill see you guys.',
#   'context/0': 'Its not gonna be exactly like last time.',
#   'context/1': 'Hey! Okay! I got my passport, fresh socks, and a snake bite kit!',
#   'context/2': 'Oh yeah, its beautiful country up there.',
#   'context/3': 'Really?!',
#   'context/4': 'Look you dont understand, Gandolf is amazing. Yknow youre never know whats gonna end up happening, you go out for a couple of beers and end up on a fishing boat to Nova Scotia!'},
#  {'response': "I can't believe you. You told me it was a nubbin.",
#   'context/0': 'Oh as, as opposed to your other multi-functional nipples?',
#   'context/1': "C'mon, there's nothin' to see, it's just a tiny bump, it's totally useless.",
#   'context/2': 'Whip it out, whip it out.',
#   'context/3': 'You bitch.',
#   'context/4': 'You have a third nipple?'},
#  {'response': 'Shes gone. She had a bag and she left.',
#   'context/0': 'What?',
#   'context/1': 'Shes gone.',
#   'context/2': 'I cant talk to you now, I gotta find Monica!',
#   'context/3': 'Dude!',
#   'context/4': 'I know.  I hate that!'},
#  {'response': 'Itll be great! We-we could talk, and play games! Huh? This could be our chance to like renew our friendship.',
#   'context/0': 'I dont know, its such a long trip.',
#   'context/1': 'I dont want to drive all the way back by myself, I get so lonely.  Ohooh! How about you come with me?',
#   'context/2': 'No, Joey! You borrowed my cab; you have to drive it back.',
#   'context/3': 'I dont need that anymore.',
#   'context/4': 'What about my cab?'},
#  {'response': 'Whered you grow up, its so simple!',
#   'context/0': 'Huh?',
#   'context/1': 'Yeah, it is. Its really tough. Yknow sometimes I thinkWow!! Nice move!',
#   'context/2': 'Its gotta be rough.',
#   'context/3': 'I dont know. I guess theres just always been this distance yknowI mean we both try to pretend its not there, but it is.',
#   'context/4': 'Why not?'},
#  {'response': 'No, no!',
#   'context/0': 'Probably.',
#   'context/1': "But if I hadn't walked in here, would you..?",
#   'context/2': 'No, no, no!',
#   'context/3': 'No, no, no!',
#   'context/4': 'And have you .. ed?'},
#  {'response': 'Very good! Okay. G.',
#   'context/0': 'Fight.',
#   'context/1': 'Okay! Here we go. Pillow.',
#   'context/2': 'I can do that.',
#   'context/3': 'Okay now, before I make my final decision I uh, I just want to make sure our personalities match. Okay, so I made up a little test. Now, Im gonna say a word and then you say the first thing that comes to mind.',
#   'context/4': 'Great!'},
#  {'response': 'Ill never get to be a best man!',
#   'context/0': 'You can be the best man when I get married.',
#   'context/1': 'Come on Ross! Look, I-I dont have any brothers; Ill never get to be a best man!',
#   'context/2': 'Joey, I figured youd understand. I mean, I-Ive known him a lot longer.',
#   'context/3': 'What?! He got to do it at your first wedding!',
#   'context/4': 'I sortve already asked Chandler.'},
#  {'response': 'Oh, Urse...',
#   'context/0': "That's right, I don't... But I was, I was drunk on you!",
#   'context/1': "You don't drink.",
#   'context/2': "You know you, you should just forget about what I said under the bridge, I was talkin' crazy that night, I was so drunk!",
#   'context/3': "I don't get it. What happened? What about everything you said under the bridge?",
#   'context/4': "I'm sorry."},
#  {'response': 'Hey.',
#   'context/0': 'Hi.',
#   'context/1': "And we're dancing. A-five, six, seven, eight...",
#   'context/2': 'Um, Pennsylvania Dutch.',
#   'context/3': "You're kidding! I-I spent three years in Amsterdam.",
#   'context/4': "Yeah. It's Dutch."},
#  {'response': "Look, I don't hate Janice, she's-she's just a lot to take, you know.",
#   'context/0': 'Ooh, that girl that I hate, eww, drives me crazy, eww, eww, oh!',
#   'context/1': 'No, Yeeees. God, how do I say this. ?',
#   'context/2': 'You know, I may be way out on a limb here, but do you, do you, have a problem with Janice?',
#   'context/3': "Jan-ice. 'Cause I, just, I feel bad for Ross, you know, we-we always go together, we're like the three hocke-teers.",
#   'context/4': 'No, Janice.'},
#  {'response': 'So what.',
#   'context/0': 'Joey, you owe 1100 at I Love Lucite.',
#   'context/1': "That's a two line part.",
#   'context/2': 'That audition.',
#   'context/3': 'What?',
#   'context/4': 'Well I guess you can start by drivin a cab on Another World.'},
#  {'response': "Yeah, at Macy's. You were the Obsession girl, right? I was the Aramis guy.  Aramis? Aramis?",
#   'context/0': 'We did?',
#   'context/1': 'Uh, hi. We uh, we used to work together.',
#   'context/2': "Yes. It's very difficult to appreciate a Thanksgiving dinner once you've seen it in reverse.",
#   'context/3': 'Oh my god.',
#   'context/4': "We just finished this magnificent Thanksgiving dinner. I have--and I remember this part vividly--a mouthful of pumpkin pie, and this is the moment my parents choose to tell me they're getting divorced."},
#  {'response': "I don't believe this... Have you guys been...",
#   'context/0': 'Yeah, sure...',
#   'context/1': 'Can I talk to you for a minute?',
#   'context/2': "...I really don't...",
#   'context/3': 'You know where Joey is?',
#   'context/4': 'Hi...'},
#  {'response': 'Wow!  Well then Ill just have to carry you.',
#   'context/0': 'I cant! My circuits are fried! Theyre fried I tell you!!',
#   'context/1': 'Come on C.H.E.E.S.E., Im not leaving without you! Try routing your backup source through your primary CPU.',
#   'context/2': 'Yeah.',
#   'context/3': 'I think so. Yeah, get off me.',
#   'context/4': 'Hey, do we do this too much?'},
#  {'response': 'Then you hold on to it!!',
#   'context/0': 'Its out there man! Ive seen it! I got it!!',
#   'context/1': 'Oh, no! No!',
#   'context/2': 'I dont know, maybe I cant. I mean, maybe theres something wrong with me.',
#   'context/3': 'You can have it!',
#   'context/4': 'Well, I want it!'},
#  {'response': 'Marcel?',
#   'context/0': 'Marcel?',
#   'context/1': 'Dun-dun-duuuur! Sorry.',
#   'context/2': "I could... but I won't. If I find that monkey, he's mine.",
#   'context/3': "Be that as it may, d'you think you could just help us out here on that monkey thing? Y'know, just for old times' sake? Go Bobcats?",
#   'context/4': 'What?!'},
#  {'response': 'Youre not stupid. Youre meaner than I thought.',
#   'context/0': 'Yeah, what, do you think were stupid?',
#   'context/1': 'Oh, come on! We know what these are worth.',
#   'context/2': 'Are you serious?',
#   'context/3': 'Boy! I didnt see that coming!',
#   'context/4': 'Just give us our apartment back!'},
#  {'response': "You're driving me crazy with that!",
#   'context/0': 'Yes! Chandler Bing, 7! Chandler Bing, 0.',
#   'context/1': 'Because I think this character is going to be suspicious about stuff.',
#   'context/2': 'Why?',
#   'context/3': 'Hey, how do you spell suspicious?',
#   'context/4': 'Come on, hurry!'},
#  {'response': 'Chandler, is that',
#   'context/0': 'God, its great to catch up! I cant believe how long its been!',
#   'context/1': 'Okay Phoebe calm down, theres no need to place blame. Okay?  I warned her about those candles.',
#   'context/2': 'Yes! I do! All the time! I love them! Oh my God! I did it! Its me! Its me! I burned down the house! I burned down the house!',
#   'context/3': 'No-no-no, do you uh light candles? Burn incense?',
#   'context/4': 'No, not usually. But yeah, I could use one right now.'},
#  {'response': 'Me too.',
#   'context/0': 'Ill give up my ticket.',
#   'context/1': 'No! No! Its just that he gave me three tickets and there are six of us!',
#   'context/2': 'Now youre thinking you gotta sleep with him.',
#   'context/3': 'Well its justits one of those situations that I just hate. Yknow? A massage client gave me three tickets to the Helmet-Pelts exhibit at the Morgan Chase museum.',
#   'context/4': 'Whats the matter?'},
#  {'response': 'Yeah.',
#   'context/0': 'Well, we should go.',
#   'context/1': 'Thats my wife!!! Get out!',
#   'context/2': 'Whoa-whoa-whoa-whoa, I-IHey! I did not go out with your wife!',
#   'context/3': 'Joey!',
#   'context/4': 'He went out with my wife!'},
#  {'response': 'Okay.',
#   'context/0': 'Wow! And Im a vegetarian! All right, all right, well Im sorry, well put some ice on it.',
#   'context/1': 'Okay, great.',
#   'context/2': 'Oh! Oh! Oh!',
#   'context/3': 'Hey!!! Oww!! And Im bleeding.',
#   'context/4': 'Hey now!'},
#  {'response': 'My scones.',
#   'context/0': "'The hills were alive with the sound of music.'",
#   'context/1': 'Oh... Yeah, you do.',
#   'context/2': 'Oh, oh Chandler...',
#   'context/3': "I don't sound like that.",
#   'context/4': "You know like... uh okay... uh... 'Could that report be any later?'"},
#  {'response': 'There she is!',
#   'context/0': 'Hi!',
#   'context/1': 'Oh, come in.',
#   'context/2': 'Can we come in?',
#   'context/3': 'Hello baby girl.',
#   'context/4': 'Oh no, Baby Girl Geller-Green.'},
#  {'response': 'Youre smoking again?!',
#   'context/0': 'Oh my God!',
#   'context/1': 'Chandler!!',
#   'context/2': 'Chandler what are you doing?!',
#   'context/3': 'Very bad.',
#   'context/4': 'Oh yeah.'},
#  {'response': 'Whoa, whoa. And the fact that you dumped him because he hit on Phoebe?',
#   'context/0': 'At his apartment. Is this juice?',
#   'context/1': 'Where?',
#   'context/2': "I don't know, I just kinda ran into him last night.",
#   'context/3': 'Rachel, how did this happen?',
#   'context/4': "Ok, Paulo, why don't you just go get dressed, and then you be on your way, ok, bye-bye."},
#  {'response': 'Come on, I mean, you know me, you know...',
#   'context/0': "This is crazy. I mean, six years? And because of me you guys aren't gonna be together? Can I ask you something? Really, what is this thing with you and Rachel?",
#   'context/1': "That's what I hear, yeah.",
#   'context/2': "Except we're not. I mean, we haven't been a couple in like, six years. Oh my god, is that right? Has it been that long?",
#   'context/3': "It's okay, Ross, alright? I totally understand. Of course you're not fine. You're.. You're Ross and Rachel.",
#   'context/4': "Hey, what are you talking about? I'm fine!"},
#  {'response': 'Looks like that no date pact thing worked out.',
#   'context/0': 'And the moment of joy is upon us.',
#   'context/1': "In twenty seconds it'll be midnight...",
#   'context/2': 'The bll is drrbing!',
#   'context/3': 'What?',
#   'context/4': 'Vrrbddy, the bll is drrbing.'},
#  {'response': 'All right, Ross!',
#   'context/0': 'Oh, I was unbelievable.',
#   'context/1': 'So, er... how did it go with Celia?',
#   'context/2': "Yeah! You know all those yummy noises? I wasn't faking.",
#   'context/3': "Look, you'll get there. You're an amazing chef.",
#   'context/4': "I know... it's just... I thought this was, you know... it."},
#  {'response': 'Hey! Dont you hang up on me! Ill marry you and me right now! I have the power!',
#   'context/0': 'Ugh! Joey, I have to go.',
#   'context/1': 'No! No, Im the minister! All right, look-look, put em both on the phone, Ill marry them right now.',
#   'context/2': 'Oh my God! Im gonna have to find another minister.',
#   'context/3': 'I know! Im sorry! The guys drunk, they wont let me go until we get this.',
#   'context/4': 'Joey! The wedding is in less than an hour!'},
#  {'response': 'He hooked up!! Tell us about her!',
#   'context/0': "Look, I don't have to answer your questions! Okay? I'm a big boy, I can do whatever I want!",
#   'context/1': 'He hooked up! He hooked up with someone.',
#   'context/2': 'You walked around all night in the city by yourself?',
#   'context/3': 'I uh, went to a bar. And then I just uh, just walked around for a while.',
#   'context/4': 'What were you doing?'},
#  {'response': 'No! She had the ring on, she seemed so excited, and then she took her breast out.',
#   'context/0': 'You still havent told Rachel you werent really proposing?',
#   'context/1': 'No. No, I dont. Could you be a dear and go tell him?',
#   'context/2': 'Honey, the question isdo you really want to marry Joey?',
#   'context/3': 'Yeah, I mean whatever.',
#   'context/4': 'Sure?'},
#  {'response': 'That was a good one. For a second there, I was like, whoa.',
#   'context/0': 'Yeah.',
#   'context/1': "You guys are messin' with me, right?",
#   'context/2': "I got it. Uh, Joey, women don't have Adam's apples.",
#   'context/3': 'You or me?',
#   'context/4': "Hold it hold it. I gotta side with Chandler on this one. When I first moved to the city, I went out a couple of times with this girl, really hot, great kisser, but she had the biggest Adam's apple. It made me nuts."},
#  {'response': "Noo! I can't take any more secrets!  I've got your secrets. I've got their secrets. I got secrets of my own y'know!",
#   'context/0': "No! You don't have to do anything! Just don't tell them that we know!",
#   'context/1': "I can't take any",
#   'context/2': "Ehhh, no, I wanna do Phoebe's thing.",
#   'context/3': 'No-no-no! No-no wait Rach, you know what would even be more fun? Telling them.',
#   'context/4': 'Ohhh, I-I would enjoy that!'},
#  {'response': 'Gimme a box a juice. Well, they switched me over to Hombre.',
#   'context/0': 'Howdy.',
#   'context/1': "You can keep saying it, but it won't stop being true.",
#   'context/2': "Oh, you've tasted it.",
#   'context/3': 'Uh huh.',
#   'context/4': "You've tasted it? You've tasted it."},
#  {'response': 'Ohh I wonder if that dude.',
#   'context/0': 'We dont know.',
#   'context/1': 'Whos the father?',
#   'context/2': 'Its Joey!',
#   'context/3': 'Phoebe I think he would notice if you didnt have a baby in nine months!',
#   'context/4': 'Hey!'},
#  {'response': "Ya know, one of these times you're gonna really be naked and we're not gonna come over.",
#   'context/0': "Hey, have you guys eaten, because uh, Richard and I just finished and we've got leftovers... Chicken and potatoes... What am I wearing?...Actually, nothing but rubber gloves.",
#   'context/1': "What, what's about to happen?  starts watching  I've never seen this part before. Hey, Travis, watcha doin' with that gun? Oh no, no no Travis, put down the gun. No no no no, he he's your buddy, he's your Yeller, no, no no, the end, THE END.  hear the gunshot from the TV",
#   'context/2': "Uh, Phoebe, I don't think your mom would want you to see what's about to happen.",
#   'context/3': "He doesn't have rabies, he has babies. That's what my mom said.",
#   'context/4': 'What about the part where he has rabies?'},
#  {'response': 'Oh! Yeah!',
#   'context/0': "Easy Rach, we'll find it.  Won't we!",
#   'context/1': "Oh, like I wasn't dreading tomorrow enough, having to give it back to him... 'Hi Barry! Remember me? I'm the girl in the veil who stomped on your heart in front of your entire family!' Oh God and now I'm gonna have to return the ring, without the ring, which makes it so much harder...",
#   'context/2': "No, look, don't touch that!",
#   'context/3': 'Oh God, oh God, oh God oh God oh God oh God....',
#   'context/4': "Yeah, it's beautiful."},
#  {'response': 'I did?',
#   'context/0': 'Yes and you talked to her...',
#   'context/1': 'I was?',
#   'context/2': 'Joey relax! My mother picked her up two hours ago. You were there!',
#   'context/3': "Where's Emma? Who has Emma!?",
#   'context/4': "They're towing a car. And I am seeing...spots."},
#  {'response': 'I dont see the baby. Where is it?',
#   'context/0': 'Oh.',
#   'context/1': 'Oh hey, show them the picture of your uterus.',
#   'context/2': 'Good.',
#   'context/3': 'Oh, everything went great.',
#   'context/4': 'Hey! So how was the doctor?'},
#  {'response': 'All right look, yknow how-yknow how when youre dating someone and you dont want to cheat on them, unless its with someone really hot?',
#   'context/0': 'I cant help it. I need the meat. The baby needs the meat.',
#   'context/1': 'Phoebe, what-what are you doing?!',
#   'context/2': 'Theres a Phoebe on my sandwich!',
#   'context/3': 'Okay.',
#   'context/4': 'Yknow it doesnt matter how much Im craving it. Yknow why Im never gonna eat meat? Because its murder, cold blooded murder.'},
#  {'response': 'Whaaat?',
#   'context/0': 'I knooow.',
#   'context/1': 'What?',
#   'context/2': 'Umm, Joey, I know.',
#   'context/3': 'Hey. Well, whats up?',
#   'context/4': 'Hey.'},
#  {'response': 'Wow! Maybe uh, maybe you and I ought to get to know each other a little better.',
#   'context/0': 'Over a month.',
#   'context/1': 'So! You and Phoebe huh? How long have you been going out?',
#   'context/2': 'What?',
#   'context/3': 'Wait a minute!',
#   'context/4': 'Yeah! Sure! Ooh, I left my purse up at Monicas. Ill be right back.'},
#  {'response': 'Hey! Dont do the crime if you cant do the time.',
#   'context/0': 'Youve sentenced him?!',
#   'context/1': 'Five years.',
#   'context/2': 'Thats a good point. So uh, how long are you gonna punish him?',
#   'context/3': 'Back when you and Rachel were together, if Chandler had kissed her, would you hear him out?',
#   'context/4': 'Listen, Joey, I know what he did was wrong but dont you think you could at least hear the guy out?'},
#  {'response': 'I need an answer!',
#   'context/0': "You're welcome.",
#   'context/1': "You're welcome. And thank you for Science Boy. I learned a lot from him",
#   'context/2': 'Still this is amazing Oh my god, thank you, Phoebe.',
#   'context/3': 'Yeah but you should know, I also have a jar of vaseline and a cat skull in here.',
#   'context/4': 'You really thought Science Boy was worth saving!'},
#  {'response': 'Gotcha.',
#   'context/0': 'His daughter was hot.',
#   'context/1': 'Dude, what are you massaging an old man for?',
#   'context/2': 'He said he liked that!! Oh youre right, youre right. Im sorry.',
#   'context/3': 'Oh, its my fault?! You didnt have to massage him! You couldve sent him away! You couldve not rolled Tonka trucks up and down his back!',
#   'context/4': 'Hey, yknow what? This is your fault! Youre the one that didnt move his-his appointment.'},
#  {'response': 'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?',
#   'context/0': 'Hey.',
#   'context/1': 'Joey that is so sweet.',
#   'context/2': 'Well Ross, it seems pretty clear. I mean whats more important? What people think or how you feel, huh? Ross, you gotta follow your heart.',
#   'context/3': 'Yeah. What-what should I do?',
#   'context/4': 'Well Ross, you be careful now. You dont want to get a reputation as yknow Professor McNailshisstudents.'},
#  {'response': 'What?',
#   'context/0': 'Joey, you had the night!',
#   'context/1': "Oh, it was great! Yeah, I-I walked her home, and it was amazing how much we connected, y'know? Then ah, then she passed out, but then she woke up. Yeah? And we stayed up all night talking, and now were like totally crazy about each other!",
#   'context/2': 'Anyway, how did it go with Kate?',
#   'context/3': 'Im so, so, so sorry, Joey. I definitely am gonna see youre play. I swear youre play is very important to us, thank you for your patience. Youre play is the next play is the next play Im gonna see.',
#   'context/4': 'Yeah! I stayed at Kates, but ah, nothing happened. Hey, Pheebs, where were ya?'},
#  {'response': 'Okay. Sorry about that Uh, so wheres C.H.E.E.S.E.?',
#   'context/0': 'Ill let you two guys get acquainted, huh?',
#   'context/1': 'This is Wayne, the man who created and operates C.H.E.E.S.E.',
#   'context/2': 'Oh wow! Hes so lifelike!  Unbelievable!  He starts tugging on the guys ears.',
#   'context/3': 'Joey Tribbiani, this is',
#   'context/4': 'Okay.'},
#  {'response': 'Well, hey! Well...  To Phoebe and Mike!',
#   'context/0': 'Well, it was really sweet, and like the most romantic thing ever.',
#   'context/1': 'So, did he get on one knee, did he have a speech prepared, or  Yeah, big surprise, I like proposals!',
#   'context/2': 'Congratulations! Wow!!',
#   'context/3': 'Hey!',
#   'context/4': 'My God!'},
#  {'response': 'Its a grand tradition!',
#   'context/0': 'I thought we werent gonna have bachelor bachelorette parties! Yknow, we agreed that it was a silly tradition.',
#   'context/1': 'She untied his G-string with her teeth.  Somebody stop me!',
#   'context/2': 'You had a bachelorette party?!',
#   'context/3': 'Your secret bachelorette party',
#   'context/4': 'Her what?!!'},
#  {'response': 'Has it been that long?!',
#   'context/0': 'I cant believe theyve been together for three years.',
#   'context/1': 'Yeah, youre right. Hows the Mrs.?',
#   'context/2': 'Phoebe thats not true.',
#   'context/3': 'Well lets just hope it works. Yknow nine out of ten marriages end in divorce?',
#   'context/4': 'I cant believe in four weeks theyre gonna be married!'},
#  {'response': 'Hey!',
#   'context/0': 'Okay!',
#   'context/1': 'Five more seconds.',
#   'context/2': 'Okay, a quick one. Come on hug it out.',
#   'context/3': 'Thats exactly what my dad used to say!',
#   'context/4': 'Im a little busy here Paul.'},
#  {'response': 'Yeah! And you have so many more choices than you do with mens underwear!',
#   'context/0': 'Thats great Joe!',
#   'context/1': 'Yeah! And-and things arent assmashed down as I thought they were gonna be.',
#   'context/2': 'Huh.',
#   'context/3': 'The silk? Feels really good!',
#   'context/4': 'Uh-huh.'},
#  {'response': 'Huh. Okay.  So uh, I think Im gonna take off.',
#   'context/0': 'Yeah its umm Yeah its uh It-its yknowIts nothing.',
#   'context/1': 'So you uh, have abig work problem?',
#   'context/2': 'Yeah Joey shesRachels got this really big work problem, and it is a head scratcher. Wow!',
#   'context/3': 'What?',
#   'context/4': 'Uh I really dont know what to tell you Rach, I really dont. I mean, maybe Joey can help you out with your, with your big work problem.'},
#  {'response': 'How good is that?',
#   'context/0': "No, eh, oh-oi, easy, it's not a hot dog!",
#   'context/1': 'Thanks.',
#   'context/2': 'Yeah! In fact, to prove how much you mean to me,  here.',
#   'context/3': 'Really?!',
#   'context/4': "No! I would never do that! You-you're like my brother!"},
#  {'response': 'So he likes to break stuff.',
#   'context/0': 'Yeah, he broke those too.',
#   'context/1': 'Well, he had gravity boots.',
#   'context/2': 'He broke that.',
#   'context/3': "That is a great idea! And! I know Ugly Naked Guy because we've been watching him for like five years so that gives me back my edge! Oh, let's see now he had the trampoline.",
#   'context/4': 'See?'},
#  {'response': 'Okay, well my girl from the other night was special. She was a scientist too!',
#   'context/0': 'ThatIts not the same thing! This is totally different! This is with David! Remember David, the scientist guy? Okay, hes very special to me.',
#   'context/1': 'No, Im gonna!! Thats right! Yeah, you made me feel really guilty about goin out with that girl! Like-like-like I did something terrible to you! And now Pheebs, youre doing the same thing!',
#   'context/2': 'Come on Joey, dont make me feel badly about this.',
#   'context/3': 'A date?! No, no Pheebs you-you must be mistaken, because I know you wouldnt schedule a date on the same night you have plans with a friend!',
#   'context/4': 'Well Its a date.'},
#  {'response': 'What he wants to buy your baby?!',
#   'context/0': 'I know I told you, its a really big problem.',
#   'context/1': 'What?! Oh my-oh my God!',
#   'context/2': 'My boss wants to buy my baby!',
#   'context/3': 'Yeah?',
#   'context/4': 'Yeah, and umm my baby.'},
#  {'response': 'Whoo-weh hey weh-hey whoo hey!!',
#   'context/0': "Yeah, it's just we don't think of you as really being so much with the words.",
#   'context/1': "Joey, we would've asked you, we just thought you wouldn't be interested.",
#   'context/2': "U-U-Um, I think there's been an oversight.",
#   'context/3': 'Thank you!',
#   'context/4': 'Thanks!'},
#  {'response': 'Do you think well get our three bucks back?',
#   'context/0': 'Ill take her back tomorrow.',
#   'context/1': 'I dont know, maybe we werent ready to have a chick.',
#   'context/2': 'I know what you meant!!  You notice that ever since we got this chick, weve been fighting a lot more than we used too?',
#   'context/3': 'Thats not what I said. Okay, I just meant...',
#   'context/4': 'And you dont think taking care of our chick is work?'},
#  {'response': "Oo...what's in the bag?",
#   'context/0': 'Hey!',
#   'context/1': 'Hi you guys!',
#   'context/2': "That's right I am!",
#   'context/3': 'Yeah...',
#   'context/4': 'Two thousand dollars!? What do you think I am? I soap opera star!?'},
#  {'response': 'Yes!',
#   'context/0': 'So uh well the director is insisting that whoever play that part be authentically, anatomically not Jewish. Do you know what Im saying?',
#   'context/1': 'SoWhat?',
#   'context/2': 'Terrific! Well uh, theres one more thing. Uhh, uh its really important to the director that everything in this movie is authentic. Yeah and so in your love scene with Sarah she talks about how shes never seen a naked man who wasnt Jewish. So',
#   'context/3': 'Yeah! Yeah sure, just long as its handled tastefully and that barn is not too cold.',
#   'context/4': 'Oh and your agent said you were okay with the nudity.'},
#  {'response': 'Id love to show ya, but I just tucked her in. Shes sleeping.',
#   'context/0': 'He has the most amazing Porsche under there!',
#   'context/1': 'Hey! How you doin?',
#   'context/2': 'Hi Joey.',
#   'context/3': 'Hey! Hey! Be careful around my Porsche!',
#   'context/4': 'Totally.'},
#  {'response': 'Original or crappy?',
#   'context/0': "I'm trying to put Emma down for a nap, have you seen Hugsy?",
#   'context/1': "oh, too late, too late! It's sent... oops sorry and so is the picture of you and the police man...",
#   'context/2': "Ross, don't press send, don't press se... !",
#   'context/3': "No! That would be stupid! You're having it for me!",
#   'context/4': "Ross, what're you... what're you... what are you doing? You're having a memorial service for yourself!?"},
#  {'response': 'Yeah-yeah, and if I get it by day Ill  Joey Trrrribbiani!',
#   'context/0': 'Thats great.',
#   'context/1': 'Oh cool!',
#   'context/2': 'Oh no, I cant go. Im practicing; I got an audition to be the host of a new game show.',
#   'context/3': 'Hey Joe! You wanna shoot some hoops?',
#   'context/4': 'Son of a bitch!'},
#  {'response': 'That I can do.',
#   'context/0': 'You can drink a gallon of milk in 10 seconds?',
#   'context/1': 'Would fall off a lot.',
#   'context/2': 'Horseback riding?',
#   'context/3': 'No.',
#   'context/4': 'Archery?'},
#  {'response': 'Hey.',
#   'context/0': "For this episode, I'm using italics to signify portions contained in the prom video.",
#   'context/1': "Can't you see what's going on here, this man is dead.",
#   'context/2': 'Cut.',
#   'context/3': 'Aaaaagggghhhhh. Mommy',
#   'context/4': "Can't you see what's going on here, this man is dying."},
#  {'response': 'I have to go to the bathroom too, but I dont want him complimenting my thing.',
#   'context/0': 'Somewhere there is someone with a tranquilizer gun and a huge butterfly net looking for that man.',
#   'context/1': 'Come on!',
#   'context/2': 'Ill go with you',
#   'context/3': 'Dahaaa!  Im going to find the mens room, be right back.',
#   'context/4': 'I dont think the flash went off.'},
#  {'response': 'Ooh-ooh, Pheebs, you want a strong name? How about, The Hulk?',
#   'context/0': 'Well, it certainly worked for that Valdez kid.',
#   'context/1': 'Ugh! No! This is so hard! I went through this whole book  and found nothing! I want a name thats really like, yknow strong and confident, yknow? Like-like Exxon.',
#   'context/2': 'Hey! Do we have a baby name yet?',
#   'context/3': 'Hey!',
#   'context/4': 'Hi!'},
#  {'response': 'Uuuh.. yes, they are my stuffed clams.',
#   'context/0': 'Oh wow, are those stuffed clams?',
#   'context/1': "oh, I didn't know you liked French fries. Help yourself! What's mine is yours.",
#   'context/2': 'Mmmh, those fries look delicious.',
#   'context/3': 'Seafood platter for the gentleman and extra fries. Enjoy!',
#   'context/4': 'Oh, that looks great! Good ordering!'},
#  {'response': 'Woo-hoo!!',
#   'context/0': 'All right! Lets do it!',
#   'context/1': 'Yeah, okay, give that a try!',
#   'context/2': 'Okay, okay, but Rachels gonna be here too, cant I just ask her this stuff?',
#   'context/3': 'Okay, if you need the vacuum, its in my closet on the left-hand side. Ah, the garbage bags are next to the refrigerator',
#   'context/4': 'There it is.'},
#  {'response': 'Fine! Do you want something to drink?',
#   'context/0': 'Because its weird!',
#   'context/1': 'Why not?',
#   'context/2': 'We cant do it again.',
#   'context/3': 'I want to do it again.',
#   'context/4': 'Ive said it! Okay?! But its over Joey!'},
#  {'response': 'Umm?',
#   'context/0': 'Hey, uh, Joey?',
#   'context/1': 'Bye!',
#   'context/2': 'Good luck, honey!',
#   'context/3': "Okay, I'm gonna go too. I'm gonna go to the airport. I figure if I hang around there long enough, someone's bound to leave one of those planes unattended.",
#   'context/4': "Oh yeah, me too. Y'know if this shirt is dirty.  Yep."},
#  {'response': "Why would you ruin it, who was that hurtin'?",
#   'context/0': "That's not what we're gonna do!",
#   'context/1': "Oh, ain't that nice? The three of you trying on slutty lingerie together.",
#   'context/2': "Ok, that'll be great!",
#   'context/3': "Hey Pheebs, I'm-I'm taking Charlie shopping, why don't you come and I'll help you find something.",
#   'context/4': 'Aaargh, sexual politics!!'},
#  {'response': 'Aww thats nice. Family should be there, huh? This is her wedding, happiest day of her life.',
#   'context/0': 'Okay, all right, Ill take you. Ill go call Joan.',
#   'context/1': 'Because! Shes my cousin. I mean, we grew up together! Were family yknow? Well thats important to me.',
#   'context/2': 'BecDid you not hear me?! Shes an assistant professor in the Linguistics department, okay? Theyre wild! Why do you want to come anyway?',
#   'context/3': 'Why not?!',
#   'context/4': 'What? I cant cancel on Joan!'},
#  {'response': "Rachel... let's be clear on this, ok? I do not love Hugsy. I like him a normal amount...",
#   'context/0': 'Joey... are you sure? I mean, I know how much you love him!',
#   'context/1': "Oh, yeah... of course... yeah... it's a stuffed animal... you know... it's for kids... not for adults... I know that!",
#   'context/2': "She was just crawling around and she found him, so I just let her sleep with him. That's all right? Isn't it?",
#   'context/3': 'Chandler... hey...',
#   'context/4': 'Oh, no! Who did that?'},
#  {'response': 'Oh yeah, no problem.',
#   'context/0': "Joey, Ross is gonna be here any second, would you mind watching Ben for me while I use the ladies' room?",
#   'context/1': 'Hmmm, soup!  Hmm, soup!',
#   'context/2': 'Okay then!',
#   'context/3': "My late husband gave me that lighter.  I'm not kidding.",
#   'context/4': 'Yes! Great! Give me those cigs! Give it! Give it!'},
#  {'response': 'Well, were fashioning a very long poking device.',
#   'context/0': 'What?',
#   'context/1': 'Well, now we got a reason.',
#   'context/2': 'Yeah.',
#   'context/3': "Hey! Y'know how we ah, save all those chopsticks for no reason we get when we get Chinese food?",
#   'context/4': 'Well, there is one way. His windows open, I say, we poke him.'},
#  {'response': 'I mean naked game. Strip poker, we should totally play strip poker.',
#   'context/0': 'What?!',
#   'context/1': "Hey, y'know what a really good rainy day game is?",
#   'context/2': 'Yeah, no, it was great.',
#   'context/3': "The three losers. Oh, poor Lily.  Ohh, y'know I-I heard about what happened, that must have been just terrible for you, losing your mother that way.",
#   'context/4': 'Oh, what? What was it?'},
#  {'response': 'Yeah, I know.',
#   'context/0': 'How sad are we?',
#   'context/1': 'Im just glad I brought that extra pair of socks, yknow? I used them as mittens, I didnt want to touch a thing in that last place.',
#   'context/2': 'I cant hear a word youre saying, my ears are ringing so bad.',
#   'context/3': 'Actually, can I get some hot water with a little lemon? I think I strained my voice screaming in there. Does it have to be so loud?',
#   'context/4': 'Yeah, me too.'},
#  {'response': 'Man, this is bad! And Ive had my share of bad reviews. I still remember my first good one though.  Everything else in this production of Our Town was simply terrible. Joey Tribbiani was abysmal.',
#   'context/0': 'No, Monicas restaurant got a horrible review in the Post.',
#   'context/1': 'Well thats no way to sell newspapers. Why dont you try, Extra! Extra! Read all about it!',
#   'context/2': 'Hey you guys I got some bad news.',
#   'context/3': 'Dana Klein Borkow',
#   'context/4': 'Brian Buckner  Sebastian Jones'},
#  {'response': "I agree. I'm, like, in disbelief.",
#   'context/0': "I can't believe we are even having this discussion.",
#   'context/1': "'Pwease, Aunt Monica, pwease?' Oh, unclench. You're not even gonna be there.",
#   'context/2': 'Oh, hang on, hang on. Does Aunt Monica get a say in this?',
#   'context/3': "That's right, you're gonna spend tomorrow at Aunt Rachel's, aren't you.",
#   'context/4': 'And I will see you tomorrow!'},
#  {'response': 'All right.',
#   'context/0': 'Okay, absolutely!',
#   'context/1': 'No you wont. Look he knows he did a terrible thing and I believe him, hes sorry. But,  youve got one more apology to make, all right, youve got to apologize to Mary-Angela.',
#   'context/2': 'Ill do it.',
#   'context/3': 'No! No! No! No, Im not going to punch Chandler.',
#   'context/4': 'Yeah! Punch him! Punch him!'},
#  {'response': 'Hey I got one! I got one!',
#   'context/0': 'All right.',
#   'context/1': 'All right.',
#   'context/2': 'All right, Ill see you downstairs then.',
#   'context/3': 'No.',
#   'context/4': 'Oh, it ate your money?'},
#  {'response': 'Thats right! By his uncle too!',
#   'context/0': 'Were gonna be all right. I mean, even if were not married this baby is gonna be so loved. Not just by us.',
#   'context/1': 'Of course hes gonna have his Uncle Joey!',
#   'context/2': 'Joey, I cant stand the thought of having this baby with you mad at me. I want him to have his uncle. Is my baby gonna have his Uncle Joey?',
#   'context/3': 'Well Id be scared of them, but all right.',
#   'context/4': 'And youre my big brother! I mean, youre my favorite guy in the whole world. Im not even scared to tell mom and dad. I was scared of telling you.'},
#  {'response': "Ok! All right, well... I'm gonna see if I can get a room for the night and I'll... I'll see you later!",
#   'context/0': "No, I-I-I-I don't, I actually don't know who I'm talking about! So!",
#   'context/1': 'No-no-no-no, no! Who, who were you talking about?',
#   'context/2': 'You know? Forget it!',
#   'context/3': 'But then who? The waitress I went out with last month?',
#   'context/4': "Yeah, I'm not talking about her..."},
#  {'response': 'Gladys?',
#   'context/0': "Okay, that's it. WE ARE SEEING OTHER PEOPLE!",
#   'context/1': 'I love you too!',
#   'context/2': 'I love you!',
#   'context/3': "I'm sorry too...",
#   'context/4': "Oh God! I am so sorry, but...  I mean it's... there's so much history between us, you know..."},
#  {'response': 'Cool.',
#   'context/0': 'Yeah.',
#   'context/1': 'Tongue?',
#   'context/2': 'And, uh, and then I kissed her.',
#   'context/3': 'Ohhhh.',
#   'context/4': 'No, actually first they started on my waist. And then, they slid up, and then, they were in my hair.'},
#  {'response': 'Look, come on you guys, you said you were gonna try! All right look, I came over here to invite you guys to a movie with me and Janine.',
#   'context/0': 'Oh nothing, were just talking. Yknow, blah-blah-blah.',
#   'context/1': 'So uh, what are you guys doing?',
#   'context/2': 'Hey.',
#   'context/3': 'Hey!',
#   'context/4': 'I know!!!'},
#  {'response': 'Probably kill myself!',
#   'context/0': 'Hey, Joey, what would you do if you were omnipotent?',
#   'context/1': 'Hey Joey. Hi. Hey, buddy.',
#   'context/2': "See, there's always one guy.",
#   'context/3': "Uh, if I were omnipotent for a day, I'd.. make myself omnipotent forever.",
#   'context/4': 'Yeah, see.. you took mine. Chandler, what about you?'},
#  {'response': 'Okay!',
#   'context/0': 'Look, I- I could go on pretending-',
#   'context/1': 'You know.. you let your guard down, you start to really care about someone, and I just- I-',
#   'context/2': "So that's it? It's over? Just like that?",
#   'context/3': "We didn't change..",
#   'context/4': "No, nononono.. it's just.. things change. People change."},
#  {'response': 'Come on! What are you doing?! Im in character! Would you talk to her!',
#   'context/0': 'Joey, you know you dont actually have one.',
#   'context/1': 'Oh, Ive been there. Yeah, I am gonna go drive my Porsche.',
#   'context/2': 'Yeah, but only a genius would swallow a sonic blaster gun.',
#   'context/3': 'That is true.',
#   'context/4': 'Of course! Only an idiot would wear this stuff if you didnt have the car! Right?'},
#  {'response': "It's a one-woman play called Why don't you like me: a bitter woman's journey through life.",
#   'context/0': 'What is it?',
#   'context/1': 'I could fall asleep at a play.',
#   'context/2': 'Look, my agent hooked me up with six tickets to a great play.',
#   'context/3': "Well, let me see... I-I believe I'm... yes, falling asleep in front of the TV.",
#   'context/4': 'Hey, you guys, what are you doing tomorrow night?'},
#  {'response': 'Oh-no, dont try and talk all normal with that thing in your ear.',
#   'context/0': 'I like it, and Emily likes it, and thats what counts. So uh, how are you guys doing?',
#   'context/1': 'You do know that Wham broke up?',
#   'context/2': 'Oh yeah, Emily convinced me to do it.',
#   'context/3': 'We dont make enough fun of you already?',
#   'context/4': 'Oh my God!'},
#  {'response': '4:30.',
#   'context/0': 'What time is it now?',
#   'context/1': 'Uh, 10:30.',
#   'context/2': "Hey, y'know what, maybe we should get going. I mean what time did Chloe say we should be there?",
#   'context/3': 'Hey, dont call him that! His name is Spackel Back Harry!',
#   'context/4': 'Yeah, well kinda cute, like really kinda cute, or kinda cute like your friend Spackel Back Larry?'},
#  {'response': "Hard to tell, they're so tiny and upside-down. Wait, wait. They're walking away... they're walking away... No, no they're not, they're coming right at us! Run! Run!",
#   'context/0': 'Whaddya see?',
#   'context/1': "I dunno, I've been standing here spelling it out for you!",
#   'context/2': "So, what's going on now?",
#   'context/3': 'That makes more sense.',
#   'context/4': "'Kay, wait a minute, are you sure she didn't say When are you gonna grow up and realise I am your mom?"},
#  {'response': "It's a... It's a welcome home sign for the baby.",
#   'context/0': 'Hey, what are you working on?',
#   'context/1': "Yeah, I'm good.",
#   'context/2': 'We could trade later.',
#   'context/3': "Alright, let's see..",
#   'context/4': 'Okay.'},
#  {'response': 'Really?',
#   'context/0': "Oh well it's not me, it's my character, Chandy. Yeah the rogue processor who seduces his co-worker's wives for sport and then laughs about it the next day at the water cooler. In fact, I have her panties right there in my drawer.",
#   'context/1': 'Ahh. What the hell are you doing to me man.',
#   'context/2': "Yeah, Karen. I'm thinking about having an affair with her. Oh, you know what? I just did.",
#   'context/3': 'Karen.',
#   'context/4': "Alright, ok, alright. So I can't fire Joseph but uh, I can sleep with his wife."},
#  {'response': 'I know. And shes so sweet. I just wanna feed her grapes and brush her hair.',
#   'context/0': 'Aw, Im sorry sweetie that she doesnt feel the same way.',
#   'context/1': 'I like her so much!',
#   'context/2': 'I can see why thats hard to resist.',
#   'context/3': 'I had to get out of the apartment. Janine is like stretching all over the place. Yknow, everywhere I look shes like',
#   'context/4': 'Hey Joe whats up?'},
#  {'response': "It's Joey.",
#   'context/0': 'Hey, did you get the turkey bastedOh my God! Oh my God!  Who is that?',
#   'context/1': 'Hey!',
#   'context/2': 'Hey!',
#   'context/3': 'Well, of course it smells really bad. You have your head up a dead animal.',
#   'context/4': 'Well then help me get it off! Plus, it smells really bad in here.'},
#  {'response': 'You hug me!',
#   'context/0': 'You are gonna be a huge star! Im gonna hug ya!',
#   'context/1': 'Yeah, youre right. Okay look, listen, lets talk about what a huge star Im gonna be!',
#   'context/2': 'Oh, we could do this all day.',
#   'context/3': 'Thats mean! You really had me going there!',
#   'context/4': 'Well thats good. Because you didnt! And Im incredibly happy for ya!!'},
#  {'response': 'Not good, no. I didnt get the part, and I lost my job here, so',
#   'context/0': 'Hey, buddy boy, howd the audition go?',
#   'context/1': 'Yknow, suddenly I find you very attractive.',
#   'context/2': 'Phoebe, its okay that you dont want me to be your girlfriend because I have the best boyfriend.',
#   'context/3': '. All right youre off my list.',
#   'context/4': 'Im sorry. Youre not easy-going, but youre passionate, and thats good. And when you get upset about the little things, I think that Im pretty good about making you feel better about that. And thats good too. So, they can say that youre high maintenance, but its okay, because I like  maintaining you.'},
#  {'response': 'It smells really bad in here.',
#   'context/0': "Oh my God! Monica's gonna totally freak out!",
#   'context/1': 'I put it on to scare Chandler!',
#   'context/2': 'Easy. Step. How did it get on?',
#   'context/3': "It's stuck!!!",
#   'context/4': 'Every year.'},
#  {'response': "Oh, sometimes we use the same extras for different parts. It's okay.",
#   'context/0': "Joey, listen. I can't do this, it doesn't make any sense. Yesterday I was a nurse, and today I'm a waitress at a cafe?",
#   'context/1': "You know what? I don't need a tie. I mean, it's better, open collar. You know, it's more casual",
#   'context/2': 'What!? You faked it?',
#   'context/3': 'That thing that I have to do to make a baby. I faked it.',
#   'context/4': 'What are you talking about?'},
#  {'response': 'Thanks. That means a lot to me.',
# ...
#   'context/0': 'I know but its so hard! Nothing rhymes with your stupid name!',
#   'context/1': 'But yknow umm, Rachel doesnt rhyme with draddle.',
#   'context/2': 'Oh, yay!',
#   'context/3': 'Pheebs, thats great!',
#   'context/4': 'Happy Chanukah, Monica! May your Christmas be snowy, Joey! Happy New Year, Chandler and Ross. Spin the draddle, Rachel!'},
#  {'response': 'Guest.',
#   'context/0': 'Fancy.',
#   'context/1': 'Everyday use.',
#   'context/2': 'Eww! No!! Her ear! All right, Monica categorizes her towels. How many categories are there?',
#   'context/3': 'Oh!',
#   'context/4': 'Correct. In what part of her body did Monica get a pencil stuck at age 14?'},
#  {'response': 'What is that?',
#   'context/0': 'Ohhh, man!!',
#   'context/1': 'Not if I get there first.',
#   'context/2': 'Ugh. Now if a cow should die of natural causes, I can have one of those right?',
#   'context/3': 'Six months.',
#   'context/4': 'Oh mama! Uh when-when is the baby due?'},
#  {'response': 'Yeah! Look!',
#   'context/0': 'Really?',
#   'context/1': 'Rach! Hey! Its fine! Youre at Joeys!',
#   'context/2': 'Oh but look! Thats gonna leave a stain!',
#   'context/3': 'No thats all right. Dont worry about it.',
#   'context/4': 'Oh, Joey! Sorry!'},
#  {'response': "Shh, OK, here I come, here I come. See I'm comin' to fix the copier, I can't get to the copier, I'm thinkin' what do I do, what do I doso I just watch 'em have sex. And then I say, wait, here's my line,  you know that's bad for the paper tray.",
#   'context/0': 'Yeah, I guess it is. And so Im gonna get on this spaceship,  So you tell your great-great-granddaughter to look me up, because Adrienne babyIm gonna want to meet her.',
#   'context/1': 'So this is it? Victor?',
#   'context/2': 'Now, I can have milk everyday.',
#   'context/3': "This is the first time hes ever used this product, he's never used this product before, you're gonna see how easy this is to do.  This works with any milk carton.",
#   'context/4': 'And there is Kevin.'},
#  {'response': 'Hey! Uh, this is just to give you an idea. Okay well, we can put screens here, , which until the baby comes we can use as walkie-talkies. Huh?',
#   'context/0': 'What is this?',
#   'context/1': 'Sounds about right.',
#   'context/2': 'You mean the one that youre wearing?',
#   'context/3': 'The pink one with the flowers?!',
#   'context/4': 'What bra?'},
#  {'response': 'Boy I tell ya, that judging stuff took a lot out of me.',
#   'context/0': 'You guys are the best!',
#   'context/1': 'Well yknow what? I hope Monica forgives you after you throw her, her vegetarian, voodoo, goddess circley shower!',
#   'context/2': 'The coins have finally forgiven me!',
#   'context/3': 'No! Yknow what? No! No! You thing was so stupid anyway, this was ridiculousWere gonna flip a coin!',
#   'context/4': 'Actually, it wasnt that close.'},
#  {'response': "Whoa-whoa dad? There's a dad in the commercial?",
#   'context/0': 'Weirder than watching his two moms make out?',
#   'context/1': 'Yeah.',
#   'context/2': "It's gonna be weird to watch some actor pretending to be Ben's dad.",
#   'context/3': "All right, I gotta take off. I'm picking up Ben then we're off to the big audition.",
#   'context/4': 'What, so I gotta shut it down now?'},
#  {'response': 'Oh, let me get this.  These are for you.',
#   'context/0': '4.50 please.',
#   'context/1': 'Hm-mmm.',
#   'context/2': 'Really?!',
#   'context/3': 'Yeah.',
#   'context/4': 'Wow!'},
#  {'response': 'Angela? Joey Tribiani. Listen, what are ya doing tonight. I know your seeing that guy I was thinking maybe you could bring him.....Hello? Hello?  picks up a statue of an Indian and walks into',
#   'context/0': "Yeah, what are they gonna say you didn't love me anymore. Come on.",
#   'context/1': 'What?!',
#   'context/2': '...from the syphilis.',
#   'context/3': 'Insane!',
#   'context/4': "Well uh, after you ran out on your wedding, Barry's parents told people that you were sort of....insane."},
#  {'response': "Hey. Y'know with that goatee you kinda look like Satan.",
#   'context/0': 'Hey.',
#   'context/1': 'Oh my.',
#   'context/2': 'Are you all right?',
#   'context/3': 'Oh my God, are you guys okay?',
#   'context/4': 'Rachel, I made you a cocoa.'},
#  {'response': 'London baby!',
#   'context/0': 'Yeah, cheerie-o!',
#   'context/1': 'Woo-hoo!!',
#   'context/2': 'All right! Lets do it!',
#   'context/3': 'Yeah, okay, give that a try!',
#   'context/4': 'Okay, okay, but Rachels gonna be here too, cant I just ask her this stuff?'},
#  {'response': 'It is???',
#   'context/0': 'Its spreading already.',
#   'context/1': 'Yeah, but, hey look, dont go through her stuff. She gets really mad.',
#   'context/2': 'Can I check out what she did to my room?',
#   'context/3': 'Uh, no, shes at dance class.',
#   'context/4': 'So, is Janine around?'},
#  {'response': 'I got this pair marked excess, I gotta tell ya, there was no room for excess anything in there.',
#   'context/0': 'Wh-what?!',
#   'context/1': "Boy, that guy's underwear sucks!",
#   'context/2': 'I know!',
#   'context/3': "Congratulations! Ohh, that's great!",
#   'context/4': 'Well, I have a job interview at Ralph Lauren tomorrow!'},
#  {'response': "Yeah, you'd think I'd give up being a minister and start paying to ride the subway? Huhuh...",
#   'context/0': 'Really?',
#   'context/1': "Oh hey, don't worry. I'm still ordained from your wedding.",
#   'context/2': 'Oh, no!',
#   'context/3': "Level 1 alert. I repeat, level 1. This is not a drill. Okay we've got a situation. The minister just called. He's snowed in. He can't make it.",
#   'context/4': 'He stinks!'},
#  {'response': 'Aaaaagggghhhhh.',
#   'context/0': "Can't you see what's going on here, this man is dying.",
#   'context/1': 'About 20 minutes. CLOSING CREDITS',
#   'context/2': "How long you been waitin' to say that?",
#   'context/3': 'Yeah. Oh, except one of the strings on my guitar is broken. Hey, Chandler, can I borrow your G-string?',
#   'context/4': 'Oh yeah.'},
#  {'response': "That's right! I'm taking the essence.",
#   'context/0': 'The cushions are the essence of the chair!',
#   'context/1': "You said I had to give you the chair, you didn't say anything about the cushions.",
#   'context/2': 'What are you doing?',
#   'context/3': 'Okay.',
#   'context/4': 'All right, you will notice that I am fully dressed. I, in turn, have noticed that you are not. So in the words of A. A. Milne, Get out of my chair, dillhole!'},
#  {'response': 'But it really',
#   'context/0': 'Youve sung Happy Birthday to 20 different women today!',
#   'context/1': 'What? No-no its her birthday!',
#   'context/2': 'Youre paying for that.',
#   'context/3': 'Happy birthday to you!',
#   'context/4': 'Im fine.'},
#  {'response': "Whoa! For a rich guy he's got, that's a pretty small TV.",
#   'context/0': 'Yes, and the dimmer switch.',
#   'context/1': 'Okay, this is the den. All right, check this out. Lights!  Oh, see you just need to find the right command.',
#   'context/2': 'Whoa.',
#   'context/3': "Thank you soo much for coming on such a short notice. Ladies and gentlemen, I've-I've-I've been practicing medicine for twenty-three years, and I'm stumped.",
#   'context/4': "Y'know I have dinner plans!!"},
#  {'response': 'Why not?',
#   'context/0': 'No, I dont want to tell you.',
#   'context/1': 'Yeah, like a moth to a flame, Im telling ya. Okay all right, so now you go.',
#   'context/2': 'Oh my God!',
#   'context/3': 'Now you cant tell anyone, but uhI put on shiny lip balm.',
#   'context/4': 'How do you do that?'},
#  {'response': "Uhm... ok... uhm... Well, yeah... You have got some nerve, coming back here. I can't believe you never called me.",
#   'context/0': 'I can explain... Joey...',
#   'context/1': 'Are you friends with him?',
#   'context/2': 'Bert! Bert! Bert! Bert!',
#   'context/3': 'What are you doing here?',
#   'context/4': "And for the last time, we do not want to be friends with you! And we don't want to buy your bat!"},
#  {'response': 'Alright, alright, hey yknow fair is fair,',
#   'context/0': 'No, no. Shes fair game if you ask me, sorry buddy!',
#   'context/1': 'Well, I was hoping after tonight that maybe I could you know',
#   'context/2': 'Look, are you dating this girl you came with?',
#   'context/3': 'Oh come on man, you can dance with my partner, shes real, uh, mellow!',
#   'context/4': 'No I dont think so.'},
#  {'response': 'I dont know. Ooh, I bet its Richard.',
#   'context/0': 'I dont know! What could she possibly be hiding in here that I cant see?!',
#   'context/1': 'Why not?',
#   'context/2': 'Monica has a secret closet and she wont let me see whats in it.',
#   'context/3': 'Whoa, Monica runs a pretty tight ship over here. What are you doing?',
#   'context/4': 'I wasnt trying to open your closet! I wasnt trying to open your closet! I swear!'},
#  {'response': 'Please, just-just, just go and talk to Rachel.',
#   'context/0': 'Maybe its something you ate?',
#   'context/1': 'Im telling you. Im telling you. Thats what it is. No wonder she was looking at me all funny during the wedding. She didnt say anything to you?',
#   'context/2': 'Oh wow, I dont feel well.',
#   'context/3': 'Why? What-what else could it be?',
#   'context/4': 'Yeah, I dont think thats what it is.'},
#  {'response': "Well, she and I said from the beginning that we weren't gonna do anything unless you were okay with it. And clearly..",
#   'context/0': 'What do you mean?',
#   'context/1': "No, no, no. You actually did that when you were dancing to the Chicago-soundtrack. Look, Ross, about, about Rachel and I. Listen, you don't have to worry about that, okay? Because nothing is gonna happen.",
#   'context/2': 'So you took off my pants and shoes?',
#   'context/3': 'Yeah.',
#   'context/4': 'Thanks. Did you stay here all night?'},
#  {'response': 'Yeah. Maybe Michael Jordon will dive for the ball and break my jaw with his knee.',
#   'context/0': 'Courtside? Oh my God.',
#   'context/1': 'No, no, no. When you get home tomorrow night, you and I are going to be at the Wizzards-Knicks game . . . courtside!',
#   'context/2': "Braid each other's hair and ride horseback on the beach?",
#   'context/3': 'Okay, what have we always wanted to do together?',
#   'context/4': "What's up Joe?"},
#  {'response': 'Yes!! Ha-ha!! All right! Hey! How cool would it be if you could watch like a real life-sized version of this? Huh? I mean how crazy would that be?',
#   'context/0': 'Oh right, your allergies.',
#   'context/1': 'Wh?! What about my allergies?!',
#   'context/2': 'Yeah okay, I was just talking to the guys. Just look at them I mean, is it okay if they come visit?',
#   'context/3': 'Were supposed to meet my parents in 15 minutes.',
#   'context/4': 'Am I naked again?!'},
#  {'response': 'So I ah, talked to Lauren, kinda told her how things were with us. Did you ah, did you talk to Marshall?',
#   'context/0': 'Hi.',
#   'context/1': 'Hey.',
#   'context/2': 'Oh, fire! There, theres a fire! Fire!!',
#   'context/3': 'Im in the shower!',
#   'context/4': 'Mon?'},
#  {'response': 'Yeah, you did some real good thinkin in there.',
#   'context/0': 'Yeah?',
#   'context/1': 'Yeah, were gonna be fine! Get out!',
#   'context/2': 'So?',
#   'context/3': 'He can still catch her! Come on, get out of there!  Get out of there!',
#   'context/4': 'What?!'},
#  {'response': "She's this really boring woman. She's a teacher!",
#   'context/0': 'Oh, yeah.',
#   'context/1': 'Okay, okay. Wait till you hear who I got for Ross.',
#   'context/2': "Well, it's this guy I used to massage. And by massage, I mean hold down so he wouldn't turn over and flash me.",
#   'context/3': 'All right! Who is he?',
#   'context/4': "Hey. I'm so excited; I just set up Rachel with the worst guy tonight."},
#  {'response': 'Oh-oh!',
#   'context/0': 'Why, just a tiny little...',
#   'context/1': 'Stop staring at me!',
#   'context/2': 'Yeah, of course. I can control myself.',
#   'context/3': 'Really! Now this all better be here when I come back.',
#   'context/4': 'Really?'},
#  {'response': "I can't believe it's Christmas already. Ya know, I mean, one day your eatin' turkey, the next thing ya know, your lords are a-leapin' and you geese are a-layin'.",
#   'context/0': "Yeah, but not very well, unless 14-across, 'Gershwin musical' actually is bitemebitemebitemebiteme.",
#   'context/1': 'Oh look, and he did my crossword puzzle.',
#   'context/2': 'Ooh, goooosh, ooh, these are cookies smashed in the sports section.',
#   'context/3': "Uhhh, I don't think you're gonna like this.",
#   'context/4': 'What?'},
#  {'response': 'Sometimes I get in here just to get away from it! Hey, a nickel!!',
#   'context/0': 'Okay.  See?! I told ya!',
#   'context/1': 'All right, you have yourself a deal.',
#   'context/2': 'Oh yeah?  If I cant, Ill knock five bucks off the price off the unit.',
#   'context/3': 'No, you, you cant fit in that thing. Thats not deep enough.',
#   'context/4': 'Oh yeah! I got in there myself once. My roommate bet me five bucks that I couldnt, and then he stuck a board through the handles that locked me in. Yeah. It was funny til I started feeling like I was in a coffin.'},
#  {'response': 'Yeah.',
#   'context/0': 'Come on! We will be there for you the whole time! Just remember gal pal Rachel Green.  Seriously, proud of you.',
#   'context/1': 'Just then or-or all the time, cause we-we have jobs yknow.',
#   'context/2': 'Fine! All right, Ill do it. But hey! You guys have to be at the next table so you can stop me if I yknow, start to say something stupid.',
#   'context/3': 'Okay, dont listen to him. Please?',
#   'context/4': 'Is that gal pal spelled L-O-S-E-R?'},
#  {'response': 'Yeah, and you know what? We could do a lot worse.',
#   'context/0': "Well, looks like it's just the two of us tonight, huh old buddy?",
#   'context/1': 'Ooh... Not so good.',
#   'context/2': "Because it's soft... Hey, so how was your date?",
#   'context/3': 'So, why are you still wearing it?',
#   'context/4': 'Turns out this sweater is made for a woman.'},
#  {'response': 'Well, I was thinking about that and I, I think the best way would be, to not.',
#   'context/0': 'What?  So what are you going to do? I mean how, how are you going to tell Chandler?',
#   'context/1': 'You guys, Joey just saw Janice kissing her ex-husband.',
#   'context/2': 'No, no hes not.',
#   'context/3': 'Hey, is, is, is Chandler here?',
#   'context/4': 'Although, dont feel like you cant visit.'},
#  {'response': 'Great.  You got anything thats not Ralph Lauren?',
#   'context/0': 'Yeah, sure. Ummhere.',
#   'context/1': 'Uhh, well Ive got an audition down the street and I spilled sauce all over the front of my shirt.  You got an extra one?',
#   'context/2': 'Hi Joey! What are you doing here?',
#   'context/3': 'Or not.',
#   'context/4': 'Okay.'},
#  {'response': "I can't tell you what I know.",
#   'context/0': "Oh no, I can't tell you until you tell me what you know.",
#   'context/1': "What's the thing you know?",
#   'context/2': 'I might know something too.',
#   'context/3': 'I might know something.',
#   'context/4': 'Do you know something?'},
#  {'response': 'Yes! Yes!! And every time you look at it, I want you to remember that you are a good person. Okay, youve had the chance to cheat, and with me, but you didnt. And thats what this ring stands for.',
#   'context/0': 'No! No-no-no',
#   'context/1': 'Sure! As long as they dont find out you can keep whatever you want! And I want you to have it.',
#   'context/2': 'Oh my God, they let you keep that stuff?!',
#   'context/3': 'Wow! Uh okay, well uh',
#   'context/4': 'The ring from the cave, yeah.'},
#  {'response': "Whoo, whoo. Wow, it's uhm... kinda weird that I'm sitting next to Charlie after we broke up.",
#   'context/0': "What d'ya know... It's a treat for the eyes and the ears.",
#   'context/1': 'And listen to this...',
#   'context/2': 'I thought so.',
#   'context/3': 'Not once.',
#   'context/4': "You've never said that in your life, have you?"},
#  {'response': 'She said yes.',
#   'context/0': 'Well, what did she say?',
#   'context/1': 'I know! I know its awful.',
#   'context/2': 'And you did it first?! This is gonna kill him! You know how much he loves to propose!',
#   'context/3': 'I guess.',
#   'context/4': 'Ross had a ring?! And he was gonna propose?'}]

# %%
lines_selected_list.append(['Oh! Joey uh, were you in our room last night?', 'No.  I was told the name of the movie would not appear on the bill!', 'Friends'])
lines_selected_list.append(['Hey.', 'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?', 'Friends'])
lines_selected_list.append(['Joey... are you sure? I mean, I know how much you love him!', "Rachel... let's be clear on this, ok? I do not love Hugsy. I like him a normal amount...", 'Friends'])
lines_selected_list.append(['Ok, ten.', 'Okay, Monica picks ten, I call nine! Anyone else?', 'Friends'])
lines_selected_list.append(["Joey, Ross is gonna be here any second, would you mind watching Ben for me while I use the ladies' room?", 'Oh yeah, no problem.', 'Friends'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP'],
#  ['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'],
#  ["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   "It'll be a rich, full day.",
#   'FTM'],
#  ["I'm too scared.",
#   'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'FTM'],
#  ['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'],
#  ['Fry, thank God we found you.',
#   'Leela? What are you guys doing here in the year 4000?',
#   'FTM'],
#  ['I will not fight you.',
#   'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ["The Emperor's coming here?",
#   'That is correct, Commander. And heis most displeased with your',
#   'SW'],
#  ['Shall I hold them?', 'No. Leave them to me. I will deal', 'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ['Oh! Joey uh, were you in our room last night?',
#   'No.  I was told the name of the movie would not appear on the bill!',
#   'Friends'],
#  ['Hey.',
#   'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?',
#   'Friends'],
#  ['Joey... are you sure? I mean, I know how much you love him!',
#   "Rachel... let's be clear on this, ok? I do not love Hugsy. I like him a normal amount...",
#   'Friends'],
#  ['Ok, ten.', 'Okay, Monica picks ten, I call nine! Anyone else?', 'Friends'],
#  ["Joey, Ross is gonna be here any second, would you mind watching Ben for me while I use the ladies' room?",
#   'Oh yeah, no problem.',
#   'Friends']]

# %% [markdown]
# ## Standard data

# %%
# Also add a few standard questions-answers to the common dataset
lines_selected_list.append(['What are you doing for a living?', 'I am a lawyer.', 'Standard'])
lines_selected_list.append(['How are you doing?', 'Good.', 'Standard'])
lines_selected_list.append(['Where are you going to?', 'I am going out.', 'Standard'])
lines_selected_list.append(['What are you wearing?', 'A T-shirt.', 'Standard'])
lines_selected_list.append(['What do you want to do tonight?', 'Watching tv.', 'Standard'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP'],
#  ['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'],
#  ["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   "It'll be a rich, full day.",
#   'FTM'],
#  ["I'm too scared.",
#   'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'FTM'],
#  ['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'],
#  ['Fry, thank God we found you.',
#   'Leela? What are you guys doing here in the year 4000?',
#   'FTM'],
#  ['I will not fight you.',
#   'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ["The Emperor's coming here?",
#   'That is correct, Commander. And heis most displeased with your',
#   'SW'],
#  ['Shall I hold them?', 'No. Leave them to me. I will deal', 'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ['Oh! Joey uh, were you in our room last night?',
#   'No.  I was told the name of the movie would not appear on the bill!',
#   'Friends'],
#  ['Hey.',
#   'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?',
#   'Friends'],
#  ['Joey... are you sure? I mean, I know how much you love him!',
#   "Rachel... let's be clear on this, ok? I do not love Hugsy. I like him a normal amount...",
#   'Friends'],
#  ['Ok, ten.', 'Okay, Monica picks ten, I call nine! Anyone else?', 'Friends'],
#  ["Joey, Ross is gonna be here any second, would you mind watching Ben for me while I use the ladies' room?",
#   'Oh yeah, no problem.',
#   'Friends'],
#  ['What are you doing for a living?', 'I am a lawyer.', 'Standard'],
#  ['How are you doing?', 'Good.', 'Standard'],
#  ['Where are you going to?', 'I am going out.', 'Standard'],
#  ['What are you wearing?', 'A T-shirt.', 'Standard'],
#  ['What do you want to do tonight?', 'Watching tv.', 'Standard']]

# %% [markdown]
# # Save the csv

# %%
# Create a pandas dataframe from the selected lines
df = pd.DataFrame(data=lines_selected_list, columns=['context/0', 'label', 'source'])
df = df[['label', 'context/0', 'source']]
df
# Out:
#                                                 label  \
# 0                 Come on. This is so about the girl.
# 1                                           Ted, Ted.
# 2     Hey, this is a chair, but go ahead and drag it.
# 3                                      Me too, buddy.
# 4                          Not even if her mom's hot.
# 5               Happy kitty, slippy kitty Pur pur pur
# 6                                   Thats just wrong.
# 7   Well, it took a little negotiating, but I wore...
# 8   Yes. Yes, he did, that is a perfectly satisfyi...
# 9   If I were not being careful, your telling me t...
# 10  The day I was at Gringotts, Hagrid took someth...
# 11                                  Expecto Patronum!
# 12                           I'm Harry. Harry Potter.
# 13                            But I didn't realize...
# 14                                         Professor.
# 15                            Wait, let's go by rank.
# 16                         It'll be a rich, full day.
# 17  Leela, your scaredness is being transmitted st...
# 18                                         He's dead.
# 19  Leela? What are you guys doing here in the yea...
# 20  Give yourself to the dark side. It is the only...
# 21              They must never again leave thiscity.
# 22  That is correct, Commander. And heis most disp...
# 23                  No. Leave them to me. I will deal
# 24              They must never again leave thiscity.
# 25  No.  I was told the name of the movie would no...
# 26  Hey-hey-hey! So, how did it go with Dana? Any ...
# 27  Rachel... let's be clear on this, ok? I do not...
# 28  Okay, Monica picks ten, I call nine! Anyone else?
# 29                               Oh yeah, no problem.
# 30                                     I am a lawyer.
# 31                                              Good.
# 32                                    I am going out.
# 33                                         A T-shirt.
# 34                                       Watching tv.
#
#                                             context/0    source
# 0                 Barney, this is about the building.     HIMYM
# 1   All right. I'll be right there. Stay where you...     HIMYM
# 2   I think there's a pretty girl smiling at me th...     HIMYM
# 3                                    I love you, man.     HIMYM
# 4                              Not even if she's hot?     HIMYM
# 5           Soft kitty, warm kitty Little ball of fur      TBBT
# 6                                              Penny.      TBBT
# 7   Oh. Sheldon, thank you. Thats so romantic. But...      TBBT
# 8   I didnt break it. I, I guess Stuart sold it to...      TBBT
# 9                                         Be careful.      TBBT
# 10             But why would anyone go near that dog?        HP
# 11                                  Expecto Patronum!        HP
# 12                                       Ron Weasley.        HP
# 13                      I spoke a different language?        HP
# 14                                             Harry?        HP
# 15            OK. First Bender, then Flexo, then Fry.       FTM
# 16  Just relax, Bender. Tomorrow we'll pry you dow...       FTM
# 17                                    I'm too scared.       FTM
# 18                          Dr. Zoidberg? Are you OK?       FTM
# 19                       Fry, thank God we found you.       FTM
# 20                              I will not fight you.        SW
# 21        Lord Vader, what about Leia and theWookiee?        SW
# 22                         The Emperor's coming here?        SW
# 23                                 Shall I hold them?        SW
# 24        Lord Vader, what about Leia and theWookiee?        SW
# 25      Oh! Joey uh, were you in our room last night?   Friends
# 26                                               Hey.   Friends
# 27  Joey... are you sure? I mean, I know how much ...   Friends
# 28                                           Ok, ten.   Friends
# 29  Joey, Ross is gonna be here any second, would ...   Friends
# 30                   What are you doing for a living?  Standard
# 31                                 How are you doing?  Standard
# 32                            Where are you going to?  Standard
# 33                              What are you wearing?  Standard
# 34                    What do you want to do tonight?  Standard

# %%
# Save the dataframe
out_file = os.path.join(base_folder, 'Data', 'common_dataset.csv')
df.to_csv(out_file, index=False)
