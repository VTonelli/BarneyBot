# %%
from Data.data_dicts import character_dict, source_dict, random_state

characters = ['Barney', 'Sheldon' , 'Harry' , 'Fry' , 'Vader' , 'Joey' , 'Phoebe' , 'Bender']
batch_size = 10

# %%
# Mount google drive
import os
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    base_folder = '/content/drive/My Drive/unibo/NLP_project/BarneyBot'
    os.system("pip install datasets")
    os.system("pip install transformers")
    os.system("pip install rouge_score")
    os.system("pip install -U sentence-transformers")
else:
    base_folder = os.getcwd()

# %%
import pandas as pd
from tqdm import tqdm
from datasets import load_dataset, DatasetDict

# %%
def select_lines(character):
    in_folder = os.path.join(base_folder, 'Data', 'Characters', character)
    if not os.path.exists(in_folder):
        os.makedirs(in_folder)
    out_folder = os.path.join(base_folder, 'Data', 'Characters', character)
    if not os.path.exists(out_folder):
        os.makedirs(out_folder)

    os.environ["HF_DATASETS_CACHE"] = os.path.join(base_folder, "cache")

    dataset_path = os.path.join(base_folder, "Data", "Characters", character, character+'.csv')
    
    character_hg = load_dataset('csv', 
                                data_files=dataset_path, 
                                cache_dir=os.path.join(base_folder, "cache"))
    
    # 85% train / 10% test / 5% validation
    train_test_hg = character_hg['train'].train_test_split(test_size=0.15, seed=random_state)
    test_val = train_test_hg['test'].train_test_split(test_size=0.33, seed=random_state)
    
    
    character_hg = DatasetDict({
        'train': train_test_hg['train'],
        'test': test_val['train'],
        'val': test_val['test']
    })
    return character_hg

# %%
lines_selected_list = []

# %% [markdown]
# # Characters

# %% [markdown]
# ## Barney

# %%
temp = select_lines(characters[0])
# Out:
# Using custom data configuration default-0c3b759885fd8d5f
# Reusing dataset csv (D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-0c3b759885fd8d5f\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading cached split indices for dataset at D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-0c3b759885fd8d5f\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-c79122a57f55334a.arrow and D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-0c3b759885fd8d5f\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-4faecb1c641ab4b9.arrow
# Loading cached split indices for dataset at D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-0c3b759885fd8d5f\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-7b672756e3cf7bb2.arrow and D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-0c3b759885fd8d5f\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519\cache-bb39fb19125a9103.arrow

# %%
[s for s in temp['test']]
# Out:
# [{'response': "Daddy's home.",
#   'context': "I know, it's two years of my life I'm never getting back. A little part of me just wants to jump the bones of the next guy I see.",
#   'context/0': "I'm just surprised you didn't dump him sooner."},
#  {'response': "I don't have much time!",
#   'context': "Wh-Where'd you get a meatball...",
#   'context/0': 'Eat this meatball sub.'},
#  {'response': "I could tell you knew something was up with me, and you're right. But I can't tell you what it is. I should tell you, but I can't! I have to. I never will! I'm going to. Let's just drop it. What's up with you?",
#   'context': 'Okay, what is so urgent that you called me and begged me to come over at 7:22 in the morning?',
#   'context/0': "Are you kidding? That was a great joke. It's smart, funny, beautiful, the whole package. It's everything you're afraid to let yourself want. In a joke. Bogeyman with a teleprompter. Classic."},
#  {'response': 'A little.',
#   'context': 'How much?',
#   'context/0': "I need a lawyer. I'll pay you."},
#  {'response': "I'm being Barney, and I think tonight's going to be de... wait for it... lightful. Delightful.",
#   'context': "You're being super nice. It's... freaking me out. Be... gross, be inappropriate. Be Barney.",
#   'context/0': 'Like what?'},
#  {'response': "Thank you, Lily. Is there anything you'd like to say about my show?",
#   'context': "Okay! Stop! You win. Fine. Barney, I'm sorry I made you come to my show.",
#   'context/0': "And when that didn't work..."},
#  {'response': 'Well, I found! There are bars country, the giddy ups, there are tons of guys in overalls. Copilot me!',
#   'context': 'There was never a next time. The window of Maggie never reopened.',
#   'context/0': "Well... I'll see you next time!"},
#  {'response': 'A Guide. I guided a young, once. I made him my co-pilot. Then one day, he hired an assistant to work 3 meters from her room, which... Check it out... is not a hottie, proving he has never listened. You know how to call this type?',
#   'context': 'No, I guide him.',
#   'context/0': 'PJ is a guy? PJ, this is not a hottie you fck?'},
#  {'response': "Do you know why you're not over Lily yet? It's 'cause you can still picture her naked. You can't get over a woman until you can no longer picture her boobs. It's a scientific fact. The average male brain can only store a finite number of boob images, or BPEGs and your hard drive's filled to capacity with Lily's.",
#   'context': "Barney, I really don't think this is gonna help.",
#   'context/0': 'Gentlemen, please welcome to the stage Sunshine!'},
#  {'response': 'Not at all. I could run a marathon anytime I wanted to.',
#   'context': "You're kidding, right?",
#   'context/0': "You don't need to train for a marathon. You just run it."},
#  {'response': 'Ted, Ted.',
#   'context': "All right. I'll be right there. Stay where you are.",
#   'context/0': "Listen to me, Ted. I'm going to lose you any second. I'm on the fourth car of the six train heading south from Pelham Bay Park in the Bronx. Meet me at the 86th Street station in, like, half an hour?"},
#  {'response': 'Anyway, I need you guys to come out to Staten Island on Saturday and help box everything up.',
#   'context': "With her new hippie husband, Clint. The comfort of home is a little ruined when someone turns your old room into what I'm pretty sure is a Tantric sx temple. With all the bamboo, pot smoke and '60s music, it's like my old G.I. Joes are frozen in some weird Vietnam flashback.",
#   'context/0': 'What are you talking about? Your mother still lives in the house you grew up in.'},
#  {'response': 'Why, am I under arrest?',
#   'context': 'Exit the vehicle.',
#   'context/0': 'You must have a permit to be as pretty. And this body? I imagine that something as explsive must be registered with the authorities.'},
#  {'response': "Come on, baby. please, no. You don't understand. What have I done? This is the worst. How could you...?  You're not going anywhere. Live claritin clear. Wow, that was close. That hippie chick wouldn't leave. She was ready to squat here.",
#   'context': "You son of a bitch! I can't believe I let you enter my sacred temple.",
#   'context/0': 'Yes.'},
#  {'response': "Your loss, her gain.  Excuse me, can I show you the roof? It's magical up there!",
#   'context': "I don't think so.",
#   'context/0': 'On a silver platter! Bon appetite!'},
#  {'response': "Okay, let's take a look. Oh, yeah, it's a cougar all right. A prime specimen. See, you can identify a cougar by a few key characteristics. Start with the hair. The cougar keeps up with current hairstyles as a form of camouflage. The prey may not realize that he's engaged a cougar until he's already being dragged, helpless, back to her lair. Now, the blouse. The cougar displays maximum cleavage possible to captivate her prey. If you're watching them bounce, she's about to pounce. See the claws? Long and sharp, to ward off rival females... Or open alimony checks. Yeah, this one's a beaut. Okay, let the hunt begin.",
#   'context': "Okay, wait, wait, wait. That's professor Lewis's office there.",
#   'context/0': 'Man, that guy is a total, well...'},
#  {'response': 'I know.',
#   'context': 'I love salmon risotto.',
#   'context/0': "San Marino! Oh, you're serious? Yikes. No. We have to try Casa A Pezzi. Best salmon risotto I have ever had."},
#  {'response': "Hi, there. We've had a lot of fun tonight, but on a more serious note, this is the time of year when we remember the importance of giving. And there's no greater gift than the gift of booty. So, this holiday season, why not bang someone in need? I'm Barney Stinson, and that's... One to grow on.",
#   'context': "Scherbatsky... I'm gonna crush it.",
#   'context/0': 'Ted, will you be my best man?'},
#  {'response': "Ranjit, take me to Gregor's.",
#   'context': 'Hello.',
#   'context/0': 'Keep it.'},
#  {'response': 'Folks, sorry to stop you before Marshall falls into tears, but Robin, check it out. What you need is a super video resume. Like mine. I present to you: Barneysvideocv.com. Hello. Barney Stinson, you have achieved great successes in business, sport and personal relationships, and have been an inspiration to many people.',
#   'context': 'Obviously, the stirrups were too far apart during his last visit to the gynecologist.',
#   'context/0': 'Thank you, Lily.'},
#  {'response': 'I like beer. We should go to Germany. MDR. JP.MDR.',
#   'context': "Deuzio: it's far too early suggestions crazy travel.",
#   'context/0': 'You like architecture? We should get married. Ha-ha.MDR. Just kidding. So what?'},
#  {'response': 'Stack we make love, we order a pizza face and it stays there to moan.',
#   'context': "And you know what happens right after a fight? Gender reconciliation. What is different... when you're in a loving and lasting relationship.",
#   'context/0': "So you're happy?"},
#  {'response': "Well, you didn't ruin it; you made it so much worse! I can't eat. I can't sleep. I've lost ten pounds; my suits are wearing me. You know what? I'm outta here.",
#   'context': 'I thought I ruined it by putting a clock on it, Barney?',
#   'context/0': "Oh, God! don't slap me again! I don't want to get slapped again, and the first two times hurt so bad, I don't like it! I don't like it one bit!"},
#  {'response': "She'd give it up for a bad pun. I'm telling you, she's a laugh slut.",
#   'context': "Yeah. No, you're right. Lily would laugh at anything.",
#   'context/0': 'And in almost no time, that spark turned into a roaring fire.'},
#  {'response': "That's what i thought.",
#   'context': "Come on people, get excited for us! We've got a great thing going here.",
#   'context/0': 'Say we want to play a game of charades...'},
#  {'response': 'Bang, bang, bangity bang...',
#   'context': "Okay, I promise I won't lie to her. I may, however, lie on her. I said, bang-bang, bangity-bang. Bang-bang-bang, bangity-bang",
#   'context/0': "Okay, fine. On one condition. You have to promise me you won't lie to Nora. She seems like something special."},
#  {'response': 'Come on. This is so about the girl.',
#   'context': 'Barney, this is about the building.',
#   'context/0': 'Um... thank you for, um, not using a first name in that story.'},
#  {'response': "No, you guys go ahead. I'm going to find the veil.",
#   'context': 'Yeah, okay.',
#   'context/0': "Or we looked everywhere, and we couldn't find one."},
#  {'response': 'Yeah, she told me already. Go on.',
#   'context': 'What?',
#   'context/0': "Oh, you mean how Robin's in love with Ted?"},
#  {'response': "You can't just... Wow!",
#   'context': "Why don't you just check out the girl's reflection in the bar mirror?",
#   'context/0': "It's one of the many risks of the blind approach. It's usually a two-man operation where Ted signals that the target is hot. But Ted's too busy being in a lesbian relationship."},
#  {'response': 'I like it.',
#   'context': 'Rotate the camera. Connectitude.',
#   'context/0': "All right. Do not do it. There are many exciting stories to cover in Canada. I just read it, the nephew of the mayor of Winnipeg went fishing on the ice and took a pole of 7 Kg Live from the worst place in the world, I'm Robin Scherbatsky."},
#  {'response': 'Look, it did.',
#   'context': 'Oh, thank you! Wait. Good evening, New York.',
#   'context/0': '59 p.m., Robin arrives at the studio of Metro New One.'},
#  {'response': 'And this, my friends, is the effect cheerleaders. Also known as the paradox of a bridesmaid syndrome sorority, and for a brief moment in the 90s, the conspiracy of the Spice Girls.Scary Spice, indeed.  Barney Stinson. OK.Understood. Great, we remember.',
#   'context': 'Yeah, really cute.',
#   'context/0': 'I know. The last one is kinda cute.'},
#  {'response': 'You regret it.',
#   'context': "I can not believe I do that. But I'll leave you one last chance. But be aware, if you exceed the limits of a toe, you play the duck shting in your mother's so fast it will make you dizzy. Get out!",
#   'context/0': 'My pleasure. Do not do that. This game is all I have.And I nearly enough tickets for the remote controlled helicopter. Pity.'},
#  {'response': "I know, it's a terrible idea. You can't do it. Just look at me.",
#   'context': 'We have an annoucement.',
#   'context/0': 'Hey, hey guys.'},
#  {'response': 'So I threw the pressure air oxygen into its mouth. I sht the tnk, boo, nomore shark. Mr. Hall and I swam back to shore. Hey,let me serve you a drink.',
#   'context': "Kids, in the spring of 2008 something kind of strange have been happening to your uncle Barney. He's been doing great with a woman.",
#   'context/0': 'Why would be looking for one?'},
#  {'response': 'Did you hear that, Ted? Dana works security at the Liberty Bell.',
#   'context': "I can't breathe!",
#   'context/0': "Really? Well I thought it was kinda weird, but if you're cool with it. Yeah. It's off and she's talking to some guy. Do you want me to go over and..."},
#  {'response': 'Is it? Describe your first 8.3 seconds with Stella.',
#   'context': "That's ridiculous.",
#   'context/0': "Ted, do you know how long it takes a woman to decide whether or not she's going to sleep with a guy? 8.3 seconds. After that, her decision is made. She will not change her mind."},
#  {'response': "You are the best. My girlfriend is at a strip club with me and she couldn't care less.",
#   'context': 'Wow.',
#   'context/0': 'Wow.'},
#  {'response': "Is insurance going to cover that? Sometimes they don't.",
#   'context': 'Right. So I went to the chiropractor yesterday. That guy bent me over the table and pounded me for a good hour.',
#   'context/0': "I'm being Barney, and I think tonight's going to be de... wait for it... lightful. Delightful."},
#  {'response': "There's been no light.",
#   'context': 'No. I want to.',
#   'context/0': 'It is said? It should.'},
#  {'response': "Dude... don't poop where you eat.",
#   'context': 'What? What do you mean?',
#   'context/0': "what's matter with you?"},
#  {'response': "You don't have to say it, though.",
#   'context': "We're showing Ted how lame he is.",
#   'context/0': 'Abby and I are in love. Not hot passionate love. Couple love. You know, movie night with my girlfriend, then waiting for her to go to bed so I can steal one pitiful moment of hollow ecstasy by the cold, blue light of my computer monitor.'},
#  {'response': 'Hey.',
#   'context': 'You always do.',
#   'context/0': 'Yes, but I always cover it with a cough.'},
#  {'response': "Dude, that's awesome! You're finally forgetting about that short redhead.",
#   'context': 'What? No. I... Barney, I was...',
#   'context/0': "You just checked out Robin's ass."},
#  {'response': 'Of course.',
#   'context': 'Hello, Barney.',
#   'context/0': 'No, no.'},
#  {'response': 'Shannon, there is no...',
#   'context': "It's just, he's still supporting me, and... Look, he's coming by soon to talk about it, but I think you should go on without me.",
#   'context/0': 'But the Nicaraguans need us!'},
#  {'response': 'I would say even more. You, sir, did think Stella. Ted looked so cool now. Do I chose the wrong? Wait a week. The bush on the back. And belly. Have you felt that? There was an earthquake Tope-there.',
#   'context': "I think you've been great.",
#   'context/0': 'Enchanted.'},
#  {'response': "Man, I always thought I had it rough not really knowing my dad, but... now I realize at least I'll never have to suffer like this. Our next video is called German Shepherd Activates Tennis Ball Cannon While Fat Kid Sips Energy Drink.",
#   'context': 'Yes.',
#   'context/0': 'Lawyered. Now can we all just admit that last words are, in fact, a big deal?'},
#  {'response': 'Really?',
#   'context': "My great... you cause me problems since you joined this club. But damn... if this is not the best battle of PQ I've ever seen. You are returned... And right away.",
#   'context/0': 'Thank you. Yours is.'},
#  {'response': 'Okay, go. You are not obliged to return, but you can not stay. I always wanted to say that. I mean, in a bar. I say all the time with me.',
#   'context': 'Do it.  Now, go find your wife.',
#   'context/0': 'I know not how you thought I draguais you, but...'},
#  {'response': 'She was the wife of Archie in All in the family, or the same voice?',
#   'context': 'You know Neil Young is my favorite musician.',
#   'context/0': 'thank you God, the song is over. Who was the old devil who sang?'},
#  {'response': 'Dude, you show up to an interview in that, even the hippie lawyers from Granola Mountain Earth Pals will hackey sack you straight out the door.',
#   'context': "I don't have another one. I'm flat broke. My only other suit options are track or birthday.",
#   'context/0': 'So wear another one.'},
#  {'response': "Of course. I'm sorry, I forgot to call you. That's not the place. The real place is on 106th and Manhattan Avenue. We're headed there right now.",
#   'context': "Regis. I'm at the place.",
#   'context/0': "I'm sorry, this is...?"},
#  {'response': "And that's not happy?",
#   'context': "You're not happy. You just think you're happy because you feel happy.",
#   'context/0': "Lily, can't you just let us be happy?"},
#  {'response': "Listen, Arthur, Marshall's wife has an idea for how we can save, not saving The Arcadian.",
#   'context': 'No! Tugboat, my other dog, that was a cute dog. This little disappointment is nothing but a cheap facsimile. I said it! Yeah, my love is reserved for dogs that go to the bathroom on command instead of wasting my time!',
#   'context/0': 'Oh, cute dog!'},
#  {'response': "First of all, Robin, my dad could beat up your dad. Second, you don't have to worry. He's cool. Now if you'll excuse me... I have to go renew my passport, and get a travel-sized rotating Vietnamese Shame Wheel. Don't ask; you're not ready.",
#   'context': "Barney, we just don't want to see you get hurt.",
#   'context/0': 'Well, this guy has flaked out on your whole life. It sounds like he just might be telling you what you want to hear.'},
#  {'response': "Then why don't you say it now?",
#   'context': "Why is this such a big deal? It's just a word. We use lots of words, every day. It shouldn't be any different than any other word.",
#   'context/0': 'Oh, Ted. Oh, Teddy boy.'},
#  {'response': 'Really?',
#   'context': "Actually, oddly, we both think you're meant for each other.",
#   'context/0': 'She told you? Great. I guess you marrez my back all this time.'},
#  {'response': "Um... Um... I'm have... I'm having trouble breathing!",
#   'context': 'I think the smaller turkey just tried to crawl further inside the bigger turkey.',
#   'context/0': "It's not awesome!"},
#  {'response': 'Ted, you klutzy, great guy, you!',
#   'context': 'Alright, um, I think we need to refine our back-story first. How did we...',
#   'context/0': "Okay, carousel four is tapped out. Ready? Because I'm about to drop some knowledge. Cute girls are not from Buffalo. Time-out. Ten o'clock. You ready to rock this, Tedder?"},
#  {'response': 'I wear this jumpsuit since 1:30!',
#   'context': "I'm in love with her for 12 years!",
#   'context/0': "I'm in love with her for 5 years!"},
#  {'response': 'Ted has a little sister who is so playful every day. And if I meet with her breasts, I will play! Little sister, Little Sister!What? I can also celebrate Hanukkah.',
#   'context': 'If I could see her naked. If I could see her naked. If I could see her naked. And fours.',
#   'context/0': "Drop your trousers. Mine hard. Under the bunch of mistletoe, I'll make your sister moan. Oh! Dear Heather, Heather dear, we'll do it in all directions..."},
#  {'response': 'Milk Duds.',
#   'context': 'Mounds.',
#   'context/0': "Yeah! It's like being in a candy store. You just walk right in and grab yourself some Whoppers. Yeah. Is Whoppers the best ones?"},
#  {'response': 'I know. I want to hire you.',
#   'context': "Yeah, I'm kind of real focused on the job hunt right now.",
#   'context/0': 'Hey, Marshall, I need your help.'},
#  {'response': 'I understand. Zoey has magic lady bits.',
#   'context': "It's not because I'm mad at you. Barney, The Arcadian was designed by a guy named John Clifford Larrabee. And even though he's been dead for half a century, it's my duty, architect to architect, to keep his work alive. Please tell me a little part of you understands.",
#   'context/0': "Secondly, Ted, I'm sorry I said mean things about Zoey. Are you really going to walk away from this project just because you're mad at me?"},
#  {'response': 'There should be a bar.',
#   'context': 'Except where everyone ended up spending the best night of his life, then we put the chairs on the tables and pulled out the margarita fountain.',
#   'context/0': 'No nightcap!'},
#  {'response': 'Why? Why? Why?! Why?!',
#   'context': 'What? Why?',
#   'context/0': 'Love it? Hold on a second. Love it? I hate it!'},
#  {'response': 'No.',
#   'context': "You're dating a girl from New Jersey?",
#   'context/0': "Wow. You know I really should check out this subway. Heard so much about it. Wow. Look at me. Slumming it. Maybe I'll make a weekend out of it and I'll call my bridge and tunnel girl tonight."},
#  {'response': "Yes. The chain of screaming starts at the top. Arthur's boss's boss screams at Arthur's boss. Arthur's boss screams at Arthur. Arthur screams at you. You go home and scream at Lily. Lily screams at one of the kids in her kindergarten class. Then that kid screams at her dad, Arthur's boss's boss. And the whole thing starts all over again, Thus completing the circle of screaming.",
#   'context': 'Chain of screaming?',
#   'context/0': "Lily, control your woman. The lesson of Blauman is that when your boss screams at you, you never scream back. That's why there's a little thing in corporate America I like to call the chain of screaming."},
#  {'response': "Ted, what's the first syllable in rutting",
#   'context': "It's not a rut, okay. It's a routine and I like it!",
#   'context/0': 'Consistently.'},
#  {'response': "You've heard of the golden rule, right? love their neighbor?",
#   'context': "and in this case, you're paying them... then yes, it counts.",
#   'context/0': "If it's someone you see on a regular basis, and you can't avoid them..."},
#  {'response': 'The committee realized he had erred. In addition, you are precious to them and they want you to be happy.',
#   'context': 'Really?',
#   'context/0': "Those guys were morons. Of course, they had cool ideas... really cool ideas. In fact, I wonder if it's not too late...The fact is: you have the job."},
#  {'response': "Oh no, the night's ruined!",
#   'context': "So, Barney, why don't we take this party to a more horizontal location?",
#   'context/0': "What are you talking about? Barney: If you must know, it wasn't a freak beverage malfunction that stopped me from riding the tricycle that night."},
#  {'response': "I'm not saying he loves pizza, but the last time he went, the doctor said, stop eating pizza. Marshall: Why? Doc: To you examine.  But seriously, we laugh because we love you.",
#   'context': 'Our coupons are your effigy.',
#   'context/0': 'I even caught a pizza in the shower.'},
#  {'response': 'Vegas.',
#   'context': "Whoa, we're leaving the city. Where the hell is this party?",
#   'context/0': "Okay, everyone, Ted's in the limo, five-minute warning! Everyone get ready! Oh, Missy, are you excit?? Yes, you are!"},
#  {'response': "Ted! Fine, fine. You cannot play it. Shannon! I love you! I love you so much. What about us changing the world together? Don't tell me you've forgotten. I know I haven't. Will I ever see another rainbow? Will an eagle ever soar through this tempest of woe? Baby, please Don't go There's a thief in the palace, she's stolen all my love There's a thief in the palace and she's...",
#   'context': 'Play the tape, play it, play it!',
#   'context/0': 'Give it to me, give it, give me...'},
#  {'response': "And right by Saint Valentine's side was his best bro, Saint Desperatius, there to pick off insecure bridesmaids.",
#   'context': "This won't be.",
#   'context/0': "Wait, there's more."},
#  {'response': "Nah. I'm so over karaoke.",
#   'context': 'So, Barney, you gonna sing anything?',
#   'context/0': "You're right. They're delightful."},
#  {'response': 'Really? Laid, you say?',
#   'context': "Yeah, well, it was supposed to be, but my professor's like the toughest grader I've ever seen. She had like a bad divorce this summer and now she's taking it out on us. To tell you the truth, I think she just needs to get laid.",
#   'context/0': 'I thought you said your semester was gonna be a piece of cake. I remember because you were eating a piece of cake at the time and you said, dude, my semester is gonna be this.'},
#  {'response': "Someone who likes you, really. And suspicious, and probably accurately you do it over more later, and therefore he feels the need... I'm sorry, you spoke of this fantastic pair of tits, right? Because I seek, and I do not see them.",
#   'context': 'What is wrong with you? What kind of people need to lie like that?',
#   'context/0': "Wait, Nora, waiting... No, please. I'm sorry."},
#  {'response': 'Ah. Thank you.',
#   'context': "That night, Barney didn't take care of business. Instead, Nora took care of Barney.",
#   'context/0': "Come on, let's get you sorted out."},
#  {'response': 'The Robin.',
#   'context': 'Night, night, little Marvin',
#   'context/0': 'Do you, Robin?'},
#  {'response': 'Go and eat your ice.',
#   'context': 'You can stop with that?',
#   'context/0': 'Come on, Barney. You have no idea of the difficulty of getting a job beneath you. I really liked your tip on the bones of dinosaurs.'},
#  {'response': "You're kidding me!",
#   'context': 'Karen is here?',
#   'context/0': 'My ex, Karen, is in New York. The usual routine.'},
#  {'response': "Well, obviously, I've been proven right, so in the interest of Robin's dignity, I won't show anymore. Plus, it's getting late. It's already slap o'clock.",
#   'context': 'Oh my God.',
#   'context/0': "Please, Mr. Johnson, I'm sorry I was a bad girl. Please don't give me detention. Isn't there something I can do to make it up to you?"},
#  {'response': "Yes, I'm in the office. This is the sound of my stapler.This is the sound of my trouilloteuse. And that, the sound of me, ranking the company's directive on sexual harassment. What's new? I gotta run, great leader.",
#   'context': "Marshall. So, you're in the office? You're not, I do not know, driving a taxi, with a wig?",
#   'context/0': 'Barney here.'},
#  {'response': 'Oh, once I am the soul man. There was this pretty girl who only go out with black.',
#   'context': "Ok, let's move. What was the worst? The best of the worst? The cream of the crop?",
#   'context/0': 'I do not have time to explain how I got there. I just need someone to suck the poison. The surgeon gave me a new face, darling. You realize that I am alive? My name is David Beckham. If I castais only the white swan, is the role for you. No, I am a lesbian. What I wear is just very realistic.'},
#  {'response': "It's a long story. As you know, my father had to leave my mother when I was a baby because he became presenter of the Just Price.",
#   'context': "What's that, Barney?",
#   'context/0': "Will in, little rascal! I'll see you at the bar?"},
#  {'response': 'No thank you.',
#   'context': 'It was pretty awesome. You should try it. I still have a few.',
#   'context/0': 'No, sir. I like to play by the rules. While I can not say I did not propose to.'},
#  {'response': 'Big fan. Barney Stinson. So, uh... what about this party?',
#   'context': "Wow. You're friendly.",
#   'context/0': 'Welcome.'},
#  {'response': 'This morning I made the heart of the Ambassador of the Netherlands. I hope he gets better.',
#   'context': 'He will watch it.',
#   'context/0': 'I look, sir.'},
#  {'response': 'Absolutely not.',
#   'context': 'And those girls over there? They are cannon.',
#   'context/0': "I'm not impressed by the talent here tonight. And more I drink, the less it is attractive. I'm a whiskey and Coke in the Cantina scene in Star Wars."},
#  {'response': "Ted, I'm going to teach you how to live.  Barney, we met at the urinal.",
#   'context': 'I see what this is about. Have you forgotten what I said to you the night we met?',
#   'context/0': "You know, ever since college it's been Marshall and Lily and me. Now it's going to be Marshall and Lily... and me. They'll get married, start a family-before long I'm the weird, middle-aged bachelor their kids call Uncle Ted."},
#  {'response': 'Hey, Ranjit, pull over.',
#   'context': "Well, you're in luck. See that gothic church over there? Those corinthian columns were designed by Giuseppe Pegatto in 1896.",
#   'context/0': 'Last seat. Thank God. I just had the worst cab ride of my life.'},
#  {'response': 'Help me!',
#   'context': 'You called, said..., and hung up. What do you want?',
#   'context/0': "Ah, ah, it's her, it's Robin. What do I do? No-no-no-no, aah! Robin... Great to hear from you. To what do I owe the pleasure?"},
#  {'response': "Suits are full of joy. They're the sartorial equivalent of a baby's smile.",
#   'context': 'Virtually.',
#   'context/0': 'Have I taught you nothing, Ted?'},
#  {'response': "gn! She's got a gn!",
#   'context': 'Actually, there is one thing I wanted to give you.',
#   'context/0': "But you did not do it, you've continued to insist."},
#  {'response': 'Solid plan, my little friend.',
#   'context': 'We do it up there sometimes.',
#   'context/0': "Oh, the moon, the stars, the shimmering skyline. You can't not fall in love on that roof."},
#  {'response': 'Son?!',
#   'context': 'Thank you, son.',
#   'context/0': "Bring 'em in, boys! Merry Christmas."},
#  {'response': "It's okay, Mom. I don't need it.",
#   'context': 'Barney.',
#   'context/0': 'Oh, you know what, dear? Apparently, there was a mix-up with the mail. I just got this letter from the Postmaster General. Dear Barney, I sincerely apologize for losing all the invitations you sent out to your eighth birthday party.'},
#  {'response': "Stay with me. It's going to come to me. No. Ah, okay, here's the point. You thought that Mary was a sure thing, right? So what happened? She took you up to a hotel room on the first date. All you have to do is be that confident with every girl you meet and your slump is over.",
#   'context': 'What point?',
#   'context/0': 'I did it to prove a point.'},
#  {'response': "...he quit, Robin, he quit! It's Meatball Sub Day today, which is why I wanted Marshall to come over and have lunch. But no. All that work wasted.  You want to make God laugh, tell him your plans, right?",
#   'context': 'I plotted my revenge for weeks. But nothing seemed right. Then it hit me. The answer was so elegant and simple-- an exploding meatball sub. For months, I experimented. More... marinara sauce. Finally, the sub was perfected. The plan was in place. The snare was baited. And then...',
#   'context/0': 'Hey, buddy, I think you got a tiny little bit of marinara sauce on your tie there.'},
#  {'response': "Well, he's not my dad. My dad's Bob Barker.",
#   'context': "Listen to me. There is no Yourson, North Dakota. Mom... And Sam Gibbs wasn't the mayor. He might be one of our fathers.",
#   'context/0': 'Stop!'},
#  {'response': 'I think someone owes me  200.',
#   'context': 'Oh, my God!',
#   'context/0': 'Who wants to go to the same old bar, sit at the same place and drink the same thing? The same thing! My favorite!'},
#  {'response': 'Oh, no.',
#   'context': 'Um, those places shut down a long time ago.',
#   'context/0': "Oh, we're not drinking here. Tonight we're going big. Let's see, what club should we hit first? There's Club Was, there's Wrong..."},
#  {'response': 'And I love you, Shannon.',
#   'context': 'I love your singing, Barney.',
#   'context/0': 'It was 1998. I was just out of college, and I was working at a coffeehouse with my girlfriend. My girlfriend... Shannon. Yeah, you were meant for me And I was meant for you. Ooh, ooh, ooh-ooh-ooh. Thank you. All right.'},
#  {'response': 'No.',
#   'context': "You're right. There must be a mistake.",
#   'context/0': 'Bad idea.'},
#  {'response': 'You think about it? You hardly know him. In addition, the guy is a draw with a job that is worthless.',
#   'context': 'I thought about it.',
#   'context/0': 'You said what?'},
#  {'response': 'No, my wife will give birth! I have a sausage with your name!',
#   'context': 'Yes, I did a search. You have 15 offenses of the past three days. Exit the vehicle.',
#   'context/0': 'Why, am I under arrest?'},
#  {'response': 'Marshall, do you know how the myth of mermaids came to be?',
#   'context': "I don't think that's gonna be a problem.",
#   'context/0': "Mark my words, Marshall. Someday you will find Iris so excruciatingly attractive, you won't be able to look her directly in the boobs."},
#  {'response': 'The calzone?',
#   'context': 'You got nothing on me.',
#   'context/0': 'Marshall?'},
#  {'response': 'Guys! I just tasted an amazing caterer.',
#   'context': 'Wow.',
#   'context/0': 'Intense? I have a wedding to plan in nine weeks for 200 people. Even if a dinosaur should poke his head out of my butt and consume this coffee table, I need you to roll with it, okay?'},
#  {'response': "Oh, God. Is that what you two do together? You sit around the house and talk about love? I think... I'm gonna be sick.",
#   'context': "Believe me, I fought this for a long time. Come on, it's embarrassing. Look, this felt unnatural to me, too, at first. But I fell in love. And Tom and I realized you can't fight love.",
#   'context/0': 'Not gay marriage-- marriage! How can you do this?We were raised in the same house, with the same values!'},
#  {'response': 'And it begins.',
#   'context': "Rock 'n' roll.",
#   'context/0': "What's that? Interesting theory, Barney, but I'll need some proof? Okay. Korean Elvis. How would you like to have a drink with me and my friends?"},
#  {'response': 'Dude, your narrow-minded views on professional fornicators were harshing my mellow. So I got you a date for the evening.',
#   'context': 'What the hell?',
#   'context/0': 'See you in two shakes, Mare. You two make yourselves comfortable.'},
#  {'response': 'These are my friends. Ted, Marshall, Lily and Robin.Guys, here is Loretta. My mother.',
#   'context': 'Your girlfriend. You did not really like, huh?',
#   'context/0': 'Who?'},
#  {'response': 'Friends! We forget what is really important here. Ted is blond.',
#   'context': 'We must control our...',
#   'context/0': 'Baby, you...'},
#  {'response': 'Abby and I are in love. Not hot passionate love. Couple love. You know, movie night with my girlfriend, then waiting for her to go to bed so I can steal one pitiful moment of hollow ecstasy by the cold, blue light of my computer monitor.',
#   'context': "That's right. And girlfriends are lame. Unless they're me. I miss you, Ted.",
#   'context/0': "That's right. I am done with this whole being awesome thing. Now I'm all about farmers' markets and day hikes in matching khaki cargo shorts. Isn't that right, sweetie?"},
#  {'response': "I know it's silly, but... And the dragon. They are happy, you know?",
#   'context': 'Are you crying?',
#   'context/0': "It's not me who cried during the song Clint."},
#  {'response': "You're next.",
#   'context': 'I was relaxed, two seconds ago.',
#   'context/0': "You're so tense."},
#  {'response': 'Okay.',
#   'context': "If you want my help, it's a super hot date.",
#   'context/0': "A great date? It's not very catchy. And if I say a mega date?"},
#  {'response': "Hi, I'm Barney.",
#   'context': 'Great. Nice.',
#   'context/0': 'You know, I do have a phone number.'},
#  {'response': "Well, that's good. All we have to do is think back to the time Ted told us about his first date with Zoey.",
#   'context': 'Okay, Zoey wrote, Meet me at 6:00, where it all began, where you gave me the orchid at the intersection.',
#   'context/0': "We've got to stop Ted. Where are they meeting?"},
#  {'response': 'Uh, gotta go. Here he comes.',
#   'context': "In a few short hours, Lily would come to regret those words. But we'll get there.",
#   'context/0': "Damn it! Well, you still gotta see it. It's so much fun having a goat at a party!"},
#  {'response': 'Feelings. Inside. Oh, no!',
#   'context': 'And then it just got weird.',
#   'context/0': 'I never get picked for audience participation.'},
#  {'response': 'God, this is awkward.',
#   'context': 'Okay.',
#   'context/0': "I'll come with you."},
#  {'response': "Why would I do that? I'll see him at poker on Tuesday.",
#   'context': "Woody Allen is eating at Gregor's, and Robin thinks that we should go see him.",
#   'context/0': "Okay, time's up. What are we talking about?"},
#  {'response': 'Yeah! I knew it.',
#   'context': 'You got me. I was just nervous. I got mugged by a monkey.',
#   'context/0': "Well done! I have too much sleep last night. Can you imagine that I almost buy a gn? I'm glad you assaulted by a monkey."},
#  {'response': 'No, the answer is Elton John. Question two: What the hell is this?',
#   'context': 'Queen Elizabeth II.',
#   'context/0': "Ready for the test maybe, but ready to be an American? Not on your sweet life. For you to be an American, we got to get the Canadian out of you. That's why I've created these questions. Question one: Who is this?"},
#  {'response': 'Well, there you should also apologize. We said some pretty hurtful.',
#   'context': 'I came to apologize to you. I exaggerated.',
#   'context/0': 'a deal!'},
#  {'response': "Tracy, could you come in here, please? Would you please inform Mr. Eriksen that I'm no longer speaking to him.",
#   'context': "This is a job for me, Barney. It's a way to make some extra wedding money, and that's it. Now I'm sorry, but I have work to do.",
#   'context/0': "Stu... Come on, man, I didn't recruit you to work here for your lawyering skills. I recruited you to be my executive mischief consultant."},
#  {'response': "OK, fine, so a judge is making me do this but I'm still doing it, and kicking ass at it, BTW.",
#   'context': "Now, all's right with the world again.",
#   'context/0': 'Oh, you are evil.'},
#  {'response': "I'm sorry. Sorry. Something Hershel said at work today.",
#   'context': 'Hey, guys. Thanks. Hey. I just had the best first day at the NRDC.',
#   'context/0': 'We take turns! Sometimes.'},
#  {'response': "It's called a shirt.",
#   'context': 'A shirt.',
#   'context/0': 'What? We do break? What does that mean? And why they wear a night gown?'},
#  {'response': 'He kind of did.',
#   'context': 'Oh, no. Did he look like a guy who tried to be an umpire but failed?',
#   'context/0': 'Oh, so when do you think someone should do it? Just wait for a lull or what?'},
#  {'response': "I'll call you.",
#   'context': 'Children, you remember Nora. But the other day...',
#   'context/0': 'Barney, he did not need your advice. You never called Nora.'},
#  {'response': "Okay, well, I guess now is as good a time as any. In keeping with tonight's award show motif, I'd like to announce this evening's big twist ending! Vampire Lou, would you do the honors?",
#   'context': 'No!',
#   'context/0': "That's her napkin."},
#  {'response': 'We are two peas.',
#   'context': 'See you later alligator.',
#   'context/0': 'After a while crocodile.'},
#  {'response': "Do you not see the powerbar in my hand? I'm fueling up.",
#   'context': "Dude, you're klling me. You didn't tame the cougar. You just made her angrier.",
#   'context/0': "Fine. Here's the ball. At least you have one now."},
#  {'response': 'Is that your water? May I?',
#   'context': '57 days.',
#   'context/0': 'Lawyered. The point is, how long has it been?'},
#  {'response': 'Hey, Robin, you should dance on the oven.',
#   'context': 'The oven.',
#   'context/0': "No, we hate Zoey! I'm so furious at you all right now, but it's Thanksgiving, and I have a Turturkeykey to make. And not that I'm The Blitz, but could everyone please come with me into the kitchen?  Okay, I'm, uh, just gonna preheat the oven."},
#  {'response': 'How will Marshall and Lily?',
#   'context': 'And suddenly, I found how to get the real scoop on Barney and Robin.',
#   'context/0': "They're probably playing the bagpipes on the shower chair."},
#  {'response': "Okay, tomorrow... oh, and I should mention this is going to rock your world-- tomorrow I'm taking you to my personal tailor.",
#   'context': "Okay, it's the National Resource Defense Council, and it's my dream job. Except it's only an internship, and I won't be getting paid. Mostly getting people coffee. But the people I'm getting coffee for... their bosses are going to save the world.",
#   'context/0': 'Dude, you show up to an interview in that, even the hippie lawyers from Granola Mountain Earth Pals will hackey sack you straight out the door.'},
#  {'response': "Lily, control your woman. The lesson of Blauman is that when your boss screams at you, you never scream back. That's why there's a little thing in corporate America I like to call the chain of screaming.",
#   'context': "How does that help me? How does any of this help me? Can somebody, for god's sakes, please give me one piece of useful advice?",
#   'context/0': 'No, no, of course not... he died.'},
#  {'response': 'Hate to cut in again here, but...',
#   'context': 'My training went on for a year.',
#   'context/0': 'Beg your pardon.'},
#  {'response': 'You think?',
#   'context': 'Whoa... this place in lourd!',
#   'context/0': "It's... not that arbitrary..."},
#  {'response': ': Hey, hey! There we go!',
#   'context': "You want to fight me? Well, I'll fight you, dummy! You don't even know!",
#   'context/0': "After that, Barney's memory of the night got a little hazy."},
#  {'response': "Robin, you're great listening. You're really great, but we're friends. This is not a good idea.",
#   'context': 'In your opinion? What we can say to that?',
#   'context/0': 'You said what?'},
#  {'response': "You're staying.",
#   'context': 'I will be awakened by screaming children in less than...',
#   'context/0': '45 a.m.'},
#  {'response': 'Do you remember how awesome it was to be co-workers... Nay, bro-workers?',
#   'context': 'Kids, you may remember that, a few years earlier, I was chosen to design the new Manhattan headquarters for Goliath National Bank. It was the opportunity every architect dreams about. And when the project was ultimately scrapped... it broke my heart.',
#   'context/0': "It's my building."},
#  {'response': "Oh, man, I am so excited that you're here! It has been forever since I have been around anyone even remotely fun. Uh, yes offense.",
#   'context': "Okay, great. How 'bout you instead?",
#   'context/0': 'Oh, my God, I do!'},
#  {'response': 'Yeah, well, you did, thanks.',
#   'context': 'I cannot believe I gave you my number',
#   'context/0': "What? No no, that's some other guy and he was a kick-ass fighter pilot"},
#  {'response': "It's always food.",
#   'context': 'I love Chow-man. They can not fire him. You know what I like about Chow-man?',
#   'context/0': 'Who wants pork barbecue? Of course you want!'},
#  {'response': 'How much fun is this? All of us reminiscing about how we met me? Robin, have I told you how I met Marshall? Robin: Yeah, like five or six times.',
#   'context': 'No, no no no no no no no no no no no.',
#   'context/0': 'Yes it was, at the freshman orientation party.'},
#  {'response': 'Mellow order, bro, mellow order.',
#   'context': 'Hey, nonfat latte to go.',
#   'context/0': "I know. Only five short weeks till we're down in Nicaragua."},
#  {'response': 'Okay.',
#   'context': 'Bilson told me he wanted to give the job to Ted.What has happened?',
#   'context/0': 'Good grief. I told Heather to put everything back as it was on your desk.'},
#  {'response': 'Maybe. I remember more. Because for me he is dead! PJ will receive a mail with a disruptive place, it should in any circumstances be three days and then send it to me.',
#   'context': 'Ted Mosby?',
#   'context/0': 'A Guide. I guided a young, once. I made him my co-pilot. Then one day, he hired an assistant to work 3 meters from her room, which... Check it out... is not a hottie, proving he has never listened. You know how to call this type?'},
#  {'response': 'My elbow slipped!',
#   'context': 'Hey. Hey, Nora. Uh, Nora, this is Barney. You want to see Anna beat him in an arm wrestle?',
#   'context/0': "Hey, guys, so sorry I'm late."},
#  {'response': "What's the matter?",
#   'context': 'I remember the night before. They made me a farewell party. They gave me a camera to take pictures and send them home. Everyone was sure I will have much success. You will really miss.',
#   'context/0': 'I think so.'},
#  {'response': "And you earned it, buddy. Check out what I'm gonna buy for myself. The dibiase. See those pinstripes? Diamonds. It is the uppest a person could ever suit.",
#   'context': 'My God, Barney! I work for GNB, too. All I got was 15 gift card to Costa Coffee.',
#   'context/0': 'Yeah. What is my third favorite word that begins with b-o-n?  Bonus. As in, my end-of-the-year bonus check.'},
#  {'response': "Not before I share with you what being in a relationship leads to, Ted. Abby, Pookie Bear... I am so pathetically desperate for you that... aw, heck, I'll just say it. Would you marry me?",
#   'context': "Um, Barney, I, I see what you're doing. Please stop.",
#   'context/0': "We can't stop breathing, Ted. Your hair looks amazing."},
#  {'response': 'Yes! Drink, drink, drink...',
#   'context': 'Drink, drink, drink, drink, drink...',
#   'context/0': 'Guys, you are being immature and moronic and drink, drink, drink'},
#  {'response': 'Smell me.',
#   'context': "I'm not gonna... Not gonna...",
#   'context/0': 'Yeah. Check it. I just drove a pedicab 26 blocks, and I still smell incredible. Smell me.'},
#  {'response': 'Yeah, no problem, of course.',
#   'context': 'Hi. Guys before you go that you bother to read my toast for the wedding?',
#   'context/0': 'Punchy asked me to be his witness.'},
#  {'response': "I'm sorry, I couldn't hear you over the sound of a butterfly landing on a leaf about three blocks away.",
#   'context': 'This is me yelling at you, Barney.',
#   'context/0': 'Yeah.'},
#  {'response': 'Whoa, a hottie with a body! Boing...!',
#   'context': 'That was really...',
#   'context/0': "If I had my dad's number, I would never not be on the phone with him."},
#  {'response': "I like this. Seduce the receptionist. That's a great plan.",
#   'context': "The receptionist. That's my way in.",
#   'context/0': "I'm sorry, I just wish that some of the patients would be nicer to you."},
#  {'response': 'Chronicles of the Oscar-winning on urban neurotic.Tape!',
#   'context': 'New Jersey coast.',
#   'context/0': 'New York has Greenwich Village.'},
#  {'response': "Stop what, Ted? Stop being in love? Next he'll ask us to stop breathing.",
#   'context': 'Uh, okay, Barney, you can stop.',
#   'context/0': "You don't have to say it, though."},
#  {'response': 'What just happened?',
#   'context': 'Oh...!',
#   'context/0': 'Look. Look what I just ripped out of the ground!'},
#  {'response': 'Thank you, God!',
#   'context': 'Oh, hold the door!',
#   'context/0': "Aw, come on, Blitz. Now it's just sad. Aw, man. Oh, go ahead. I forgot my jacket."},
#  {'response': 'I know, it was hilarious.',
#   'context': 'Not funny, dude.',
#   'context/0': 'That was not funny.'},
#  {'response': 'See you guys later.',
#   'context': "Well, if he needs a transplant, he can have mine. I'll be right there.",
#   'context/0': 'Come on, daddy, break me off a piece of that white chocolate.'},
#  {'response': "That's how I'm gonna use mine.",
#   'context': "Thanks, baby.  Oh. Ooh, I gotta go. The invitations are ready. The party's for a bunch of environmentalists, so I found a guy downtown who makes biodegradable party invitations that can also be used as toilet paper.",
#   'context/0': 'Baby, you have my full support.'},
#  {'response': 'I have big news!',
#   'context': "Oh my God! I can't believe it!",
#   'context/0': 'This is incredible!'},
#  {'response': 'Look, our forefathers died for the pursuit of happiness, okay. Not for the sit around and wait of happiness. Now if you want, you can go to the same bar, drink the same beer talk to the same people everyday, or you can lick the Liberty Bell! You can grab life by the crack and lick the crap out of it!',
#   'context': "No, I'm not.",
#   'context/0': "Ted, Ted... you're not even looking."},
#  {'response': 'When will you understand the difference between my life and a porno is that my life has better lighting.',
#   'context': "It's from a porno. I saw him. Shit, I did.",
#   'context/0': 'False. This has never happened.'},
#  {'response': 'You really put a knot!',
#   'context': 'They are not all bad. Like... this. Look. I have my eyes open.',
#   'context/0': "He was right. Your uncle Marshall is many things well, but for the pictures, it's terrible."},
#  {'response': 'A hot air balloon?',
#   'context': 'Why does he keep doing this?',
#   'context/0': "This is so strange, you know, now that Ted's gone, it's just a... a different vibe."},
#  {'response': "You guys just had sx? Oh! Wasn't me.",
#   'context': 'Now, notice the vacant eyes, the pale, queasy expression, suggesting nausea. What do these mean?',
#   'context/0': 'Top Ten Robin Scherbatsky Facial Expressions and Their Meaning.'},
#  {'response': 'How you doing, Lily?! Should I have a boner?!',
#   'context': "Yeah, I'm sorry, but unless I see Barney at the same time, I... I'll never be sure that Dr. Stangel isn't him.",
#   'context/0': 'Oh, yeah... Bjorney.'},
#  {'response': 'New bet, then. If you can finish your list before me, we will cover the laser PQ and you pay toilet paper.Biodegradable and not this crap. I want up there forever.',
#   'context': 'Removes colonoscopy and sleeping with an old, and is a cinch.',
#   'context/0': 'A list of things that you are too young. Do all these things and tell me if you still want to be old.'},
#  {'response': "Exactly. Science. There is an 83 correlation between the times men wear boutonnieres and the times they get laid. Think about it. Proms, weddings. Grandmas' funerals. Thanks for the redhead, Nana. The everyday boutonniere by Stinson.",
#   'context': 'Why does Barney do anything ever?',
#   'context/0': 'Why are you wearing that?'},
#  {'response': "Oh my God. Are you gonna cry? Marshall: No. You're gonna cry.",
#   'context': 'One because you lied. And two for being prematurely slapped. Three slaps.',
#   'context/0': 'Three?'},
#  {'response': "Thanks. You're the only one who's nice to me about this.",
# ...
#   'context': "Alright, cool kids are leaving now. Grandma, grandpa... don't wait up.",
#   'context/0': 'Wow, who knew being committed in a heterosexual relationship could make a guy so gay.'},
#  {'response': 'And...',
#   'context': 'At our table.',
#   'context/0': 'It may seem insignificant, but they got to our table.'},
#  {'response': "I'm really sorry about you and Robin. I know I was always joking around about wanting you two to break up, but you were really good together.",
#   'context': "So Marshall and Lily were married, and Robin and I were broken up. And as hard as it was at the time, in the end we both got what we wanted. She did eventually go on to live in Argentina and Morocco and Greece, Russia, even Japan for a little while. And I... well, I met your mom. I think for the most part if you're really honest with yourself about what you want out of life, Of course, at that moment, all I really wanted was a scotch and soda and a cigar.",
#   'context/0': 'My wife...'},
#  {'response': 'I know, right?',
#   'context': 'Where do you see this relationship going? My God, that sounds so cheesy.',
#   'context/0': 'Fine. But how do these things even work? What do we say?'},
#  {'response': "Wow. Wow. Great stuff, Tommy Lee. See what you don't understand is, I'm Ted wingman. It's a sacred bond, much stronger that any... They're making out again!",
#   'context': 'Oh, well. You can check out off 08:54, dress up like a dork and bother the cool kids. Beat it, nerd.',
#   'context/0': "I'm not gonna remember that. Now, if you'll excuse me, random chick from earlier tonight, as you shall henceforth be known. Ted and I have a schedule to keep."},
#  {'response': 'You... Been to Ted?',
#   'context': "Doug Martin was in McClaren's bartender. He was always in the corner.",
#   'context/0': 'I spoke to Doug, children? Not? Well...'},
#  {'response': "It's hot.",
#   'context': 'Sorry.',
#   'context/0': 'It has returned to you.'},
#  {'response': 'So what happened next?',
#   'context': 'Oh, look, more strawberries!',
#   'context/0': 'Lily, you could have burped or said the word Yes, but the fact that you did both is exactly why I married you.'},
#  {'response': 'Party number one!',
#   'context': 'Party number one!',
#   'context/0': "Okay, nobody get down. We knew this going in. We're a man down. That just means we're gonna have to party that much harder. Ranjit! Party number one."},
#  {'response': "Ted, it's Barney. Listen to me, I need you to come and pick me up on the subway.",
#   'context': 'Hello?',
#   'context/0': 'So Barney did it. He actually finished the marathon. But a little while later... I got an interesting phone call.'},
#  {'response': 'My brother, lay your hand on the box tops and repeat after me. Me, the false name you give to women.',
#   'context': 'Do not depict me as a monster for wanting to remain independent. In there is a lot of people who do not want it.',
#   'context/0': "God thank you, you're not my mother. You're an ice queen. All you have breastfed baby by a frozen brain."},
#  {'response': 'An Ottoman 19th in an antique shop.',
#   'context': 'And a half?',
#   'context/0': "If, when you're great like me. Listen to this. Robin taking into account the number of beds in which we did. One is 83 and a half."},
#  {'response': "Ted's goanna get it on with a TV reporter",
#   'context': 'go, go, GO!  Everybody brings flowers.',
#   'context/0': 'Hey, HEY!'},
#  {'response': "No, uh, we're good. We're good. Happy New Year, Not Moby.",
#   'context': "You're sure? Come on. It's going to get nuts in there. There's this dude who owes me money.",
#   'context/0': 'Nah.'},
#  {'response': 'Prisoners on the run are not sexy. At the same time it was a faulty concept. Next step, the patient zero.',
#   'context': 'During the season of super bowl, but if they mean the super bowl. Go Vikings.',
#   'context/0': 'Go Browns!'},
#  {'response': 'You called me, said you were never coming back. So, I jumped on a plane, flew across the Atlantic...',
#   'context': 'How did you find me, anyway?',
#   'context/0': "We started drinking. And the next thing I know, they're inviting me to a Bryan Adams Rich title double bill in Toronto."},
#  {'response': "Okay, time's up. What are we talking about?",
#   'context': 'By the end of this day, Robin would have done all of those things.',
#   'context/0': "Those rules are all stupid, okay? I've never done any of those things."},
#  {'response': 'Jealous. Jealous. Hero. Strangely silent during this conversation on his number of sexual partners. Hero. The grand total, it is the only number that matters.',
#   'context': "Let 20. So 20 girls a week, that's 1,040 girls a year.In its 16 years of sexual activity, it would mean that he has dredged 16,640 girls. If he has slept with 199, it's a success rate... slightly higher than one per cent. This is an average of 12 hits, eight times worse than average in career... launcher in one hand, the launcher... Jim Abbott.",
#   'context/0': "It's more than 20. B. Does nothing more precise estimate."},
#  {'response': 'It was that day... July 23, 1981. My mom got pretty mad that he let me destroy a New York City landmark.',
#   'context': 'So when was the last time you saw him?',
#   'context/0': 'There he goes. The Marathon Man. Mr. Stamina himself. I can kiss better than that old man.'},
#  {'response': "Yeah. That doesn't go away.",
#   'context': 'It hurts my eyes.',
#   'context/0': "See that wall? 300-inch flat-screen. They only sell them in Japan, but I know a guy. Had to ship it over in a tugboat like freakin' King Kong."},
#  {'response': 'Okay, everybody, listen up.',
#   'context': "And that's the only time my father ever said he was proud of me.",
#   'context/0': "Dear Marshall, I know this is a strange way to apologize, but I'm sorry I let Carl name your drink after me."},
#  {'response': "Guys, guys, guys, we're on me now. And it is getting in-teh-resting. Looks at these texts. Read this one. Yowza! Now look at this one. Does she text her mother with those fingers? Now look at this one... or this one, or this one, or this one, or...",
#   'context': 'I did NOT...say... it was a good plan.',
#   'context/0': 'Getting drunk and cleaning the apartment was a plan?'},
#  {'response': 'Me too, man. More than you, certainly. Instance. Super spicy. I feel bad.',
#   'context': 'I do too. It is more spicy, the better.',
#   'context/0': 'From spicy tuna? My favorite.'},
#  {'response': "Who knows? This feud goes so far back I can't remember who fired the first shot.",
#   'context': 'Ooh! Duck! That is sick! Why would you do that?',
#   'context/0': "And now I'm e-mailing said picture to him."},
#  {'response': 'Oh, no. Someone put your painting up behind the bar. Classic! What a memorable prank.',
#   'context': 'Field trip!',
#   'context/0': 'Yo, why you gotta ruin my riddles?'},
#  {'response': "Stella! You have a serious girlfriend now! You're over this one. Robin who, right? Stella makes this one look like a filthy bag of gbabage, am I right? Happy birthday, bro.",
#   'context': "Guys, cut the act. I know. I know about the surprise party you guys are throwing me. Marshall let it slip earlier today. Hey, I'll totally act surprised and everything. Just be sure to invite Stella.",
#   'context/0': 'Nothing.'},
#  {'response': "Ted, have you not been listening? Attraction, bargaining, submission, perks, tipping point, purgatory, confrontation, fallout! These things will all happen to you as surely as they happened to all of us! It's a rule of nature.",
#   'context': "You're such a jerk!",
#   'context/0': 'I have a date.'},
#  {'response': 'What do I do? Tell me what to do, Ted.',
#   'context': 'Zitch dogs, this. Or nothing.',
#   'context/0': 'Dude, a dog.'},
#  {'response': "You're really gonna pretend this never happened?",
#   'context': 'What thing?',
#   'context/0': 'Because of our thing.'},
#  {'response': 'Ted, you still with us?',
#   'context': 'Good luck, dude. Grab me a cupcake.',
#   'context/0': 'Buttercup Bakery. This is it.'},
#  {'response': "I only have one rule. Never, ever, ever meet a girl's parents.",
#   'context': 'This was a big deal for Barney.',
#   'context/0': "It's funny you should say that, because, as it happens, my parents are in town. They're only here like once a year. We're getting brunch tomorrow. Do you want to meet them?"},
#  {'response': "And there's more. Do you still do that thing where you give people in need clothes for job interviews?",
#   'context': 'Positive.',
#   'context/0': 'You sure?'},
#  {'response': "I should go, too. I hooked up with this Chinese girl last night and I don't know, it's weird. I already feel like seconds.",
#   'context': 'What!',
#   'context/0': 'Even better, seeing him naked.'},
#  {'response': 'What, she is upset?',
#   'context': 'Barney, sit down, there are two three things to tell you.',
#   'context/0': 'Typical of a guy.'},
#  {'response': 'And I said my name was...?',
#   'context': 'It rhymes with your name.',
#   'context/0': "... don't see eye-to-eye on anything! Totally."},
#  {'response': 'Really? Laid, you say?',
#   'context': "Yeah, well, it was supposed to be, but my professor's like the toughest grader I've ever seen. She had like a bad divorce this summer and now she's taking it out on us. To tell you the truth, I think she just needs to get laid.",
#   'context/0': 'I thought you said your semester was gonna be a piece of cake. I remember because you were eating a piece of cake at the time and you said, dude, my semester is gonna be this.'},
#  {'response': "I don't always want to be that guy. Sometimes I want to be someone you can have an actual conversation with. Now, tell me something about you that I don't know yet. Seriously.",
#   'context': 'Nothing? Not even a glance? Even I was thinking about rocking a motorboat on those bad boys. What the hell is wrong with you?',
#   'context/0': 'Thanks.'},
#  {'response': 'Can you believe...',
#   'context': "I'd love to.  There's just one little thing, and it probably doesn't matter, but... I don't want to get married. I've been saying that all night just to get in your pants.",
#   'context/0': 'Do you want to come upstairs?'},
#  {'response': 'Okay, this place is actually pretty nice.',
#   'context': 'I have a hot tub.',
#   'context/0': 'Your place? Thanks, but no thanks, 1994 Courtney Love.'},
#  {'response': 'Mind you, it is rather barrel.  I choose you you, baby. Tomorrow morning, I get rid of these costumes.',
#   'context': 'Nothing suits her better... than... Costume.In costume! In costume! Costume...!',
#   'context/0': "I'll stop. These are the costumes. Stops just bullshit.Two, three, four! Girls come and depart, but the clothes remain constant! Each buddy dpote and rambling, it is no substitute!Sorry, my costumes, I give you my life. My Sunday clothes are my best friends! The casual clothes go in the basket because nothing goes better with the undisputed often praised, claiming to fame... a true... Expect more... Costume..."},
#  {'response': "Really? 'Cause I could swear you fell straight out of heaven. Angel... Give him your number. What? Give him your number. What?",
#   'context': "No, I haven't.",
#   'context/0': "You've had a terrible fall."},
#  {'response': "Awesome. Say that is a tailor and you have found a nice suit. A nice suit Canada. Superb chest. You try it, but it does not suit you perfectly. So you return it. Then I try it. I'm not too keen... a suit that you have caught the eye, but at the same time, I love this costume.",
#   'context': 'I have to really work, so...',
#   'context/0': 'What do you think of Robin?'},
#  {'response': "How would you like to extend your stay here? All you'd have to do is pretend to be my wife, and scare off the occasional one-night stand. I know,I know. You've got your ethics. You've got your principles...",
#   'context': 'Thank you.',
#   'context/0': "She was freakishly immune to everything in my apartment... Except you. You're better than prn."},
#  {'response': 'Oh, my God.',
#   'context': 'I showed up with wet hair once! Once!',
#   'context/0': 'What, wear a wrinkled suit and not give a damn about what your hair looked like?'},
#  {'response': 'Your nails?',
#   'context': "You know what, Doug? I will gladly pay. And why?As adults do. They pay their glasses, and they fight it. You know what I did when you were kids? That's what I did.",
#   'context/0': 'Because thou hast not supported. They supported me.'},
#  {'response': 'I just want to see your phone. Let me see your phone.',
#   'context': 'Why?',
#   'context/0': "Don't change the subject. Let me see your phone."},
#  {'response': "Yeah, I couldn't get her face in it. But she looks just like you.",
#   'context': 'Oh!',
#   'context/0': 'Ladies, meet Stripper Lily.'},
#  {'response': "Lily, this girl hates me. I hooked up with her in an apartment I was pretending was my own, told her I loved her, and then ditched her there. She got arrested for trespassing, bit a cop, and spent eight days in jail. Oh, crap, there she is! If she sees me, she's gonna kll me!",
#   'context': "Barney, you're doing this.",
#   'context/0': "Are you nuts? That would involve me speaking to a woman I've already had sx with, which, frankly, is a little t like changing the oil in a rental car."},
#  {'response': 'What?',
#   'context': 'Ah, here we go.',
#   'context/0': 'This wedding does sound pretty amazing though. Fancy hotel ballroom, everybody all dressed up.'},
#  {'response': "More than once... Wow, this is... I guess if we... so, technically, there were a number of times I've lied to a woman to sleep with her.",
#   'context': 'More than once?',
#   'context/0': "Have I ever... If I'm totally honest... Yes."},
#  {'response': 'Mini golf?',
#   'context': "beautiful, smart, funny, huge fan of prewar architecture, favorite poet Neruda, favorite movie Ghostbusters, and she didn't hate Cleveland.",
#   'context/0': 'That night I tried online dating.'},
#  {'response': 'They have a big problem.',
#   'context': 'There is nothing serious. And certainly nothing serious enough that you hold my hand.',
#   'context/0': 'She makes her dishes right away, Ted. I give them two or three weeks maximum.'},
#  {'response': "- Yeah. He's the awesome-est, most best looking-est, greatest guy ever.",
#   'context': '- You have a brother?',
#   'context/0': '- Hey!'},
#  {'response': "All right, Ted. Imagine the heads of two Irish babies. Let's call them...",
#   'context': 'Paint me a word picture.',
#   'context/0': 'Mmmm...'},
#  {'response': "Well, well, well. How rich. You make me promise to be on my best behavior around your girlfriend, yet, you have been lying to her since day one. Excuse me.Hi. Leg Warehouse? Yeah, my friend Ted needs something to stand on. So, nothing for him to stand on? Okay, and thanks so much. Ted, doesn't Victoria deserve to know that you once had the hots for Robin? I have half a mind to tell the story of the re-return.",
#   'context': "Okay, I want to lay down some ground rules for tonight. Barney, I actually like Victoria... a lot, so don't say anything embarrass... Don't say anything. And guys, I haven't exactly told Victoria that I used to have a kind of thing for Robin, so we you could just avoid the...",
#   'context/0': "I'm going to go get another round."},
#  {'response': 'Owl. How do we go? We will do what? Jump?',
#   'context': 'It looks to be a... sacred... spa.',
#   'context/0': 'The terrace of the building next door. A paradise waiting for us behind a pit of 2 or 3 meters. And the best...'},
#  {'response': "A bit strongly. She's not my girlfriend.",
#   'context': "That's putting it a bit strongly.",
#   'context/0': 'Wow, wow, wow, Girlfriend? Hey, come on.'},
#  {'response': "I'm gonna head out to a reggae concert. I'm a huge fan of reggae.",
#   'context': 'I do.',
#   'context/0': "Yeah, wait, don't tell me you go to yoga here too?"},
#  {'response': 'Basically, it is of Mad Men.',
#   'context': "It's great. Drinking at work.",
#   'context/0': 'And then you go up on the roof... and drink beer.'}]

# %%
lines_selected_list.append(['Barney, this is about the building.', 'Come on. This is so about the girl.', 'HIMYM'])
lines_selected_list.append(["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'])
lines_selected_list.append(["I think there's a pretty girl smiling at me there.", 'Hey, this is a chair, but go ahead and drag it.', 'HIMYM'])
lines_selected_list.append(['I love you, man.', 'Me too, buddy.', 'HIMYM'])
lines_selected_list.append(["Not even if she's hot?", "Not even if her mom's hot.", "HIMYM"])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM']]

# %% [markdown]
# ## Sheldon

# %%
temp = select_lines(characters[1])
# Out:
# Using custom data configuration default-54511809920e97ec
# Downloading and preparing dataset csv/default to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-54511809920e97ec\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-54511809920e97ec\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
[s for s in temp['test']]
# Out:
# [{'response': 'She called me dumbass.',
#   'context': 'Oh, sweetie, Im sorry.',
#   'context/0': 'Leslie Winkle, Penny. She belittles my research.'},
#  {'response': 'Well never know.',
#   'context': 'Oh. Wow. Good job. Okay, um, can you do this?',
#   'context/0': 'I am doing it.'},
#  {'response': 'Oh, you shouldnt have.',
#   'context': 'Thanks. And, Sheldon, I know tonights the night you eat Thai food, so I went to the Asian market, got all the ingredients and made it from scratch.',
#   'context/0': 'Ooh, it smells good.'},
#  {'response': 'Youre going up Euclid Avenue?',
#   'context': 'Too bad.',
#   'context/0': 'Of course not.'},
#  {'response': 'Get rid of the trade route part? Then how would Palpatine get Chancellor Valorum kicked out of office? How would he get himself elected? How? Can we get through one holiday without you saying something ridiculous?',
#   'context': 'Okay, so youd lose most of Jar Jar, all the trade route talk and the boring senate hearings, which are like watching C-SPAN with monsters.',
#   'context/0': 'You know, I heard of this way of watching the movies called the Machete Order, where you watch Episodes IV and V, then skip Episode I, watch II and III as a flashback, and then finish with VI.'},
#  {'response': 'Are you comfortable?',
#   'context': 'It was a classic western set in the post-Jurassic period, and it changed my life.',
#   'context/0': 'You shouldve seen us after The Good Dinosaur.'},
#  {'response': 'Offer them a hot beverage.',
#   'context': 'Sheldon, your friend is hurtin. What do we do when someones hurtin?',
#   'context/0': 'Oh, yes, born alone, die alone. Its a tragic human condition. Now, Raj, if youll excuse my mother, shes about to make a pecan pie thatll be so good Ill almost forget how she blew it with the fried chicken.'},
#  {'response': 'If I am permitted to speak again, Dr. Sheldon Cooper for the win.',
#   'context': 'Really? Oh, look at that, I have a girlfriend.',
#   'context/0': 'Stephanie Barnett is in a relationship with Leonard Hofstadter.'},
#  {'response': 'Hmm. What are you doing now?',
#   'context': 'Uh, making sure the telescopes camera is white-field balanced.',
#   'context/0': 'What are you doing?'},
#  {'response': 'Clarify something for me. Isnt the point of a communal meal the exchange of ideas and opinions? An opportunity to consider important issues of the day?',
#   'context': 'Fine.',
#   'context/0': 'I did shut up. Now you shut up.'},
#  {'response': 'Stop yelling! Im not happy about this.',
#   'context': 'Irasshaimase!',
#   'context/0': 'Although, I do regret not following up with that specialist in Houston.'},
#  {'response': 'Well, they cant cancel it. It ended on a cliffhanger.',
#   'context': 'There is no season three. They cancelled that show.',
#   'context/0': 'No, thats the season two finale. That was quite the cliffhanger. Im going to re-watch it before season three starts.'},
#  {'response': 'Just to be clear here, youre asking for my assistance.',
#   'context': 'Sheldon, wait! Will you?',
#   'context/0': 'Of course I could.'},
#  {'response': 'April 13, a dark night, indeed.',
#   'context': 'Well, the last time you made an unscheduled video-chat, there was a curly fry in your regular fries and you thought someone might be trying to slip you a mickey.',
#   'context/0': 'Yes. Why?'},
#  {'response': 'All right, now Im starting to sense a little tension.',
#   'context': 'Hello to you, you wrinkled old bastard.',
#   'context/0': 'Hello, my hateful shrew.'},
#  {'response': 'Fine. Bad.', 'context': 'No.', 'context/0': 'Bad. However'},
#  {'response': 'Thank you. I wouldnt even know how to begin.',
#   'context': 'Thats me, your emotional outhouse. You know, if you ever decide you want to do something about this, Im, Im here for you.',
#   'context/0': 'What good is having a girlfriend if you cant unload your psychological sewage on her?'},
#  {'response': 'Well, I know it was your idea, but the reporter said hes been following my work for a while, and the only reason they even mentioned it in the magazine is cause my name is on it.',
#   'context': 'You know, for an extra four bucks, I can have this thing here tomorrow.',
#   'context/0': 'Why did he think youre the lead scientist? It was my idea.'},
#  {'response': 'How is it sexist? My character wields a battle axe as well as any man.',
#   'context': 'Guys, our topic is encouraging women in science, can you at least play a less sexist game',
#   'context/0': 'No, youre a tool I was using to make my point.'},
#  {'response': 'I wouldnt say amazing. At best, its a modest leap forward from the basic technology that gave us Country Bear Jamboree.',
#   'context': 'Oh ha-ha, oh. Thats amazing.',
#   'context/0': 'Okay, here we go. Passing the soy sauce. Put out your hand.'},
#  {'response': 'I know what your point is. Youre intimidated by Amys intellect. To that I say, buck up.',
#   'context': 'Yeah, not my point.',
#   'context/0': 'Oh, I never identified with the rebel alliance. Despite their tendency to build Death Stars, Ive always been more of an empire man.'},
#  {'response': 'Okay. Do you think your fathers doing unspeakable things to my mother?',
#   'context': 'Go to sleep.',
#   'context/0': 'I hope youre right. Cause a grown man living with his brother and his brothers wife is weird.'},
#  {'response': 'I have no idea. Because the story of me sewing the first American flag is unsupported poppycock.',
#   'context': 'Say, Betsy Ross, what you working on?',
#   'context/0': 'Fwag, fwag, not a fwag, fwag, I am cwushing this.'},
#  {'response': 'Fair enough. What stake do you propose?',
#   'context': 'Okay, I believe a chicken made you his bitch. But the cricket thing, I dont buy. Bet me.',
#   'context/0': 'Thank God.'},
#  {'response': 'No, of course not.',
#   'context': 'And you want me to kill her? Done.',
#   'context/0': 'Priya has essentially nullified my roommate agreement with Leonard, making life in the apartment very uncomfortable for me.'},
#  {'response': 'Well, right now, Pennys imagination is running wild, but if they meet, that will eliminate the mystery and alleviate her fears. Like when that Sparkletts guy let me look under his eye patch.',
#   'context': 'What? Why?',
#   'context/0': 'Bring Penny to meet Mandy.'},
#  {'response': 'You know, a number of significant innovations have been inspired by science fiction. The, the geosynchronous satellite from Arthur C. Clarke. The Motorola flip phone, that came from Star Trek. And Ive long suspected that the idea of an African-American president was stolen from the movie Deep Impact.',
#   'context': 'You know, lets just come up with something new.',
#   'context/0': 'No, it vibrates. Keep going.'},
#  {'response': 'Because Im trying to decide between getting an Xbox One or a PS4. Oh, pee, whyd I say that?',
#   'context': 'Why not?',
#   'context/0': 'I cant.'},
#  {'response': 'Thats exactly what my father said. Come to the games, watch the games, week in and week out from the time I was five until I went off to college. Longest seven years of my life.',
#   'context': 'Come on, Sheldon, please teach me about football. Itll be fun.',
#   'context/0': 'If you want to blend in with Pennys friends, Id think looking like an idiot would be the perfect camouflage.'},
#  {'response': 'Leonard, are you in the shower?',
#   'context': 'Youre pregnant?',
#   'context/0': 'Yes, not important. Just stopped by to let you know Im getting orthotics. Also, Im carrying Sheldons baby. Mums the word.'},
#  {'response': 'Or the first door closing causes a change of air pressure that acts upon the second door.',
#   'context': 'No, no, I meant',
#   'context/0': 'No it doesnt. Not unless the two doors are connected by relays, or there are motion sensors involved.'},
#  {'response': 'Oh! I dont usually pick up on those things. Good for me.',
#   'context': 'Yes Im upset.',
#   'context/0': 'Well, it was a number of things. First the late hour, then your demeanour seems very low energy, plus your irritability'},
#  {'response': 'Not Sunday, I love Sunday.',
#   'context': 'Sundays gone.',
#   'context/0': 'Oh, Sundays the worst. Everybodys leaving, most of the good panels are over, and the only T-shirts they have left are small and XXXXL.'},
#  {'response': 'Oh, God, now even youre smarter than me.',
#   'context': 'Antonio Salieri?',
#   'context/0': 'Fifteen years old. Dennis Kim is fifteen years old, and hes already correcting my work. Today I went from being Wolfgang Amadeus Mozart to you know, that other guy.'},
#  {'response': 'Hardly. Fear of heights is illogical. Fear of falling, on the other hand, is prudent and evolutionary. What would you say is the minimum altitude I need to achieve to cement our new-found friendship?',
#   'context': 'You afwaid of heights, Cooper?',
#   'context/0': 'This appears significantly more monolithic than it did on my laptop. No, one expects to see Hominids learning to use bones as weapeons.'},
#  {'response': 'Whos in the mood to laugh?',
#   'context': 'No, forget it. I take it back. Offers off the table.',
#   'context/0': 'That is not what I said.'},
#  {'response': 'Frankly, Mom, Im encouraged to see how advanced your group has become, willing to sail out into the ocean without fear of falling off the edge.',
#   'context': 'Oh, it is a hoot and a half. You write your sins on a clay pigeon, they fire em up in the air, and you pulverize them with a 12-gauge shotgun full of our Lords forgiveness.',
#   'context/0': 'Whats Gunning with God? Im afraid to ask.'},
#  {'response': 'You know, I dont want to tell you how to do your job, but when a mouse completes a maze, it gets a food pellet.',
#   'context': '33 seconds. Okay, thatll be our baseline.',
#   'context/0': 'Done.'},
#  {'response': 'Okay. Ill give it a shot.',
#   'context': 'I said, get out.',
#   'context/0': 'Well, I have to tell you that while I do have a theoretical understanding of the workings of an internal combustion engine, Im not sure Im capable of performing diagnostics.'},
#  {'response': 'Oh, no, I got bored with that. Im just browsing cuticle scissors on Amazon.',
#   'context': 'Its actually steamier than it looks. Sheldons looking up the phallic symbolism of root vegetables in Renaissance paintings.',
#   'context/0': 'Awkward silence, Sheldon on his phone, no touching. Somebodys having date night.'},
#  {'response': 'Whos he?',
#   'context': 'Okay. How bout a little Miley Cyrus next?',
#   'context/0': 'Then Ill look from the door of my heavenly home, and pity the miner that mines my poor bones.'},
#  {'response': 'He also has a remarkable amount of credit card debt.',
#   'context': 'Wait, wait, not shopping for clothes, right? Because look.',
#   'context/0': 'Well, his rent and car lease are exceedingly high. You couple that with his penchant for dining out and shopping.'},
#  {'response': 'I wasnt referring to this evening. Ten years ago, upon first seeing me, your husband claimed that I looked like C-3PO and Pee-wee Herman. And he called me C-3P-wee Herman.',
#   'context': 'I didnt do anything. I was just sitting here.',
#   'context/0': 'Well, with that sorted out, Im happy to answer your question, Bernadette. Howard started it.'},
#  {'response': 'Well, wait. What if, just this once, we suspend the date night parameters and you stay later?',
#   'context': 'Come on, Ill help you take this down.',
#   'context/0': 'Well, of course we do. Fort Knox doesnt have a secret physics lending library.'},
#  {'response': 'Danger, danger.',
#   'context': 'That girl needs to get a life.',
#   'context/0': 'Right, gimme, gimme, gimme, I want to kill the guard captain. .'},
#  {'response': 'The fun starts with brunch at Carneys in Studio City, a hot dog stand in a converted railroad dining car. Next stop, Travel Town, an outdoor museum featuring 43 railroad engines, cars and other rolling stock from the 1880s to the 1930s. Finally, were off to the glitz and glamour of Hollywood for dinner at, thats right, the Hollywood Carneys, a hot dog stand in a different converted railroad dining car.',
#   'context': 'Train day?',
#   'context/0': 'I always tell people, if you have only one day in Los Angeles, make it a train day.'},
#  {'response': 'Youre just misappropriating my understanding.',
#   'context': 'Well, I understand, too.',
#   'context/0': 'No, he doesnt understand. I understand.'},
#  {'response': 'Leonard will be here in a moment. Hes looking for a different parking space.',
#   'context': 'Needy Baby, Greedy Baby indeed.',
#   'context/0': 'Fine.'},
#  {'response': 'Oh, no, the new ones, theyre here.',
#   'context': 'I guess I wont be needing this.',
#   'context/0': 'Hey, Penny, its Leonard. Good news, you can take your head out of the oven.'},
#  {'response': 'You know, exactly. Weve never thrown a brunch before, and I wanted to work out all the kinks.',
#   'context': 'Uh, no. He, he just means that you were the first people we thought of.',
#   'context/0': 'Practice round? For-for what?'},
#  {'response': 'Cathedra mea, regulae meae. Thats Latin for my chair, my rules. Now, you said on the phone that your area of study is physics.',
#   'context': 'Can you do that?',
#   'context/0': 'This seat is ideally located both in relation to the heat source in the winter and a cross breeze in the summer. It also faces the television at a direct angle allowing me to immerse myself in entertainment or game play without being subjected to conversation. As a result, Ive placed it in a state of eternal dibs.'},
#  {'response': 'Oh, no, he broke my collarbone. I can still hear it click.',
#   'context': 'Did it work?',
#   'context/0': 'Oh, certainly. Uh, when I was eight years old, Billy Sparks cornered me in the playground. I asked myself what would Spock do? Then I grabbed Billy on his shoulder and performed my first Vulcan nerve pinch.'},
#  {'response': 'He cant kill me, even if I turn.',
#   'context': 'Yeah. We also put in what happens if one of us wins a MacArthur Grant, or if one of us gets superpowers, or if one of us is bitten by a zombie.',
#   'context/0': 'You actually put that in an agreement?'},
#  {'response': 'Thats just wrong.',
#   'context': 'Penny.',
#   'context/0': 'Please try to wear something appropriate. It wont help my case if the judge is busy trying to read the word Juicy scrawled across your buttocks.'},
#  {'response': 'Howards allergic to peanuts. How can I use that against him?',
#   'context': 'Yeah.',
#   'context/0': 'Leonard?'},
#  {'response': 'Why would she keep something from me, you know? I shared my body with that woman. And my Netflix password. They recommended Stella Got Her Groove Back because of her.',
#   'context': 'You heard him, guys, dont ask.',
#   'context/0': 'Well, whatever it is, its troubling me. And I cant eat, I cant sleep. And dont even ask about the consistency of my bowel movements.'},
#  {'response': 'So trick her.',
#   'context': 'Instead of dwelling on the negative, think about this. Your girlfriend was given an amazing opportunity, which gives you an opportunity to show her that youre a loving and supportive boyfriend.',
#   'context/0': 'No, but that list was sounding a little thin.'},
#  {'response': 'Even the girls.',
#   'context': 'All of them?',
#   'context/0': 'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.'},
#  {'response': 'That would be acceptable. On Mondays, I eat Thai food. Mee krob and chicken sate with extra peanut sauce from Siam Palace.',
#   'context': 'What if I brought food to your place?',
#   'context/0': 'Three tines is not a fork, three tines is a trident. Forks are for eating, tridents are for ruling the seven seas.'},
#  {'response': 'Hello, Amy. Its nice to see you.',
#   'context': 'Okay. I dont get it, you said make an effort, here I am making an effort.',
#   'context/0': 'Okay. Leonard, I really appreciate that, but I need a little time to myself.'},
#  {'response': 'I think the same thing that appeals to people everywhere, the dream of a cold, rational world entirely without human emotion. Spock came from a planet governed only by logic. You know, on Vulcan, when your brother asks, why are you hitting yourself? the answer is, Im not. Youre moving my arm. To which he says, Fascinating. And then you both watch educational television.',
#   'context': 'What was it about Spock that appealed to you?',
#   'context/0': 'The first episode of Star Trek: The Original Series I ever saw was The Galileo Seven. Uh, Spock had just landed on the planet Taurus II. Then my brother came in, sat on my head, and said eat farts. After that day, I was hooked. On Star Trek, not my brothers sphincter-based cuisine.'},
#  {'response': 'Like what?',
#   'context': 'Cancel my next appointment. This is gonna take a while. Dr. Cooper, you said things to your employee that you just cannot say in the workplace.',
#   'context/0': 'So Ive been told. But I cant understand what she has to complain about. I mean, she has a front-row seat as I make scientific history. Theres string cheese in my mini-fridge, and thats for anyone. Yeah, and just yesterday I led her away from a life of sexual promiscuity by making her look at pictures of disease-ridden genitalia.'},
#  {'response': 'Oh yes, like the male peacock with brilliant plumage or the rutting baboon with engorged hindquarters.',
#   'context': 'Noticed the eye patch, did you? Its all part of a technique Ive been studying for picking up women. You employ a visual display designed to make yourself distinctive and memorable.',
#   'context/0': 'Ahoy, matey.'},
#  {'response': 'Youre overestimating the tensile strength of the substructure youre building.',
#   'context': 'Hang on, I think Ive got this. Help me see if we can wedge this little piece of PVC behind the support rod.',
#   'context/0': 'If you really want to clean up your karma, go get my freakin latte.'},
#  {'response': 'And then Leonard took me to the barber and the dentist, and then to cap off the perfect day, the Los Angeles Bureau of Weights and Measures.',
#   'context': 'Uh, it wasnt anything weird. It was just to see how big they were.',
#   'context/0': 'Thank you.'},
#  {'response': 'Fine. Leonard made me soup, and I was mean to him. Hey, I felt a little something. Let me try again. Leonard made me soup, and I was mean to him. I was mean to him. He must have felt terrible. Oh, now I feel terrible. Neat.',
#   'context': 'Great. Now try it as if this isnt your first day as a person.',
#   'context/0': 'I have empathy. Watch. Leonard made me soup, and I was mean to him.'},
#  {'response': 'Try and stop me.',
#   'context': 'Sheldon, you cant go back there.',
#   'context/0': 'A little tremor that turns routine sinus surgery into a frontal lobotomy. Oh, I dont care for this at all. Oh, I need to see hes okay.'},
#  {'response': 'Hes a snowy tree cricket, and his name is Jiminy.',
#   'context': 'All right. Tell you what, lets go down to the Entomology Department and let Professor',
#   'context/0': 'We havent established that Im wrong once.'},
#  {'response': 'Its Oatmeal Day.',
#   'context': 'All right, want some French toast?',
#   'context/0': 'The math would suggest that in a few Im a clown made of candy. But I dont dance.'},
#  {'response': 'All I know is you can only fit one of her in a car. And theres the clown that came out of her. I really didnt want to come here, but this is shaping up to be one of the best Thanksgivings Ive had in a long time.',
#   'context': 'I dont know whats scarier, the bathroom clowns or the woman that put them there.',
#   'context/0': 'Did somebody say pie?'},
#  {'response': 'All right, Ill bow to social pressure. Hey!',
#   'context': 'Hey.',
#   'context/0': 'Hey.'},
#  {'response': 'Hello.', 'context': 'Hey.', 'context/0': 'Amy.'},
#  {'response': 'Just the hits.  Where its dark as a dungeon, and its damp as the dew.',
#   'context': 'Do you know any mining songs?',
#   'context/0': 'Miners often sang mining songs to keep their spirits up.'},
#  {'response': 'You are ignoring the square-cube law. The giant ant would be crushed under the weight of its own exoskeleton. And for the record, the appropriate ranking of cool modes of transportation is jet pack, hoverboard, transporter, Batmobile, and then giant ant.',
#   'context': 'Sheldon says impossible. Howard and I say not only possible, but as a mode of transportation, way cooler than a Batmobile.',
#   'context/0': 'Hey, Leonard, where do you come down on giant ants?'},
#  {'response': 'Oh. Remember when we got this at Comic-Con?',
#   'context': 'Yeah, let him do it.',
#   'context/0': 'Howard just did that.'},
#  {'response': 'Did you get the part?',
#   'context': 'Oh, yeah, yeah. Its real great. Today I drove to Van Nuys for an audition I thought was going to be for a cat food commercial. Turned out to be porn.',
#   'context/0': 'So, Penny, Leonard tells me youre an actress. That must be pretty exciting.'},
#  {'response': 'Need you ask? But I still dont understand why no-one else bid.',
#   'context': 'A time share time machine? Im in. Sheldon?',
#   'context/0': 'Why dont we share it? Well each put in two hundred bucks and well take turns having it in our homes.'},
#  {'response': 'These are my own bowling shoes.',
#   'context': 'I thought you were bringing your own bowling shoes.',
#   'context/0': 'Please reserve that butch spirit for the lanes.'},
#  {'response': 'Dont stop. Yes, keep going. Just like that.',
#   'context': 'And the home of the brave.',
#   'context/0': 'There he is.'},
#  {'response': 'Leonard takes Los Robles Avenue.',
#   'context': 'Mm-hmm.',
#   'context/0': 'Youre going up Euclid Avenue?'},
#  {'response': 'Amy, its Pennys turn. Penny?',
#   'context': 'Are you in the lanthanoid series?',
#   'context/0': 'No.'},
#  {'response': 'A tad asymmetrical, but nothing to be concerned about.',
#   'context': 'So, what do you think?',
#   'context/0': 'More.'},
#  {'response': 'Leonard, social protocol states when a friend is upset, you offer them a hot beverage, such as tea.',
#   'context': 'No.',
#   'context/0': 'Did you offer him a hot beverage?'},
#  {'response': 'Doesnt like games. Thats one.',
#   'context': 'Can we not play this game?',
#   'context/0': 'Thats not a problem, we can figure this out. What are the reasons women reject Raj?'},
#  {'response': 'What are you doing? Two fifty is already the discounted price.',
#   'context': 'Slow down. Two hundred.',
#   'context/0': 'Oh, did you hear that? Were getting the friends and family discount. We are honoured and we will take it.'},
#  {'response': 'All right. Look, now, this may be the rum talking, but as long as the unpinning rate of the vortices is kept within 1.1 and 1.3, the Magnus force issue should be negligible.',
#   'context': 'Can you focus on what were talking about?',
#   'context/0': 'This video. The baby panda sneezes, and the mama panda gets so scared.'},
#  {'response': 'And now you know as much about him as I do.',
#   'context': 'Oh, oh, I have a receipt from a blood bank. Im O-negative.',
#   'context/0': 'Thats true, but had I done something under the line, there wouldnt be a man in your kitchen who cant produce a single form of ID.'},
#  {'response': 'Really? Cause every time I come in here, I think less of me.',
#   'context': 'I dont.',
#   'context/0': 'It ends with dinosaurs. Im sorry if you think less of me.'},
#  {'response': 'All right, theres no need to bark at me. According to the inexplicably irritable nurse behind the desk, youll be seen after the man who claims to be having a heart attack, but appears to be well enough to play Doodle Jump on his iPhone. We have to fill these out. Describe illness or injury.',
#   'context': 'Okay.',
#   'context/0': 'Me too. Check and see if we have any more pudding.'},
#  {'response': 'Hi.', 'context': 'Hi.', 'context/0': 'Hi.'},
#  {'response': 'How did we get in the car?',
#   'context': 'Well, we were on our way to my mothers house',
#   'context/0': 'And before our next drive to Comic-Con, I need the name of that juice.'},
#  {'response': 'Would you like some aloe vera? You just got burned. All right, my turn. Howard, Bernadette. Daq tu taH Daq yIn tlhej ghajtaH.',
#   'context': 'Thank you, Amy. Very touching. Howard and Bernadette, you are lucky enough to be best friends who love each other. And thats the strongest kind of love because at its core, it has kindness, patience, and respect. Qualities that are hard to find in people these days.',
#   'context/0': 'Well, Im ending it. Bernadette, I want to thank you for allowing me to be your maid of honour. I also want you to know, that I will be happy to do it again if this marriage craps out.'},
#  {'response': 'Howard Hughes saved his urine in milk bottles.',
#   'context': 'Ill love you no matter what.',
#   'context/0': 'Its hard to say. Ive never really lived by myself. What if I become strange and eccentric?'},
#  {'response': 'To comfort you, of course. No, thats not going to work at all, Ill comfort you from over here. Leonard, what youre experiencing is a classic Jungian crisis in which the aging individual mourns the loss of the never-to-be realized ideal family unit.',
#   'context': 'I want that too. Why are you here?',
#   'context/0': 'What I want is to be departing the Starship Enterprise in a one-man shuttle craft headed to the planetoid I rule known as Sheldon Alpha Five.'},
#  {'response': 'Simple extrapolation. In the three years that Ive known you, you were single for two. During that time, I saw 17 different suitors. If we work backwards, correcting for observation bias and postulate an initial dating age of 15',
#   'context': 'What? Where did you get 171 men?',
#   'context/0': 'Your characterization of approximately 171 different men as a few.'},
#  {'response': 'They lose their sensitivity to serotonin and norepinephrine.',
#   'context': 'Okay, Sheldon. What happens to our neuroreceptors when we dont get enough REM sleep?',
#   'context/0': 'No, thats a crazy thing.'},
#  {'response': 'I like it. Yeah, well take the A-M from Amy and, uh, the Y from Emily.',
#   'context': 'So, uh, what were you thinking? Combine their names?',
#   'context/0': 'Its perfect. It appears romantic, but its really just a rock in space that gets me out of Valentines Day forever.'},
#  {'response': 'Well, what if I spill tomato soup on my shirt and have to come home to change, only to find theres no water for an enzyme soak.',
#   'context': 'No, no, it doesnt matter, well be at work.',
#   'context/0': 'Thats unacceptable. Were supposed to be given written notice.'},
#  {'response': 'I assure you I am quite real and Im having regular intercourse with your daughter.',
#   'context': 'Its nice to meet you, too, Sheldon. I honestly didnt believe Amy when she told me she had a boyfriend.',
#   'context/0': 'I look forward to it.'},
#  {'response': 'Well, then its settled.',
#   'context': 'Blue and yellow make green.',
#   'context/0': 'Thats not true. Any colours fine with me. Yeah, I could be a-a combination of blue and yellow.'},
#  {'response': 'Oh, uh, Stuart, Bert from the geology lab, and Mrs. Petrescu from downstairs.',
#   'context': 'Well, thats so nice. Whos coming?',
#   'context/0': 'You expressed an interest in having people over, and I feel I dismissed it too quickly. So, I took matters into my own hands, and I arranged a brunch.'},
#  {'response': 'Ive invented a science joke, would you like to hear it?',
#   'context': 'So, tell me, Cooper, are the ways of physical love different in the future?',
#   'context/0': 'As he stood for Amelia to dry him'},
#  {'response': 'I wont. This feels right. My mother always said, to thine own self be true.',
#   'context': 'Then dont do it.',
#   'context/0': 'Oh, but if I do, Ill be a phony, a sellout, a Hollywood poser.'},
#  {'response': 'Im fine.',
#   'context': 'Yeah, um, of all the things about this that are sad, that might not be number one. You okay? I know he meant a lot to you.',
#   'context/0': 'But, thats Star Wars Day.'},
#  {'response': 'Thats not fair. I got stuck behind a tree.',
#   'context': 'Ha! Eat my dust, racially stereotypical plumber.',
#   'context/0': 'Bazinga. I dont care.'},
#  {'response': 'Oh, right. This is a disaster.',
#   'context': 'Actually, your name is on the electric bill.',
#   'context/0': 'Good, good. And your name is on the electric bill and mine isnt. And Im okay with that.'},
#  {'response': 'Really? Why?',
#   'context': 'Okay, thats it, youre fired.',
#   'context/0': 'All right, lets get right to the vote. Show of hands all those opposed to Leonard and his reign of tyranny.'},
#  {'response': 'Because it was immaculate, I mean, you open that mans closet, it was left to right, evening gowns, cocktail dresses, then his police uniforms.',
#   'context': 'When the transvestite lived here, you didnt care how he kept the place.',
#   'context/0': 'This is not anyones home, this is a swirling vortex of entropy.'},
#  {'response': 'Ow! You hit me! Im bleeding!',
#   'context': 'How am I looking now?',
#   'context/0': 'If you had gone out with me three years ago, by now, youd have my great Aunt Idas brooch that she smuggled out of occupied Belgium in a cat.'},
#  {'response': 'Oh my! Thats awfully sticky. Alright, lets see. Bernie Bunny has Two Daddies Now. Its probably about homosexual rabbits. Jerry the Gerbil and the Bullies on the Bus. Read it, not helpful. Oh! Here we go. Stu the Cockatoo is New at the Zoo. Author Sarah Carpenter lives in Fort Wayne, Indiana, with her husband and best friend Mark, and their cockatoos too. Hardly makes her an expert in making friends, wouldnt you agree?',
#   'context': 'I bet you do.',
#   'context/0': 'Oh! I love trains!'},
#  {'response': 'Well, excuse me. That was not a betrayal, that was an experiment to determine at what concentration food starts tasting mothy.',
#   'context': 'And as long as were talking about betraying our friends, how about the month Sheldon spent grinding up insects and mixing them into Leonards food.',
#   'context/0': 'That was all a lie? This years gifts are already wrapped!'},
#  {'response': 'Well, why should I leave, this is my apartment too.',
#   'context': 'Yes.',
#   'context/0': 'You mean just go someplace else and be someplace else?'},
#  {'response': 'Well, dont feel bad. I think weve all been distracted since the girls entered our lives.',
#   'context': 'I think someone owes me an apology.',
#   'context/0': 'And a few weeks ago, he almost did a pull-up.'},
#  {'response': 'Theres a draft on my neck over here.',
#   'context': 'Why?',
#   'context/0': 'And I said yes. And I settle all ties. Change seats with me.'},
#  {'response': 'Armin who?',
#   'context': 'And if you dont start treating me better, Im leaving you for a miniature horse breeder named Armin.',
#   'context/0': 'Ooh, burn!'},
#  {'response': 'Oh, goody, were getting a cat.',
#   'context': 'No, but youre right. I should march over there and ask her out.',
#   'context/0': 'No. No, now that was not my point. My point was, dont buy a cat.'},
#  {'response': 'Thank you, Jesus! As my mother would say.',
#   'context': 'The ball! The ball! The ball! The ball! The ball! The ball!',
#   'context/0': 'Excuse me. I dont know who youre chanting for as I am currently the ball.'},
#  {'response': 'How? You had the whole floor to yourself.',
#   'context': 'Well, I didnt, and its your fault.',
#   'context/0': 'Really? I slept great.'},
#  {'response': 'No. Hmmm. What happens if you use argon lasers instead of helium neon?',
#   'context': 'Yes.',
#   'context/0': 'Oh, sure you do. Now, see, whats this here in the schematic, is that a laser array?'},
#  {'response': 'Undoubtedly yet another snide response to my repeated letters complaining that the flags in front of the courthouse are flying in the wrong order. From left to right, its supposed to be federal, state, and then city of Pasadena.',
#   'context': 'Youve also got something from the Pasadena Municipal Court.',
#   'context/0': 'I dont trust banks. I believe that when the robots rise up, ATMs will lead the charge.'},
#  {'response': 'What qualifies you to attempt to understand my mind?',
#   'context': 'I thought I could try to analyze you and get to the root of your anxiety.',
#   'context/0': 'Thats not exactly a mutation that would get you into Xaviers School for Gifted Youngsters, but go on. Leonard?'},
#  {'response': 'Creepy old dude from Dancing with the Stars.',
#   'context': 'Or as I know him?',
#   'context/0': 'Oh, easy, Bill Nye the Science Guy.'},
#  {'response': 'Mohammed Lee.',
#   'context': 'It gets better. Someone has to go up with the telescope as a payload specialist, and guess who that someone is.',
#   'context/0': 'Howie, thats wonderful! Congratulations!'},
#  {'response': 'Well, I have and it will knock your socks off! Good luck getting them back on.',
#   'context': 'No.',
#   'context/0': 'Excuse me, Stuart. Have you read the new Flash?'},
#  {'response': 'The water level rose.',
#   'context': 'Oh, yeah. Right. Anyway, she takes off all of her clothes, climbs into the hot tub, and the first thing I notice',
#   'context/0': 'Can you please get back to the drunk girl? Id like something to think about in the shower.'},
#  {'response': 'Yes. I read recently about a fellow in Kansas with an enormous ball of twine. I bet you could give him a run for his money.',
#   'context': 'A hobby?',
#   'context/0': 'Priya has moved back to India to pursue her law career. Instead of desperately trying to keep this intercontinental relationship alive, you could use that time to take up a hobby.'},
#  {'response': 'About what?',
#   'context': 'Okay, we need to talk.',
#   'context/0': 'I was going to name him Herman von Helmholtz, but hes so zazzy.'},
#  {'response': 'Do you know, its amazing how many supervillains have advanced degrees. Graduate school should probably do a better job of screening those people out.',
#   'context': 'Okay, I get it, I get it, I get it.',
#   'context/0': 'Yes, the Doctor Doom to my Mr Fantastic. The Doctor Octopus to my Spiderman. The Doctor Sivana to my Captain Marvel.'},
#  {'response': 'I knew it! What do I do?',
#   'context': 'You were right. Your larynx is terribly inflamed. I mean, Ive never seen anything like it.',
#   'context/0': 'Wha??'},
#  {'response': 'Well, thats certainly amusing, but I have no interest.',
#   'context': 'Okay, well, how about this? From the university Web site, 7pm to 10pm, Norton Hall Multipurpose Room, mixer for grad students and faculty of the science and humanities departments. Whether you split atoms or infinitives, this is the place to be.',
#   'context/0': 'Thats a semantically null sentence.'},
#  {'response': 'Hello.',
#   'context': 'Hey, Sheldon.',
#   'context/0': 'Amen to that.'},
#  {'response': 'Hello.',
#   'context': 'Oh, hey, guys.',
#   'context/0': 'Rock-paper-scissors-lizard-Spock. Oh!'},
#  {'response': 'Im mapping basic topics of conversation and with whom they can be discussed. I call these circles zones of privacy. Dont Google that unless you want to see pictures of peoples genitals. This circle contains only me and you. It represents subjects we only share with each other, details of physical intimacy, bathroom habits. Although, as Im saying it, I may need to add Dr. Fink in here.',
#   'context': 'What is this?',
#   'context/0': 'Not exactly the welcome wagon, but Ill take it.'},
#  {'response': 'All right.',
#   'context': 'Sheldon, Im not going to learn Morse code at three oclock in the morning!',
#   'context/0': 'Its very simple. This is A  this is C'},
#  {'response': 'Leonard, whos really in charge? The person in charge, or those who put him in charge?',
#   'context': 'Sheldon, youre not in charge. Raj is in charge.',
#   'context/0': 'I sure did. Oh, my goodness. Well, from Jabbas head to ice cream with Darth Vader, Im having a heck of a ride. Yeah, look, clearly, good things happen when Im in charge. Now, why dont you boys step aside, let me knock this project out?'},
#  {'response': 'I have a lady friend who will be staying with me for a few days.',
#   'context': 'Sheldon, what are you doing with maxi pads?',
#   'context/0': 'The stock boy at Walgreens was frustratingly uninformed on the subject.'},
#  {'response': 'Please, thats a seagull. If youre not going to help, dont help.',
#   'context': 'I dont know. Scree-scree.',
#   'context/0': 'Quick, what does a hawk sound like?'},
#  {'response': 'Well take some Funyuns.',
#   'context': 'What if we brought them down with us?',
#   'context/0': 'Youre not going to have Funyuns when were a mile below the surface of the Earth.'},
#  {'response': 'I know. Its replaced Godzilla as my principle source of anxiety.',
#   'context': 'Sheldon. Sheldon, Im worried about you. Youre not eating, you havent slept in days, and, to be honest, that cap is starting to smell.',
#   'context/0': 'Oh, you said it.'},
#  {'response': 'If I did, would I find any?',
#   'context': 'Oh, now dont you go looking through my suitcase for presents.',
#   'context/0': 'Oh, well, you two sit down and get to know each other. Ill get your room ready.'},
#  {'response': 'No, we dont. The one we have works great.',
#   'context': 'Shelly, youre not eight years old any more. We have to have a different relationship.',
#   'context/0': 'Yours.'},
#  {'response': 'Then Ill settle for an aneurysm.',
#   'context': 'You cannot blow up my head with your mind.',
#   'context/0': 'Okay, that is it.'},
#  {'response': 'Are you sure? Every time my dad stayed out all night, my mom would put hamster poop in his chewing tobacco.',
#   'context': 'Sheldon, were in a relationship. When you get angry, just tell me. You dont need to seek revenge.',
#   'context/0': 'Thats silly. Almost as silly as Dr. Baker having a telephone, since telephones only existed in large cities at that time. This is more like Little House on the Preposterous.'},
#  {'response': 'Thats a somewhat ambiguous response. Am I going or not?',
#   'context': 'I dont need to see your presentation. This discussion is over!',
#   'context/0': 'Howard, could you lower the lights? I have a short PowerPoint presentation.'},
#  {'response': 'Isnt that their burden? Im the one with something interesting to say.',
#   'context': 'All right. Have you considered improving your socialization skills, thus allowing you to communicate more effectively with other people?',
#   'context/0': 'Hmm, no. One slip of the hand, and suddenly Im sitting in the Engineering Department, building doodads with Wolowitz.'},
#  {'response': 'I thought I just did.',
#   'context': 'Just say thank you.',
#   'context/0': 'Stale pastry is hollow succour to a man who is bereft of ostrich.'},
#  {'response': 'Leonard, explain it to her.',
#   'context': 'Okay, Im sorry, I dont understand.',
#   'context/0': 'No, Im not all right. Its been six days since I was supposed to get a haircut and nothing horrible has happened.'},
#  {'response': 'Im going to answer that with a visual aid. This is my nine-disc complete Lord of the Rings trilogy blu-ray set. Mr. Wolowitz borrowed it, damaged plastic retention hub number three, and then returned it to me, hoping I wouldnt notice. Would you characterize that as responsible?',
#   'context': 'Thank you. Would you characterize him as responsible?',
#   'context/0': 'A little, but go on.'},
#  {'response': 'Oh, yes, but theres usually planning, courtship and advance notice. Last time I was able to book a cruise to the Arctic to see a solar eclipse.',
#   'context': 'Oh, come on, you know, Leonards had girls over before, right?',
#   'context/0': 'This is very awkward.'},
#  {'response': 'Very well.',
#   'context': 'Your parents are old. Anything unspeakable was finished by 9:30. Go to sleep.',
#   'context/0': 'Are you saying that because the things are unspeakable?'},
#  {'response': 'We havent established that Im wrong once.',
#   'context': 'Yeah, fine, whatever. The point is, youre wrong again.',
#   'context/0': 'Forgive me. Yiddish was not spoken in east Texas. And if it was, it wasnt spoken for long.'},
#  {'response': 'Not at all. In fact, I have got something for just such an occasion. I was starting to think I might never get a chance to give it to you. Good job.',
#   'context': 'You do? Youre not messing with me?',
#   'context/0': 'I like it. I think youre on to something.'},
#  {'response': 'Meemaw, look, Im sorry, but I have to defend my girlfriend to you.',
#   'context': 'Go ahead.',
#   'context/0': 'Hello.'},
#  {'response': 'Do you speak Klingon?',
#   'context': 'No.',
#   'context/0': 'Do you have a working knowledge of quantum physics?'},
#  {'response': 'Yes, baseball.',
#   'context': 'A sports metaphor?',
#   'context/0': 'You have two strikes. Three strikes and youre out. Its a sports metaphor.'},
#  {'response': 'You talk about if werewolves can swim? See, Leonard says yes, but I say it depends on if the human could swim before he was bitten. What do you think?',
#   'context': 'Sheldon, we are just people. We talk about the same things you guys talk about.',
#   'context/0': 'And how difficult it is to do when shes bloated, cranky and crampy? Continue.'},
#  {'response': 'Im sorry. But in what universe is Wonder Woman blonde?',
#   'context': 'All right. Lets get this thing over with.',
#   'context/0': 'Look up in the sky. Its a bird. Its a plane. I forget the rest.'},
#  {'response': 'Now, Ive learned some fun facts about New Jersey to help you make small talk. Would you like to know the state bird or the murder rate? Theyre both shocking.',
#   'context': 'Pretty well. Princeton has a beautiful campus.',
#   'context/0': 'How are you settling in?'},
#  {'response': 'Wouldnt have been any ass-kickings if that stupid death ray had worked.',
#   'context': 'Because people dont like it. Remember all the ass-kickings you got from the neighbour kids? Now lets get cracking. Shower, shirt, shoes, and lets shove off.',
#   'context/0': 'Why not?'},
#  {'response': 'Oh, I hardly think so.',
#   'context': 'No, youre coming with me.',
#   'context/0': 'Good luck.'},
#  {'response': 'Quvatlh', 'context': 'ghobe', 'context/0': 'Dayaja'},
#  {'response': 'Lets see what Ill be washing that succotash down with. A pitcher of margaritas.',
#   'context': 'Uh, no, thats not it. Just come with me, please.',
#   'context/0': 'Uh, I dont want to show any more of your friends how I can fit in the booster seats.'},
#  {'response': 'Well, then, I guess its plausible. Hang on a second, mister.',
#   'context': 'Uh, uh, uh, yes, I did.',
#   'context/0': 'Seems unlikely. Did you bring your asthma inhaler?'},
#  {'response': 'Fine. Amy, will you be my girlfriend?',
#   'context': 'Hi, Stuart.',
#   'context/0': 'Youre being impossible.'},
#  {'response': 'Ah, very good. Because a gorilla go-go dancer of any sexual preference would be out of place in a film about the Holocaust.',
#   'context': 'I dont know. The bisexual gorilla go-go dancer in Schindlers List is tough to beat.',
#   'context/0': 'Thanks. Theres no reason why I shouldnt be the best bisexual go-go dancer slowly transforming into a killer gorilla anyones ever seen.'},
#  {'response': 'Boy, Im not nearly as mysterious as I think I am.',
#   'context': 'Uh, youre sad about not getting anything done last night, so youre gonna sit around and pout about it?',
#   'context/0': 'Im not going. Would you like to know why?'},
#  {'response': 'Did he finally write a sequel to his autobiography? Im sure ages 79 through 87 were just action-packed.',
#   'context': 'Well, you might want to mark your Google calendars. Stan Lee is coming to do a signing on Thursday.',
#   'context/0': 'Hey, Stuart, whats going on?'},
#  {'response': 'Gentlemen.',
#   'context': 'Tell you what, well skype.',
#   'context/0': 'Halfway is 600 miles off the coast of Japan.'},
#  {'response': 'Ah, touch.',
#   'context': 'What about a game of tag on a French schoolyard?',
#   'context/0': 'And as an added bonus, the word touch comes from fencing. It would be our only opportunity to use it in a non-metaphorical sense.'},
#  {'response': 'Actually, I was wondering if I could add a third new chess piece. How do you think people would feel about Prince Joey, the kings feeble-minded but well-meaning cousin?',
#   'context': 'I, uh, I guess youre probably wondering whats got me down.',
#   'context/0': 'Its not optional. Were out of tea. I hope you like bouillon.'},
#  {'response': 'I have a functioning and satisfying relationship with a female. You have none.',
#   'context': 'Jealousy? What do I have to be jealous of?',
#   'context/0': 'May I suggest that your criticism is based on jealousy.'},
#  {'response': 'You say youre Special Agent Page, FBI.',
#   'context': 'Im Special Agent Page, FBI.',
#   'context/0': 'Yes.'},
#  {'response': 'I want a different question.',
#   'context': 'Then what is it?',
#   'context/0': 'Well its not what he said.'},
#  {'response': 'Since its not bee season, you can have my epinephrine.',
#   'context': 'Uh, Im not sure, everyone keep an eye on Howard in case he starts to swell up.',
#   'context/0': 'But does it have peanut oil?'},
#  {'response': 'Oh, Indians making Tex-Mex. Might as well have had the Chinese pizza.',
#   'context': 'Oh, sounds great.',
#   'context/0': 'Hey, youre just in time. We made Tex-Mex.'},
#  {'response': 'Oh, did I forget to tell you? That store went out of business years ago.',
#   'context': 'You got it. If this sweater shuts you up, Im gonna make a fortune selling them to everyone we know. Now all I need to do is head down to the video store and return the DVD.',
#   'context/0': 'Put it on. Lets share the experience.'},
#  {'response': 'I thought we were the Lightning Sharks.',
#   'context': 'Hey, Princeton, look at that, Team Community College Night School is in the lead.',
#   'context/0': 'Got it.'},
#  {'response': 'Or do I, hmm? Sir Isaac Newton wrote his Principia while convinced he was an armadillo.',
#   'context': 'You dont need to drive yourself crazy in order to be productive.',
#   'context/0': 'But after months of struggling, Im finally making progress.'},
#  {'response': 'Well, now, but do you think thats a good idea? Uh, you know Star Trek. Should a guy with no name and a red shirt really go on an expedition?',
#   'context': 'He knows, wow.',
#   'context/0': 'Yeah, Ive worked with Hawking. I talked you up. He knows your research. I think this could happen.'},
#  {'response': 'Yeah, one would assume, on getting out of the pit.',
#   'context': 'For your information, Emily is working tonight.',
#   'context/0': 'Well, cause you have a steady girlfriend now, and we assumed youd have to stay home to lower the food down to her in the pit.'},
#  {'response': 'Brobdingnagian, Brobdingna How did you even get it in here?',
#   'context': 'Now three times fast?',
#   'context/0': 'Brobdingnagian.'},
#  {'response': 'If it makes you feel any better, Amy and I are fine. I mean, really good.',
#   'context': 'Bernie',
#   'context/0': 'Find somewhere else to sleep tonight.'},
#  {'response': 'You just lied to Penny.',
#   'context': 'See you.',
#   'context/0': 'Oh, too bad, well, I got to get to rehearsal, see you guys.'},
#  {'response': 'Oh, thank you.',
#   'context': 'Likewise. I read your paper, it was very impressive.',
#   'context/0': 'Oh, Doctor Hofstadter, its so good to see you again.'},
#  {'response': 'Fascinating.',
#   'context': 'You heard that, Ladies Night ladies? Were eventually coming for you!',
#   'context/0': 'Oh, absolutely.'},
#  {'response': 'So, a sandwich, a rabbi and yo mama walk into a bar. Where are you going?',
#   'context': 'No, no, I just need to be alone.',
#   'context/0': 'Penny, dont.'},
#  {'response': 'Are you ill?',
#   'context': 'Apparently so.',
#   'context/0': 'Look at that, thats a dent. Thank you, Howard Ham-Fisted Wolowitz. Did you just shut the TV off in the middle of the classic Deep Space Nine Star Trek The Original Series Trouble With Tribbles crossover episode?'},
#  {'response': 'What are you doing in my room? Stop it. Thats mine. Why are you so strong?',
#   'context': 'Who cares?',
#   'context/0': 'I love you.'},
#  {'response': 'That depends.',
#   'context': 'Oh, this is pretty nice. Uh, the bedrooms are back there?',
#   'context/0': 'Correct. Youve passed the first barrier to roommate-hood. You may enter.'},
#  {'response': 'Yeah, 1-2-3-4 is not a secure password.',
#   'context': 'Keep walking.',
#   'context/0': 'Well, for one thing, were late for Leonards birthday party. And for another, I told him to call security.'},
# ...
#   'context/0': 'Of course. I just explained it to you. Now, where do you stand on it?'},
#  {'response': 'But I made a video.',
#   'context': 'Cant you just tell me?',
#   'context/0': 'Actually, as part of the application, I was required to make a short video answering that very question. You want to see it?'},
#  {'response': 'I cant sleep.',
#   'context': 'You okay?',
#   'context/0': 'Never shouldve had all these kids so close together.'},
#  {'response': 'Im Sheldon. How do you do?',
#   'context': 'Youre very funny. Im Abby.',
#   'context/0': 'Its a limited edition Green Lantern lantern. My friend is looking for someone to copulate with.'},
#  {'response': 'When did we get to the Cheesecake Factory?',
#   'context': 'Sheldon?',
#   'context/0': 'That is so beautiful.'},
#  {'response': 'Whats life without whimsy?',
#   'context': 'Why?',
#   'context/0': 'As I will not be engaging in this nonsense, my choice of beverage is moot. But for the record, I only drink hot chocolate in months with an R in them.'},
#  {'response': 'Im thinking of wearing a tuxedo.',
#   'context': 'Sheldon, you know that if you stay up all night, youre gonna be sleepy tomorrow. And a sleepy Sheldon is a cranky Sheldon. And a cranky Sheldon is actually no different than a regular Sheldon. Good night.',
#   'context/0': 'Do you realize that in less than nine hours, Arthur Jeffries, aka Professor Proton, will be in our apartment?'},
#  {'response': 'May I come in?',
#   'context': 'Oh, thank you.',
#   'context/0': 'Penny. Zucchini bread.'},
#  {'response': 'Yes, we could use science. But its your bachelor party. Lighten up.',
#   'context': 'Guys, excuse me, not that calling one of the Avengers isnt a perfectly reasonable choice, but were scientists. Dont you think we can figure this out using actual science?',
#   'context/0': 'Oh, please, the Hulk would never get across the border with that temper.'},
#  {'response': 'Amy, come back. I dont know how to open the oysters.',
#   'context': 'Okay, Ive had enough.',
#   'context/0': 'Anything youd like to pet? Not my hair. Theres a lot of goop in it.'},
#  {'response': 'Is it kung pao chicken?',
#   'context': 'Here you go. I picked up the Chinese food just the way Leonard used to.',
#   'context/0': 'Its too late. Well see him at his Bar Mitzvah.'},
#  {'response': 'Play that funky music, white boy.',
#   'context': 'What? This road trip just got crazy.',
#   'context/0': 'I suppose it is. In fact, if youd like to celebrate with a little music, Id be okay with that.'},
#  {'response': 'Oh, okay, okay, calm down.  Its him. Hes trying to video chat. Perhaps I shouldnt have taken this into the real world.',
#   'context': 'Come on, Sheldon!',
#   'context/0': 'Are you crazy? You dont know who this person is. Delete that.'},
#  {'response': 'You want to play Jenga? Or, uh, Ticket to Ride? Hearthstone? What would you be the happiest losing at?',
#   'context': 'I really dont know.',
#   'context/0': 'Well, what can we do to cheer you up?'},
#  {'response': 'No, we turned our stereo down by sending a signal around the world via the internet.',
#   'context': 'Yeah, you turned your stereo down with your laptop.',
#   'context/0': 'Hang on, hang on, do you not realise what we just did.'},
#  {'response': 'You know, the German philosopher, Friedrich Nietzsche, believed that morality is just a fiction used by the herd of inferior human beings to hold back the few superior men.',
#   'context': 'Well, they say at the end of your life, you regret the stuff you didnt do more than the stuff that you did, and Im pretty sure Alice is the stuff I want to do.',
#   'context/0': 'All right. So the topic at hand is sexual fidelity. Probably wont be relying on Seuss here. Although One Fish, Two Fish, Red Fish, Blue Fish might be surprisingly applicable. Go on.'},
#  {'response': 'I havent. Ive been meaning to, but who has the time?',
#   'context': 'Have you had your appendix out?',
#   'context/0': 'Its part of an unlikely scenario that involves sleepwalking and a 24-hour flower mart with a less-than-vigilant proprietor. Oh, Lord, my belly!'},
#  {'response': 'Oh!',
#   'context': 'It was great. We talked about movies.',
#   'context/0': 'So, come on, how was the first day with Hawking?'},
#  {'response': 'Theres a motion on the floor, Im ridiculous. Do we have a second? Hmm? Hmm? There is no second. The motion is denied. Next time, make sure you have the votes first. That was embarrassing.',
#   'context': 'Youre being ridiculous.',
#   'context/0': 'Of course, it will require a vote. Unfortunately, my official gavel is in my bedroom, but luckily, I have my travel gavel.'},
#  {'response': 'Oh.', 'context': 'Come in.', 'context/0': 'Birthday girl.'},
#  {'response': 'Well?',
#   'context': 'Cant talk. Spitball. Probably gonna die.',
#   'context/0': 'You mean, like, where shes nice to your face? Okay got it. Bye. Hey, boyfriend.'},
#  {'response': 'Sadly, its not. Substance abuse is a lifelong struggle, but beyond that I have realised that the Leo I described would not have agreed to go to rehab.',
#   'context': 'What are you talking about, its fine, she bought it, its over.',
#   'context/0': 'No, thats the least of our worries. Ive been doing some research on addiction, both the biochemical and behavioural aspects, and I think theres a problem with the current version of our lie.'},
#  {'response': 'Oh, I dont know. He kind of looks like a jerk. How about this one?',
#   'context': 'Lets forget about them, and pick ourselves out a nice turtle. Oh, how about this one up on the log?',
#   'context/0': 'That was a lot of puppies.'},
#  {'response': 'All righty! An 8.2 magnitude earthquake devastates Pasadena, reducing mighty edifices to dust, engulfing the city in flames. The streets flow with blood and echo with the cries of the wounded. Oh, excellent choice. Now, put on your hard hat and safety vest.',
#   'context': 'Fine.',
#   'context/0': 'Yeah, really? You think those hippies in Washington and Oregon can stop them?'},
#  {'response': 'Thank you.',
#   'context': 'Denial. Denial, denial. Come in.',
#   'context/0': 'Is not. Is not, is not.'},
#  {'response': 'Im not going to pay a fine. That would imply Im guilty.',
#   'context': 'Its not that big a deal. You just go down to the court on Thursday and you pay the fine.',
#   'context/0': 'Yes, yes, look, and now you have a photo to remember that heroic day.'},
#  {'response': 'Thank you.',
#   'context': 'Well, thank you for sharing it with me. I wont tell anyone.',
#   'context/0': 'The point of the experiment is to be completely honest with each other.'},
#  {'response': 'What, so you thought I was going to be alone for the rest of my life?',
#   'context': 'Shelly, how do I put this? By your third birthday, you had memorized over a thousand different kinds of trains, and I never imagined a woman getting aboard any of them.',
#   'context/0': 'Oh, boy, I think its about to get bad.'},
#  {'response': 'I know how to behave.',
#   'context': 'Right. Be polite.',
#   'context/0': 'Here he comes.'},
#  {'response': 'Ive worked up a bit of a sweat.',
#   'context': 'It is warm in here.',
#   'context/0': 'I apologize that its so warm in here.'},
#  {'response': 'Good. Dont do it.',
#   'context': 'No. Why?',
#   'context/0': 'Leonard, have you gotten married yet?'},
#  {'response': 'She doesnt want to live with Leonard, so he has to come live here again. Shes the snake in our garden. Shes the reason we cant be happy.',
#   'context': 'What?',
#   'context/0': 'Its Pennys fault.'},
#  {'response': 'Did you get hit on the head with a coconut?',
#   'context': 'No, I did not.',
#   'context/0': 'Move across the hall? Did you take a marijuana?'},
#  {'response': 'Penny.',
#   'context': 'Damn his Vulcan hearing. Not a good time, Sheldon.',
#   'context/0': 'Whispering do not make a sound is a sound.'},
#  {'response': 'Its dark matter. When I entered the field of string theory, I was a prodigy. I rose to a position of respect, and I assumed my career would continue on that upward trajectory. Now here I am in my 30s, Im back at square one. And, frankly, its frightening.',
#   'context': 'Oh. Is it Amy?',
#   'context/0': 'My struggle is emotional.'},
#  {'response': 'I cant see it! It just wont coalesce.',
#   'context': 'Aye, aye, Captain.',
#   'context/0': 'Captain Hooks hand was eaten by a crocodile, not an alligator. If youre going to mock me, at least get your facts straight.'},
#  {'response': 'Leonard.',
#   'context': 'You want me to put it back?',
#   'context/0': 'No. It upsets Sheldon when she willy-nilly takes it from the containers without regard for its equitable distribution. This is essentially why you have famine in India.'},
#  {'response': 'Im fine.',
#   'context': 'Sheldon, knight takes bishop. You all right?',
#   'context/0': 'Bishop to queen four, level two. Check.'},
#  {'response': 'I was asking for directions. Apparently, there was a communication problem.',
#   'context': 'Whyd you get that? You hate lamb.',
#   'context/0': 'Well, I do now. Theyre a lovely people. Although terrifying when you wake up face-to-face with them. If youre hungry, I brought home some mutton and coconut milk.'},
#  {'response': 'See, I did all this great work, and now hes just going to come along and ruin it. I am angrier than ever and filled with despair.',
#   'context': 'Oh, teacher! Me! Me!',
#   'context/0': 'Yes, cocoa. Do you have any idea what its like to be paired with someone whos so incredibly annoying?'},
#  {'response': 'Penny..', 'context': 'Im back here.', 'context/0': 'Penny?'},
#  {'response': 'Or a mutant army. It depends on how my Kickstarter goes.',
#   'context': 'Stop it.',
#   'context/0': 'A crazy person with a long memory, and if all goes according to plan, a robot army.'},
#  {'response': 'Its a rhetorical question. There is nothing more important than Wii bowling night.',
#   'context': 'Actually, I was',
#   'context/0': 'Where were you thats more important than Wii bowling night?'},
#  {'response': 'Actually, yes. I do.',
#   'context': 'You did it. Do you feel okay?',
#   'context/0': 'I will always have the dent to remember it by.'},
#  {'response': 'What are you smiling at?',
#   'context': 'Hello, boys.',
#   'context/0': 'That reminds me, I was thinking about wearing my NASA jumpsuit as a costume. But then I realized everyone would be, like, wheres your costume? Why are you wearing your work clothes, you nut?'},
#  {'response': 'Yes, youre fine as long as you have a buffer living with you to distract from your marital problems. It used to be me. Now its Raj and his attack Tribble. Anyway, Im sorry for everything. Oh, and FYI, if you cry while theyre fighting, theyll take you to McDonalds.',
#   'context': 'What are you talking about? Were fine.',
#   'context/0': 'Beverly pointed out that Im experiencing insecurities in my relationship with Amy, in the same way that Leonard and Penny are in their relationship.'},
#  {'response': 'Tuesday night we played Klingon boggle until one in the morning.',
#   'context': 'Yes I now, but',
#   'context/0': 'Thats not true. Koothrapali and Wolowitz come over all the time.'},
#  {'response': 'Bernadette.',
#   'context': 'We should play limbo next. No one beats me at limbo.',
#   'context/0': 'Bernadette, left foot yellow.'},
#  {'response': 'Oh, Ive been meaning to tell you, I figured out your magic trick.',
#   'context': 'It is pretty spicy.',
#   'context/0': 'Oh, thats, hot, hot, hot, hot! Whoo! It really sneaks up on ya, huh? All right, I gotta go.'},
#  {'response': 'That doesnt sound terrifying.',
#   'context': 'He gave me his business card and asked me to please pass it along to Howard.',
#   'context/0': 'Oh, what did he say?'},
#  {'response': 'But it wasnt my fault. I didnt exclude him. And I didnt write the article.',
#   'context': 'Leonard is as much a part of this paper as you are, and he was overlooked. Hes going to feel bad.',
#   'context/0': 'Well, I dont know, were all Groot? Just tell me.'},
#  {'response': 'Seriously? Airborne worms?',
#   'context': 'Fine. I want to release butterflies.',
#   'context/0': 'Fine. I want black-tie.'},
#  {'response': 'Listen, Leonards mom is a renowned psychiatrist and woman of science. Can you please keep the Bible babble to yourself while shes here?',
#   'context': 'The floating bodies of drowned sinners, of course.',
#   'context/0': 'What did they feed the lions, Mother?'},
#  {'response': 'Well, then at least hold her still so I can pretend shes stuffed. Raj, I let my emotions get the best of me, and I unfairly took it out on you.',
#   'context': 'Sheldon, shes fine.',
#   'context/0': 'Hey, Raj, I owe you an apology. Look, could you please put your dog on a leash?'},
#  {'response': 'When its done charging. Or you land on the time machine. Obviously.',
#   'context': 'Hang on. When is my pawn allowed to use the golf cart?',
#   'context/0': 'Nice. Okay, rook to transporter pad. And he comes out at Leonards Queens Bishop'},
#  {'response': 'No. Now that you know my weakness, I hate you more than ever.',
#   'context': 'Is it working?',
#   'context/0': 'I was hoping by admitting my weakness to you, Id somehow be unburdened.'},
#  {'response': 'Thank you for carving a smiley face in my grilled cheese sandwich.',
#   'context': 'Whatever. Jesus still loves you.',
#   'context/0': 'My objection was based on considerations other than difficulty.'},
#  {'response': 'It doesnt matter.',
#   'context': 'And go where?',
#   'context/0': 'No. Ive reached my breaking point. I need to leave. Now.'},
#  {'response': 'Wow. Im starting to think you didnt mean it when you said you wanted to spruce up the place.',
#   'context': 'For the last time, no Hulk, no Batman, no life-size statues.',
#   'context/0': 'Lets hope he thinks so, too.'},
#  {'response': 'Oh, nice job, man-hands.',
#   'context': 'What?',
#   'context/0': 'Its broken.'},
#  {'response': 'Ive never slept on an air mattress before. No lumbar support whatsoever.',
#   'context': 'Shouldnt you have put him in a brown paper bag and set him on fire?',
#   'context/0': 'Tag. Youre it.'},
#  {'response': 'All right. So the topic at hand is sexual fidelity. Probably wont be relying on Seuss here. Although One Fish, Two Fish, Red Fish, Blue Fish might be surprisingly applicable. Go on.',
#   'context': 'Oh, what the hell. Im supposed to go see that girl from the comic book store, Alice, but I dont know if I should, because Im going out with Priya, but shes in India.',
#   'context/0': 'Well, if its of any help, Ive read all the great moral philosophers, including Dr. Seuss.'},
#  {'response': 'They lie so they dont look petty.',
#   'context': 'I, looked her in the eye, smiled and said, Im happy for you. Because thats what friends do.',
#   'context/0': 'You ripped out your own fake blonde hair.'},
#  {'response': 'Well, you doled out affection as a reward for achievement, a proven way to raise a child. Or train a rat.',
#   'context': 'I cant help but notice how her unconditional love for you is diametrically opposed to my own parenting strategies.',
#   'context/0': 'Oh, its all right. Shell forgive you. She has to or she goes to hell.'},
#  {'response': 'Yes, Id like a seven-day course of penicillin, some, uh, syrup of ipecac, to induce vomiting, and a mint.',
#   'context': 'You guys ready to order?',
#   'context/0': 'Hey! Thats my sister and my country youre talking about. Leonard may have defiled one, but I wont have you talking smack about the other.'},
#  {'response': 'Yes. Now, when the robots rise up, theyll know that Ive been rooting for them the whole time.',
#   'context': 'Its amazing a machine can do that.',
#   'context/0': 'This things pretty cool. It interprets emotions using a wireless signal to analyse subtle changes in breathing and heart rate.'},
#  {'response': 'What is that awful smell?',
#   'context': 'Scientific Principle: Accelerated Corrosion.',
#   'context/0': 'Its a bachelor party. Lighten up.'},
#  {'response': 'An interesting question. Well, good night.',
#   'context': 'I dont understand it. Im a nice guy, I have a great job, Im well-educated, come from a good family. Why dont women want to be with me?',
#   'context/0': 'Hmm. You think youre five-foot-six, thats funny.'},
#  ...]

# %%
lines_selected_list.append(['Soft kitty, warm kitty Little ball of fur', 'Happy kitty, slippy kitty Pur pur pur', 'TBBT'])
lines_selected_list.append(['Penny.', 'Thats just wrong.', 'TBBT'])
lines_selected_list.append(['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?', 'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.', 'TBBT'])
lines_selected_list.append(['I didnt break it. I, I guess Stuart sold it to me like this.', 'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.', 'TBBT'])
lines_selected_list.append(['Be careful.', 'If I were not being careful, your telling me to be careful would not make me careful.', 'TBBT'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT']]

# %% [markdown]
# ## Harry

# %%
temp = select_lines(characters[2])
# Out:
# Using custom data configuration default-d593b2171ebfd931
# Downloading and preparing dataset csv/default to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-d593b2171ebfd931\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-d593b2171ebfd931\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
[s for s in temp['test']]
# Out:
# [{'response': 'Stop, Dobby!',
#   'context': 'Bad Dobby!',
#   'context/0': 'That was an awful thing to say.'},
#  {'response': "My dad wasn't a drunk.",
#   'context': 'What did you say?',
#   'context/0': "That's a lie."},
#  {'response': "Alive, you're free.",
#   'context': 'Besides, dead, the truth dies with him.',
#   'context/0': "I didn't think my dad would have wanted his best friends to become killers."},
#  {'response': "Don't even think about it.",
#   'context': "In fact, I'm going to have to do the same to you.",
#   'context/0': "I'd never have sold another book."},
#  {'response': 'Fortuna Major.',
#   'context': "She just won't let me in.",
#   'context/0': 'Here, listen.'},
#  {'response': "It's a snake.",
#   'context': "That's why I can hear it speak.",
#   'context/0': 'The monster in the Chamber of Secrets is a basilisk.'},
#  {'response': 'This is it.',
#   'context': 'I just remember seeing a pair of great, big, yellow eyes over there by that sink.',
#   'context/0': 'Just like that? How?'},
#  {'response': 'You need to sound more like Crabbe.',
#   'context': 'We still sound like ourselves.',
#   'context/0': 'Bloody hell!'},
#  {'response': 'Are you mad?',
#   'context': "Why aren't we leaving?",
#   'context/0': "And we aren't leaving?"},
#  {'response': 'Malfoy.',
#   'context': "Who's that?",
#   'context/0': "He'll have to be trained up a bit, of course."},
#  {'response': "But you're innocent.",
#   'context': "And besides you're meant to be here.",
#   'context/0': 'For some time, my life will be too unpredictable.'},
#  {'response': 'Thank you. Bye.',
#   'context': 'Okay, bye.',
#   'context/0': "Right. I'll leave you to it."},
#  {'response': "I'll see you back in the common room.",
#   'context': 'For all we know, you could be.',
#   'context/0': 'He lived a thousand years ago.'},
#  {'response': 'I fell over.',
#   'context': 'What you doing down there?',
#   'context/0': 'My name is Stan Shunpike, and I will be your conductor for this evening.'},
#  {'response': 'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'context': 'But why would anyone go near that dog?',
#   'context/0': "But, he got himself bitten, that's why he's limping."},
#  {'response': 'This way, now.',
#   'context': 'This way.',
#   'context/0': 'Come on.'},
#  {'response': 'Oh!', 'context': 'Yeah!', 'context/0': "I've got presents?"},
#  {'response': "Snape doesn't want the stone for himself, he wants the stone for Voldemort.",
#   'context': "Don't you see? We had it wrong.",
#   'context/0': "He's living off the unicorns."},
#  {'response': 'Follow the spiders.',
#   'context': 'You heard what Hagrid said.',
#   'context/0': 'What?'},
#  {'response': "I think it's a warning.",
#   'context': 'Perhaps you should see the nurse.',
#   'context/0': 'Not like this.'},
#  {'response': 'we almost get killed by a tree...',
#   'context': "So a house-elf shows up in my bedroom we can't get through the barrier to platform 93 4...",
#   'context/0': 'See you, Hedwig.'},
#  {'response': 'Oh, no.',
#   'context': "Buckbeak didn't mean no harm.",
#   'context/0': "Let's go!"},
#  {'response': "You see, sir, I couldn't help but notice certain things, certain...",
#   'context': "It's just...",
#   'context/0': 'Am I right, Harry?'},
#  {'response': "I didn't.",
#   'context': 'What did you say your name was?',
#   'context/0': "It's going to be a bumpy ride."},
#  {'response': "Hey, he's gone!",
#   'context': 'I got about six of him.',
#   'context/0': "I've got Dumbledore!"},
#  {'response': 'Where are we? A graveyard.',
#   'context': "I don't like this at all.",
#   'context/0': "I don't like this."},
#  {'response': "Look. Buckbeak's still alive.",
#   'context': "Come on. We should be at Hagrid's.",
#   'context/0': 'Not good, brilliant.'},
#  {'response': 'Hey, Hagrid.',
#   'context': 'Hello, Harry.',
#   'context/0': 'Come on now, hurry up.'},
#  {'response': "Let's go.",
#   'context': "Come on, Ginny, we'll get you a seat. Hurry.",
#   'context/0': 'After you, dear.'},
#  {'response': 'Come on, move faster!',
#   'context': 'Come on!',
#   'context/0': 'Now!'},
#  {'response': 'Hello, can you hear me?',
#   'context': 'Are you Tom Riddle?',
#   'context/0': "Could you tell me what's going on here?"},
#  {'response': 'I should be in Slytherin.',
#   'context': 'So the Sorting Hat was right.',
#   'context/0': 'Not intentionally but yes.'},
#  {'response': 'RON!', 'context': 'Ahhhh!', 'context/0': 'Check.'},
#  {'response': 'Mr. Weasley why would I go looking for someone who wants to kill me?',
#   'context': "Harry, swear to me that whatever you might hear you won't go looking for Black.",
#   'context/0': 'And kill me.'},
#  {'response': 'Who is it?',
#   'context': 'No, Dobby. Tell me.',
#   'context/0': 'Dobby only wants Harry Potter to be safe.'},
#  {'response': "It's fine. I'll stay.",
#   'context': "No. Don't worry, okay?",
#   'context/0': 'You better go.'},
#  {'response': "We've got to talk to Hagrid, Ron.",
#   'context': 'Unless the culprit behind these attacks is caught it is likely the school will be closed.',
#   'context/0': 'I should tell you this:'},
#  {'response': 'Tell those spiders.',
#   'context': "I don't wanna tap-dance!",
#   'context/0': 'Spiders. They want me to tap-dance.'},
#  {'response': 'Professor, why do the dementors affect me so?',
#   'context': 'No.',
#   'context/0': 'Is there no chance of fixing it?'},
#  {'response': 'I spoke a different language?',
#   'context': 'Snake language.',
#   'context/0': 'I heard you speaking Parseltongue.'},
#  {'response': 'Sorry about him.',
#   'context': "He's boring.",
#   'context/0': "He's asleep!"},
#  {'response': 'But this is important!',
#   'context': "He's gone?! Now?",
#   'context/0': 'He received an urgent owl from the Ministry of Magic and left immediately for London.'},
#  {'response': 'Sounds like wings.',
#   'context': "I don't know.",
#   'context/0': 'What is that?'},
#  {'response': 'Come on!',
#   'context': 'Now!',
#   'context/0': 'Get us out of here.'},
#  {'response': 'Rictusempra!',
#   'context': 'Everte Statum!',
#   'context/0': 'One. Two...'},
#  {'response': "Don't follow until I give you a sign.",
#   'context': "I'll go first.",
#   'context/0': 'Come on! Okay. Push!'},
#  {'response': 'What are you talking about?',
#   'context': 'After you, of course.',
#   'context/0': 'Can I have a go, Harry?'},
#  {'response': "But Flamel, he'll die, won't he?",
#   'context': 'My friend Nicholas and I had a little chat and agreed it was best all around.',
#   'context/0': 'Relax, dear boy. The stone has been destroyed.'},
#  {'response': "But the Muggles. Can't they see us?",
#   'context': 'If you have pea soup make sure you eat it before it eats you.',
#   'context/0': 'The Leaky Cauldron.'},
#  {'response': "Be thankful it's not your neck.",
#   'context': 'My wand. Look at my wand.',
#   'context/0': 'Stop! Stop! Stop!'},
#  {'response': "Only that he's escaped from Azkaban.",
#   'context': 'What do you know about Sirius Black, Harry?',
#   'context/0': 'Has this anything to do with Sirius Black, sir?'},
#  {'response': "I don't understand.",
#   'context': 'Yes?',
#   'context/0': 'No, thank you. Minister?'},
#  {'response': "She only saw the basilisk's reflection.",
#   'context': 'There was water on the floor that night.',
#   'context/0': 'The water.'},
#  {'response': "It's Mrs. Norris.",
#   'context': "It's Filch's cat.",
#   'context/0': 'Oh, no.'},
#  {'response': 'Dumbledore?',
#   'context': 'Professor Dumbledore.',
#   'context/0': 'Riddle! Come.'},
#  {'response': 'Dobby, please, no!',
#   'context': 'Dobby, get back here!',
#   'context/0': 'No! Ahh! Ooh...'},
#  {'response': 'Come on.',
#   'context': 'Run! Run!',
#   'context/0': 'Remus! Remus!'},
#  {'response': 'Platform 9 3 4?',
#   'context': 'Stick to your ticket.',
#   'context/0': "Stick to it, Harry that's very important."},
#  {'response': 'Open it.',
#   'context': 'Come, Dobby.',
#   'context/0': "Why don't you prove it?"},
#  {'response': 'Expecto Patronum!',
#   'context': 'Expecto Patronum!',
#   'context/0': 'Just do it.'},
#  {'response': 'I think we found the train.',
#   'context': "I'm trying. Your hand's all sweaty.",
#   'context/0': 'Hold on!'},
#  {'response': 'We are pleased to inform you that you have been accepted at Hogwarts School of Witchcraft and Wizardry.',
#   'context': 'Dear Mr. Potter,',
#   'context/0': "Anything you couldn't explain, when you were angry or scared?"},
#  {'response': 'that was drinking its blood...that was Voldemort?',
#   'context': 'Do you mean to say...that that thing that killed the unicorn...',
#   'context/0': 'Can you think of no one?'},
#  {'response': 'Dumbledore and the others, I mean?',
#   'context': 'Do you think I should have told them?',
#   'context/0': "and then Mrs. Norris turns up Petrified. It's just strange."},
#  {'response': "Hermione that's the he betrayed my parents.",
#   'context': "Harry, you can't.",
#   'context/0': "That's Pettigrew."},
#  {'response': "I'm Harry. Harry Potter.",
#   'context': 'Ron Weasley.',
#   'context/0': "I'm Ron, by the way."},
#  {'response': "Right there. You'll see.",
#   'context': 'Any minute now.',
#   'context/0': "He'll conjure the Patronus."},
#  {'response': "I don't know, Sir.",
#   'context': 'And what is the difference between monkshood and wolfsbane?',
#   'context/0': "I don't know, Sir."},
#  {'response': 'Hedwig.',
#   'context': 'Room 11.',
#   'context/0': 'Yeah, take it away, Ernie!'},
#  {'response': 'Not as long as those who remain are loyal to him.',
#   'context': "He'll never be gone.",
#   'context/0': "Dumbledore's been driven out of this castle by the mere memory of me."},
#  {'response': 'Hang on.',
#   'context': 'I was lost, I...',
#   'context/0': "People will think you're up to no good."},
#  {'response': 'Why was he trying to get past that 3 headed dog on Halloween?',
#   'context': 'Who knows.',
#   'context/0': "Why would Snape put a curse on Harry's broom?"},
#  {'response': 'Earlier, it showed someone in the castle.',
#   'context': "Professor, just so you know, I don't think that map always works.",
#   'context/0': 'If you do, I shall know.'},
#  {'response': 'This says platform 9 3 4.',
#   'context': 'But, Hagrid, there must be a mistake.',
#   'context/0': 'Platform 9 3 4?'},
#  {'response': 'Sir? I wonder if I could have that?',
#   'context': "Come, Dobby. We're leaving.",
#   'context/0': 'Dumbledore.'},
#  {'response': "Hagrid, what's that?",
#   'context': "Right. Let's go.",
#   'context/0': 'Nighty-night.'},
#  {'response': 'Dobby?', 'context': 'Hello.', 'context/0': 'Time to kill..'},
#  {'response': 'Wait a minute.',
#   'context': 'Pawn to C-3!',
#   'context/0': 'Castle to E-4!'},
#  {'response': "No. Don't worry, okay?",
#   'context': 'You better go.',
#   'context/0': 'Okay.'},
#  {'response': 'Catch the key!',
#   'context': 'This complicates things a bit!',
#   'context/0': "You're the youngest seeker in a century!"},
#  {'response': 'You were brilliant, Fawkes.',
#   'context': "Follow the Chamber and you'll find Ron.",
#   'context/0': 'Ginny, you need to get yourself out.'},
#  {'response': 'With the Elixir of Life, Voldemort will be strong again.',
#   'context': "Snape doesn't want the stone for himself, he wants the stone for Voldemort.",
#   'context/0': "Don't you see? We had it wrong."},
#  {'response': "She's cold as ice.",
#   'context': 'A memory preserved in a diary for 50 years.',
#   'context/0': 'Are you a ghost?'},
#  {'response': 'Expecto Patronum!',
#   'context': 'No. Sirius!',
#   'context/0': 'Sirius!'},
#  {'response': 'Hagrid!', 'context': 'Harry?', 'context/0': 'No. Please...'},
#  {'response': 'You were right, Hermione.',
#   'context': 'Expecto Patronum!',
#   'context/0': 'Harry!'},
#  {'response': 'I think you do, sir.',
#   'context': "Mine? I don't know what you're talking about.",
#   'context/0': 'I have something of yours.'},
#  {'response': 'Hagrid, who gave you the dragon egg?',
#   'context': "Why didn't I see it before?",
#   'context/0': 'I mean, how many people wander around with dragon eggs in their pockets?'},
#  {'response': 'Lucky Hermione pays attention in Herbology.',
#   'context': "Whew. Lucky we didn't panic!",
#   'context/0': 'Okay.'},
#  {'response': "No. Mr. Filch! You don't understand...",
#   'context': 'Mark my words.',
#   'context/0': "I'll have you out this time, Potter."},
#  {'response': 'Everyone?',
#   'context': 'Everyone.',
#   'context/0': 'So you mean this map shows...'},
#  {'response': 'Yes, sir... See why Ive got to go back?',
#   'context': 'And fix that door!',
#   'context/0': 'One more sound, and youll wish youd never been born, boy!'},
#  {'response': "So a house-elf shows up in my bedroom we can't get through the barrier to platform 93 4...",
#   'context': 'See you, Hedwig.',
#   'context/0': "Dad's gonna kill me."},
#  {'response': 'Tom. Tom Riddle.',
#   'context': "She won't wake.",
#   'context/0': 'Please wake up.'},
#  {'response': 'Are you a ghost?',
#   'context': "She's still alive, but only just.",
#   'context/0': "She's not...?"},
#  {'response': "I don't suppose you could tell me why you're trying to kill me?",
#   'context': 'Dobby gets them five times a day at home.',
#   'context/0': 'Dobby is used to death threats, sir.'},
#  {'response': 'Look in properly. Go on.',
#   'context': 'I only see us.',
#   'context/0': "Come on. Come. Come look, it's my parents!"},
#  {'response': "I can't be.",
#   'context': "But I'm not.",
#   'context/0': "Now the whole school's gonna think you're his great-great-great grandson."},
#  {'response': "he Leaky Cauldron. That's in London.",
#   'context': 'Where abouts are you headed?',
#   'context/0': "I didn't."},
#  {'response': 'Professor.', 'context': 'Harry?', 'context/0': "You're wrong."},
#  {'response': 'What?',
#   'context': "He's not about to steal it!",
#   'context/0': 'Snape is one of the teachers protecting the Stone!'},
#  {'response': "They're my letters!",
#   'context': 'Get off!',
#   'context/0': 'Give me that letter!'},
#  {'response': "But I didn't realize...",
#   'context': 'I spoke a different language?',
#   'context/0': 'Snake language.'},
#  {'response': 'Certain similarities between Tom Riddle and me.',
#   'context': "You see, sir, I couldn't help but notice certain things, certain...",
#   'context/0': "It's just..."}]

# %%
lines_selected_list.append(['But why would anyone go near that dog?', 'The day I was at Gringotts, Hagrid took something out of one of the vaults.', 'HP'])
lines_selected_list.append(['Expecto Patronum!', 'Expecto Patronum!', 'HP'])
lines_selected_list.append(['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'])
lines_selected_list.append(['I spoke a different language?', "But I didn't realize...", 'HP'])
lines_selected_list.append(['Harry?', 'Professor.', 'HP'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP']]

# %% [markdown]
# ## Fry

# %%
temp = select_lines(characters[3])
# Out:
# Using custom data configuration default-7576c78852c6ab3d
# Downloading and preparing dataset csv/default to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-7576c78852c6ab3d\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-7576c78852c6ab3d\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
[s for s in temp['test']]
# Out:
# [{'response': "If I were in charge I wouldn't treat you like this. You're nothing but a big blowhard.",
#   'context': "Eh, I've heard better.",
#   'context/0': "Fine, I've got a toast. To Captain Bender! He's the best......at being a big jerk and his big ugly face is as dumb as a butt."},
#  {'response': 'Evil Knievel could!',
#   'context': 'Hah! No human could do all that.',
#   'context/0': 'And I can deliver them. Billions and billions in one night.'},
#  {'response': 'I was just working my way towards the medulla oblongata - control centre of the heart and lungs. And if I kill myself, you die with me.',
#   'context': "You've damaged your brain Universe, but no more than a week of binge drinking or five minutes on a cell phone.",
#   'context/0': 'Stop it man!'},
#  {'response': 'Who said that? Hey! What the--? Ooh! Ow! Ow!',
#   'context': 'There he is. Seize him.',
#   'context/0': 'Toss it in the garbage!'},
#  {'response': 'Hey! You opened a franchise!',
#   'context': "Welcome to Fenway Park, home of the Boston Poindexters where the Mets close out a season that'll rank among mankind's most awful crimes.",
#   'context/0': "Oh you got that too? I think there's a rash goin' around."},
#  {'response': 'Professor, when did you become so obsessed with voting?',
#   'context': "Yes, that's a capital idea. Let's all go register.",
#   'context/0': "The point is, one vote can make a difference and even though it won't, I'm still taking you to get registered."},
#  {'response': 'I can sorta dance like a robot. Will that help?',
#   'context': "We'll have to walk like robots, talk like robots and, if necessary, solve complex differential equations like robots.",
#   'context/0': 'I am fully operational, captain.'},
#  {'response': "Wait, let's go by rank.",
#   'context': 'OK. First Bender, then Flexo, then Fry.',
#   'context/0': "Wait, I don't like the sound of that. Let's just go alphabetically."},
#  {'response': "Now it's personal.",
#   'context': 'Once their task is complete, they will ensure no new information arises in the only way possible: by destroying the universe.',
#   'context/0': "I'm as mad as I've ever been."},
#  {'response': 'But instead of falling in and getting frozen, I missed and wanged my head.',
#   'context': 'I call it a Hawking Chamber.',
#   'context/0': 'So then my chair tilted back and I almost fell into this freezer thingy.'},
#  {'response': "Bigfoot? Is that you? I'm not like the others Bigfoot. I see through your monster coatings to the gentle loner inside. I bet you have a wounded racoon friend that you tenderly nurse back to health and go......and in the end they shoot you. But you teach us about things. Oh, it's a flying saucer. Excuse me? You can't park here. The parking area's over there. Wow nice tube! Hey. Hey what's the big idea? Stop abducting me. Why does your vanity plate say Probe 1?",
#   'context': 'Bigfoot? Bigfoot?',
#   'context/0': "Who's that? A wolf? Or some kind of boogen? Oh God I wish I was safe inside a tent. Fry, Fry wake up! It's me! Bigface!"},
#  {'response': "Stand back. I'm a tool-bot.",
#   'context': "I'll show ye!",
#   'context/0': "That's a plus sign, you pointy-haired loony! Quit thinking you're a robot!"},
#  {'response': 'Whoa! Letters like U and R can mean words like You and Are. Here Leela, U-R-2 Cute!',
#   'context': "My family has been making these hearts since the 1900's. Tastes may have changed but our secret recipe sure hasn't.",
#   'context/0': 'Impressive!'},
#  {'response': 'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'context': "I'm too scared.",
#   'context/0': 'Bender, do something.'},
#  {'response': "He's dead.",
#   'context': 'Dr. Zoidberg? Are you OK?',
#   'context/0': 'All opposed? All abstaining?'},
#  {'response': "Look out! We're heading straight for those trees!",
#   'context': 'Sweet lion of Zion! Look at the Professor go.',
#   'context/0': "At least you're not cold blooded!"},
#  {'response': 'Hm.',
#   'context': 'Behold: The Great Stone Face of Mars.',
#   'context/0': 'Did I say girlfriend? She sounds more like a wife!'},
#  {'response': 'Damn.', 'context': 'As a friend.', 'context/0': 'Even me?'},
#  {'response': 'Huh?',
#   'context': "Well, whatever. Hey, listen, as long as we're not seeing each other, you mind if I ask someone else out for Valentine's Day?",
#   'context/0': "I'm sorry, but it is."},
#  {'response': 'Yes!',
#   'context': "Won't you come in?",
#   'context/0': 'You favourite what? Why does my foot hurt?'},
#  {'response': 'Why?',
#   'context': 'Enough! There will be no further questions.',
#   'context/0': "I'm just asking cause they look kind of secret."},
#  {'response': "I don't mean to nitpick, super-doc, but do you think maybe you could take one more whack at this?",
#   'context': 'I may not know from emotions but when it comes to medicine, forget about it.',
#   'context/0': 'Yeah!'},
#  {'response': "I'll take care of this! Back! Back!",
#   'context': "Mutants! They're real!",
#   'context/0': 'Mutants!'},
#  {'response': "Wait a second! That's my name! Good Lord. He ditched his goofy name and stole mine!",
#   'context': "Hold the phone. If that's Yancy then why does the inscription read Philip J. Fry?",
#   'context/0': "It's my brother Yancy! And there in his lapel - my seven leaf clover! I knew he stole it."},
#  {'response': "I'm walking on sunshine! La la la la sunshine!",
#   'context': 'What up?',
#   'context/0': "Aw, I'll never recombobulate this ship! When the Professor finds out, he'll tear me a new cloaca! Wait! What would the robot do? Frame someone."},
#  {'response': 'There must be people somewhere.',
#   'context': "Oh, yeah? Well, listen to this: I'm leaving you.",
#   'context/0': 'Quit standing up for yourself, Fry. When we get back to the hole, we are going to have a long, boring talk about our relationship!'},
#  {'response': 'Hey, I plan on having a few brewskis myself.',
#   'context': "You're in tremendous danger, you idiot! Half of these Emperors were drunk at their own coronation.",
#   'context/0': "Well at least my assassin will get what's coming to him."},
#  {'response': 'Ha! That barely hurt Leela at all!',
#   'context': 'Fire detected in the vicinity of Leela.',
#   'context/0': "Now look missy! If you don't trun around now I'm going to have to shut down your brain!"},
#  {'response': 'Words. Nothing sweet, sweet words that turn into bitter orange wax in my ears.',
#   'context': "Fry, it doesn't mean anything. I have love enough for two.",
#   'context/0': 'It was very sweet of you, Bender.'},
#  {'response': "Bender? No! He's an old fashioned one spaceship robot. Look I'll tell him you stopped by OK?",
#   'context': "Oh I see. He didn't fly there in another spaceship did he?",
#   'context/0': "Uh, um no. I think he's at his parent's."},
#  {'response': "He's made of candy.",
#   'context': 'And hard working.',
#   'context/0': "He's so polite."},
#  {'response': "So that's where my clover is? Hey, is that orbitting cemetary near here?",
#   'context': "Phil came in right, sturmmed out this tune yeah. And I said That's a number one record!",
#   'context/0': "That's what I'm known for!"},
#  {'response': "I've had better.",
#   'context': 'What about that bathroom egg salad from the truck stop?',
#   'context/0': 'No.'},
#  {'response': "But I don't like being a delivery boy.",
#   'context': '...out of a cannon into the Sun!',
#   'context/0': 'Fine!'},
#  {'response': "I'm bored. You're boring, Zoidberg. I'm gonna go watch TV.",
#   'context': "So, it's just as I suspected all along. The crime is unsolvable! A letter from Bender, my good friend. Dear Dr. Jerkberg, if you're reading this, I'm already dead. The person who killed me was ... was-- My God! It can't be! The murderer, it was--",
#   'context/0': "Scruffy knows who killed them people. In Scruffy's opinion, it were--"},
#  {'response': 'Giant Space Robot, this is Captain Fry of the USS Planet Express Ship; We come in peace.',
#   'context': 'By J. Stewart Burns Transcribed by Dave, The Neutral Planet',
#   'context/0': 'FUTURAMA'},
#  {'response': 'Leela? What are you guys doing here in the year 4000?',
#   'context': 'Fry, thank God we found you.',
#   'context/0': "Yes! Footprints! And hand prints? But? What's happening?"},
#  {'response': 'Tell me what?',
#   'context': 'Someone should tell him.',
#   'context/0': 'Uh...no.'},
#  {'response': 'Wait a minute! This says Z-Ray.',
#   'context': 'Ah! Is X-Ray eyes. See through anything!',
#   'context/0': "Ooh! What's this?"},
#  {'response': 'Nah, I had it coming.',
#   'context': 'Cram a ham in it you twerps! Sorry!',
#   'context/0': "Well mine's louder!"},
#  {'response': 'Is that an invitation?',
#   'context': "Look at yourself. You're a wreck! You've got to find a new place to live.",
#   'context/0': "Oh, it's Bender's apartment. He put in carpeting yesterday so now my head hits the ceiling. Hey, do you realise you're standing at a weird angle? Now you're OK."},
#  {'response': 'Uh, sorry.',
#   'context': 'But soon after Charles graduated, our marriage ran into difficulties.',
#   'context/0': 'Sorry.'},
#  {'response': "You're right Professor. We might not be a traditional family like the Murphy's next door or the lesbian coven across the street but we are a family, and That Guy understands that.",
#   'context': "This isn't a business, I've always thought of it as more of a source of cheap labour. Like a family.",
#   'context/0': "I don't care what Ms Johnson says, Thst Guy's turning this place into some kind of...business."},
#  {'response': 'Who are you?',
#   'context': "I'm so lonely since I came to the future. Will you be my friend? Ow!",
#   'context/0': 'My work here is done!'},
#  {'response': "I didn't order any --",
#   'context': "We're here to tighten your drains.",
#   'context/0': "Mr. Fry. It's those three plumbers you called for."},
#  {'response': 'Be brave my friend.',
#   'context': 'Poor Bender.',
#   'context/0': 'Destroy all robots! Destroy all robots!'},
#  {'response': 'Where are we?',
#   'context': 'Icky!',
#   'context/0': 'You have not won yet. Each book in this room is a gateway to a mental realm and I shall take you there and imprison you forever.'},
#  {'response': "I don't get it.",
#   'context': "No way! Mine's 2716057!",
#   'context/0': '3370318.'},
#  {'response': "I'm nobody. There are guys in the background with Mary Worth comics who are more important than me.",
#   'context': "So? I'm just as important as him. It's just that, the kind of importance I have, it doesn't matter if I...don't do it.",
#   'context/0': "I do go! He's a very important man."},
#  {'response': "Of all the parasites I've had over the years, these worms are among the - hell! They are the best! Leela, how can I ever repay you for saving them?",
#   'context': "If anyone wants to tell me what's going on here, I'll be in the lounge.",
#   'context/0': "Oh that's stupid!"},
#  {'response': "C'mon!",
#   'context': 'Mine! Mine!',
#   'context/0': "Son your name is Yancy, just like me and my grandfather and so on. All the way back to minuteman Yancy Fry, who blasted commies in the American Revolution. Philip, until I find a suitable model of an ICBM you'll have to make do learnin' to fear this toy spacecraft."},
#  {'response': "I'm over here.",
#   'context': 'Aww, that was uncalled for!',
#   'context/0': 'Try to stay with the crowd so no one notices how crummy you look.'},
#  {'response': "Please, it's important to me.",
#   'context': "You don't have to do that. I'm still seduced from before.",
#   'context/0': "I'm about to. Leela, let me play for you one for time."},
#  {'response': 'Wow!',
#   'context': 'And Superking! The best one of the three!',
#   'context/0': 'Clobberella!'},
#  {'response': 'I do other human stuff! I age! See?',
#   'context': 'Yes, you do. You need to relax more. Terrific. Now, consider the following: You were admitted to this robot asylum. Therefore, you must be a robot. Diagnosis complete.',
#   'context/0': "Look! There's been a terrible mistake. I'm a human being. See? I'm all squishy and flabby. Also, I complain a lot."},
#  {'response': 'Blast-off!', 'context': 'One!', 'context/0': 'Two.'},
#  {'response': 'I should be the one in that grave!',
#   'context': "They buried your brother in the world heroes section? I'm impressed.",
#   'context/0': "Hmm Breakfast Club, this'll clear out the room at the end of the reception."},
#  {'response': 'No! No!',
#   'context': 'Hey everyone jam a sock in your spit faucets. Not long ago I spent my lonely nights renting slash flicks with Rat Man and his girlfriend. But then a beautiful woman arrived and - stop eating pig! And she brought new hope for me and our once great civilisation. Now a million centuries of Cyclops destiny depend on the answer to one question......Leela, will you marry me?',
#   'context/0': "I'm trying."},
#  {'response': 'Start with a compliment: Tell her she looks thin.',
#   'context': "Dr. Zoidberg, that doesn't make sense. But OK.",
#   'context/0': "I just wanna talk, it has nothing to do with mating. Fry, that doesn't make sense."},
#  {'response': "Why would robots vote for Nixon now that he's just a head in a jar?",
#   'context': 'Get out of town!',
#   'context/0': 'What?'},
#  {'response': "It'll be a rich, full day.",
#   'context': "Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   'context/0': "Wouldn't it make sense to weld everyone except me to the wall?"},
#  {'response': 'Sure.',
#   'context': 'Anyone wanna play Dungeons amp; Dragons for the next quadrillion years?',
#   'context/0': "Eternity with nerds. It's the Pasadena Star Trek convention all over again."},
#  {'response': "Uh....I-I've got talking hump syndrome.",
#   'context': 'Did you hump just say something?',
#   'context/0': 'Stupid robot.'},
#  {'response': "Don't you worry about blank let me worry about blank.",
#   'context': "OK, lets work on your execu-speak. I'm worried about blank.",
#   'context/0': 'Make it two. And a glass of all your water.'},
#  {'response': "Oh wow. It's like that drug trip I saw in that movie when I was on that drug trip.",
#   'context': 'Come out of your universe with your hands up!',
#   'context/0': "I tell you they're not evil. But don't be confused. They are jerks."},
#  {'response': 'Bathroom.',
#   'context': 'Bath what?',
#   'context/0': "Uh, listen, Bender, uh, where's your bathroom?"},
#  {'response': 'Oh, no! Any sign of Leela or Amy?',
#   'context': "Well, hello! I usually don't say this but you are the most beautiful trio of gigantic ladies I've ever laid eyes on. I find the most erotic part of a woman is the boo--",
#   'context/0': 'No big deal. Everybody make mistake.'},
#  {'response': "Great he's whacked out on electricity again.",
#   'context': "Oh, what a beautiful morning, oh what a beautiful day! Greetings, friends. Don't we all look nice today?",
#   'context/0': 'This is a witch hunt!'},
#  {'response': "What's the word...uh...sir?",
#   'context': 'Of course, my significant soldier. The bomb is voice activated. It will detonate the instant the robot unwittingly speaks a certain word.',
#   'context/0': 'Uh, commander? Could you tell me when the bomb is exploding?'},
#  {'response': 'What a pleasant surprise!',
#   'context': "Very good. I also would have accepted Blank? Blank?! you're not looking at the big picture!",
#   'context/0': "Don't you worry about blank let me worry about blank."},
#  {'response': 'Strike him out Leela! Do it for the hundreds of women everywhere!',
#   'context': 'Put it right down the pike!',
#   'context/0': 'Come on Leela!'},
#  {'response': "I don't get it, Michelle. The last time I saw you, you were doing great. You had just dumped me and you were well on your way to getting you life back on track. Why'd you freeze yourself?",
#   'context': 'Oh, Fry, it is you!',
#   'context/0': 'Who wants to know?'},
#  {'response': 'What?',
#   'context': "Uh-oh, jealousy. You think you're so hot!",
#   'context/0': "Hell, no! It's Leela's stupid feelings. Why can't she just drink herself happy like a normal person?"},
#  {'response': "If those aren't tears of happiness, please stop crying.",
#   'context': 'Wooo!',
#   'context/0': 'Yes! I mean no! Just make sure you get my nonchalant side!'},
#  {'response': "Junk? Maybe you can't understand this but I've finally found what I need to be happy, and it's not friends: It's things.",
#   'context': 'Yeah. Now are you gonna come to the squid fights with us or sit here wallowing in your prehistoric junk?',
#   'context/0': "But we're your friends and we live here in the year 3000."},
#  {'response': "They're OK.",
#   'context': "Oh, here's a cryogenic counsellor! Do you like Mondays?",
#   'context/0': "Delivery boy? I must have mixed up the chips. It's a simple mis -"},
#  {'response': 'There. Finished!',
#   'context': 'Show us this, the wheel.',
#   'context/0': 'Never heard of it.'},
#  {'response': 'Never mind Professor, she came to.',
#   'context': 'I was having the most wonderful dream. Except you were there and you were there and you were there.',
#   'context/0': 'Leela, are you alright? You got wanged on the head.'},
#  {'response': 'Are you still mad at me for wrecking your once in a lifetime chance to learn the meaning of your existence?',
#   'context': 'Come on. We have worked to do.',
#   'context/0': "Oh Leela. I feel terrible. If there's anything I can ever do - Gotcha! I won! I'm the greatest!"},
#  {'response': 'To the left! No to the up! U-turn, U-turn!',
#   'context': 'To the flying machine!',
#   'context/0': "I'm zeroing in on him. Bengay...mothballs......letters to the editor. It's the Professor!"},
#  {'response': 'One year later I gave Leela a diamond scrunchy, and we were married.',
#   'context': 'You really missed out on something Leela. That date was magical.',
#   'context/0': "You mean you flipped the coin too? And it was tails? So that's why you said you had to meet that ghost."},
#  {'response': "What's happening?",
#   'context': 'Time-out! Time-out!',
#   'context/0': 'Ladies and gentlemen, something very strange has just happened in this basketball game between space clowns and atomic monsters.'},
#  {'response': "What's with the specs Bender?",
#   'context': "C'mon, let's deal. You'll have plenty of time to talk when you're poor.",
#   'context/0': "And my wife doesn't know I have a job. I keep my personal and professional lives serparate."},
#  {'response': 'No knife can penetrate my skin-tanium armour.',
#   'context': "Let's see how much of a robot you really are!",
#   'context/0': "Fry! Don't be a hero! It's not covered by the health plan!"},
#  {'response': 'Oh yeah? Then what about this?',
#   'context': "It, uh, oo! Uh, hey sweetie, just go back to the castle and wait for me. She, she's nuts, I can morph into a 5-eyed alien and I kinda said I'd marry her. But I'm really a Cyclops and I'm really going to marry you.",
#   'context/0': 'Alkazar, why you are so late for our wedding? And why you have only one eye?'},
#  {'response': 'Christmas. You know? X-M-A-S.',
#   'context': 'What-mas?',
#   'context/0': 'Yeah, it really puts you in the Christmas spirit.'},
#  {'response': "Xmas, huh? Y'know this'll be my first Xmas away from home.",
#   'context': 'Oh, you mean Xmas. You must be using an archaic pronunciation. Like when you say ask instead of aks.',
#   'context/0': 'Christmas. You know? X-M-A-S.'},
#  {'response': 'How can you people be so blase? Here you are in the year 3000 or so, yet you just sit around like its the boring time I came from.',
#   'context': "We all feel like that all the time. You don't hear us gassin' on about it.",
#   'context/0': 'Big deal.'},
#  {'response': 'Aha! Cornered!',
#   'context': 'Alright, bird, you thought you could beat me in a game of wits. But you just met your equal.',
#   'context/0': "I'm telling you why. Santa Claus is coming to town!"},
#  {'response': "Ah, no one likes them at first but they'll grow on you.",
#   'context': "I don't know, I've had cow. Ew! Gross!",
#   'context/0': "OK, my friends. Get ready for the most delicious extinct animal you've ever tasted."},
#  {'response': "OK, my best friend's life is at stake. I can finally prove that I'm not a coward. Will you push me?",
#   'context': "We're here. I followed the bouncing balls. I'll keep the chopper at a safe altitude while you parachute down.",
#   'context/0': "This isn't a productive area of discussion."},
#  {'response': 'Ugh!',
#   'context': 'Nah, those lousy Moochers cleaned out our pantry. All they left was baking soda and capers. And here it is!',
#   'context/0': 'Dinner ready?'},
#  {'response': "Sir, I'm outfitting an expedition to a monestary high in the Himalayas. I'll need a long sleeved coat.",
#   'context': "What part of nay doesn't thou understand?",
#   'context/0': 'But, but Metal Lord.'},
#  {'response': "I don't know. Is it really you?",
#   'context': 'Fry? Is it really you?',
#   'context/0': 'Oh, my God!'},
#  {'response': "I'm not a robot! I'm not a robot!",
#   'context': 'Jeez, Red. Quit cowering. You call yourself a robot?',
#   'context/0': "Hey! Keep it down in there! I'm tuning my banjo!"},
#  {'response': 'Where?',
#   'context': "Sandstorm! We're in the eye of the storm!",
#   'context/0': "Hey, it's that barbecue's over sound again."},
#  {'response': "Uh, I'll have a coffee.",
#   'context': "I don't know you well enough to get into that. 300 please. Noon tomorrow. If you're late you only get to tread water in the scallop tank.",
#   'context/0': "Then why'd you become a whale biologist?"},
#  {'response': 'Oh, right. Plus, the magnet screws up your inhibition unit and makes you sing folk songs.',
#   'context': "Oh, no, I'm not going near it. Last time, that magnetic psycho nearly cut my head off.",
#   'context/0': 'Whale oil. Bender, lift it up to the can opener.'},
#  {'response': 'Tremble? I laugh. Nobody knows more about Star Trek than me!',
#   'context': 'Centuries ago, the videotaped adventures of the Enterprise crew rained down upon my planet. Over and over, I watched them. Especially the five with the energy beings. I am Melllvar! Seer of the tapes, knower of the episodes! Tremble before my encyclopaedic knowledge of Star Trek!',
#   'context/0': "Alright, you gas, what's the deal?"},
#  {'response': "Well Rudy, how'd you like this action?",
#   'context': 'No.',
#   'context/0': 'And remember when Mayor Giuliani cracked down on jaywalking?'},
#  {'response': 'Come on!',
#   'context': 'Please, no!',
#   'context/0': 'Tom Sawyer, you tricked me. This is less fun than previously indicated. Let this corny slice of Americana be your tomb for all eternity.'},
#  {'response': 'Hey, Bender?',
#   'context': "Come, Kif, it's time to begin our life as civilians. That's an order, soldier.",
#   'context/0': "No, it doesn't."},
#  {'response': "You don't have to get so mad, Leela.",
#   'context': "Alright, this is the third hose fight I've broken up today and the second one using actual hoses. Now move your lazy asses and start scrubbing the ship like I ordered you to.",
#   'context/0': 'Yeah?'},
#  {'response': "He's gonna blow.",
#   'context': "Rudolph's nose!",
#   'context/0': 'Watch out! His belly is shaking like a bowl full of nitro-glycerine!'},
#  {'response': 'Why would a robot need to drink?',
#   'context': "Well that's your job, whether you like it or not and it's my job to make you do your job whether I like it or not - which I do - very much! Now get to work! Life is good!",
#   'context/0': "Look, he's just a nobody who doesn't want to be a delivery boy. I'd really rather not force it on him."},
#  {'response': "I'll never remember that.",
#   'context': "Name's Old Man Waterfall. But most folks just call me Old Man.",
#   'context/0': 'Who are you, old man?'},
#  {'response': "How's that?",
#   'context': "Aw yeah, that's it. A little lower.",
#   'context/0': 'Uh...sure.'},
#  {'response': "I'm telling you, Leela was cool, she was in command, and when she kicked people it hurt. It really hurt.",
#   'context': 'Yeah it broke alright',
#   'context/0': 'Alright!'},
#  {'response': 'No. Make up some feelings and tell her you have them. Yes?',
#   'context': 'Then mating.',
#   'context/0': 'Well, tell her that. And then?'},
#  {'response': 'Its my old neighbourhood. Man, this brings back a lot of memories.',
#   'context': "It's the decaying ruins of Old New York. Welcome home, pal!",
#   'context/0': 'Good Lord! What is this?'},
#  {'response': "Oh, that. Maybe we'd better talk in private. I'll meet you in the closet.",
#   'context': 'So, what was it you wanted to talk about before we crashed anyway?',
#   'context/0': 'Ooh, sorry. I guess I control that arm.'},
#  {'response': 'Well, yeah. Robots are made of metal.',
#   'context': "Sure...right. Robot! Oh, Fry! My skin's all dry and clanky.",
#   'context/0': "You don't have a heart; you're a robot."},
#  {'response': "Yes I did Leels! And I'll tell you why. Because it grows the brand.",
#   'context': 'Did you approve that awful ad Fry?',
#   'context/0': "I don't even know what we do. Nah just kidding, what are like a bus or something?"},
#  {'response': "I don't see you anywhere.",
#   'context': "Hey, look. It's our old group picture.",
#   'context/0': "Mmm! And try one of these Popsicle sticks. They've absorbed quite a bit of flavour."},
#  {'response': 'Hmm. We lost Bender.',
#   'context': 'I should be the one in that grave!',
#   'context/0': "They buried your brother in the world heroes section? I'm impressed."},
#  {'response': 'Wow! You got that off the Internet? In my day the Internet was only used to download pornography.',
#   'context': "New York City: the year 2000. The most wasteful society in the history of the galaxy and it was running out of places to empty its never-ending output of garbage. The landfills were full. New Jersey was full. And so, under cover of darkness, the city put its garbage out to sea on the world's largest barge. The repulsive barge circled the oceans for 50 years but no country would accept it. Not even that really filthy one. You know the one I mean. Finally, in 2052, the city used its mob connections to obtain ",
#   'context/0': 'Ah! Just as I thought. The answer lies in this movie I found on the Internet.'},
#  {'response': "Who's the lucky lobsterina?",
#   'context': "I'm feeling less nuts, thank you, because tomorrow I will be depositing my jelly in the cloacal vents of a female. If you catch my drift.",
#   'context/0': "You're looking less nuts, crabby."},
#  {'response': "Uh, aren't we looking for your gargoyle?",
#   'context': "Oh it's 2:30, we can still catch the early bird dinner special.",
#   'context/0': 'Yo, Captain Cateracts, what are we doing here?'},
#  {'response': 'Go ahead. I deserve it. I wish those stupid racoons had never brought me to the future.',
#   'context': 'We could sing American Pie.',
#   'context/0': 'Well, here we are. Trapped for eternity.'},
#  {'response': 'Oh. How is it?',
#   'context': "No. There's already a soda like that: Soylent Cola.",
#   'context/0': 'My God. What if the secret ingredient ... is people?'},
#  {'response': "Then when I feel so stuffed I can't eat anymore, I just use the restroom, and then I can eat more.",
#   'context': 'I said later!',
#   'context/0': 'Would you like to take a moment to register me?'},
#  {'response': "Then I have no choice but to do something so pitiful and embarrassing that I'm ashamed to tell you about it.",
#   'context': "You're too late, Fry. I'm sharing Valentine's Day with a very special man. He's not Zapp Brannigan or anything!",
#   'context/0': "This is an emergency. Amy made Valentine's plans with some goon and I'm gonna be stuck there, lonely and miserable. Will you be my date, please?"},
#  {'response': 'But you just said--',
#   'context': 'Eight bucks.',
#   'context/0': 'Oh, yeah? Well I want one too.'},
#  {'response': 'Hey! You have no right to criticise the 20th century. We gave the world the lightbulb, the steamboat and the cotton gin.',
#   'context': 'Typical 20th century attitude.',
#   'context/0': 'The future is disgusting.'},
#  {'response': 'Bender, are you alright?',
#   'context': 'Fencing diamonds, Fixing cockfights, Publishing indecent magazines...',
#   'context/0': 'My ass has blisters from the slide.'},
#  {'response': "But won't that crush my bones?",
#   'context': "Relax, Fry. I'll simply spin you in a high-speed centrifuge separating out the denser fluid of His Highness.",
#   'context/0': "We've gotta get the Emperor out of your body before they kill you!"},
#  {'response': 'Thirty days hath September, April, June and ... wonder ... is that peanut butter ... what am I gonna do? Oh, God! What? What? What is it now?',
#   'context': "Oh, don't worry, Fry. I too once spent a nightmare-ish time in a robot asylum. But now it's nearly over. So long.",
#   'context/0': "Help me! For God's sake, help me!"},
#  {'response': 'Then where are we? You said you knew how to navigate.',
#   'context': "Captain, I don't think we're on Pluto any longer. In fact, we may have left space as we know it.",
#   'context/0': "Then let's fish."},
#  {'response': "So this is where they stick old people. It's horrific.",
#   'context': 'Prepare to be surprised.',
#   'context/0': 'Sounds nice.'},
#  {'response': 'Alright!',
#   'context': 'Welcome aboard, brother!',
#   'context/0': 'OK then, screw it.'},
#  {'response': "It's clovering time!",
#   'context': "You're twice the the he ever was.",
#   'context/0': "It's all lies every word of it! He wasn't original, he wasn't a Martian, he wasn't Philip Fry and since when is he a the?"},
#  {'response': "Then I must've fallen asleep.",
#   'context': 'No.',
#   'context/0': 'He must have used a sleep ray on me. Sleep rays exist in the future right?'},
#  {'response': 'When will that be?',
#   'context': "No food or drink allowed on the tour. You'll have to wait until you're partying with Slurms MacKenzie.",
#   'context/0': 'Uh, could I have some Slurm, please?'},
#  {'response': 'Ow! Thanks.',
#   'context': "I'll do it for you.",
#   'context/0': 'I feel like a rat. Here I am whining like a pig while all along Leela was lonely as a frog. I could kick myself.'},
#  {'response': "These new hands are great. I'm gonna break them in tonight.",
#   'context': 'The tongue tickles.',
#   'context/0': 'Keep your palms flat.'},
#  {'response': 'I get it!',
#   'context': 'And now, the women who Mom-opolises the robot industry...',
#   'context/0': "The secret is to scratch 'em really really hard!"},
#  {'response': 'What proof is this? Some huge number?',
#   'context': "Sorry but we're totally sealed in. Nothing can get in or out. Except millions of snakes. Here, have a pomergranate scnapps from my private distillery and start sharing fond memories of me, Bender.",
#   'context/0': 'Well rot in peace. Fry and I are leaving.'},
#  {'response': 'Leela, is the person that parrot is mimicking telling the truth by proxy?',
#   'context': "Leela told her parents. Leela's parents blabbed.",
#   'context/0': 'Zookeeper! How did you know our real identities?'},
#  {'response': 'Um, Leela?',
#   'context': 'Only a few more. Hey! I won free admission to Six Flags! Just one more reason we must survive this.',
#   'context/0': 'Want...to...engulf...Bender!'},
#  {'response': "I don't care how educational it is. Let's do it!",
#   'context': "Maybe I should take Fry on the Luna Rover ride. You get to wear a space suit and drive around on the surface. And the line's short because it's educational.",
#   'context/0': "Yeah! You're the kind of guy who visits Jerusalem and doesn't want to see the Sexeteria!"},
#  {'response': 'So what do you nerds want?',
#   'context': 'A school bus!',
#   'context/0': "You're travelling in a specially-equipped terrestrial transport module."},
#  {'response': "Wait a second. You're a bender, right? We can get out of here if you just bend the bars.",
#   'context': "Oh, we're trapped!",
#   'context/0': 'Yeah, you know the law: You gotta do what you gotta do.'},
#  {'response': "Mathematics of wanton burrito meals. I'll be there!",
#   'context': 'Same thing I teach every semester: The mathematics of quantum neutrino fields. I made up the title so that no student would dare take it.',
#   'context/0': "Oh, I don't know. Hey, Professor, what are you teaching this semester?"},
#  {'response': "Hey, don't blame me. You tried to force Guenter to be a human but he's an animal. He belongs in the wild. Or in the circus on one of those tiny tricycles. Now that's entertainment.",
#   'context': 'You what? After I spent months slaving over a hot monkey brain?',
#   'context/0': 'I guess he realised I was right when I told him to go back to the jungle.'},
#  {'response': 'Uh...',
#   'context': "As long as it's not about my eye.",
#   'context/0': 'Can I ask you a question?'},
#  {'response': "That's right, honey! Whatever you say.",
#   'context': 'No! Ancient Atlanta was more than just a Delta hub. It was a vibrant metropolis, the equal of Paris or New York.',
#   'context/0': 'I think it was just an airport. They had a place where you could buy nuts.'},
#  {'response': "What's so far-fetched about mermaids? I mean, there's all sorts of weird sea creatures here in the future. Like Dr. Zoidberg.",
#   'context': "You're simply hallucinating, you ... moron.",
#   'context/0': 'OK, Fry!'},
#  {'response': "Bees make honey and jelly? Huh. How come nothing humans make taste good? Help! I can't swim in jelly as far as I know!",
#   'context': 'Royal jelly. They feed it to the queen.',
#   'context/0': "Hey what's this goop?"},
#  {'response': 'Nothing in here but a couple of elephant skin rugs.',
#   'context': 'Where in funkytown is the professor?',
#   'context/0': "I've got a big, big thirst for human blood!"},
#  {'response': 'Uh, excuse me? I missed a few lectures. Uh, what subject is this?',
#   'context': "Good morning, class. I trust you've all prepared for today's final exam.",
#   'context/0': 'Sorry!'},
#  {'response': 'Shut up!',
#   'context': 'I do. I just want to say that today I got up and I had a piece of toast. Then I brushed my teeth--',
#   'context/0': 'Edna, have you anything to say before begins the Claw-Plach?'},
#  {'response': 'Here I come. Let me just-- One more taste.',
#   'context': 'Fry, untie us, quick!',
#   'context/0': 'Farewell! Oh, and congratulations again on winning the contest.'},
#  {'response': "I don't need them. Not when I have my antique videos, my bucket of fossilised KFC and 50 million dollars worth of anchovies.",
#   'context': "Fry please. My ponytail's caught in the door.",
#   'context/0': 'Just leave me alone.'},
#  {'response': 'Relax, mammal. My robotic software shall meet your calculatory needs. What is the meaning of this symbol?',
#   'context': "Robots don't say ye!",
#   'context/0': 'Fear not! For I shall assist ye!'},
#  {'response': "And another thing: You're using an awful lot of make-up there.",
#   'context': 'What business is it of yours?',
#   'context/0': "Why exactly did you shave your legs anyway? Are you expecting something to happen with your Valentine's date?"},
#  {'response': "That's a great idea! Crying.",
#   'context': 'What about crying?',
#   'context/0': 'Slightly. But my favourite so far is the bone-crushing.'},
#  {'response': "What is the meaning of this? We've got a delivery people, let's move, let's move! Amy? Mission profile? Interesting, interesting. Dr Zoidberg, mission bag?",
#   'context': 'Dr Zoidberg, soaking in brine.',
#   'context/0': 'Delivery boy Philip J. Fry reporting for duty.'},
#  {'response': "Ooh! What's this?",
#   'context': 'Psst! You want to buy organ? Fresh and cheap. Ready for transplant!',
#   'context/0': "Come on, man, don't hold out on me like this!"},
#  {'response': 'My God! This mean the flying saucer that crashed in Roswell...was...us!',
#   'context': "That's no flying saucer, that's my ass!",
#   'context/0': 'No over here! Flying Saucer Captured!'},
#  {'response': 'So?',
#   'context': 'You see Emperor Plon here? He met his end when he was drunk by Emperor Strug. And before he could even wipe his mouth, Strug was drunk by Shwab.',
#   'context/0': "Fry, I have to talk to you. You're in terrible danger."},
#  {'response': "So? I'm just as important as him. It's just that, the kind of importance I have, it doesn't matter if I...don't do it.",
#   'context': "I do go! He's a very important man.",
#   'context/0': 'Ooo, you go mutant girl!'},
#  {'response': 'No fair!',
#   'context': 'Punishment?',
#   'context/0': 'Let the punishment commence!'},
#  {'response': "Hi Leela! I'm just gonna keep talking, even if you can't hear me. Blah blah blah, blah blah blah blah blah.",
#   'context': "No no, no one's saying that! But I'm certainly thinking it loudly.",
#   'context/0': "Are you saying I'm going crazy?"},
#  {'response': 'Yowza! I know what I want for dessert!',
#   'context': 'See that waitress there?',
#   'context/0': "Man, them crackers cut my mouth up somethin' bad! Let's stop off for a malt!"},
#  {'response': "OK, we're in the middle of nowhere, which is the safest part of nowhere. Just stay put and enjoy this calendar.",
#   'context': "For me it is! I'm getting you out of here!",
#   'context/0': "Well, it ain't as bad as getting killed!"},
#  {'response': 'I learned how to work the gravity pump too. In case we need to move more stars. So are we dating now?',
#   'context': "Yeah, actually. You're doing OK. The core reactor temperature's nominal, the blinker's off.",
#   'context/0': "Look. I've been studying how to pilot the ship. Impressed?"},
#  {'response': 'Mighty sir, we have nowhere to go. Could we please join your society?',
#   'context': 'FRY',
#   'context/0': 'OK.'},
#  {'response': 'Good news everyone!',
#   'context': 'Stop!',
#   'context/0': "You are not fit to wear Fry's leotard!"},
#  {'response': 'I hate my life I hate my life I hate my life.',
#   'context': "It's not working out, Fry. I put your stuff out on the sidewalk!",
#   'context/0': 'Michelle, baby! Where you going?'},
#  {'response': "Wow! That ice dispenser's so big, the ice crushes you! Yakov Smirnov said it!",
#   'context': 'Deploying ice drill.',
#   'context/0': "Yes there's no safer occupation than mining. Especially when you're on a snowball whipping through space at a million miles an hour! Safe!"},
#  {'response': "He's dead.",
#   'context': "I was so busy being an 80's guy, I forgot to cure it. My only regret is...that I have...boneitis!",
#   'context/0': 'Oh my God! His boneitis!'},
#  {'response': 'So what were they doing to you in that awful drawer?',
#   'context': "I'm as spry as a 140 year old. See? I only broke one ankle.",
#   'context/0': 'All right!'},
#  {'response': "Man, I thought Ultimate Robot Fighting was real, like pro wrestling. But it turns out it's fixed, like boxing.",
#   'context': "So then I said, See you at the fight. And that's the story.",
#   'context/0': 'See you at the fight.'},
#  {'response': "I can't believe this. Bender is supposed to murder his closest friend, which I thought was me. But he went straight for you. He didn't even try to second-degree murder me.",
#   'context': 'You jerk. I thought I was your best friend. What kind of two-timing kill-mobile are you?',
#   'context/0': 'Fry, stay back!'},
#  {'response': 'OK.',
#   'context': 'Yeah, anyone who misses this will regret it for the rest of his life! Hey Fry could you go make some popcorn?',
#   'context/0': "I've never seen a supernova blow up. But if it's anything like my old Chevy Nova, it'll light up the night sky!"},
#  {'response': "Dear Horse God, I know I don't usually pray to you, sometimes I doubt you even exist. But if you're willing to grant me luck, please, stamp your hoof once. Come on number six move it! Don't do that! What are you - Man it's contagious!",
#   'context': 'This.',
#   'context/0': 'Hey what are you doing?'},
#  {'response': 'Banana, banana, banana!',
#   'context': 'Consider the philosophical and metaphysical ramifications of the--',
#   'context/0': 'No, the banana, the banana!'},
#  {'response': "Look, Guenter, if you're so miserable here, maybe you should just go back to the jungle.",
#   'context': "They can't. It's all the hat.",
#   'context/0': "That's so sad. I didn't even know monkeys could cry."},
#  {'response': 'Uh, not everything.',
#   'context': 'Feeling responsible for your death was driving me mad. But now everything is alright.',
#   'context/0': 'Me too.'},
#  {'response': 'I love this job.',
#   'context': 'Like what?',
#   'context/0': 'I woke you up early so we could hang out and do stuff.'},
#  {'response': "Who's it going to?",
#   'context': "Good news, everyone. We've got a very special delivery today.",
#   'context/0': 'By J. Stewart Burns Transcribed by Dave, The Neutral Planet'},
#  {'response': "That's great! What's the little guy's name?",
#   'context': '...great great great great great nephew.',
#   'context/0': "Interesting. Your DNA test shows one living relative. He's your great great great great great great great..."},
#  {'response': 'Who?',
#   'context': 'That is most wise.',
#   'context/0': "Sorry, what? I wasn't paying attention."},
#  {'response': 'Yup. We call them land-sealions ... I tame them!',
#   'context': 'Lions? There are sealions on the land?',
#   'context/0': "You know what I like best about you, Umbriel? You find me fascinating even when I'm not claiming to be a jewel thief or a lion tamer."},
#  {'response': 'Phew!',
#   'context': "Spluh! It's a video-phone. Lucky I'm a member of the Astro-Afro-Antarctico-Amer-Asian Auto Association. Hello? Septuple-A?",
#   'context/0': 'What are you doing?'},
#  {'response': "Wait! I'm usually the first guy to toot my own lower horn -",
#   'context': 'Remove pants!',
#   'context/0': 'Then bring it to our royal bedchamber and put it in the sock drawer with all the other things that have failed to arouse my passion for this woman.'},
#  {'response': 'Cool. Can I try these on before I buy them?',
#   'context': 'What a lovely face. We just need to draw attention away from the eye area.',
#   'context/0': 'No thanks I --'},
#  {'response': "That's the one.",
#   'context': 'Labor Day? That phoney-baloney holiday crammed down our throats by fat-cat union gangsters?',
#   'context/0': "Ow! Hey, quit it, Hermes. It's Labor Day."},
#  {'response': 'Now let us each remember the best things about Bender in our own way. Professor?',
#   'context': 'Aww, you knew my favourite cause of death!',
#   'context/0': 'Dearly beloved, we are here today to remember Bender, taken from us in the prime of life, when he was crushed by a runaway semi, driven by the Incredible Hulk.'},
#  {'response': 'You know? 1966? 79 episodes, about 30 good ones.',
#   'context': "I have absolutely no idea what you're talking about.",
#   'context/0': "Mr. Nimoy, I came as soon as I heard what happened centuries ago. I can't believe your show was banned."},
#  {'response': 'Pizza delivery for Mr......Seymour Asses.',
#   'context': 'Yes?',
#   'context/0': "Don't wave your fancy degrees at me. I recognise all this stuff. Petrified sausages, Old Mr Patelli, and that's"},
#  {'response': "Trust me on this. While other people were out living their lives, I wasted mine watching TV, because deep down I knew it might one day help me save the world. Plus, I would have lost my Workman's Comp if I hadd gone outside. Now just read these cue cards.",
#   'context': "Whatchoo talkin' 'bout, Fry?",
#   'context/0': "You see? TV audiences don't want anything original. They wanna see the same thing they've seen a thousand times before."},
#  {'response': 'Ow! No! Quit it! Stop it!',
#   'context': "It's too grumpy!",
#   'context/0': 'The...Grumpy Snail. Sorry.'},
#  {'response': "Check it out everyone. I'm back from hell and I've got the Robot Devil's hands!",
#   'context': "Oh sorry, that'll wear off in a couple of days.",
#   'context/0': 'At last! At last I have the power to make Leela love me.'},
#  {'response': "Stupid slug. I've never been so thirsty. Oh, come on! Go down already! Ah!",
#   'context': "Jeez, will you lay off! I was delivering things before you were born! I think I know what I'm doing.",
#   'context/0': "Don't touch anything or talk to anyone. Just go to the palace, drop it off and come right back."},
#  {'response': 'Hmm, you got any sacred artwork of her from the back?',
#   'context': 'This sacred mosaic depicts our goddess of beauty.',
#   'context/0': "There's so much information and yet somehow I feel as if I know it all already."},
#  {'response': "Then today's your lucky day because I happen to be a holding, stroking, lovin' machine! Also spankin'!",
#   'context': 'I told a whole crowd today that being an orphan made me strong. But all I really wanted was a mom and dad, to hold me and stroke my hair and tell me they loved me.',
#   'context/0': 'Yeah, I do that with my stupidness.'},
#  {'response': 'Who are you monsters? Is one of you Icy Wiener?',
#   'context': 'Hey, look! An ugly scared guy! Boo!',
#   'context/0': 'It appears that the very fabric of space-time has ripped.'},
#  {'response': "You're right. Let's do this now and let's never regret it.",
#   'context': 'Fry, why must you analyse everything with your relentless logic? Nothing matters but our love.',
#   'context/0': 'Well, sure. To the extent a man can love a woman. But this seems like a big step.'},
#  {'response': 'But you live in a gingerbread house.',
#   'context': "Hey, you got any food? Old teabags, chewed gum, apple cores? Come on! We're starving here!",
#   'context/0': 'You hit me! You owe me a dollar.'},
#  {'response': "Oh Leela. I feel terrible. If there's anything I can ever do - Gotcha! I won! I'm the greatest!",
#   'context': "Fry, you idiot. Ever since I was abandoned on Earth I've been searching for who my people are and where they come from. Then I finally meet another Cyclops and you blast him. You wrecked my one chance to learn who I am.",
#   'context/0': 'Do you think perhaps you and I - ?'},
#  {'response': 'Uh, Fry.',
#   'context': 'Good afternoon, sir. Name?',
#   'context/0': 'Cool! Just like in Star Trek! Ow!'},
#  {'response': "No I'm...doesn't.",
#   'context': 'I heard alcohol makes you stupid.',
#   'context/0': "We're making beer! I'm the brewery."},
#  {'response': "I can't believe it! How'd you all end up here?",
#   'context': 'Ever since then, Welshy has been a welcome participant in our escapades.',
#   'context/0': "We did some musical reunion specials in the 2200's but the guy who played Scotty had trouble yodelling."},
#  {'response': "Valentine's Day's coming? Oh, crap! I forgot to get a girlfriend again. Well since neither of us has a date, why don't we...",
#   'context': "Myself. I asked myself a Valentine's Day off. But I was in no mood for any of my shenanigans.",
#   'context/0': 'Hermes. Who were you yelling at?'},
#  {'response': 'Yeah! An old-fashioned Xmas tree!',
#   'context': 'Hey, hey. Let me aks you something: Would it cheer you up if we went and cut down an Xmas tree?',
#   'context/0': "Xmas, huh? Y'know this'll be my first Xmas away from home."},
#  {'response': "Relax! She can't be my grandmother! I figured it all out.",
#   'context': 'What the hell have you done Fry?',
#   'context/0': 'Eurgh!'},
#  {'response': "Sure when he's sober!",
#   'context': 'He seemed nice.',
#   'context/0': "The short answer is I'm teaching."},
#  {'response': 'My hands. My horrible human hands. And what did you do to my nails?',
#   'context': 'Surgery in an opera? How wonderfully decadent and just as I was beginning to lose interest. The chocolate icing! Oh my!',
#   'context/0': 'No! Stop! Take my hands! You evil metal dork!'},
#  {'response': 'What about me? Can I come back at severely reduced pay?',
#   'context': "It's better than nothing!",
#   'context/0': "Well, it looks like I'll be needing my heroic bureaucrat back. At severely reduced pay of course."},
#  {'response': 'Whoa!',
#   'context': 'See you in a thousand years! You owe me one.',
#   'context/0': "Hold still, damnit. I don't have good depth perception! You've got until the count of five to let me out of here. One..."},
#  {'response': 'I woke you up early so we could hang out and do stuff.',
#   'context': "Hey, listen, skippy. I was supposed to be unfrozen in Hollywood for the thousandth anniversary screening of Jury Duty II. How come I'm not there?",
#   'context/0': 'The weasel?'},
#  {'response': 'Aww I know how you feel. My grandfather died recently.',
#   'context': 'Every little thing reminds me of Enos.',
#   'context/0': 'Hooray!'},
#  {'response': 'And I can deliver them. Billions and billions in one night.',
#   'context': 'Toys! Toys! Toys!',
#   'context/0': 'Now we can make toys again!'},
#  {'response': "Uh I can't get any lower than this.",
#   'context': "Lower. Yeah that's it. A little lower though.",
#   'context/0': "How's that?"},
#  {'response': 'Nothing like a power nap.',
#   'context': "Oh, good. Then you won't mind if I use this.",
#   'context/0': 'We have a cure for it now!'},
#  {'response': 'No, you have a healthy glow.',
#   'context': "I'm really starting to swell up with beer. I must look ridiculous.",
#   'context/0': 'More like seven!'},
#  {'response': "Well, I'm older than you. I can beat you up.",
#   'context': 'On what grounds do you challenge my authority?',
#   'context/0': "Alright, alright. If it'll make you happy, I'll overthrow society."},
#  {'response': 'I said later!',
#   'context': 'Would you like to take a moment to register me?',
#   'context/0': 'So uh, what do you feel like doing?'},
#  {'response': "I can't believe it. She's risking her life for me after the way I treated her. I don't deserve this. I feel terrible.",
#   'context': 'Oh, no. They have her totally outnumbered.',
#   'context/0': 'Wait a second. Here comes Leela.'},
#  {'response': "Fancy cigar why don't you smoke it already? Puff puff go go go go go!",
#   'context': 'Ah! Mighty fine smokable!',
#   'context/0': "Of course I've been up all night! Not because of caffine it was insomnia I couldn't stop thinking about coffee I need a nap. Coffee time!"},
#  {'response': "Wait, I'll be back in a minute.",
#   'context': "We're all gonna die!",
#   'context/0': 'That should do it.'},
#  {'response': 'Yeah.',
#   'context': 'Was it out in front of Discount Shoe Outlet?',
#   'context/0': 'I just saw something incredibly cool. A big floating ball that lit up with every colour of the rainbow, plus some new ones that were so beautiful I fell to my knees and cried.'},
#  {'response': 'Well, usually on the show someone would come up with a complicated plan then explain it with a simple analogy.',
#   'context': "I didn't wanna leave them either, Fry, but what are we supposed to do?",
#   'context/0': "I dunno, I'm feeling pretty good about it."},
#  {'response': 'Fight it!',
#   'context': "Then what am I s'posed to do?",
#   'context/0': "Leela! No! Listen to me, you don't want to lie in bed like a vegetable and do nothing the rest of your life. I've tried it. Bedsores hurt!"},
#  {'response': 'Its OK, I had another guy!',
#   'context': 'Oh my god, he ate Fry! Fry is dead!',
#   'context/0': 'Uh oh!'},
#  {'response': 'Lets go, already!',
#   'context': "Guh! It's the happiest place orbiting Earth.",
#   'context/0': "You're not gonna believe this but they landed an amusement park on the moon!"},
#  {'response': "Owww! That...didn't hurt.",
#   'context': "Hey Captain Yesterday, can I like, wail on you with this 2x4 and it doesn't hurt you?",
#   'context/0': 'Man, this costume is so damn heavy!'},
#  {'response': 'Stop being such a baby and chop my hands off.',
#   'context': "Y'know I only put my name on there as a show of good faith for the other robots.",
#   'context/0': "It's not ironic it's just coincidental. Now fork over those lady-fingers cookie!"},
#  {'response': 'Yo yo, Bezender! What up?',
#   'context': "I know. Sometimes when I'm lonely, I look up at the sky and I get this feeling that somewhere, on some unknown planet, circling a distant star, my parents are up there, looking down on me.",
#   'context/0': 'Well, anyway, just remember that people care about you.'},
#  {'response': 'Pfft. A female leader?',
#   'context': 'We take them to our leader. She know what do.',
#   'context/0': 'Women go free. Men stay in chains.'},
#  {'response': "Leela could beat that. She's pitched her whole career without getting an out.",
#   'context': 'Low? It was zero you fungo! You went your whole career without getting a hit.',
#   'context/0': 'Well, I have a low batting average.'},
#  {'response': 'Affirmative. I feel nothing. I am a robot. Beep, beep, beep',
#   'context': "You'll notice he no longer suffers delusions of humanity.",
#   'context/0': 'Thank God!'},
#  {'response': 'Shh! What was that sound?',
#   'context': 'Oh Lord. Hiking is always such a strain on the buttocks.',
#   'context/0': 'By Ron Weiner Transcribed by Dave, The Neutral Planet'},
#  {'response': "Leela! No! Listen to me, you don't want to lie in bed like a vegetable and do nothing the rest of your life. I've tried it. Bedsores hurt!",
#   'context': "OK, I'm insane! But I'm still sane enough to know it. The only time I feel alright is in my dreams. With you. Three spoonfuls. Then I can dream forever. One. Two Here goes. Goodbye waking world.",
#   'context/0': 'You killed Fry!'},
#  {'response': "Alright, here's the plan--",
#   'context': 'Move! Go!',
#   'context/0': 'Oh, your God!'},
#  {'response': 'And no one will have to punish anyone for the mutiny.',
#   'context': 'You did it! You actually did it!',
#   'context/0': 'Quick.'},
#  {'response': 'Third date!',
#   'context': 'Do I ask her to mate now?',
#   'context/0': "...And then you threw an octopus at my window. You know, Zoidberg, it's crazy but when you talk this way your obvious deficiencies as a male seem ... less obvious. Your genes seem less detrimental. You even stink more."},
#  {'response': 'Bender! Think of the seoritas!',
#   'context': "Eh, I don't know.",
#   'context/0': 'We gotta go rescue them!'},
#  {'response': 'Whoa! Check out that guy. He makes Speedy Gonzales look like Regular Gonzales.',
#   'context': "What's the matter, private? Tent got your tongue? Tent got your... Kif, write that down and send it to Humour In Uniform.",
#   'context/0': 'They look like dorks!'},
#  {'response': 'Ah, futuristic!',
#   'context': "Uh, Fry, you're in the womens' steam room.",
#   'context/0': 'Co-ed steam rooms! I love the future!'},
#  {'response': "Obviously you've never been in love! Ow! Ow! Ow! Now, the hand-eye co-ordination lobe.",
#   'context': "He's bluffing. No creature would willingly make an idiot out of itself.",
#   'context/0': 'Everyone out of my body or the brain gets it!'},
#  {'response': 'You OK there in the embassy, Zoidberg?',
#   'context': "Wait, you're a lawyer? You're hired!",
#   'context/0': "I don't condone what Dr. Zoidberg did but I'll fight tooth and nail for his freedom to do it. Or I would if I hadn't lost my teeth and nails on Mars and Saturn respectively."},
#  {'response': 'Wow The jungles on Mars look just like the jungles on Earth.',
#   'context': 'Hey!',
#   'context/0': 'Fraternities, on your marks.'},
#  {'response': 'Thanks. Where is she?',
#   'context': 'Thanks.',
#   'context/0': 'That dress looks great on you.'},
#  {'response': "No you can't. Shut your adorable trap!",
#   'context': 'We can explain!',
#   'context/0': 'You little runts froze me! You took away my life!'},
#  {'response': 'And action!',
#   'context': "Trust me on this. While other people were out living their lives, I wasted mine watching TV, because deep down I knew it might one day help me save the world. Plus, I would have lost my Workman's Comp if I hadd gone outside. Now just read these cue cards.",
#   'context/0': "Whatchoo talkin' 'bout, Fry?"},
#  {'response': 'Think about it. Seymour lived a full life after I was gone. He probably added new songs to his repertoire.',
#   'context': "Fry, what's wrong?",
#   'context/0': "Oh sure! Smash the smart guy's machine!"},
#  {'response': 'Even bigger than those? Holy nuts! Where is it?',
#   'context': 'You go fight biggest brain of all.',
#   'context/0': 'No, Leela. Brain make people smart.'},
#  {'response': "Nope, I'm better than ever. Before the accident I couldn't do this!",
#   'context': 'Fry? I thought you were dead.',
#   'context/0': 'Leela?'},
#  {'response': 'Same thing.',
#   'context': "Bender's not a guy, he's a robot.",
#   'context/0': "Don't girl me with that girl stuff. Bender and me are guys. Guys don't have feelings."},
#  {'response': 'Leela back yet?',
#   'context': "Too bad Nibbler's not around. I guess I'll have to eat this raw, dripping ham by myself. Nibbler? Nibbler, you're scaring me. Nibbler?! Am I going crazy? Have my years of wild hedonism finally caught up with me? Nibbler, help! Don't leave me here. Uh, Nibbler? Could you scooch the seat up just a little bit?",
#   'context/0': 'No! Nibbler, come back!'},
#  {'response': 'Yeah!',
#   'context': 'A portion of the proceeds might go to help broken robots.',
#   'context/0': 'Tuesday, Golden Gate Park, the monsters of vaguely folkish alterna-rock will strum your brains out at Bend-Aid! Featuring Beck, Wailing Fungus and special guest, Bender!'},
#  {'response': 'I just wanted to do something to make you happy. I mean, I miss my family but you never even had a family.',
#   'context': "You didn't need to buy me a present, Fry.",
#   'context/0': 'Leela! Oh, my God! You saved my life. I am gonna get you so many lizards.'},
#  {'response': 'Hey, business is great.',
#   'context': "Bender's a genius.",
#   'context/0': 'Good idea.'},
#  {'response': 'Hooray!',
#   'context': "Bad news everyone. You're not good enough to go on your next mission.",
#   'context/0': 'A hush comes over the crowd. The only sound is Bender calling everyone else a jerk and he swings! And he slices it into the water, oh man!'},
#  {'response': 'I wanna hear a space story!',
#   'context': 'There. Todays story is from New Teen magazine. What would you rather hear about? Four legged Chachi or tentacled Chachi?',
#   'context/0': "I can't see from down here I can't."},
#  {'response': 'You alright, Bender?',
#   'context': "Ow, my head! My precious head! Stupid can opener. You killed my father and now you've come back for me!",
#   'context/0': 'Is it me?'},
#  {'response': 'Ow!',
#   'context': "Fry, that's offensive to our people. Isn't it?",
#   'context/0': "Is that anything like a cemetary 'cause I gotta take a leak. Ow!"},
#  {'response': 'Yeah, Leela.',
#   'context': "You left the keys in the ignition. I mean, look at those two. Wasn't it obvious what would happen?",
#   'context/0': 'What did I do?'},
#  {'response': "Then she wants me as a trophy husband. Leela, you gotta come to Europa with us, I can't be alone with her.",
#   'context': "Fry, she's pulling down billionaire trust-fund money.",
#   'context/0': "Am I? Face it, I'm a prize catch. I mean, I'm pulling down delivery boy money."},
#  {'response': "My nose is an aphrodisiac? I'm gonna drop a barf!",
#   'context': 'The valuable nose or human horn fetches a high price on alien worlds as an aphrodisiac.',
#   'context/0': 'The culprits: Shameless poachers, hunting humans without a permit.'},
#  {'response': "Apology accepted. After all, you're only human.",
#   'context': "You're my best friend, Fry, I'm sorry I treated you so badly.",
#   'context/0': "She's right."},
#  {'response': 'Uh, cheese and a -- That was quick!',
#   'context': 'Oh, right! Cheese pizza and a large soda!',
#   'context/0': 'Soda!'},
#  {'response': "Look, so we're not millionaires. At least we all still get to work together!",
#   'context': "Aha! Once again the conservative sangwich-heavy portfolio pays off for the hungry investor! Oh! I'm ruined. Why? Why?",
#   'context/0': "It is? Yahoo! We're poor no matter what I do! The deal is off!"},
#  {'response': "Phil wins! Yancy's fans are stunned! There'll be no celebration at the Yancy dome!",
#   'context': "I'm dying of old age!",
#   'context/0': 'Holy camolie! A seven leaf clover!'},
#  {'response': 'Yeah. Give a little credit to our public schools.',
#   'context': "As unclean as it makes me feel, I agree with Bender. Kids don't turn rotten just from watching TV.",
#   'context/0': "Whoa, whoa, whoa. You can't censor me just 'cause I'm an obscenely bad role model."},
#  {'response': "Wow Bender. Are you and the ship an item? I mean I know you're both items but...how can you date a ship anyway? It'd be like me dating a really fat lady. And living inside her. And she'd be all like...",
#   'context': "It's not what it looks like. Bender was just helping me...zip up my turbine.",
#   'context/0': "Bender! What's going on in here? Planet Express Ship! Cover your shame!"},
#  {'response': "So, Leela, how about a romantic ride in one of those swan boats? They're kinda dangerous but I finally mastered them.",
#   'context': 'Go get it, boy!',
#   'context/0': 'By Ken Keeler Transcribed by Dave, The Neutral Planet'},
#  {'response': "Aw hey c'mon don't worry. We'll watch you clean up.",
#   'context': "Oh! I'll never pass inspection now! They'll bust me lower than a limbo stick - at carnival time. And that's as low as limbo sticks get.",
#   'context/0': 'Uh, it was ghosts! Big ones! And a tornado!'},
#  {'response': "Yeah, that'd be a timesaver.",
#   'context': "That'll take forever. What she oughta do is find a nice guy with two eyes, then poke one out.",
#   'context/0': "I bet you Leela's holding out for a nice guy with one eye."},
#  {'response': "Shall we say 8 o'clock?",
#   'context': "You just assume I can't get a Valentine's date?",
#   'context/0': "Valentine's Day's coming? Oh, crap! I forgot to get a girlfriend again. Well since neither of us has a date, why don't we..."},
#  {'response': "Let's just forget about the box. The Professor said to stay away.",
#   'context': 'Whatever.',
#   'context/0': 'Right! If they try to look in the box.'}]

# %%
lines_selected_list.append(['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'])
lines_selected_list.append(["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.", "It'll be a rich, full day.", 'FTM'])
lines_selected_list.append(["I'm too scared.", 'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!', 'FTM'])
lines_selected_list.append(['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'])
lines_selected_list.append(['Fry, thank God we found you.', 'Leela? What are you guys doing here in the year 4000?', 'FTM'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP'],
#  ['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'],
#  ["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   "It'll be a rich, full day.",
#   'FTM'],
#  ["I'm too scared.",
#   'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'FTM'],
#  ['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'],
#  ['Fry, thank God we found you.',
#   'Leela? What are you guys doing here in the year 4000?',
#   'FTM']]

# %% [markdown]
# ## Vader

# %%
temp = select_lines(characters[4])
# Out:
# Using custom data configuration default-8c85b46caa75ae36
# Downloading and preparing dataset csv/default to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-8c85b46caa75ae36\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-8c85b46caa75ae36\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
[s for s in temp['test']]
# Out:
# [{'response': 'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'context': 'I will not fight you.',
#   'context/0': 'You cannot hide forever, Luke.'},
#  {'response': 'Did you find any droids?',
#   'context': 'Unlock one-five-seven and nine.Release charges.',
#   'context/0': 'They must be trying to return thestolen plans to the princess. Shemay yet be of some use to us.'},
#  {'response': 'They must never again leave thiscity.',
#   'context': 'Lord Vader, what about Leia and theWookiee?',
#   'context/0': 'He will not be permanently damaged.'},
#  {'response': 'All to easy. Perhaps you are not as strong as the Emperor thought.',
#   'context': 'No!',
#   'context/0': 'Your destiny lies with me, Skywalker. Obi-Wan knew this to be true.'},
#  {'response': 'Sister! So...you have a twinsister. Your feelings have now',
#   'context': 'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'context/0': 'I will not fight you.'},
#  {'response': "I've been waiting for you, Obi-Wan. We meet again, at last. The circle is now complete.",
#   'context': 'Open the blast doors! Open theblast doors!',
#   'context/0': 'Close the blast doors!'},
#  {'response': 'They are clear, my Master.',
#   'context': 'Strange, that I have not. I wonder if your feelings on this matter are clear, Lord',
#   'context/0': 'I have felt him, my Master.'},
#  {'response': 'I have you now.',
#   'context': "Vader's targeting computer swings around into position.",
#   'context/0': "Luke's ship barrels down the trench."},
#  {'response': 'That is correct, Commander. And heis most displeased with your',
#   'context': "The Emperor's coming here?",
#   'context/0': 'Then perhaps you can tell him when'},
#  {'response': 'Obi-Wan is here. The Force is withhim.',
#   'context': 'The princess! Put all sections onalert!',
#   'context/0': 'Governor Tarkin, we have anemergency alert in detention blockA A-twenty- three.'},
#  {'response': 'Obi-Wan has taught you well.',
#   'context': 'Good.Use your aggressivefeelings, boy!Let the hate flowthrough you.',
#   'context/0': "Chewie!Get down here!She'swounded!No, wait....I got anidea."},
#  {'response': "Don't underestimate the power ofthe Force.",
#   'context': 'Surely he must be dead by now.',
#   'context/0': 'A tremor in the Force. The last time I felt it was in the presence of my old master.'},
#  {'response': 'No. Leave them to me. I will deal',
#   'context': 'Shall I hold them?',
#   'context/0': "It's an older code, sir, but itchecks out. I was about to clear"},
#  {'response': 'The Empire will compensate you if he dies. Put him in!',
#   'context': "What if he doesn't survive? He's worth a lot to me.",
#   'context/0': "You're being put into carbonfreeze."},
#  {'response': 'He will come to me?',
#   'context': 'Then you must go to the Sanctuary',
#   'context/0': 'They are clear, my Master.'},
#  {'response': 'I have felt him, my Master.',
#   'context': 'Are you sure?',
#   'context/0': 'My son is with them.'}]

# %%
lines_selected_list.append(['I will not fight you.', 'Give yourself to the dark side. It is the only way you can save your friends. Yes, your', 'SW'])
lines_selected_list.append(['Lord Vader, what about Leia and theWookiee?', 'They must never again leave thiscity.', 'SW'])
lines_selected_list.append(["The Emperor's coming here?", 'That is correct, Commander. And heis most displeased with your', 'SW'])
lines_selected_list.append(['Shall I hold them?', 'No. Leave them to me. I will deal', 'SW'])
lines_selected_list.append(['Lord Vader, what about Leia and theWookiee?', 'They must never again leave thiscity.', 'SW'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP'],
#  ['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'],
#  ["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   "It'll be a rich, full day.",
#   'FTM'],
#  ["I'm too scared.",
#   'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'FTM'],
#  ['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'],
#  ['Fry, thank God we found you.',
#   'Leela? What are you guys doing here in the year 4000?',
#   'FTM'],
#  ['I will not fight you.',
#   'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ["The Emperor's coming here?",
#   'That is correct, Commander. And heis most displeased with your',
#   'SW'],
#  ['Shall I hold them?', 'No. Leave them to me. I will deal', 'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW']]

# %% [markdown]
# ## Joy

# %%
temp = select_lines(characters[5])
# Out:
# Using custom data configuration default-07e325241d88ad1f
# Downloading and preparing dataset csv/default to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-07e325241d88ad1f\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to D:\University\Esami da Superare\Natural Language Processing\BarneyBot\BarneyBot\cache\csv\default-07e325241d88ad1f\0.0.0\433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
[s for s in temp['test']]
# Out:
# [{'response': 'Oh, yknow what? Since Im here, I think Im gonna have me a little beer on the port side.',
#   'context': 'No! No-no, no-no-no, very quiet, said with love, no yelling.',
#   'context/0': 'Okay! Okay, youre yelling again! See that?'},
#  {'response': 'Hey come on now, this is a real date. Uh, sonice place you got here. Foosball, huh? Pizza box. Oh, a subscription to Playboy, my kind of woman.',
#   'context': 'Oh man! This is so great! I actually feel like Im going on a real date! Although, I have a hint of morning sickness, and Im wearing underwear that goes up to aboutthere.',
#   'context/0': 'And, a brownie!  Well, half a brownie. Actually, its just bag. Its been a long walk from the flower shop and I was startin to feel faint so'},
#  {'response': 'No.  I was told the name of the movie would not appear on the bill!',
#   'context': 'Oh! Joey uh, were you in our room last night?',
#   'context/0': 'Hey!'},
#  {'response': 'We cant watch that! I mean thats Phoebe!',
#   'context': 'Wh-what, why?',
#   'context/0': 'All right well, Id better take that back.'},
#  {'response': "Guess I don't know. My experience: if a girl says yes to being taped... She doesn't say no to much else, I tell ya...",
#   'context': "Allright, I'm gonna watch it... I mean look, it's probably not even what I think it is... And even if it is... It can't possibly be as bad as what I'm picturing in my head...  Can it?",
#   'context/0': 'How did she get me to settle down?'},
#  {'response': "Yeah! How you doin'? Yeah alright!",
#   'context': "David, I'm pretending to read here!!",
#   'context/0': 'How do you think I should propose?'},
#  {'response': "Okay, buddy-boy. Here it is. You hide my clothes, I'm wearing everything you own.",
#   'context': 'Is it wrong that I was totally aroused by that?',
#   'context/0': "She's just getting dressed."},
#  {'response': "You got it. Thanks man. Thanks for doing this, I owe you one.  Oh, hey! There wasn't any change from that twenty, was there?",
#   'context': "No, it's a book that's just a book, okay? It's an early edition of the Velveteen Rabbit. It was her favorite book as a kid. So, uh, just... let me know if she likes it, okay?",
#   'context/0': "Is it like a book that's also a safe?"},
#  {'response': 'What?',
#   'context': 'Joey, there was a little girl who lived here, but she died like 30 years ago.',
#   'context/0': 'Oh well, the little girl who lives here made me feel a lot better about the whole thing.'},
#  {'response': 'Over the line?! You-youre-youre so far past the line, that you-you cant even see the line! The line is a dot to you!',
#   'context': 'Youre right, I have no excuses! I was totally over the line.',
#   'context/0': 'Who cares?! You went behind my back! I would never do that to you!'},
#  {'response': 'Yeah?!',
#   'context': 'Yes!!',
#   'context/0': 'Two brothers, one died!'},
#  {'response': "Yeah, we haven't dropped it in",
#   'context': 'Monica, whatever you do, do not drop that ball!',
#   'context/0': 'What?!'},
#  {'response': 'MIKE!!!',
#   'context': 'That I was going to eat him.',
#   'context/0': 'Why? What was it?'},
#  {'response': 'Hey, can I ask you something? In this, in this picture of you and your wife, is your wife Rachel?',
#   'context': 'No! No I cant. I mean Rachels out with some guy. My baby went with her. If anything that picture keeps moving further away.',
#   'context/0': 'Thats a nice picture. Maybe you can still have that!'},
#  {'response': 'All right, Ill see you guys.',
#   'context': 'Its not gonna be exactly like last time.',
#   'context/0': 'Hey! Okay! I got my passport, fresh socks, and a snake bite kit!'},
#  {'response': "I can't believe you. You told me it was a nubbin.",
#   'context': 'Oh as, as opposed to your other multi-functional nipples?',
#   'context/0': "C'mon, there's nothin' to see, it's just a tiny bump, it's totally useless."},
#  {'response': 'Shes gone. She had a bag and she left.',
#   'context': 'What?',
#   'context/0': 'Shes gone.'},
#  {'response': 'Itll be great! We-we could talk, and play games! Huh? This could be our chance to like renew our friendship.',
#   'context': 'I dont know, its such a long trip.',
#   'context/0': 'I dont want to drive all the way back by myself, I get so lonely.  Ohooh! How about you come with me?'},
#  {'response': 'Whered you grow up, its so simple!',
#   'context': 'Huh?',
#   'context/0': 'Yeah, it is. Its really tough. Yknow sometimes I thinkWow!! Nice move!'},
#  {'response': 'No, no!',
#   'context': 'Probably.',
#   'context/0': "But if I hadn't walked in here, would you..?"},
#  {'response': 'Very good! Okay. G.',
#   'context': 'Fight.',
#   'context/0': 'Okay! Here we go. Pillow.'},
#  {'response': 'Ill never get to be a best man!',
#   'context': 'You can be the best man when I get married.',
#   'context/0': 'Come on Ross! Look, I-I dont have any brothers; Ill never get to be a best man!'},
#  {'response': 'Oh, Urse...',
#   'context': "That's right, I don't... But I was, I was drunk on you!",
#   'context/0': "You don't drink."},
#  {'response': 'Hey.',
#   'context': 'Hi.',
#   'context/0': "And we're dancing. A-five, six, seven, eight..."},
#  {'response': "Look, I don't hate Janice, she's-she's just a lot to take, you know.",
#   'context': 'Ooh, that girl that I hate, eww, drives me crazy, eww, eww, oh!',
#   'context/0': 'No, Yeeees. God, how do I say this. ?'},
#  {'response': 'So what.',
#   'context': 'Joey, you owe 1100 at I Love Lucite.',
#   'context/0': "That's a two line part."},
#  {'response': "Yeah, at Macy's. You were the Obsession girl, right? I was the Aramis guy.  Aramis? Aramis?",
#   'context': 'We did?',
#   'context/0': 'Uh, hi. We uh, we used to work together.'},
#  {'response': "I don't believe this... Have you guys been...",
#   'context': 'Yeah, sure...',
#   'context/0': 'Can I talk to you for a minute?'},
#  {'response': 'Wow!  Well then Ill just have to carry you.',
#   'context': 'I cant! My circuits are fried! Theyre fried I tell you!!',
#   'context/0': 'Come on C.H.E.E.S.E., Im not leaving without you! Try routing your backup source through your primary CPU.'},
#  {'response': 'Then you hold on to it!!',
#   'context': 'Its out there man! Ive seen it! I got it!!',
#   'context/0': 'Oh, no! No!'},
#  {'response': 'Marcel?',
#   'context': 'Marcel?',
#   'context/0': 'Dun-dun-duuuur! Sorry.'},
#  {'response': 'Youre not stupid. Youre meaner than I thought.',
#   'context': 'Yeah, what, do you think were stupid?',
#   'context/0': 'Oh, come on! We know what these are worth.'},
#  {'response': "You're driving me crazy with that!",
#   'context': 'Yes! Chandler Bing, 7! Chandler Bing, 0.',
#   'context/0': 'Because I think this character is going to be suspicious about stuff.'},
#  {'response': 'Chandler, is that',
#   'context': 'God, its great to catch up! I cant believe how long its been!',
#   'context/0': 'Okay Phoebe calm down, theres no need to place blame. Okay?  I warned her about those candles.'},
#  {'response': 'Me too.',
#   'context': 'Ill give up my ticket.',
#   'context/0': 'No! No! Its just that he gave me three tickets and there are six of us!'},
#  {'response': 'Yeah.',
#   'context': 'Well, we should go.',
#   'context/0': 'Thats my wife!!! Get out!'},
#  {'response': 'Okay.',
#   'context': 'Wow! And Im a vegetarian! All right, all right, well Im sorry, well put some ice on it.',
#   'context/0': 'Okay, great.'},
#  {'response': 'My scones.',
#   'context': "'The hills were alive with the sound of music.'",
#   'context/0': 'Oh... Yeah, you do.'},
#  {'response': 'There she is!', 'context': 'Hi!', 'context/0': 'Oh, come in.'},
#  {'response': 'Youre smoking again?!',
#   'context': 'Oh my God!',
#   'context/0': 'Chandler!!'},
#  {'response': 'Whoa, whoa. And the fact that you dumped him because he hit on Phoebe?',
#   'context': 'At his apartment. Is this juice?',
#   'context/0': 'Where?'},
#  {'response': 'Come on, I mean, you know me, you know...',
#   'context': "This is crazy. I mean, six years? And because of me you guys aren't gonna be together? Can I ask you something? Really, what is this thing with you and Rachel?",
#   'context/0': "That's what I hear, yeah."},
#  {'response': 'Looks like that no date pact thing worked out.',
#   'context': 'And the moment of joy is upon us.',
#   'context/0': "In twenty seconds it'll be midnight..."},
#  {'response': 'All right, Ross!',
#   'context': 'Oh, I was unbelievable.',
#   'context/0': 'So, er... how did it go with Celia?'},
#  {'response': 'Hey! Dont you hang up on me! Ill marry you and me right now! I have the power!',
#   'context': 'Ugh! Joey, I have to go.',
#   'context/0': 'No! No, Im the minister! All right, look-look, put em both on the phone, Ill marry them right now.'},
#  {'response': 'He hooked up!! Tell us about her!',
#   'context': "Look, I don't have to answer your questions! Okay? I'm a big boy, I can do whatever I want!",
#   'context/0': 'He hooked up! He hooked up with someone.'},
#  {'response': 'No! She had the ring on, she seemed so excited, and then she took her breast out.',
#   'context': 'You still havent told Rachel you werent really proposing?',
#   'context/0': 'No. No, I dont. Could you be a dear and go tell him?'},
#  {'response': 'That was a good one. For a second there, I was like, whoa.',
#   'context': 'Yeah.',
#   'context/0': "You guys are messin' with me, right?"},
#  {'response': "Noo! I can't take any more secrets!  I've got your secrets. I've got their secrets. I got secrets of my own y'know!",
#   'context': "No! You don't have to do anything! Just don't tell them that we know!",
#   'context/0': "I can't take any"},
#  {'response': 'Gimme a box a juice. Well, they switched me over to Hombre.',
#   'context': 'Howdy.',
#   'context/0': "You can keep saying it, but it won't stop being true."},
#  {'response': 'Ohh I wonder if that dude.',
#   'context': 'We dont know.',
#   'context/0': 'Whos the father?'},
#  {'response': "Ya know, one of these times you're gonna really be naked and we're not gonna come over.",
#   'context': "Hey, have you guys eaten, because uh, Richard and I just finished and we've got leftovers... Chicken and potatoes... What am I wearing?...Actually, nothing but rubber gloves.",
#   'context/0': "What, what's about to happen?  starts watching  I've never seen this part before. Hey, Travis, watcha doin' with that gun? Oh no, no no Travis, put down the gun. No no no no, he he's your buddy, he's your Yeller, no, no no, the end, THE END.  hear the gunshot from the TV"},
#  {'response': 'Oh! Yeah!',
#   'context': "Easy Rach, we'll find it.  Won't we!",
#   'context/0': "Oh, like I wasn't dreading tomorrow enough, having to give it back to him... 'Hi Barry! Remember me? I'm the girl in the veil who stomped on your heart in front of your entire family!' Oh God and now I'm gonna have to return the ring, without the ring, which makes it so much harder..."},
#  {'response': 'I did?',
#   'context': 'Yes and you talked to her...',
#   'context/0': 'I was?'},
#  {'response': 'I dont see the baby. Where is it?',
#   'context': 'Oh.',
#   'context/0': 'Oh hey, show them the picture of your uterus.'},
#  {'response': 'All right look, yknow how-yknow how when youre dating someone and you dont want to cheat on them, unless its with someone really hot?',
#   'context': 'I cant help it. I need the meat. The baby needs the meat.',
#   'context/0': 'Phoebe, what-what are you doing?!'},
#  {'response': 'Whaaat?', 'context': 'I knooow.', 'context/0': 'What?'},
#  {'response': 'Wow! Maybe uh, maybe you and I ought to get to know each other a little better.',
#   'context': 'Over a month.',
#   'context/0': 'So! You and Phoebe huh? How long have you been going out?'},
#  {'response': 'Hey! Dont do the crime if you cant do the time.',
#   'context': 'Youve sentenced him?!',
#   'context/0': 'Five years.'},
#  {'response': 'I need an answer!',
#   'context': "You're welcome.",
#   'context/0': "You're welcome. And thank you for Science Boy. I learned a lot from him"},
#  {'response': 'Gotcha.',
#   'context': 'His daughter was hot.',
#   'context/0': 'Dude, what are you massaging an old man for?'},
#  {'response': 'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?',
#   'context': 'Hey.',
#   'context/0': 'Joey that is so sweet.'},
#  {'response': 'What?',
#   'context': 'Joey, you had the night!',
#   'context/0': "Oh, it was great! Yeah, I-I walked her home, and it was amazing how much we connected, y'know? Then ah, then she passed out, but then she woke up. Yeah? And we stayed up all night talking, and now were like totally crazy about each other!"},
#  {'response': 'Okay. Sorry about that Uh, so wheres C.H.E.E.S.E.?',
#   'context': 'Ill let you two guys get acquainted, huh?',
#   'context/0': 'This is Wayne, the man who created and operates C.H.E.E.S.E.'},
#  {'response': 'Well, hey! Well...  To Phoebe and Mike!',
#   'context': 'Well, it was really sweet, and like the most romantic thing ever.',
#   'context/0': 'So, did he get on one knee, did he have a speech prepared, or  Yeah, big surprise, I like proposals!'},
#  {'response': 'Its a grand tradition!',
#   'context': 'I thought we werent gonna have bachelor bachelorette parties! Yknow, we agreed that it was a silly tradition.',
#   'context/0': 'She untied his G-string with her teeth.  Somebody stop me!'},
#  {'response': 'Has it been that long?!',
#   'context': 'I cant believe theyve been together for three years.',
#   'context/0': 'Yeah, youre right. Hows the Mrs.?'},
#  {'response': 'Hey!', 'context': 'Okay!', 'context/0': 'Five more seconds.'},
#  {'response': 'Yeah! And you have so many more choices than you do with mens underwear!',
#   'context': 'Thats great Joe!',
#   'context/0': 'Yeah! And-and things arent assmashed down as I thought they were gonna be.'},
#  {'response': 'Huh. Okay.  So uh, I think Im gonna take off.',
#   'context': 'Yeah its umm Yeah its uh It-its yknowIts nothing.',
#   'context/0': 'So you uh, have abig work problem?'},
#  {'response': 'How good is that?',
#   'context': "No, eh, oh-oi, easy, it's not a hot dog!",
#   'context/0': 'Thanks.'},
#  {'response': 'So he likes to break stuff.',
#   'context': 'Yeah, he broke those too.',
#   'context/0': 'Well, he had gravity boots.'},
#  {'response': 'Okay, well my girl from the other night was special. She was a scientist too!',
#   'context': 'ThatIts not the same thing! This is totally different! This is with David! Remember David, the scientist guy? Okay, hes very special to me.',
#   'context/0': 'No, Im gonna!! Thats right! Yeah, you made me feel really guilty about goin out with that girl! Like-like-like I did something terrible to you! And now Pheebs, youre doing the same thing!'},
#  {'response': 'What he wants to buy your baby?!',
#   'context': 'I know I told you, its a really big problem.',
#   'context/0': 'What?! Oh my-oh my God!'},
#  {'response': 'Whoo-weh hey weh-hey whoo hey!!',
#   'context': "Yeah, it's just we don't think of you as really being so much with the words.",
#   'context/0': "Joey, we would've asked you, we just thought you wouldn't be interested."},
#  {'response': 'Do you think well get our three bucks back?',
#   'context': 'Ill take her back tomorrow.',
#   'context/0': 'I dont know, maybe we werent ready to have a chick.'},
#  {'response': "Oo...what's in the bag?",
#   'context': 'Hey!',
#   'context/0': 'Hi you guys!'},
#  {'response': 'Yes!',
#   'context': 'So uh well the director is insisting that whoever play that part be authentically, anatomically not Jewish. Do you know what Im saying?',
#   'context/0': 'SoWhat?'},
#  {'response': 'Id love to show ya, but I just tucked her in. Shes sleeping.',
#   'context': 'He has the most amazing Porsche under there!',
#   'context/0': 'Hey! How you doin?'},
#  {'response': 'Original or crappy?',
#   'context': "I'm trying to put Emma down for a nap, have you seen Hugsy?",
#   'context/0': "oh, too late, too late! It's sent... oops sorry and so is the picture of you and the police man..."},
#  {'response': 'Yeah-yeah, and if I get it by day Ill  Joey Trrrribbiani!',
#   'context': 'Thats great.',
#   'context/0': 'Oh cool!'},
#  {'response': 'That I can do.',
#   'context': 'You can drink a gallon of milk in 10 seconds?',
#   'context/0': 'Would fall off a lot.'},
#  {'response': 'Hey.',
#   'context': "For this episode, I'm using italics to signify portions contained in the prom video.",
#   'context/0': "Can't you see what's going on here, this man is dead."},
#  {'response': 'I have to go to the bathroom too, but I dont want him complimenting my thing.',
#   'context': 'Somewhere there is someone with a tranquilizer gun and a huge butterfly net looking for that man.',
#   'context/0': 'Come on!'},
#  {'response': 'Ooh-ooh, Pheebs, you want a strong name? How about, The Hulk?',
#   'context': 'Well, it certainly worked for that Valdez kid.',
#   'context/0': 'Ugh! No! This is so hard! I went through this whole book  and found nothing! I want a name thats really like, yknow strong and confident, yknow? Like-like Exxon.'},
#  {'response': 'Uuuh.. yes, they are my stuffed clams.',
#   'context': 'Oh wow, are those stuffed clams?',
#   'context/0': "oh, I didn't know you liked French fries. Help yourself! What's mine is yours."},
#  {'response': 'Woo-hoo!!',
#   'context': 'All right! Lets do it!',
#   'context/0': 'Yeah, okay, give that a try!'},
#  {'response': 'Fine! Do you want something to drink?',
#   'context': 'Because its weird!',
#   'context/0': 'Why not?'},
#  {'response': 'Umm?', 'context': 'Hey, uh, Joey?', 'context/0': 'Bye!'},
#  {'response': "Why would you ruin it, who was that hurtin'?",
#   'context': "That's not what we're gonna do!",
#   'context/0': "Oh, ain't that nice? The three of you trying on slutty lingerie together."},
#  {'response': 'Aww thats nice. Family should be there, huh? This is her wedding, happiest day of her life.',
#   'context': 'Okay, all right, Ill take you. Ill go call Joan.',
#   'context/0': 'Because! Shes my cousin. I mean, we grew up together! Were family yknow? Well thats important to me.'},
#  {'response': "Rachel... let's be clear on this, ok? I do not love Hugsy. I like him a normal amount...",
#   'context': 'Joey... are you sure? I mean, I know how much you love him!',
#   'context/0': "Oh, yeah... of course... yeah... it's a stuffed animal... you know... it's for kids... not for adults... I know that!"},
#  {'response': 'Oh yeah, no problem.',
#   'context': "Joey, Ross is gonna be here any second, would you mind watching Ben for me while I use the ladies' room?",
#   'context/0': 'Hmmm, soup!  Hmm, soup!'},
#  {'response': 'Well, were fashioning a very long poking device.',
#   'context': 'What?',
#   'context/0': 'Well, now we got a reason.'},
#  {'response': 'I mean naked game. Strip poker, we should totally play strip poker.',
#   'context': 'What?!',
#   'context/0': "Hey, y'know what a really good rainy day game is?"},
#  {'response': 'Yeah, I know.',
#   'context': 'How sad are we?',
#   'context/0': 'Im just glad I brought that extra pair of socks, yknow? I used them as mittens, I didnt want to touch a thing in that last place.'},
#  {'response': 'Man, this is bad! And Ive had my share of bad reviews. I still remember my first good one though.  Everything else in this production of Our Town was simply terrible. Joey Tribbiani was abysmal.',
#   'context': 'No, Monicas restaurant got a horrible review in the Post.',
#   'context/0': 'Well thats no way to sell newspapers. Why dont you try, Extra! Extra! Read all about it!'},
#  {'response': "I agree. I'm, like, in disbelief.",
#   'context': "I can't believe we are even having this discussion.",
#   'context/0': "'Pwease, Aunt Monica, pwease?' Oh, unclench. You're not even gonna be there."},
#  {'response': 'All right.',
#   'context': 'Okay, absolutely!',
#   'context/0': 'No you wont. Look he knows he did a terrible thing and I believe him, hes sorry. But,  youve got one more apology to make, all right, youve got to apologize to Mary-Angela.'},
#  {'response': 'Hey I got one! I got one!',
#   'context': 'All right.',
#   'context/0': 'All right.'},
#  {'response': 'Thats right! By his uncle too!',
#   'context': 'Were gonna be all right. I mean, even if were not married this baby is gonna be so loved. Not just by us.',
#   'context/0': 'Of course hes gonna have his Uncle Joey!'},
#  {'response': "Ok! All right, well... I'm gonna see if I can get a room for the night and I'll... I'll see you later!",
#   'context': "No, I-I-I-I don't, I actually don't know who I'm talking about! So!",
#   'context/0': 'No-no-no-no, no! Who, who were you talking about?'},
#  {'response': 'Gladys?',
#   'context': "Okay, that's it. WE ARE SEEING OTHER PEOPLE!",
#   'context/0': 'I love you too!'},
#  {'response': 'Cool.', 'context': 'Yeah.', 'context/0': 'Tongue?'},
#  {'response': 'Look, come on you guys, you said you were gonna try! All right look, I came over here to invite you guys to a movie with me and Janine.',
#   'context': 'Oh nothing, were just talking. Yknow, blah-blah-blah.',
#   'context/0': 'So uh, what are you guys doing?'},
#  {'response': 'Probably kill myself!',
#   'context': 'Hey, Joey, what would you do if you were omnipotent?',
#   'context/0': 'Hey Joey. Hi. Hey, buddy.'},
#  {'response': 'Okay!',
#   'context': 'Look, I- I could go on pretending-',
#   'context/0': 'You know.. you let your guard down, you start to really care about someone, and I just- I-'},
#  {'response': 'Come on! What are you doing?! Im in character! Would you talk to her!',
#   'context': 'Joey, you know you dont actually have one.',
#   'context/0': 'Oh, Ive been there. Yeah, I am gonna go drive my Porsche.'},
#  {'response': "It's a one-woman play called Why don't you like me: a bitter woman's journey through life.",
#   'context': 'What is it?',
#   'context/0': 'I could fall asleep at a play.'},
#  {'response': 'Oh-no, dont try and talk all normal with that thing in your ear.',
#   'context': 'I like it, and Emily likes it, and thats what counts. So uh, how are you guys doing?',
#   'context/0': 'You do know that Wham broke up?'},
#  {'response': '4:30.',
#   'context': 'What time is it now?',
#   'context/0': 'Uh, 10:30.'},
#  {'response': "Hard to tell, they're so tiny and upside-down. Wait, wait. They're walking away... they're walking away... No, no they're not, they're coming right at us! Run! Run!",
#   'context': 'Whaddya see?',
#   'context/0': "I dunno, I've been standing here spelling it out for you!"},
#  {'response': "It's a... It's a welcome home sign for the baby.",
#   'context': 'Hey, what are you working on?',
#   'context/0': "Yeah, I'm good."},
#  {'response': 'Really?',
#   'context': "Oh well it's not me, it's my character, Chandy. Yeah the rogue processor who seduces his co-worker's wives for sport and then laughs about it the next day at the water cooler. In fact, I have her panties right there in my drawer.",
#   'context/0': 'Ahh. What the hell are you doing to me man.'},
#  {'response': 'I know. And shes so sweet. I just wanna feed her grapes and brush her hair.',
#   'context': 'Aw, Im sorry sweetie that she doesnt feel the same way.',
#   'context/0': 'I like her so much!'},
#  {'response': "It's Joey.",
#   'context': 'Hey, did you get the turkey bastedOh my God! Oh my God!  Who is that?',
#   'context/0': 'Hey!'},
#  {'response': 'You hug me!',
#   'context': 'You are gonna be a huge star! Im gonna hug ya!',
#   'context/0': 'Yeah, youre right. Okay look, listen, lets talk about what a huge star Im gonna be!'},
#  {'response': 'Not good, no. I didnt get the part, and I lost my job here, so',
#   'context': 'Hey, buddy boy, howd the audition go?',
#   'context/0': 'Yknow, suddenly I find you very attractive.'},
#  {'response': 'It smells really bad in here.',
#   'context': "Oh my God! Monica's gonna totally freak out!",
#   'context/0': 'I put it on to scare Chandler!'},
#  {'response': "Oh, sometimes we use the same extras for different parts. It's okay.",
#   'context': "Joey, listen. I can't do this, it doesn't make any sense. Yesterday I was a nurse, and today I'm a waitress at a cafe?",
#   'context/0': "You know what? I don't need a tie. I mean, it's better, open collar. You know, it's more casual"},
#  {'response': 'Thanks. That means a lot to me.',
#   'context': 'I always knew you were gonna make it. Im so proud of you.',
#   'context/0': 'Its not just the stuff he paid for, I mean its-its everything. Yknow? He read lines with me. He-he went with me on auditions when I was really nervous, and then he consoled me after I didnt get parts that I really wanted. You always believed in me man. Even, even when I didnt believe in myself.'},
#  {'response': "Too long! Oh my God, Rach, I've been dying to talk to someone about this for so long! Listen, listen, we can't say anything about this to anybody, they're so weird about that! Listen",
#   'context': 'Chandler and Monica?!! Oh, this is unbelievable!! How long have you known?',
#   'context/0': 'Yeah, I know!!!!'},
#  {'response': 'So thats why I feed my dog Purina One! Pick up a bag today!',
#   'context': 'Oh my God!!',
#   'context/0': 'Oh yeah, sure, no problem, Ill justhold on one second.  Hey Timmy, Ive got a surprise for you!'},
#  {'response': 'Sure?',
#   'context': 'Are you asking me to have a frenaissance?',
#   'context/0': 'Itll be great! We-we could talk, and play games! Huh? This could be our chance to like renew our friendship.'},
#  {'response': "How far'd ya get?",
#   'context': 'OK.',
#   'context/0': "Huh-hoo, yeah, no, it's still basil."},
#  {'response': 'Well, hes too shy, he doesnt thing hes good enough to dance with girls yet.',
#   'context': 'Well, why doesnt he practice with a girl?',
#   'context/0': 'Yeah, theres this superintendents dance, the Super Ball. I dont know, and he wants to impress Marge, this lady super that hes a crush on.'},
#  {'response': "Yeah, right Monica. I'm so sorry.",
#   'context': "I can't believe you thought I was cheating.  You own me an apology.",
#   'context/0': 'I guess not.'},
#  {'response': "Did you know this isn't Ma?",
#   'context': "Gotta go. I miss you too, I love you, but it's getting real late now",
#   'context/0': "Oh, 'scuse me. So Ross, uh, how's the wife?  Off there too, uh? Uh, Chandler, quick, say something funny!"},
#  {'response': 'Oh well then, good night!',
#   'context': 'Oh good.',
#   'context/0': 'Absolutely!'},
#  {'response': "Y'know what, I dont think we should listen to this anymore.",
#   'context': 'Well, you sure had a hell of a time at the wake!',
#   'context/0': 'Look, Im not trying to get out of anything, okay. I thought our relationship was dead!'},
#  {'response': 'Six and a half! You knocked that last one out of my hand! Remember?',
#   'context': 'Well, does a good student drink seven beers during his first lesson?',
#   'context/0': 'Does a good teacher say, Put down the beer pinhead!?'},
#  {'response': 'Listen, I ah, went to that restaurant that you were talking about last week...',
#   'context': 'Morning.',
#   'context/0': 'Hey, Kate!'},
#  {'response': 'You think I need a new walk?',
#   'context': 'What if they dont?',
#   'context/0': 'Yeah, come on, its Ross and Rachel, theyve got too.'},
#  {'response': 'Sorry! Sorry, Im late; sorry, Im late! My duck and my chick and a fight, it-it was ugly.',
#   'context': 'Ohh, thats a good one.',
#   'context/0': 'Ooh, I dont know. Probably the smell of freshly cut grass.'},
#  {'response': 'Huh, Rach I got to say its gonna take a lot of money for me to go out on a date with a dude.',
#   'context': 'How would you feel about taking out my assistant Tag? Ill pay.',
#   'context/0': 'Nothing, why?'},
#  {'response': 'What are you doing?',
#   'context': "Ok, it's too hard, I can't teach you!",
#   'context/0': 'Me pooh pooh!'},
#  {'response': "Maybe, I should call this place and get them to put my 'Days of Our Lives' on here. You know, juice this puppy up a little.",
#   'context': "Well, honey, it is pretty competitive. I mean I've got an actual rocket scientist here.",
#   'context/0': "Noooo, that's what I was wearing when I donated. I'm kinda surprised there's any of my boys left."},
#  {'response': "What's a matter Ross? What you're nervous about your speech?",
#   'context': 'Glass of fat?',
#   'context/0': "Yeah! Once, I figure out what I'm wearing."},
#  {'response': 'Uh yeah, where-wheres the guy who decides whos pictures go up on the wall?',
#   'context': 'Can I help you?',
#   'context/0': 'NOOOO!!!!!!!!'},
#  {'response': 'Oh yeah, sure, that makes sense. Yeah. Cause you already told her you love her and she didnt say it back, then she called you and told you that theres another guy, so yeah, go to London thatll scare her!',
#   'context': 'Yeah, you have to go fight for her!',
#   'context/0': 'What?'},
#  {'response': "Please, we're trying to have a conversation.",
#   'context': "That's okay Mike, I have forgiven you. And now we're friends again everything's great!",
#   'context/0': "No, I didn't."},
#  {'response': 'No dude, Ross tore up the tickets!',
#   'context': 'Great! Now, we can go to the Ranger game!  Last night!',
#   'context/0': 'Yay!'},
#  {'response': 'Hey.',
#   'context': 'Thank you!',
#   'context/0': 'I dont know. Yknow, they didnt get us anything.'},
#  {'response': 'Thats not gonna happen. No.  Because we have a new deal!',
#   'context': 'Will it? Will it?! I mean, how would you feel if you found out you were 31?',
#   'context/0': 'Oh, I dont know Pheebs. Itll be okay.'},
#  {'response': 'Okay, the ring fell on the floor and I went down to pick it up and you thought I was proposing.',
#   'context': 'Yeah, what did happen?',
#   'context/0': 'Then what did happen?'},
#  {'response': 'What?!!',
#   'context': 'We want you to marry her!',
#   'context/0': 'Oh Joey, Im sorry I just couldnt tell her all those things you wanted me to tell her. And yknow we got to talking and I'},
#  {'response': 'Argh!',
#   'context': 'I do too! I do too!',
#   'context/0': 'I want the drugs Ross, I want the drugs!'},
#  {'response': 'All right, we have to pick captains.',
#   'context': 'That almost hit me in the face.',
#   'context/0': 'Here you go.'},
#  {'response': "That he doesn't exist.",
#   'context': 'Hey, Joey, when you said the deal with Santa Clause, you meant?',
#   'context/0': "She's talking."},
#  {'response': 'my parents, whove always been there for me. Id also like to thank my friends, Chandler, Monica, Phoebe, Rachel',
#   'context': 'I did, but that was really fun.',
#   'context/0': 'I thought you knew I was looking at you.'},
#  {'response': 'Ross-Ross-Ross-Ross! Stay away from that guy . And that oneDude! Theyre all huge!',
#   'context': 'Oh, well maybe there was a dog lookin at him.',
#   'context/0': 'Oh!'},
#  {'response': 'No, they-they werent in the play.',
#   'context': 'How do you do.  Did they have representation?',
#   'context/0': 'Hey you guys, this is my agent, Estelle.'},
#  {'response': 'Oh.', 'context': 'Or Joseph.', 'context/0': "It's not."},
#  {'response': "Well hurry, I can't feel my ears!",
#   'context': "Alright, we're gonna have to unscrew the chain.",
#   'context/0': "It isn't working."},
#  {'response': "Hey, listen Pheebs. I was just talking to the director, and he was thinking, maybe this time you don't hit Drake, you just wait on the tables?",
#   'context': "Thank you, thank you. How about I do something for you? Tomorrow, I'll bring you a hat, cover up the bald?",
#   'context/0': 'Okay, okay. But this is her last chance.'},
#  {'response': 'Whoa, store will be open tomorrow!',
#   'context': 'Well, he made a move on me.',
#   'context/0': "I'm familiar with his work, yes..."},
#  {'response': 'All-all right!  Start it up! Lets go!',
#   'context': 'Yes! My babys finally free!',
#   'context/0': 'God, do you realize in ten years were gonna be 40?'},
#  {'response': 'Hey!',
#   'context': 'Aah!',
#   'context/0': "Yeah. Oh! It'll be like I have a wife in the fifties!"},
#  {'response': "Fine. I'll go. But let me ask you one question...",
#   'context': 'No, I told you...get out!',
#   'context/0': 'OH!'},
#  {'response': 'Ah, Kate?',
#   'context': 'Yeah! Yeah, it was definitely an improvement. Gnight.',
#   'context/0': 'Better?'},
#  {'response': "I can't believe it. When you guys come back, you're gonna have a baby! That is so weird!",
#   'context': "Yep, we're gonna meet the lady who could be carrying our baby.",
#   'context/0': 'Oh, right! Your adoption interview!'},
#  {'response': 'Hey, is uhm... is Chandler here?',
#   'context': 'If only there were a smaller one to clean this one!',
#   'context/0': 'Oh, look at her, so happy!'},
#  {'response': 'What? You ordered pizza without me?!',
#   'context': 'Ooh, the pizza guys here!',
#   'context/0': 'Ahh, the babies miss me?'},
#  {'response': 'Yeah, see... you were all worried for nothing.',
#   'context': 'Football? Just football?',
#   'context/0': "Well it's okay, its like... its just a football game."},
#  {'response': "Maybe you can tell me. My agent would like to know why I didn't show up at the audition I didn't know I had today. The first good thing she gets me in weeks. How could you not give me the message?!",
#   'context': "Hey, man. What's up?",
#   'context/0': 'Hey.'},
#  {'response': 'Oh yeah?',
#   'context': 'Excellent! Yknow Ross met somebody too!',
#   'context/0': 'Two days ago.'},
#  {'response': 'Thursday! Look if you need help remembering think of like this, the third day. All right? Monday, one day. Tuesday, two day. Wednesday, when? Huh? What day? Thursday! The third day! Okay?!',
#   'context': 'Yeah so, Tuesday?',
#   'context/0': 'All right! Thanks! Youre the best! Now listen, the last day of auditions is Thursday. Okay? So I gotta get in there by Thursday. Okay? Just remember Thursday. Thursday. Can you remember Thursday?'},
#  {'response': "Okay, listen, hey, Ross. Why don't you try to relax, okay? Maybe have a drink.",
#   'context': "What? Fine? Because I am! Aren't you? Aren't you? Aren't you? You see? Who else is fine?",
#   'context/0': 'Gosh, Ross, you know, you seem a little...'},
#  {'response': "Hey, that pregnant girl's name was Erica.",
#   'context': 'Aw..',
#   'context/0': 'Her name is Erica.'},
#  {'response': "All right, I guess I can hold out a little longer. Let's have a game.",
#   'context': "All right look, y'know, this maybe tough but come on, this is Ross! I survived college with him!",
#   'context/0': "Um-hmm! Look, I-I-I don't know how much more of this I can take! Did you know he taped over my Baywatch tape with some show about bugs! My God! What if that had been porn?"},
#  {'response': 'Okay, look, I think we have to tell Rachel she messed up her dessert.',
#   'context': 'Oh, uh, can it wait a second Joey? I have to tell my parents something. No it cant? Okay.',
#   'context/0': 'Ross! Can I talk to you for a second?'},
#  {'response': 'I was tryin to make a sale!! Oh, man, if I ever run into that guy again, do you know what Im gonna do?',
#   'context': 'So--You got in voluntarily?!',
#   'context/0': 'Well, this guy came by to look at the unit and-and he said he didnt think big enough to fit a grown man!'},
#  {'response': 'Well to tell you the truth, they uh,  they had a problem with the bag!',
#   'context': 'What kind of problem?',
#   'context/0': 'Yeah, I thought so too but, she said the casting people had some problems with me.'},
#  {'response': 'Yeah! Okay!  Hey! Hi!',
#   'context': 'Yeah, I understand.',
#   'context/0': 'Yeah! Much! Listen uh, not that Im yknow insecure about my manhood or anything yknow, but I think I need to hook up with a woman like right now.'},
#  {'response': 'No, can we get back to me?',
#   'context': 'Joey, look at me, look at me. Do I have lipstick on my teeth?',
#   'context/0': "So, you're not mad at me for getting fired and everything?"},
#  {'response': "Whoa, maybe I was! Hey, Monica, this totally hot girl in Ross's building is flirting with me.",
#   'context': 'Nope. Op, wait! There he goes.',
#   'context/0': 'Is he doing his shark attack bit yet?'},
#  {'response': 'In what John Houston film would you hear this line, Badges? We dont need no stinkin badges!',
#   'context': 'Okay mommy, dont ever leave me.',
#   'context/0': 'Its actually a bassinet.'},
#  {'response': 'I say push her down the stairs.',
#   'context': 'Ooh, she should not be wearing those pants.',
#   'context/0': 'If I let go of my hair, my head will fall off.'},
#  {'response': 'Oh thats okay. Hey, actually in a way its kinda nice. Me, bringing the food of my ancestors, you, the food of yours!',
#   'context': 'Oh, I wish Id know you were going to do that, I ordered Chinese.',
#   'context/0': 'Here it is! Our last pizzas together as roommates.'},
#  {'response': 'Yeah, I wouldnt know about that.',
#   'context': 'I think so too. And that little flap? Great for holding my lipstick.',
#   'context/0': 'Thatskinda hot.'},
#  {'response': 'But youre still moving in together, right? Because my ad came out today.',
#   'context': 'Nothing, Monica and I had a stupid fight.',
#   'context/0': 'Hey, whats up?'},
#  {'response': 'Just put it on a plate and leave.',
#   'context': "I'm sorry, I didn't know to look for Chinese food on the floor.",
#   'context/0': 'You stepped on my egg roll?'},
#  {'response': 'Joey.  Hey Jake, do you like the Knicks?',
#   'context': 'Its Jake.',
#   'context/0': 'So uh, whats your name?'},
#  {'response': 'Well, I heard Emma stirring, so I came to make sure she could reach Hugsy.',
#   'context': 'What are you doing?',
#   'context/0': "It's okay, it's okay Rach, it's me. Put down the scrunchy."},
#  {'response': 'Okay! Okay, youre yelling again! See that?',
#   'context': 'Huh?',
#   'context/0': 'Okay, go to the left.  The left!'},
#  {'response': 'She is so hot!',
#   'context': 'Score.',
#   'context/0': 'I went back to Riffs. I think Ursula likes me. All I ordered was coffee, she brought me a tuna meltt and four plates of curly fries.'},
#  {'response': 'Never had that dream.',
#   'context': "That's right.",
#   'context/0': 'Instead of...?'},
#  {'response': 'Vulva?',
#   'context': 'Um... uh.... vulva.',
#   'context/0': 'What?'},
#  {'response': 'Sure is.',
#   'context': 'Yeah.',
#   'context/0': "Wow, this is it, I'm gonna meet my dad. This is like the biggest thing ever, huh."},
#  {'response': 'So you uh, still wondering?',
#   'context': "God, this was really fun! I've been wondering if you were going to ask me out.",
#   'context/0': "That was the water fountain! Okay?! Anyway, people are writing reports for me, uh pushing back deadlines to meet my schedule, I'm telling you, you get tough with people you can get anything you want.  Hey Tribbiani, give me that coffee! Now!"},
#  {'response': 'Come on! Admit it! That was the best nap you ever had!',
#   'context': 'I I dont know what you are talking about.',
#   'context/0': 'Yes we do! Now look, that was the best nap I ever had!!'},
#  {'response': 'Wait a second, I see what youre trying to do here! You-youre trying to give me money again!',
#   'context': 'No, but waitwhat if I bought it from you, yknow? And your nice gesture would be giving it to me at a reasonable price, say  1,500?',
#   'context/0': 'Its him, not it!'},
#  {'response': 'All the time!',
#   'context': 'All the time?',
#   'context/0': 'Hey-hey-hey-ho-ho, I got this one. Here you go.  Yknow I gotta tell ya, sometimes I justI dont get Chandler. Yknow, me and him do stuff all the time without you and you dont get all upset.'},
#  {'response': "Where's Emma? Who has Emma!?",
#   'context': "They're towing a car. And I am seeing...spots.",
#   'context/0': "I'm parked in a garage on Morton!"},
#  {'response': 'I, ah, I never said hate, I was very careful about that.',
#   'context': 'So, I hear, you hate me!',
#   'context/0': "Okay, this isn't working. I'm still awake and now I have to pee."},
#  {'response': 'Well, so, will you help me? I really wanna be in this play.',
#   'context': "Oh... you're so sexy!",
#   'context/0': "Oui, bien sur je parle Franais! Qu'est-ce que tu penses alors?"},
#  {'response': "That's right baby.",
#   'context': 'Four hours? You guys have been doing this for four hours?',
#   'context/0': "Monica! Stop throwing it so hard! We're on the same team!"},
#  {'response': 'Yeah, hes the best.',
#   'context': 'Okay. Um is he a good guy?',
#   'context/0': 'No. I dont think so.'},
#  {'response': "What?!!  No I'm not!!",
#   'context': "Joey's a sex addict.",
#   'context/0': 'Thank you!'},
#  {'response': "Well, he's gonna. I'll see you a little later, ok?  Hey, how ya doin'?",
#   'context': "I guess he doesn't know.",
#   'context/0': "What's he doin' in my section?"},
#  {'response': 'Wow, Ive admired your work for years. You-youve done some really amazing stuff.',
#   'context': 'Dennis Phillips',
#   'context/0': 'I dont believe weve met, Joey Tribbiani.'},
#  {'response': 'Well, dont get your hopes up, because probably not gonna happen.',
#   'context': 'HuhWait so Joey if you get this, youre gonna be like the star of your own TV show! I mean youll be like the Big Cheese!  Or the Big MacHey! You love those!',
#   'context/0': 'That is lucky.'},
#  {'response': 'Baby shower. Wow! That sounds sooo like something I dont want to do! Later!',
#   'context': 'The baby shower for Phoebe!',
#   'context/0': 'Well umm'},
#  {'response': "Try it, I can't feel a thing!",
#   'context': 'What are you guys doing?',
#   'context/0': 'Mhm, helpful brother - creepy loner at teen movie.'},
#  {'response': 'I think I know that girl.',
#   'context': 'Yeah, its for our catering business!',
#   'context/0': "What did you want to show us? Because all I can see is this bitchin' van!"},
#  {'response': "What, you think I'm gonna tell a girl I like that I'm also seeing a cup?",
#   'context': 'Yeah? What does she think of your little science project?',
#   'context/0': "I don't know, she's, uh.... she's pretty great."},
#  {'response': 'Wow.  Good speech.',
#   'context': 'Thank you. Thank you very much. Umm, Ive known them separately and Ive known them together and-and to know them as a couple is to know that you are truly in the presence of love. So I would like to raise my glass  to Monica and Chandler and the beautiful adventure they are about to embark upon together. I can think of no two people better prepared for the journey.',
#   'context/0': 'Oh! Thats nice.'},
#  {'response': 'This is where I keep the pizza.',
#   'context': 'Oh.',
#   'context/0': 'It couldve been a hair straightener.'},
#  {'response': 'What party?',
#   'context': 'We know about your party Joey.',
#   'context/0': "Hey you guys, I'm turning in. Have fun."},
#  {'response': "Hey! Handcuffs! And fur line, nice! I didn't know you guys had it in ya!",
#   'context': 'What the hell is this?',
#   'context/0': 'You guys hear a ringing?'},
#  {'response': 'Hey Gunther, let me get a lemonade to go.',
#   'context': "That's a tomato. This one definitely goes in the display.",
#   'context/0': "Your last roommate's kidney?"},
#  {'response': 'Whoah!',
#   'context': 'Not so much!',
#   'context/0': 'Relax your hand!'},
#  {'response': 'I want you to take this seriously! Phoebe is very very important to me, ok? And I wanna make sure that you are gonna take care of her.',
#   'context': 'Joey, I kinda have a lot to do today, what do you want?',
#   'context/0': 'More back talk. And yes, I may be borrowing a few lines from my recent unsuccessful audition for Family Honor 2: Thissa Time Itsa Personal.'},
#  {'response': 'Center ice.',
#   'context': 'Guess where they are?',
#   'context/0': "Yeah, they're great seats too!"},
#  {'response': 'All right, uh  Oh hey, youve done this before Ross, well what did you say when you made up your vows?',
#   'context': 'There are no words! This should not be this hard!',
#   'context/0': 'Look at her go! She must love me more than I love her! Whats wrong with me? Ooh, dont open that door.'},
#  {'response': "I'm excited! I've never gotten reviewed before.",
#   'context': "Joey, would you slow down? They're not gonna be sold out of papers at one o'clock in the morning.",
#   'context/0': "They're ribbed for your pleasure."},
#  {'response': 'Blah?!',
#   'context': 'I dont know, theyre just a little blah!',
#   'context/0': 'What-whats wrong with Monica and Chandler?'},
#  {'response': 'Wait a second, wait a second, where have I seen that cowgirl outfit before...',
#   'context': 'And it looks like she put makeup on her!',
#   'context/0': 'You entered Emma into a Beauty Pageant?'},
#  {'response': "And Rachel. I would've told you but they made me promise not to tell!",
#   'context': 'Joey!',
#   'context/0': 'Uhhh, Phoebe and Joey.'},
#  {'response': 'Paper, snow, a ghost!',
#   'context': "It's white!",
#   'context/0': 'Salami, anchovies, jam!'},
#  {'response': "Thanks! I've been working out. Hey listen, is it obvious that I'm wearing six sweaters?",
#   'context': 'Hi! Wow! You look, you lookbig.',
#   'context/0': 'Hey!'},
#  {'response': 'Okay.',
#   'context': 'One more fight!',
#   'context/0': "I don't know..."},
#  {'response': 'Okay, but lets say there was. How might that go?',
#   'context': 'Excuse me, there was no time!',
#   'context/0': 'What?!!'},
#  {'response': "So, you're not mad at me for getting fired and everything?",
#   'context': "Don't worry about it already. Things happen.",
#   'context/0': "Ok, this is a typical lightning-bearer thing. Right there, it's like, um, 'Hello, who wants one of my fallic shaped man cakes?'"},
#  {'response': 'Oh yeah, I still cant believe you havent seen Cujo. What is wrong with you?',
#   'context': 'Hi! Hey, remember how last night we were talking about that movie Cujo?',
#   'context/0': 'Hey!'},
#  {'response': 'NO!!!',
#   'context': 'Hey, you guys! What do you, what do you think about making that beach trip an annual thing?',
#   'context/0': 'Ill give you a thousand dollars to talk to us.'},
#  {'response': "You're blowin' me off for a monkey?",
#   'context': "Hey Joey I have to cancel racketball for tonight, that was Marcel's trainer. He's gonna let me have him for a couple of hours.",
#   'context/0': 'I know. Oh, like you would drink her coffee after what you did to her with Van Damme.'},
#  {'response': 'Morning!',
#   'context': 'Oh, okay!',
#   'context/0': 'I know! Ill tell you something, we are gonna do that again!'},
#  {'response': "Maybe. So this is the living room huh? Ooh, it's pretty dark.",
#   'context': "Maybe because it's you hung your head out of the window like a dog the whole ride here.",
#   'context/0': 'Okay. Then I guess I have dry eyes and a scratchy throat for no reason.'},
#  {'response': "No, no, it's not a girl, it's... a brand new Hugsy!",
#   'context': "Joey, Emma's right here! You promised not to bring girls home in the middle of the day anymore.",
#   'context/0': "Hey, look who's here! It's Joey, and he brought home a friend."},
#  {'response': 'A woman in a mans body.',
#   'context': 'Thats right! Thats right, dont you play a woman?',
#   'context/0': 'Well Joey doesnt like to talk about it but, hes one of the stars of Days Of Our Lives.'},
#  {'response': 'Arghhh! Double standards!',
#   'context': "I'm a woman!",
#   'context/0': 'Hey hey! You dye your hair!'},
#  {'response': 'Come, come here.',
#   'context': 'Wow! I cant, I cant feel my hands.',
#   'context/0': 'When was the last time someone told you just how beautiful you are?'},
#  {'response': 'No! I want an award I did win! But nobodys giving me any of those! PlusHey Rach, if-if I put it up there  right? When people come over theyll see it and theyll think I won it.',
#   'context': 'Do you really want an award you didnt win?',
#   'context/0': 'Come on Rach! No one saw me take it! There was a whole table full of em.'},
#  {'response': 'Yeah, were gonna be fine! Get out!',
#   'context': 'So?',
#   'context/0': 'He can still catch her! Come on, get out of there!  Get out of there!'},
#  {'response': 'Ah. Yeah. Well look, the thing is its the same day as my nieces christening and I really want my parents to be there in time to see me. Cause my parts just in the beginning Im not even in the rest of the showWedding!',
#   'context': 'Have you ever been to one of my weddings?',
#   'context/0': 'Right. Right. The wedding, gotcha. But I mean, its gonna start a little late right? I mean, weddings start late. Right?'},
#  {'response': "I don't know. We're talking about whipped fish, Monica. I'm just happy I'm keeping it down, y'know?",
#   'context': 'Yeah, well, is that better?',
#   'context/0': "It's creamier."},
#  {'response': 'Thank you. Yeah, I appreciate that.',
#   'context': 'Oh God! Alright, fine. You know what Joey, forget it. When we go back to New York, I will tell him.',
#   'context/0': "I couldn't. He was saying all these really nice things about me. I didn't want him to get mad and take 'em all back. I'm on a edge on Chandler."},
# ...
#   'context': "Bye! Hey, I hope Emma isn't making it too hard on you.",
#   'context/0': 'Bye!'},
#  {'response': 'Morning.',
#   'context': "Oh God, it freaked me out. Okay, I know it shouldnt have, but it did. I mean I like her, I dont want to stop seeing her, but every so often its like Hey, y'know what, wheres your leg? I mean Im the smallest person in the world arent I? Im the smallest person in the world.",
#   'context/0': 'Uh-huh.'},
#  {'response': 'Chandler, look theyre actors. Theyre there to do a job, just cause they work together, doesnt mean theyre gonna get together. I mean just cause it happened with Susan Sarandon and Tim Robbins, it doesnt mean its gonna happen with them.',
#   'context': 'All right, look, look, what am I gonna do?',
#   'context/0': 'That-that is a good trick.'},
#  {'response': 'Oh yeah? Ross, how many items left in that bag?',
#   'context': 'Yeah.',
#   'context/0': 'Im so not impressed. Everybody snacks when they shop.'},
#  {'response': 'Okay!',
#   'context': 'Okay. Umm, ooh, oohoh, I have a game!',
#   'context/0': 'Oh, okay, well, I think we should let Phoebe decide, because shes the only whos impartial, and shes so pretty.'},
#  {'response': 'Now you cant tell anyone, but uhI put on shiny lip balm.',
#   'context': 'How do you do that?',
#   'context/0': 'Ah, well, if I want the girl to kiss me, first thing I do is make my lips look irresistible.'},
#  {'response': "Ok, ok! Fine! You can come, but don't tell anybody else. It's up on the roof at 8.",
#   'context': 'Oh, Joey, come on! Please, please! Let me come, I will behave, I promise! I will behave! Please, please, please...',
#   'context/0': "Please, I was trying to be nice, you're the worst one!"},
#  {'response': 'Well, I didnt realize until I got home. I wasnt gonna walk all the way back down here with one shoe! Yknow what? Im gonna go find that guys car and leave a note on the windshield.',
#   'context': 'You left a shoe here?!',
#   'context/0': 'Theres a lost and found?'},
#  {'response': 'Remember what happened the last time I did an interview for them? I said I write a lot of my own lines, and then the writers got mad and made my character fall down the elevator shaft. So who knows what I might say this time.',
#   'context': 'Whyd you say no?',
#   'context/0': 'No. They really like me over there. They want to do a big profile on me, but I said no.'},
#  {'response': 'Yeah, yeah, and directing.',
#   'context': 'Yeah, and Lennart Haze is starring in it',
#   'context/0': "Well, it must be, because I read and I didn't understand a singe word."},
#  {'response': 'Yeah. So uh Ross, well nowwhy did that first marriage breakup? Was it because the woman was straight or she was a lesbian?',
#   'context': 'You said the waiter ate my crab cake.',
#   'context/0': 'Yes. And another time after that. Boy Im getting hungry! Hey Joey, have you ever been so hungry on a date that when a girl goes to the bathroom you eat some of her food?'},
#  {'response': 'I got you something! Open it! Open it!',
#   'context': 'Hey!',
#   'context/0': 'Hey!!'},
#  {'response': 'Karen.',
#   'context': "Alright, ok, alright. So I can't fire Joseph but uh, I can sleep with his wife.",
#   'context/0': "Oh yeah. Well you can't fire Joseph. You know why, 'cause he's not in your department."},
#  {'response': 'Uhh, I dont believe in these crazy diets yknow, just everything in moderation.',
#   'context': 'Hey, come on now!',
#   'context/0': 'Stick to your side!'},
#  {'response': 'Oh... uh... look... before you...',
#   'context': "I am speachless... I mean the fact that you would put my happiness first like that. I mean, you're an incredible friend, you know that?",
#   'context/0': 'Yeah... Now I have something...'},
#  {'response': 'You partied with Hootie and the Blowfish?',
#   'context': "It wasn't so much a party as...a gathering of people, with food, and music, and, and the band.",
#   'context/0': 'What party?'},
#  {'response': 'Yeah, they do! Quit being a baby and leave me alone! There, youve just had your first class!',
#   'context': 'They dont have those.',
#   'context/0': 'Look, I told ya, Im not going to any clinic! I dont have a problem, youre the one with the problem! You should go to a Quit being a baby and leave me alone clinic!'},
#  {'response': 'Uh, hey, Rach let me ask you something. Uh, I was just over there talking to Monica and Chandler, boy they are really tight.',
#   'context': 'Thanks!',
#   'context/0': "Oh, I'd love too, but I got acting class. But y'know what? I guess I can blow that off,  for you."},
#  {'response': 'Hey Ross, listen, you want anything to drink, cause Im heading up there.',
#   'context': 'Yeah, that-that Chandler cracks me up.',
#   'context/0': 'Oh, hey, Gunther, check this out.'},
#  {'response': 'Yeah, I got too excited!',
#   'context': 'You okay there man?',
#   'context/0': 'Just stop it! Come on!'},
#  {'response': 'We have to find the rest of the platoon!',
#   'context': 'Okay, all right. Lets do it.  AndAction!',
#   'context/0': 'Yeah, sure.'},
#  {'response': 'Well he made Rachel cry!',
#   'context': 'I told you not to go down there!',
#   'context/0': 'What?! You got us evicted!!'},
#  {'response': 'Ross! Can I talk to you for a second?',
#   'context': 'Okay, fine!',
#   'context/0': 'Ross, if you dont tell them, then I will!'},
#  {'response': 'Eight hundred and twelve bucks.',
#   'context': "What's this?",
#   'context/0': "Nice, nice. Hey I got somethin' for you.  hands Chandler an envelope."},
#  {'response': 'Oh yeah. If you ah, move your hamper, you see what color the tile used to be.  Yeah.',
#   'context': 'I highly doubt that.',
#   'context/0': 'Nothing. Its just old and dingy, thats all.'},
#  {'response': 'Hey well, you cant teach someone to be good with women. Yknow, thats why I never had any luck with Chandler.',
#   'context': 'Yknow, all the women.',
#   'context/0': 'What?'},
#  {'response': 'Hey, opposite, is opposite!',
#   'context': 'What are you, what are you gonna show me my clothes?',
#   'context/0': "Okay, you hide my clothes. I'm gonna do the exact opposite to you."},
#  {'response': 'Only if you think its better than this...  snow-in-a-can!! I got it at work. Mon, you want me to decorate the window, give it a kind of Christmas lookie.',
#   'context': 'What, that wasnt the great news?',
#   'context/0': 'And now for the great news.'},
#  {'response': 'Hey-hey, check it out! Check it out! Ugly Naked Guy has a naked friend!',
#   'context': "Good. I'm really looking forward to you and me having sexual intercourse.",
#   'context/0': 'Yes.'},
#  {'response': "Couldn't have this conversation down at the truck huh?",
#   'context': 'Right. Except that I do want to get married.',
#   'context/0': "No but... You don't want to get married either right?"},
#  {'response': 'Now youre thinking you gotta sleep with him.',
#   'context': 'Well its justits one of those situations that I just hate. Yknow? A massage client gave me three tickets to the Helmet-Pelts exhibit at the Morgan Chase museum.',
#   'context/0': 'Whats the matter?'},
#  {'response': 'Ah!',
#   'context': 'Joey-',
#   'context/0': 'See what happens when you break the code?'},
#  {'response': 'No-no, not for like another two weeks.',
#   'context': 'Oh-oh, oh, oh-oh!',
#   'context/0': 'Okay, the last thing'},
#  {'response': 'Dont worry man, I get to bring a guest. Well show him.',
#   'context': 'Noo.',
#   'context/0': 'Hey! Hey, did you get your invitation to Rosss wedding?'},
#  {'response': 'Yeah, so.',
#   'context': 'The spoon. You licked and-and you put. You licked and you put.',
#   'context/0': 'What?'},
#  {'response': 'What are you talking about? Lots of things rhyme with Rachel. Bagel. Mail. Jail. Bail. Able. May-pole.',
#   'context': 'I know but its so hard! Nothing rhymes with your stupid name!',
#   'context/0': 'But yknow umm, Rachel doesnt rhyme with draddle.'},
#  {'response': 'Guest.', 'context': 'Fancy.', 'context/0': 'Everyday use.'},
#  {'response': 'What is that?',
#   'context': 'Ohhh, man!!',
#   'context/0': 'Not if I get there first.'},
#  {'response': 'Yeah! Look!',
#   'context': 'Really?',
#   'context/0': 'Rach! Hey! Its fine! Youre at Joeys!'},
#  {'response': "Shh, OK, here I come, here I come. See I'm comin' to fix the copier, I can't get to the copier, I'm thinkin' what do I do, what do I doso I just watch 'em have sex. And then I say, wait, here's my line,  you know that's bad for the paper tray.",
#   'context': 'Yeah, I guess it is. And so Im gonna get on this spaceship,  So you tell your great-great-granddaughter to look me up, because Adrienne babyIm gonna want to meet her.',
#   'context/0': 'So this is it? Victor?'},
#  {'response': 'Hey! Uh, this is just to give you an idea. Okay well, we can put screens here, , which until the baby comes we can use as walkie-talkies. Huh?',
#   'context': 'What is this?',
#   'context/0': 'Sounds about right.'},
#  {'response': 'Boy I tell ya, that judging stuff took a lot out of me.',
#   'context': 'You guys are the best!',
#   'context/0': 'Well yknow what? I hope Monica forgives you after you throw her, her vegetarian, voodoo, goddess circley shower!'},
#  {'response': "Whoa-whoa dad? There's a dad in the commercial?",
#   'context': 'Weirder than watching his two moms make out?',
#   'context/0': 'Yeah.'},
#  {'response': 'Oh, let me get this.  These are for you.',
#   'context': '4.50 please.',
#   'context/0': 'Hm-mmm.'},
#  {'response': 'Angela? Joey Tribiani. Listen, what are ya doing tonight. I know your seeing that guy I was thinking maybe you could bring him.....Hello? Hello?  picks up a statue of an Indian and walks into',
#   'context': "Yeah, what are they gonna say you didn't love me anymore. Come on.",
#   'context/0': 'What?!'},
#  {'response': "Hey. Y'know with that goatee you kinda look like Satan.",
#   'context': 'Hey.',
#   'context/0': 'Oh my.'},
#  {'response': 'London baby!',
#   'context': 'Yeah, cheerie-o!',
#   'context/0': 'Woo-hoo!!'},
#  {'response': 'It is???',
#   'context': 'Its spreading already.',
#   'context/0': 'Yeah, but, hey look, dont go through her stuff. She gets really mad.'},
#  {'response': 'I got this pair marked excess, I gotta tell ya, there was no room for excess anything in there.',
#   'context': 'Wh-what?!',
#   'context/0': "Boy, that guy's underwear sucks!"},
#  {'response': "Yeah, you'd think I'd give up being a minister and start paying to ride the subway? Huhuh...",
#   'context': 'Really?',
#   'context/0': "Oh hey, don't worry. I'm still ordained from your wedding."},
#  {'response': 'Aaaaagggghhhhh.',
#   'context': "Can't you see what's going on here, this man is dying.",
#   'context/0': 'About 20 minutes. CLOSING CREDITS'},
#  {'response': "That's right! I'm taking the essence.",
#   'context': 'The cushions are the essence of the chair!',
#   'context/0': "You said I had to give you the chair, you didn't say anything about the cushions."},
#  {'response': 'But it really',
#   'context': 'Youve sung Happy Birthday to 20 different women today!',
#   'context/0': 'What? No-no its her birthday!'},
#  {'response': "Whoa! For a rich guy he's got, that's a pretty small TV.",
#   'context': 'Yes, and the dimmer switch.',
#   'context/0': 'Okay, this is the den. All right, check this out. Lights!  Oh, see you just need to find the right command.'},
#  {'response': 'Why not?',
#   'context': 'No, I dont want to tell you.',
#   'context/0': 'Yeah, like a moth to a flame, Im telling ya. Okay all right, so now you go.'},
#  {'response': "Uhm... ok... uhm... Well, yeah... You have got some nerve, coming back here. I can't believe you never called me.",
#   'context': 'I can explain... Joey...',
#   'context/0': 'Are you friends with him?'},
#  {'response': 'Alright, alright, hey yknow fair is fair,',
#   'context': 'No, no. Shes fair game if you ask me, sorry buddy!',
#   'context/0': 'Well, I was hoping after tonight that maybe I could you know'},
#  {'response': 'I dont know. Ooh, I bet its Richard.',
#   'context': 'I dont know! What could she possibly be hiding in here that I cant see?!',
#   'context/0': 'Why not?'},
#  {'response': 'Please, just-just, just go and talk to Rachel.',
#   'context': 'Maybe its something you ate?',
#   'context/0': 'Im telling you. Im telling you. Thats what it is. No wonder she was looking at me all funny during the wedding. She didnt say anything to you?'},
#  {'response': "Well, she and I said from the beginning that we weren't gonna do anything unless you were okay with it. And clearly..",
#   'context': 'What do you mean?',
#   'context/0': "No, no, no. You actually did that when you were dancing to the Chicago-soundtrack. Look, Ross, about, about Rachel and I. Listen, you don't have to worry about that, okay? Because nothing is gonna happen."},
#  {'response': 'Yeah. Maybe Michael Jordon will dive for the ball and break my jaw with his knee.',
#   'context': 'Courtside? Oh my God.',
#   'context/0': 'No, no, no. When you get home tomorrow night, you and I are going to be at the Wizzards-Knicks game . . . courtside!'},
#  {'response': 'Yes!! Ha-ha!! All right! Hey! How cool would it be if you could watch like a real life-sized version of this? Huh? I mean how crazy would that be?',
#   'context': 'Oh right, your allergies.',
#   'context/0': 'Wh?! What about my allergies?!'},
#  {'response': 'So I ah, talked to Lauren, kinda told her how things were with us. Did you ah, did you talk to Marshall?',
#   'context': 'Hi.',
#   'context/0': 'Hey.'},
#  {'response': 'Yeah, you did some real good thinkin in there.',
#   'context': 'Yeah?',
#   'context/0': 'Yeah, were gonna be fine! Get out!'},
#  {'response': "She's this really boring woman. She's a teacher!",
#   'context': 'Oh, yeah.',
#   'context/0': 'Okay, okay. Wait till you hear who I got for Ross.'},
#  {'response': 'Oh-oh!',
#   'context': 'Why, just a tiny little...',
#   'context/0': 'Stop staring at me!'},
#  {'response': "I can't believe it's Christmas already. Ya know, I mean, one day your eatin' turkey, the next thing ya know, your lords are a-leapin' and you geese are a-layin'.",
#   'context': "Yeah, but not very well, unless 14-across, 'Gershwin musical' actually is bitemebitemebitemebiteme.",
#   'context/0': 'Oh look, and he did my crossword puzzle.'},
#  {'response': 'Sometimes I get in here just to get away from it! Hey, a nickel!!',
#   'context': 'Okay.  See?! I told ya!',
#   'context/0': 'All right, you have yourself a deal.'},
#  {'response': 'Yeah.',
#   'context': 'Come on! We will be there for you the whole time! Just remember gal pal Rachel Green.  Seriously, proud of you.',
#   'context/0': 'Just then or-or all the time, cause we-we have jobs yknow.'},
#  {'response': 'Yeah, and you know what? We could do a lot worse.',
#   'context': "Well, looks like it's just the two of us tonight, huh old buddy?",
#   'context/0': 'Ooh... Not so good.'},
#  {'response': 'Well, I was thinking about that and I, I think the best way would be, to not.',
#   'context': 'What?  So what are you going to do? I mean how, how are you going to tell Chandler?',
#   'context/0': 'You guys, Joey just saw Janice kissing her ex-husband.'},
#  {'response': 'Great.  You got anything thats not Ralph Lauren?',
#   'context': 'Yeah, sure. Ummhere.',
#   'context/0': 'Uhh, well Ive got an audition down the street and I spilled sauce all over the front of my shirt.  You got an extra one?'},
#  {'response': "I can't tell you what I know.",
#   'context': "Oh no, I can't tell you until you tell me what you know.",
#   'context/0': "What's the thing you know?"},
#  {'response': 'Yes! Yes!! And every time you look at it, I want you to remember that you are a good person. Okay, youve had the chance to cheat, and with me, but you didnt. And thats what this ring stands for.',
#   'context': 'No! No-no-no',
#   'context/0': 'Sure! As long as they dont find out you can keep whatever you want! And I want you to have it.'},
#  {'response': "Whoo, whoo. Wow, it's uhm... kinda weird that I'm sitting next to Charlie after we broke up.",
#   'context': "What d'ya know... It's a treat for the eyes and the ears.",
#   'context/0': 'And listen to this...'},
#  {'response': 'She said yes.',
#   'context': 'Well, what did she say?',
#   'context/0': 'I know! I know its awful.'}]

# %%
lines_selected_list.append(['Oh! Joey uh, were you in our room last night?', 'No.  I was told the name of the movie would not appear on the bill!', 'FRS'])
lines_selected_list.append(['Hey.', 'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?', 'FRS'])
lines_selected_list.append(['Joey... are you sure? I mean, I know how much you love him!', "Rachel... let's be clear on this, ok? I do not love Hugsy. I like him a normal amount...", 'FRS'])
lines_selected_list.append(['Ok, ten.', 'Okay, Monica picks ten, I call nine! Anyone else?', 'FRS'])
lines_selected_list.append(["Joey, Ross is gonna be here any second, would you mind watching Ben for me while I use the ladies' room?", 'Oh yeah, no problem.', 'FRS'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP'],
#  ['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'],
#  ["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   "It'll be a rich, full day.",
#   'FTM'],
#  ["I'm too scared.",
#   'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'FTM'],
#  ['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'],
#  ['Fry, thank God we found you.',
#   'Leela? What are you guys doing here in the year 4000?',
#   'FTM'],
#  ['I will not fight you.',
#   'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ["The Emperor's coming here?",
#   'That is correct, Commander. And heis most displeased with your',
#   'SW'],
#  ['Shall I hold them?', 'No. Leave them to me. I will deal', 'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ['Oh! Joey uh, were you in our room last night?',
#   'No.  I was told the name of the movie would not appear on the bill!',
#   'FRS'],
#  ['Hey.',
#   'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?',
#   'FRS'],
#  ['Joey... are you sure? I mean, I know how much you love him!',
#   "Rachel... let's be clear on this, ok? I do not love Hugsy. I like him a normal amount...",
#   'FRS'],
#  ['Ok, ten.', 'Okay, Monica picks ten, I call nine! Anyone else?', 'FRS'],
#  ["Joey, Ross is gonna be here any second, would you mind watching Ben for me while I use the ladies' room?",
#   'Oh yeah, no problem.',
#   'FRS']]

# %% [markdown]
# ## Standard data

# %%
lines_selected_list.append(['What are you doing for a living?', 'I am a lawyer.', 'STD'])
lines_selected_list.append(['How are you doing?', 'Good.', 'STD'])
lines_selected_list.append(['Where are you going to?', 'I am going out.', 'STD'])
lines_selected_list.append(['What are you wearing?', 'A T-shirt.', 'STD'])
lines_selected_list.append(['What do you want to do tonight?', 'Watching tv.', 'STD'])
lines_selected_list
# Out:
# [['Barney, this is about the building.',
#   'Come on. This is so about the girl.',
#   'HIMYM'],
#  ["All right. I'll be right there. Stay where you are.", 'Ted, Ted.', 'HIMYM'],
#  ["I think there's a pretty girl smiling at me there.",
#   'Hey, this is a chair, but go ahead and drag it.',
#   'HIMYM'],
#  ['I love you, man.', 'Me too, buddy.', 'HIMYM'],
#  ["Not even if she's hot?", "Not even if her mom's hot.", 'HIMYM'],
#  ['Soft kitty, warm kitty Little ball of fur',
#   'Happy kitty, slippy kitty Pur pur pur',
#   'TBBT'],
#  ['Penny.', 'Thats just wrong.', 'TBBT'],
#  ['Oh. Sheldon, thank you. Thats so romantic. But what about Rajesh? He was okay with you choosing the name?',
#   'Well, it took a little negotiating, but I wore him down. Uh, we get the asteroid, and if you and I have children, they all have to be named Rajesh.',
#   'TBBT'],
#  ['I didnt break it. I, I guess Stuart sold it to me like this.',
#   'Yes. Yes, he did, that is a perfectly satisfying and plausible explanation. Yeah, lets all be mad at Stuart.',
#   'TBBT'],
#  ['Be careful.',
#   'If I were not being careful, your telling me to be careful would not make me careful.',
#   'TBBT'],
#  ['But why would anyone go near that dog?',
#   'The day I was at Gringotts, Hagrid took something out of one of the vaults.',
#   'HP'],
#  ['Expecto Patronum!', 'Expecto Patronum!', 'HP'],
#  ['Ron Weasley.', "I'm Harry. Harry Potter.", 'HP'],
#  ['I spoke a different language?', "But I didn't realize...", 'HP'],
#  ['Harry?', 'Professor.', 'HP'],
#  ['OK. First Bender, then Flexo, then Fry.', "Wait, let's go by rank.", 'FTM'],
#  ["Just relax, Bender. Tomorrow we'll pry you down, have a nice breakfast and then go hunt down and slaughter that ancient evil.",
#   "It'll be a rich, full day.",
#   'FTM'],
#  ["I'm too scared.",
#   'Leela, your scaredness is being transmitted straight to Bender. If you care about Nibbler, stop caring about him!',
#   'FTM'],
#  ['Dr. Zoidberg? Are you OK?', "He's dead.", 'FTM'],
#  ['Fry, thank God we found you.',
#   'Leela? What are you guys doing here in the year 4000?',
#   'FTM'],
#  ['I will not fight you.',
#   'Give yourself to the dark side. It is the only way you can save your friends. Yes, your',
#   'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ["The Emperor's coming here?",
#   'That is correct, Commander. And heis most displeased with your',
#   'SW'],
#  ['Shall I hold them?', 'No. Leave them to me. I will deal', 'SW'],
#  ['Lord Vader, what about Leia and theWookiee?',
#   'They must never again leave thiscity.',
#   'SW'],
#  ['Oh! Joey uh, were you in our room last night?',
#   'No.  I was told the name of the movie would not appear on the bill!',
#   'FRS'],
#  ['Hey.',
#   'Hey-hey-hey! So, how did it go with Dana? Any reason I should leave a block of time open say Thursday?',
#   'FRS'],
#  ['Joey... are you sure? I mean, I know how much you love him!',
#   "Rachel... let's be clear on this, ok? I do not love Hugsy. I like him a normal amount...",
#   'FRS'],
#  ['Ok, ten.', 'Okay, Monica picks ten, I call nine! Anyone else?', 'FRS'],
#  ["Joey, Ross is gonna be here any second, would you mind watching Ben for me while I use the ladies' room?",
#   'Oh yeah, no problem.',
#   'FRS'],
#  ['What are you doing for a living?', 'I am a lawyer.', 'STD'],
#  ['How are you doing?', 'Good.', 'STD'],
#  ['Where are you going to?', 'I am going out.', 'STD'],
#  ['What are you wearing?', 'A T-shirt.', 'STD'],
#  ['What do you want to do tonight?', 'Watching tv.', 'STD']]

# %% [markdown]
# # Save the csv

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=lines_selected_list, columns=['context', 'label', 'name_serie'])
df
# Out:
#                                               context  \
# 0                 Barney, this is about the building.
# 1   All right. I'll be right there. Stay where you...
# 2   I think there's a pretty girl smiling at me th...
# 3                                    I love you, man.
# 4                              Not even if she's hot?
# 5           Soft kitty, warm kitty Little ball of fur
# 6                                              Penny.
# 7   Oh. Sheldon, thank you. Thats so romantic. But...
# 8   I didnt break it. I, I guess Stuart sold it to...
# 9                                         Be careful.
# 10             But why would anyone go near that dog?
# 11                                  Expecto Patronum!
# 12                                       Ron Weasley.
# 13                      I spoke a different language?
# 14                                             Harry?
# 15            OK. First Bender, then Flexo, then Fry.
# 16  Just relax, Bender. Tomorrow we'll pry you dow...
# 17                                    I'm too scared.
# 18                          Dr. Zoidberg? Are you OK?
# 19                       Fry, thank God we found you.
# 20                              I will not fight you.
# 21        Lord Vader, what about Leia and theWookiee?
# 22                         The Emperor's coming here?
# 23                                 Shall I hold them?
# 24        Lord Vader, what about Leia and theWookiee?
# 25      Oh! Joey uh, were you in our room last night?
# 26                                               Hey.
# 27  Joey... are you sure? I mean, I know how much ...
# 28                                           Ok, ten.
# 29  Joey, Ross is gonna be here any second, would ...
# 30                   What are you doing for a living?
# 31                                 How are you doing?
# 32                            Where are you going to?
# 33                              What are you wearing?
# 34                    What do you want to do tonight?
#
#                                                 label name_serie
# 0                 Come on. This is so about the girl.      HIMYM
# 1                                           Ted, Ted.      HIMYM
# 2     Hey, this is a chair, but go ahead and drag it.      HIMYM
# 3                                      Me too, buddy.      HIMYM
# 4                          Not even if her mom's hot.      HIMYM
# 5               Happy kitty, slippy kitty Pur pur pur       TBBT
# 6                                   Thats just wrong.       TBBT
# 7   Well, it took a little negotiating, but I wore...       TBBT
# 8   Yes. Yes, he did, that is a perfectly satisfyi...       TBBT
# 9   If I were not being careful, your telling me t...       TBBT
# 10  The day I was at Gringotts, Hagrid took someth...         HP
# 11                                  Expecto Patronum!         HP
# 12                           I'm Harry. Harry Potter.         HP
# 13                            But I didn't realize...         HP
# 14                                         Professor.         HP
# 15                            Wait, let's go by rank.        FTM
# 16                         It'll be a rich, full day.        FTM
# 17  Leela, your scaredness is being transmitted st...        FTM
# 18                                         He's dead.        FTM
# 19  Leela? What are you guys doing here in the yea...        FTM
# 20  Give yourself to the dark side. It is the only...         SW
# 21              They must never again leave thiscity.         SW
# 22  That is correct, Commander. And heis most disp...         SW
# 23                  No. Leave them to me. I will deal         SW
# 24              They must never again leave thiscity.         SW
# 25  No.  I was told the name of the movie would no...        FRS
# 26  Hey-hey-hey! So, how did it go with Dana? Any ...        FRS
# 27  Rachel... let's be clear on this, ok? I do not...        FRS
# 28  Okay, Monica picks ten, I call nine! Anyone else?        FRS
# 29                               Oh yeah, no problem.        FRS
# 30                                     I am a lawyer.        STD
# 31                                              Good.        STD
# 32                                    I am going out.        STD
# 33                                         A T-shirt.        STD
# 34                                       Watching tv.        STD

# %%
out_file = os.path.join(base_folder, 'Data', 'common_dataset.csv')
df.to_csv(out_file, index=False)
